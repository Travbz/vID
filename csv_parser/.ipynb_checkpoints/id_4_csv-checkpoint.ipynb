# %% [markdown]
# ### This script converts a column of names into unique IDs and populates a new column with those values.
#
# ### You will need to change a few values to run this code on your unique file name and colume name

# %%
import pandas as pd

# %%
# This code reads the file. Change to ('path/your-file-name.filetype')
try:
    df = pd.read_excel('company.xlsx')
    df.to_csv('company.csv', mode = 'w', index=False)
except:
    df = pd.read_csv('company.csv')
df
# Out:
#        Rank            Metals Industry  Number Of Employees Change In \n Rank  \
# 0       1.0                    Walmart            2200000.0                 -
# 1       2.0                 Amazon.com             798000.0               3.0
# 2       3.0                Exxon Mobil              74900.0              -1.0
# 3       4.0                      Apple             137000.0              -1.0
# 4       5.0                 Cvs Health             290000.0               3.0
# ..      ...                        ...                  ...               ...
# 995   996.0           Mr. Cooper Group               9100.0                 -
# 996   997.0              Herc Holdings               5100.0              -4.0
# 997   998.0      Healthpeak Properties                204.0                 -
# 998   999.0                   Spx Flow               5000.0             -37.0
# 999  1000.0  Liberty Oilfield Services               2571.0             -58.0
#
#                         Industry  \
# 0                 Retail Company
# 1             E-commerce Company
# 2                    Corporation
# 3             Technology Company
# 4             Healthcare Company
# ..                           ...
# 995          Home Loan Servicers
# 996             Equipment Rental
# 997       Real Estate Investment
# 998  Pumps And Pumping Equipment
# 999                  Oil And Gas
#
#                                    Company Description  \
# 0    Walmart Inc. Is An American Multinational Reta...
# 1    Amazon.com, Inc. Is An American Multinational ...
# 2    Exxon Mobil Corp. engages in the exploration, ...
# 3    Apple Inc. Is An American Multinational Techno...
# 4    Cvs Health Is An American Healthcare Company T...
# ..                                                 ...
# 995  Mr. Cooper Group Inc. Provides Quality Servici...
# 996  They Are One Of The Largest Equipment Rental C...
# 997  Healthpeak Properties, Inc. Is A Real Estate I...
# 998  It Is A World Leader In Sustainable Solutions ...
# 999  Liberty Is An Innovative Service Company Provi...
#
#      Revenues\n ($millions) Revenue \n Change Profits\n ($millions)  \
# 0                  523964.0             0.019               14881.0
# 1                  280522.0             0.205               11588.0
# 2                  264938.0            -0.087               14340.0
# 3                  260174.0             -0.02               55256.0
# 4                  256776.0              0.32                6634.0
# ..                      ...               ...                   ...
# 995                  2007.0                 -                 274.0
# 996                  1999.0             0.011                  47.5
# 997                  1997.0             0.082                  45.5
# 998                  1996.0            -0.045                 -95.1
# 999                  1990.0            -0.076                  39.0
#
#     Profit \n Change  Assets\n ($millions) Market Value \n As of 3/31/20 ($m)
# 0              1.231              236495.0                           321803.0
# 1               0.15              225248.0                           970680.0
# 2             -0.312              362597.0                           160696.0
# 3             -0.072              338516.0                          1112641.0
# 4                  -              222449.0                            77376.0
# ..               ...                   ...                                ...
# 995                -               18305.0                              674.0
# 996           -0.313                3817.0                              591.0
# 997           -0.957               14033.0                            12059.0
# 998           -3.161                2437.0                             1212.0
# 999           -0.692                1283.0                              303.0
#
# [1000 rows x 12 columns]

# %%
import pandas as pd

def generate_unique_id(company_name: str) -> str:
    """
    :params company_name 
    :return a unique 12 character ID based on the named from the input
    
    """
    unique_key = ''
    company_name = company_name.upper()
    
    for char in (("THE ", ""), (" THE ", " "), (" AND ", " "), (" OF ", " ")):
        company_name = company_name.replace(*char)
        
    new_name_list = []
    name_list = company_name.split(' ')
    wordCount = len(name_list)
    
    for name in name_list:
        new_name_list.append(''.join(ch for ch in name if ch.isalnum()))
    
    if wordCount == 1:
            unique_key = new_name_list[0][0:8]
    else:
        for i in range(len(new_name_list)):
            if i == 0:
                unique_key += new_name_list[i][:4]
            else:
                unique_key += new_name_list[i][:2]

            if len(unique_key) > 7:
                break

    if len(unique_key) <= 8:
        unique_key += 'x' * (8 - len(unique_key))
    
    hash_number = str(hash(unique_key.upper()))[1:4]
        
    unique_key += hash_number
    
    return unique_key

# %%
keys_list = []
"""Change the name of (row[" <Your name column's name here>  "])) to match your columns name"""

for index, row in df.iterrows():       # change name here to your columns name
    keys_list.append(generate_unique_id(row["Metals Industry"]))
                                    # RIGHT HERE ^^^
df['unique_ID'] = keys_list

# %%
temp_cols=df.columns.tolist()
new_cols=temp_cols[-1:] + temp_cols[:-1]
df=df[new_cols]
df[500:520]
# Out:
#     Market Value \n As of 3/31/20 ($m)    unique_ID   Rank  \
# 500                             2943.0  KBRxxxxx060  501.0
# 501                             2185.0  SPROFAMA510  502.0
# 502                             4305.0  LPLFIHOx751  503.0
# 503                            22788.0  TROPRxxx142  504.0
# 504                            20615.0  YUMBRxxx393  505.0
# 505                            18171.0  CHIPMEGR669  506.0
# 506                             1465.0  PATTERSO287  507.0
# 507                             7721.0  RPMINxxx140  508.0
# 508                            53366.0  EQUINIXx356  509.0
# 509                             1466.0  NAVIENTx393  510.0
# 510                             1456.0  CHEMOURS281  511.0
# 511                             5114.0  ONSExxxx349  512.0
# 512                            17190.0  TRANGRxx208  513.0
# 513                             7793.0  HOSTHORE625  514.0
# 514                             2015.0  SELEMEHO256  515.0
# 515                              381.0  PARPAHOx610  516.0
# 516                             4651.0  SONOPRxx893  517.0
# 517                            33086.0  ROPETExx666  518.0
# 518                             2893.0  HARLEYDA841  519.0
# 519                             3788.0  JEFFFIGR735  520.0
#
#                Metals Industry  Number Of Employees Change In \n Rank  \
# 500                        Kbr              28000.0              47.0
# 501     Sprouts Farmers Market              30000.0              25.0
# 502     Lpl Financial Holdings               4343.0              28.0
# 503              T. Rowe Price               7365.0              15.0
# 504                 Yum Brands              34000.0             -11.0
# 505     Chipotle Mexican Grill              83000.0              45.0
# 506                  Patterson               7800.0               3.0
# 507          Rpm International              14957.0              14.0
# 508                    Equinix               8378.0              30.0
# 509                    Navient               5800.0             -13.0
# 510                   Chemours               7000.0             -57.0
# 511           On Semiconductor              34800.0             -27.0
# 512            Transdigm Group              18300.0             137.0
# 513      Host Hotels & Resorts                175.0             -12.0
# 514    Select Medical Holdings              42800.0              23.0
# 515       Par Pacific Holdings               1408.0             181.0
# 516            Sonoco Products              23000.0               1.0
# 517         Roper Technologies              16460.0              12.0
# 518            Harley-davidson               5600.0             -27.0
# 519  Jefferies Financial Group               4800.0            -148.0
#
#                                 Industry  \
# 500                          Engineering
# 501                          Supermarket
# 502                        Broker-dealer
# 503                Investment Management
# 504                    Fast Food Company
# 505                   Restaurant Company
# 506                     Dental Equipment
# 507                            Chemicals
# 508                             Internet
# 509                   Financial Services
# 510                    Chemicals Company
# 511  Semiconductor Manufacturing Company
# 512                 Aerospace Components
# 513                          Real Estate
# 514                              Medical
# 515         Petroleum Refineries Company
# 516               Packaging And Labeling
# 517                         Conglomerate
# 518             Motorcycle Manufacturers
# 519           Investment Banking Company
#
#                                    Company Description  \
# 500  Kbr, Inc. Is An American Engineering, Procurem...
# 501  Sprouts Farmers Market, Inc., Is A Supermarket...
# 502  Lpl Financial Holdings Is Considered The Large...
# 503  T. Rowe Price Group, Inc. Is A Global Investme...
# 504  Yum! Brands, Inc. Is An American Fast Food Cor...
# 505  Chipotle Mexican Grill, Inc. Is An American Ch...
# 506  Patterson Companies Inc Is A Medical Supplies ...
# 507  Rpm International Inc. Owns Subsidiaries That ...
# 508  Equinix Is An Internet Company That Provides D...
# 509  Navient Corporation's Focus Is In Education Lo...
# 510  The Chemours Company Is Using The Power Of Che...
# 511  On Semiconductor Is A Leading Supplier And Dri...
# 512  Transdigm Group Inc. Is A Leading Global Produ...
# 513  The Trust Provides Equity Holdings, Asset Mana...
# 514  Select Medical Holdings Corporation Is An Oper...
# 515  Par Pacific Holdings Is A Houston-based Oil An...
# 516  Sonoco Products Company Is A United States-bas...
# 517  Roper Technologies, Inc. Is An American Divers...
# 518  Harley-davidson Is Pulling Out Of India, The W...
# 519  The Firm Provides Clients With Capital Markets...
#
#      Revenues\n ($millions) Revenue \n Change Profits\n ($millions)  \
# 500                  5639.0             0.148                 202.0
# 501                  5635.0             0.082                 149.6
# 502                  5625.0             0.084                 559.9
# 503                  5618.0             0.046                2131.3
# 504                  5597.0            -0.016                1294.0
# 505                  5586.0             0.148                 350.2
# 506                  5575.0              0.02                  83.6
# 507                  5565.0             0.046                 266.6
# 508                  5562.0             0.097                 507.5
# 509                  5529.0            -0.014                 597.0
# 510                  5526.0            -0.168                 -52.0
# 511                  5518.0            -0.061                 211.7
# 512                  5517.0             0.443                 889.8
# 513                  5469.0             -0.01                 920.0
# 514                  5454.0             0.073                 148.4
# 515                  5402.0             0.584                  40.8
# 516                  5374.0            -0.003                 291.8
# 517                  5367.0             0.034                1767.9
# 518                  5362.0            -0.062                 423.6
# 519                  5359.0            -0.343                 964.7
#
#     Profit \n Change  Assets\n ($millions)
# 500           -0.281                5364.0
# 501           -0.056                2723.0
# 502            0.274                5880.0
# 503             0.16                9330.0
# 504           -0.161                5231.0
# 505            0.983                5105.0
# 506           -0.584                3269.0
# 507           -0.211                5441.0
# 508            0.389               23966.0
# 509            0.511               94903.0
# 510           -1.052                7258.0
# 511           -0.663                8426.0
# 512            -0.07               16255.0
# 513           -0.154               12305.0
# 514            0.077                7340.0
# 515            0.035                2701.0
# 516           -0.069                5126.0
# 517            0.872               18109.0
# 518           -0.203               10528.0
# 519            -0.06               49460.0

# %%
# check for duplicates, none if true
print(len(keys_list) == len(list(set(keys_list))))
# Out:
# False

# %%
"""Change the name of ['Metals Industry'] to match your columns name"""
keys = keys_list

# your col name below vvvvv
values = df['Metals Industry'].to_list()
# change name above ^^^^^

alphaZip= zip(keys,values)
myDict = dict(alphaZip)
myDict
# Out:
# {'WALMARTx303': 'Walmart',
#  'AMAZONCO512': 'Amazon.com',
#  'EXXOMOxx713': 'Exxon Mobil',
#  'APPLExxx170': 'Apple',
#  'CVSHExxx849': 'Cvs Health',
#  'BERKHAxx122': 'Berkshire Hathaway',
#  'UNITGRxx597': 'Unitedhealth Group',
#  'MCKESSON935': 'Mckesson',
#  'ATTxxxxx581': 'At&t',
#  'AMERISOU460': 'Amerisourcebergen',
#  'ALPHABET308': 'Alphabet',
#  'FORDMOxx243': 'Ford Motor',
#  'CIGNAxxx207': 'Cigna',
#  'COSTWHxx332': 'Costco Wholesale',
#  'CHEVRONx429': 'Chevron',
#  'CARDHExx236': 'Cardinal Health',
#  'JPMOCHxx348': 'Jpmorgan Chase',
#  'GENEMOxx822': 'General Motors',
#  'WALGBOAL391': 'Walgreens Boots Alliance',
#  'VERICOxx772': 'Verizon Communications',
#  'MICROSOF320': 'Microsoft',
#  'MARAPExx208': 'Marathon Petroleum',
#  'KROGERxx123': 'Kroger',
#  'FANNMAxx997': 'Fannie Mae',
#  'BANKAMxx755': 'Bank Of America',
#  'HOMEDExx820': 'Home Depot',
#  'PHIL66xx570': 'Phillips 66',
#  'COMCASTx616': 'Comcast',
#  'ANTHEMxx915': 'Anthem',
#  'WELLFAxx822': 'Wells Fargo',
#  'CITIGROU756': 'Citigroup',
#  'VALEENxx182': 'Valero Energy',
#  'GENEELxx860': 'General Electric',
#  'DELLTExx526': 'Dell Technologies',
#  'JOHNJOxx483': 'Johnson & Johnson',
#  'STATFAIN440': 'State Farm Insurance',
#  'TARGETxx501': 'Target',
#  'IBMxxxxx667': 'Ibm',
#  'RAYTTExx698': 'Raytheon Technologies',
#  'BOEINGxx423': 'Boeing',
#  'FREDMAxx529': 'Freddie Mac',
#  'CENTENEx566': 'Centene',
#  'UNITPASE549': 'United Parcel Service',
#  'LOWESxxx475': "Lowe's",
#  'INTELxxx744': 'Intel',
#  'FACEBOOK592': 'Facebook',
#  'FEDEXxxx178': 'Fedex',
#  'METLIFEx579': 'Metlife',
#  'WALTDIxx677': 'Walt Disney',
#  'PROCGAxx880': 'Procter & Gamble',
#  'PEPSICOx323': 'Pepsico',
#  'HUMANAxx433': 'Humana',
#  'PRUDFIxx123': 'Prudential Financial',
#  'ARCHDAMI263': 'Archer Daniels Midland',
#  'ALBERTSO973': 'Albertsons',
#  'SYSCOxxx952': 'Sysco',
#  'LOCKMAxx495': 'Lockheed Martin',
#  'HPxxxxxx705': 'Hp',
#  'ENERTRxx715': 'Energy Transfer',
#  'GOLDSAGR332': 'Goldman Sachs Group',
#  'MORGSTxx049': 'Morgan Stanley',
#  'CATERPIL450': 'Caterpillar',
#  'CISCSYxx913': 'Cisco Systems',
#  'PFIZERxx126': 'Pfizer',
#  'HCAHExxx659': 'Hca Healthcare',
#  'AIGxxxxx414': 'Aig',
#  'AMEREXxx597': 'American Express',
#  'DELTAILI459': 'Delta Air Lines',
#  'MERCKxxx169': 'Merck',
#  'AMERAIGR664': 'American Airlines Group',
#  'CHARCOxx436': 'Charter Communications',
#  'ALLSTATE843': 'Allstate',
#  'NEWYOLIIN233': 'New York Life Insurance',
#  'NATIONWI336': 'Nationwide',
#  'BESTBUxx471': 'Best Buy',
#  'UNITAIHO754': 'United Airlines Holdings',
#  'LIBEMUIN408': 'Liberty Mutual Insurance Group',
#  'DOWxxxxx011': 'Dow',
#  'TYSOFOxx782': 'Tyson Foods',
#  'TJXxxxxx167': 'Tjx',
#  'TIAAxxxx729': 'Tiaa',
#  'ORACLExx197': 'Oracle',
#  'GENEDYxx426': 'General Dynamics',
#  'DEERExxx515': 'Deere',
#  'NIKExxxx375': 'Nike',
#  'PROGRESS114': 'Progressive',
#  'PUBLSUMA309': 'Publix Super Markets',
#  'COCACOLA549': 'Coca-cola',
#  'MASSMULI040': 'Massachusetts Mutual Life Insurance',
#  'TECHDAxx317': 'Tech Data',
#  'WORLFUSE522': 'World Fuel Services',
#  'HONEINxx682': 'Honeywell International',
#  'CONOCOPH226': 'Conocophillips',
#  'USAAxxxx351': 'Usaa',
#  'EXELONxx977': 'Exelon',
#  'NORTGRxx417': 'Northrop Grumman',
#  'CAPIONFI163': 'Capital One Financial',
#  'PLAIGPHO087': 'Plains Gp Holdings',
#  'ABBVIExx505': 'Abbvie',
#  'STONGRxx987': 'Stonex Group',
#  'ENTEPRPA451': 'Enterprise Products Partners',
#  'NORTMUxx285': 'Northwestern Mutual',
#  '3Mxxxxxx406': '3m',
#  'ABBOLAxx077': 'Abbott Laboratories',
#  'CHSxxxxx279': 'Chs',
#  'TRAVELER325': 'Travelers',
#  'PHILMOIN564': 'Philip Morris International',
#  'RAYTHEON524': 'Raytheon',
#  'HEWLPAEN978': 'Hewlett Packard Enterprise',
#  'ARROELxx294': 'Arrow Electronics',
#  'VIACOMCB927': 'Viacomcbs',
#  'DOLLGExx714': 'Dollar General',
#  'USBAxxxx016': 'U.s. Bancorp',
#  'STARBUCK348': 'Starbucks',
#  'BRISSQxx703': 'Bristol-myers Squibb',
#  'USFOHOxx251': 'Us Foods Holding',
#  'MONDINxx738': 'Mondelez International',
#  'PACCARxx761': 'Paccar',
#  'THERFISC362': 'Thermo Fisher Scientific',
#  'MACYSxxx691': "Macy's",
#  'JABILxxx967': 'Jabil',
#  'KRAFHExx312': 'Kraft Heinz',
#  'DUKEENxx500': 'Duke Energy',
#  'TESLAxxx280': 'Tesla',
#  'PBFENxxx436': 'Pbf Energy',
#  'QUALCOMM726': 'Qualcomm',
#  'NGLENPAx430': 'Ngl Energy Partners',
#  'CBREGRxx197': 'Cbre Group',
#  'BAKEHUxx816': 'Baker Hughes',
#  'SYNNEXxx237': 'Synnex',
#  'DOLLTRxx075': 'Dollar Tree',
#  'CUMMINSx656': 'Cummins',
#  'UNITNAFO331': 'United Natural Foods',
#  'MICRTExx031': 'Microchip Technology',
#  'AMGENxxx511': 'Amgen',
#  'PENSAUGR534': 'Penske Automotive Group',
#  'VISAxxxx398': 'Visa',
#  'BROADCOM830': 'Broadcom',
#  'NUCORxxx241': 'Nucor',
#  'GILESCxx859': 'Gilead Sciences',
#  'SOUTAIxx198': 'Southwest Airlines',
#  'HALLIBUR855': 'Halliburton',
#  'CENTURYL051': 'Centurylink',
#  'INTEPAxx379': 'International Paper',
#  'ELILIxxx202': 'Eli Lilly',
#  'AFLACxxx545': 'Aflac',
#  'LENNARxx767': 'Lennar',
#  'OCCIPExx629': 'Occidental Petroleum',
#  'UNIOPAxx825': 'Union Pacific',
#  'RITEAIxx519': 'Rite Aid',
#  'PNCFISEGR221': 'Pnc Financial Services Group',
#  'DUPONTxx610': 'Dupont',
#  'SOUTHERN144': 'Southern',
#  'AUTONATI781': 'Autonation',
#  'DXCTExxx779': 'Dxc Technology',
#  'MCDONALD529': "Mcdonald's",
#  'MARRINxx361': 'Marriott International',
#  'MANPOWER822': 'Manpowergroup',
#  'BANKNEYO711': 'Bank Of New York Mellon',
#  'HARTFISE351': 'Hartford Financial Services Group',
#  'DANAHERx908': 'Danaher',
#  'WHIRLPOO850': 'Whirlpool',
#  'AECOMxxx203': 'Aecom',
#  'NETFLIXx617': 'Netflix',
#  'KOHLSxxx465': "Kohl's",
#  'LEARxxxx553': 'Lear',
#  'ALTRGRxx787': 'Altria Group',
#  'PERFFOGR760': '\nperformance Food Group',
#  'AVNETxxx905': 'Avnet',
#  'SYNCFIxx108': 'Synchrony Financial',
#  'GENUPAxx676': 'Genuine Parts',
#  'NEXTENxx607': 'Nextera Energy',
#  'CARMAXxx496': 'Carmax',
#  'TENEHExx603': 'Tenet Healthcare',
#  'KIMBERLY163': 'Kimberly-clark',
#  'EMERELxx515': 'Emerson Electric',
#  'WESTROCK399': 'Westrock',
#  'CDWxxxxx078': 'Cdw',
#  'JONELALA509': 'Jones Lang Lasalle',
#  'SHERWINW754': 'Sherwin-williams',
#  'FLUORxxx291': 'Fluor',
#  'PAYPHOxx614': 'Paypal Holdings',
#  'DRHOxxxx863': 'D.r. Horton',
#  'HOLLYFRO173': 'Hollyfrontier',
#  'TENNECOx365': 'Tenneco',
#  'EOGRExxx849': 'Eog Resources',
#  'BECTDIxx165': 'Becton Dickinson',
#  'LINCNAxx268': 'Lincoln National',
#  'PGExxxxx865': 'Pg&e',
#  'SALESFOR992': 'Salesforce.com',
#  'MASTERCA103': 'Mastercard',
#  'GENEMIxx055': 'General Mills',
#  'MOLIHExx042': 'Molina Healthcare',
#  'COGNTESO189': 'Cognizant Technology Solutions',
#  'MARSMCxx670': 'Marsh & Mclennan',
#  'XPOLOxxx512': 'Xpo Logistics',
#  'DOMIENxx913': 'Dominion Energy',
#  'WESTDIxx889': 'Western Digital',
#  'GAPxxxxx219': 'Gap',
#  'ARAMARKx096': 'Aramark',
#  'PRINFIxx368': 'Principal Financial',
#  'ROSSSTxx858': '\nross Stores',
#  'COLGATEP334': 'Colgate-palmolive',
#  'AMERELPO518': 'American Electric Power',
#  'NORDSTRO444': 'Nordstrom',
#  'JACOENGR523': 'Jacobs Engineering Group',
#  'WASTMAxx039': 'Waste Management',
#  'CHROWOxx855': 'C.h. Robinson Worldwide',
#  'PPGINxxx896': 'Ppg Industries',
#  'BOOKHOxx190': 'Booking Holdings',
#  'OMNIGRxx691': 'Omnicom Group',
#  'LOEWSxxx315': 'Loews',
#  'ECOLABxx457': 'Ecolab',
#  'STRYKERx605': 'Stryker',
#  'ESTELAxx735': 'Estee Lauder',
#  'GOODTIRU764': 'Goodyear Tire & Rubber',
#  'TRUIFIxx909': 'Truist Financial',
#  'APPLMAxx704': 'Applied Materials',
#  'BLACKROC381': 'Blackrock',
#  'STANBLDE237': 'Stanley Black & Decker',
#  'FREEPORT441': 'Freeport-mcmoran',
#  'TEXAINxx783': 'Texas Instruments',
#  'BIOGENxx963': 'Biogen',
#  'PARKERHA646': 'Parker-hannifin',
#  'REINGRAM335': 'Reinsurance Group Of America',
#  'HOWMAExx754': 'Howmet Aerospace',
#  'AUTODAPR326': 'Automatic Data Processing',
#  'UBERTExx778': 'Uber Technologies',
#  'ILLITOWO391': 'Illinois Tool Works',
#  'DAVITAxx623': 'Davita',
#  'DISCFISE981': 'Discover Financial Services',
#  'LANDOLxx408': "Land O'lakes",
#  'VFxxxxxx327': 'Vf',
#  'CORTEVAx248': 'Corteva',
#  'LASVESAx797': 'Las Vegas Sands',
#  'TEXTRONx431': 'Textron',
#  'KELLOGGx891': 'Kellogg',
#  'GUARLIIN133': 'Guardian Life Ins. Co. Of America',
#  'QURARExx218': 'Qurate Retail',
#  'COREHOxx672': 'Core-mark Holding',
#  'COMMHESY742': 'Community Health Systems',
#  'KINDMOxx629': 'Kinder Morgan',
#  'BJSWHCLx501': "Bj's Wholesale Club",
#  'STATSTxx012': 'State Street',
#  'AMERFIxx349': 'Ameriprise Financial',
#  'GLOBPAxx145': 'Global Payments',
#  'UNITSTST434': 'United States Steel',
#  'LBRxxxxx307': 'L Brands',
#  'MGMREINx615': 'Mgm Resorts International',
#  'L3HATExx449': 'L3harris Technologies',
#  'DISHNExx234': 'Dish Network',
#  'LITHMOxx704': 'Lithia Motors',
#  'DTEENxxx225': 'Dte Energy',
#  'AMERFAIN134': 'American Family Insurance Group',
#  'FARMINEX840': 'Farmers Insurance Exchange',
#  'CONSEDxx421': 'Consolidated Edison',
#  'LKQxxxxx600': 'Lkq',
#  'SEMPENxx919': 'Sempra Energy',
#  'EDISINxx491': 'Edison International',
#  'CENTENxx953': 'Centerpoint Energy',
#  'QUANSExx992': 'Quanta Services',
#  'MURPUSxx863': 'Murphy Usa',
#  'EXPEGRxx361': 'Expedia Group',
#  'GROU1AUx360': 'Group 1 Automotive',
#  'BEDBABEx542': 'Bed Bath & Beyond',
#  'UNUMGRxx329': 'Unum Group',
#  'CSXxxxxx778': 'Csx',
#  'AUTOZONE462': 'Autozone',
#  'PACILIxx800': 'Pacific Life',
#  'VISTENxx432': 'Vistra Energy',
#  'CHARSCxx700': 'Charles Schwab',
#  'CROWHOxx178': 'Crown Holdings',
#  'ALLYFIxx350': 'Ally Financial',
#  'LABOCOAM320': 'Laboratory Corp. Of America',
#  'LIVENAEN276': 'Live Nation Entertainment',
#  'XCELENxx874': 'Xcel Energy',
#  'CORNINGx447': 'Corning',
#  'WWGRxxxx448': 'W.w. Grainger',
#  'BALLxxxx642': 'Ball',
#  'FOXxxxxx667': 'Fox',
#  'UNIVHESE828': 'Universal Health Services',
#  'BAXTINxx816': 'Baxter International',
#  'NORFSOxx804': 'Norfolk Southern',
#  'NAVIINxx575': 'Navistar International',
#  'ADOBExxx789': 'Adobe',
#  'JCPExxxx386': 'J.c. Penney',
#  'DISCOVER052': 'Discovery',
#  'KEURDRPE300': 'Keurig Dr Pepper',
#  'LEIDHOxx623': 'Leidos Holdings',
#  'IQVIHOxx783': 'Iqvia Holdings',
#  'RELISTAL018': 'Reliance Steel & Aluminum',
#  'NVIDIAxx165': 'Nvidia',
#  'ENTERGYx588': 'Entergy',
#  'FIRSTENE102': 'Firstenergy',
#  'EBAYxxxx591': 'Ebay',
#  'BOSTSCxx611': 'Boston Scientific',
#  'OFFIDExx820': 'Office Depot',
#  'MOLSCOBE439': 'Molson Coors Beverage',
#  'STEEDYxx336': 'Steel Dynamics',
#  'MUTUOMIN879': 'Mutual Of Omaha Insurance',
#  'SONIAUxx742': 'Sonic Automotive',
#  'ALCOAxxx151': 'Alcoa',
#  'FIDENAIN454': 'Fidelity National Information Services',
#  'HENRSCxx664': 'Henry Schein',
#  'REPUSExx364': 'Republic Services',
#  'LIBEMExx775': 'Liberty Media',
#  'PETEKISO355': "Peter Kiewit Sons'",
#  'INTEGRxx704': 'Interpublic Group',
#  'PULTEGRO760': 'Pultegroup',
#  'AESxxxxx256': 'Aes',
#  'FISERVxx203': 'Fiserv',
#  'BORGWARN413': 'Borgwarner',
#  'ONEOKxxx910': 'Oneok',
#  'OREIAUxx730': "O'reilly Automotive",
#  'ASSURANT475': 'Assurant',
#  'NEWEBRxx337': 'Newell Brands',
#  'PUBLSEEN410': 'Public Service Enterprise Group',
#  'NEWSCOxx412': 'News Corp.',
#  'CALPINEx886': 'Calpine',
#  'AUTOINxx489': 'Auto-owners Insurance',
#  'MOHAINxx227': 'Mohawk Industries',
#  'PVHxxxxx401': 'Pvh',
#  'CAMPSOxx469': 'Campbell Soup',
#  'NRGENxxx823': 'Nrg Energy',
#  'FIFTTHBA555': 'Fifth Third Bancorp',
#  'HERTGLHO818': 'Hertz Global Holdings',
#  'ALTIUSxx704': 'Altice Usa',
#  'NEWMONTx226': 'Newmont',
#  'CHENENxx921': 'Cheniere Energy',
#  'ADVAAUPA751': 'Advance Auto Parts',
#  'LAMRExxx548': 'Lam Research',
#  'OWENMIxx824': 'Owens & Minor',
#  'EQUIHOxx065': 'Equitable Holdings',
#  'CONABRxx107': 'Conagra Brands',
#  'MARKELxx417': 'Markel',
#  'JONEFIED703': 'Jones Financial (edward Jones)',
#  'HORMFOxx319': 'Hormel Foods',
#  'HILTWOHO159': 'Hilton Worldwide Holdings',
#  'UNIVSOxx270': 'Univar Solutions',
#  'UNITRExx943': 'United Rentals',
#  'PIONNARE792': 'Pioneer Natural Resources',
#  'DELEUSHO768': 'Delek Us Holdings',
#  'EASTCHxx638': 'Eastman Chemical',
#  'EMCOGRxx488': 'Emcor Group',
#  'AVISBUGR540': 'Avis Budget Group',
#  'JBHUTRSE382': 'J.b. Hunt Transport Services',
#  'XEROHOxx403': 'Xerox Holdings',
#  'WAYFAIRx561': 'Wayfair',
#  'KKRxxxxx745': 'Kkr',
#  'AGCOxxxx647': 'Agco',
#  'ALLEGHAN532': 'Alleghany',
#  'ICAHENxx243': 'Icahn Enterprises',
#  'VOYAFIxx340': 'Voya Financial',
#  'RYDESYxx346': 'Ryder System',
#  'AIRPRCHx863': 'Air Products & Chemicals',
#  'MOSAICxx328': 'Mosaic',
#  'HUNTININ783': 'Huntington Ingalls Industries',
#  'BERRGLGR255': 'Berry Global Group',
#  'ANIXINxx589': 'Anixter International',
#  'ALASAIGR862': 'Alaska Air Group',
#  'YUMCHHOx707': 'Yum China Holdings',
#  'DICKSPGO904': "Dick's Sporting Goods",
#  'CAESENxx211': 'Caesars Entertainment',
#  'GENWFIxx681': 'Genworth Financial',
#  'TARGRExx835': 'Targa Resources',
#  'COTYxxxx345': 'Coty',
#  'DANAxxxx740': 'Dana',
#  'THRIFIFO775': 'Thrivent Financial For Lutherans',
#  'AUTOLIVx908': 'Autoliv',
#  'SPARTANN861': 'Spartannash',
#  'EVERENxx185': 'Eversource Energy',
#  'DARDRExx591': 'Darden Restaurants',
#  'CHESENxx581': 'Chesapeake Energy',
#  'NATIOIVA747': 'National Oilwell Varco',
#  'FIDENAFI706': 'Fidelity National Financial',
#  'ERIEINGR128': 'Erie Insurance Group',
#  'OSHKOSHx122': 'Oshkosh',
#  'CASEGEST167': "Casey's General Stores",
#  'WESCINxx914': 'Wesco International',
#  'TRACSUxx726': 'Tractor Supply',
#  'COMMHOxx794': 'Commscope Holding',
#  'HUNTSMAN945': 'Huntsman',
#  'AMERFIGR105': 'American Financial Group',
#  'MASCOxxx520': 'Masco',
#  'SANMINAx100': 'Sanmina',
#  'AMPHENOL484': 'Amphenol',
#  'WILLIAMS113': 'Williams-sonoma',
#  'WESTAIBR252': 'Westinghouse Air Brake',
#  'EXPEINWA675': 'Expeditors Intl. Of Washington',
#  'ANDERSON413': 'Andersons',
#  'WESTCHxx637': 'Westlake Chemical',
#  'CONSBRxx702': 'Constellation Brands',
#  'FRONCOxx428': 'Frontier Communications',
#  'JETBAIxx739': 'Jetblue Airways',
#  'CITIFIGR645': 'Citizens Financial Group',
#  'RAYMJAFI019': 'Raymond James Financial',
#  'FOOTLOxx602': 'Foot Locker',
#  'HERSHEYx394': 'Hershey',
#  'ZIMMBIHO159': 'Zimmer Biomet Holdings',
#  'CINCFIxx749': 'Cincinnati Financial',
#  'WESTSOFI107': 'Western & Southern Financial Group',
#  'WRBExxxx715': 'W.r. Berkley',
#  'MOTOSOxx309': 'Motorola Solutions',
#  'THORINxx368': 'Thor Industries',
#  'REGEPHxx787': 'Regeneron Pharmaceuticals',
#  'SPIRAEHO704': 'Spirit Aerosystems Holdings',
#  'JMSMxxxx675': 'J.m. Smucker',
#  'PPLxxxxx432': 'Ppl',
#  'INSIENxx024': 'Insight Enterprises',
#  'QUESDIxx037': 'Quest Diagnostics',
#  'KEYCORPx417': 'Keycorp',
#  'VERITIVx577': 'Veritiv',
#  'DCPMIxxx418': 'Dcp Midstream',
#  'AMERTOxx396': 'American Tower',
#  'GRAYELxx005': 'Graybar Electric',
#  'WECENGRx537': 'Wec Energy Group',
#  'NVRxxxxx331': 'Nvr',
#  'ULTABExx152': 'Ulta Beauty',
#  'DEVOENxx420': 'Devon Energy',
#  'BLACGRxx861': 'Blackstone Group',
#  'DEANFOxx060': 'Dean Foods',
#  'FORTIVEx761': 'Fortive',
#  'UGIxxxxx354': 'Ugi',
#  'BURLSTxx159': 'Burlington Stores',
#  'BUILFIxx843': 'Builders Firstsource',
#  'TOLLBRxx315': 'Toll Brothers',
#  'OLDREINx261': 'Old Republic International',
#  'ASBUAUGR700': 'Asbury Automotive Group',
#  'ARTHJGAx211': 'Arthur J. Gallagher',
#  'MASTECxx812': 'Mastec',
#  'OWENCOxx257': 'Owens Corning',
#  'MAGEHExx853': 'Magellan Health',
#  'DOVERxxx101': 'Dover',
#  'BEACROSU914': 'Beacon Roofing Supply',
#  'AVERDExx176': 'Avery Dennison',
#  'HANESBRA651': 'Hanesbrands',
#  'PACKCOAM442': 'Packaging Corp. Of America',
#  'MTBAxxxx204': 'M&t Bank',
#  'NCRxxxxx550': 'Ncr',
#  'NORTTRxx468': 'Northern Trust',
#  'CINTASxx080': 'Cintas',
#  'POLARISx572': 'Polaris',
#  'CMSENxxx713': 'Cms Energy',
#  'SEABOARD280': 'Seaboard',
#  'INTUITxx180': 'Intuit',
#  'REGIFIxx437': 'Regions Financial',
#  'FMGLxxxx702': 'Fm Global',
#  'ADVAMIDE759': 'Advanced Micro Devices',
#  'OVINTIVx365': 'Ovintiv',
#  'BOOZALHA106': 'Booz Allen Hamilton Holding',
#  'SPGLxxxx200': 'S&p Global',
#  'ROCKAUxx303': 'Rockwell Automation',
#  'OIGLxxxx662': 'O-i Glass',
#  'WYNNRExx307': 'Wynn Resorts',
#  'SECUFIGR077': 'Securian Financial Group',
#  'ALLIDASY516': 'Alliance Data Systems',
#  'WEYERHAE091': 'Weyerhaeuser',
#  'BRIGFIxx648': 'Brighthouse Financial',
#  'INTEEXxx297': 'Intercontinental Exchange',
#  'AMERAXMA511': 'American Axle & Manufacturing',
#  'HESSxxxx341': 'Hess',
#  'ABMINxxx653': 'Abm Industries',
#  'ACTIBLxx424': 'Activision Blizzard',
#  'GAMESTOP219': 'Gamestop',
#  'APACHExx007': 'Apache',
#  'SCIEAPIN312': 'Science Applications International',
#  'AKSTHOxx445': 'Ak Steel Holding',
#  'DILLARDS838': "Dillard's",
#  'RALPLAxx162': 'Ralph Lauren',
#  'CELANESE870': 'Celanese',
#  'RRDOSOxx179': 'R.r. Donnelley & Sons',
#  'ZOETISxx677': 'Zoetis',
#  'ASCEREGR917': 'Ascena Retail Group',
#  'CLOROXxx490': 'Clorox',
#  'INGREDIO083': 'Ingredion',
#  'FIRSAMFI560': 'First American Financial',
#  'GRAPPAHO607': 'Graphic Packaging Holding',
#  'NETAPPxx178': 'Netapp',
#  'HDSUHOxx237': 'Hd Supply Holdings',
#  'TRAVAMxx378': 'Travelcenters Of America',
#  'OLINxxxx896': 'Olin',
#  'ROBEHAIN375': 'Robert Half International',
#  'ENLIMIxx919': 'Enlink Midstream',
#  'AVANTORx185': 'Avantor',
#  'TAPESTRY082': 'Tapestry',
#  'TDAMHOxx514': 'Td Ameritrade Holding',
#  'ANALDExx114': 'Analog Devices',
#  'AMERENxx619': 'Ameren',
#  'REALHOxx728': 'Realogy Holdings',
#  'COMMMExx485': 'Commercial Metals',
#  'RUSHENxx614': 'Rush Enterprises',
#  'FRANRExx122': 'Franklin Resources',
#  'FORTBRHO294': 'Fortune Brands Home & Security',
#  'LEVISTxx892': 'Levi Strauss',
#  'CROWCAIN871': 'Crown Castle International',
#  'SIMOPRGR803': 'Simon Property Group',
#  'CERNERxx035': 'Cerner',
#  'POSTHOxx131': 'Post Holdings',
#  'HUNTBAxx487': 'Huntington Bancshares',
#  'KBRxxxxx852': 'Kbr',
#  'SPROFAMA774': 'Sprouts Farmers Market',
#  'LPLFIHOx230': 'Lpl Financial Holdings',
#  'TROPRxxx054': 'T. Rowe Price',
#  'YUMBRxxx118': 'Yum Brands',
#  'CHIPMEGR319': 'Chipotle Mexican Grill',
#  'PATTERSO549': 'Patterson',
#  'RPMINxxx733': 'Rpm International',
#  'EQUINIXx503': 'Equinix',
#  'NAVIENTx201': 'Navient',
#  'CHEMOURS281': 'Chemours',
#  'ONSExxxx111': 'On Semiconductor',
#  'TRANGRxx110': 'Transdigm Group',
#  'HOSTHORE114': 'Host Hotels & Resorts',
#  'SELEMEHO621': 'Select Medical Holdings',
#  'PARPAHOx814': 'Par Pacific Holdings',
#  'SONOPRxx357': 'Sonoco Products',
#  'ROPETExx550': 'Roper Technologies',
#  'HARLEYDA351': 'Harley-davidson',
#  'JEFFFIGR929': 'Jefferies Financial Group',
#  'KELLSExx557': 'Kelly Services',
#  'MCCORMIC187': 'Mccormick',
#  'MDUREGRx483': 'Mdu Resources Group',
#  'FASTENAL464': 'Fastenal',
#  'BIGLOxxx630': 'Big Lots',
#  'PENNNAGA368': 'Penn National Gaming',
#  'WESTUNxx277': 'Western Union',
#  'UNDEARxx187': 'Under Armour',
#  'XYLEMxxx377': 'Xylem',
#  'SKECUSxx520': 'Skechers U.s.a.',
#  'DOMTARxx979': 'Domtar',
#  'NISOURCE179': 'Nisource',
#  'MARAOIxx471': 'Marathon Oil',
#  'NATIGEHO623': 'National General Holdings',
#  'TELEDASY574': 'Telephone & Data Systems',
#  'AGILTExx254': 'Agilent Technologies',
#  'AMETEKxx031': 'Ametek',
#  'EVERGYxx386': 'Evergy',
#  'INTEFLFR714': 'International Flavors & Fragrances',
#  'ADTxxxxx150': 'Adt',
#  'WELLTOWE800': 'Welltower',
#  'WINDHOxx867': 'Windstream Holdings',
#  'MICHAELS308': 'Michaels',
#  'KEMPERxx729': 'Kemper',
#  'HYATHOxx597': 'Hyatt Hotels',
#  'ALEXPHxx714': 'Alexion Pharmaceuticals',
#  'RESITExx161': 'Resideo Technologies',
#  'CACIINxx611': 'Caci International',
#  'ELECARxx164': 'Electronic Arts',
#  'VULCMAxx137': 'Vulcan Materials',
#  'TREEFOxx306': 'Treehouse Foods',
#  'HANOINGR102': 'Hanover Insurance Group',
#  'CAMPWOHO093': 'Camping World Holdings',
#  'CORNBUBR355': 'Cornerstone Building Brands',
#  'YRCWOxxx699': 'Yrc Worldwide',
#  'CMEGRxxx286': 'Cme Group',
#  'CHEWYxxx003': 'Chewy',
#  'KNIGTRHO610': 'Knight-swift Transportation Holdings',
#  'MOODYSxx195': "Moody's",
#  'COCACOxx527': 'Coca-cola Consolidated',
#  'CARLISLE245': 'Carlisle',
#  'SEALAIxx100': 'Sealed Air',
#  'AMARPRME375': 'A-mark Precious Metals',
#  'WATSCOxx791': 'Watsco',
#  'TAYLMOHO297': 'Taylor Morrison Home',
#  'IACINTER421': 'Iac/interactivecorp',
#  'LEGGPLxx325': 'Leggett & Platt',
#  'ONEMHOxx460': 'Onemain Holdings',
#  'SCHNNAxx864': 'Schneider National',
#  'MARTMAMA152': 'Martin Marietta Materials',
#  'NORTONLI681': 'Nortonlifelock',
#  'HASBROxx685': 'Hasbro',
#  'SQUARExx271': 'Square',
#  'TEREXxxx430': 'Terex',
#  'SYNEHExx678': 'Syneos Health',
#  'FMCxxxxx433': 'Fmc',
#  'BOISCAxx951': 'Boise Cascade',
#  'SSCTEHOx576': 'Ss&c Technologies Holdings',
#  'CONTRExx883': 'Continental Resources',
#  'PEABENxx114': 'Peabody Energy',
#  'ENCOHExx671': 'Encompass Health',
#  'GREIFxxx823': 'Greif',
#  'CONCRExx705': 'Concho Resources',
#  'HUBBELLx852': 'Hubbell',
#  'CFINHOxx093': 'Cf Industries Holdings',
#  'KLAxxxxx884': 'Kla',
#  'GENEHExx864': 'Genesis Healthcare',
#  'BRUNSWIC555': 'Brunswick',
#  'KBHOxxxx457': 'Kb Home',
#  'GLOBLIxx540': 'Globe Life',
#  'MATTELxx744': 'Mattel',
#  'RYERHOxx687': 'Ryerson Holding',
#  'SILGHOxx860': 'Silgan Holdings',
#  'ZEBRTExx175': 'Zebra Technologies',
#  'INTUSUxx856': 'Intuitive Surgical',
#  'WARNMUGR999': 'Warner Music Group',
#  'CONDUENT227': 'Conduent',
#  'TUTOPExx897': 'Tutor Perini',
#  'JUNINExx227': 'Juniper Networks',
#  'NOBLENxx742': 'Noble Energy',
#  'VERTHOxx546': 'Vertiv Holdings',
#  'TIFFANYx893': 'Tiffany',
#  'EQTxxxxx369': 'Eqt',
#  'UFPINxxx733': 'Ufp Industries',
#  'DIEBNIxx445': 'Diebold Nixdorf',
#  'ANTERExx280': 'Antero Resources',
#  'MERITORx147': 'Meritor',
#  'BROAFISO864': 'Broadridge Financial Solutions',
#  'CHURDWxx050': 'Church & Dwight',
#  'MARRVAWO180': 'Marriott Vacations Worldwide',
#  'EDWALIxx537': 'Edwards Lifesciences',
#  'COLFAXxx635': 'Colfax',
#  'INSPERIT777': 'Insperity',
#  'AMEREAOU483': 'American Eagle Outfitters',
#  'KEYSTExx039': 'Keysight Technologies',
#  'JELDHOxx687': 'Jeld-wen Holding',
#  'IRONMOxx262': 'Iron Mountain',
#  'NASDAQxx536': 'Nasdaq',
#  'GARTNERx203': 'Gartner',
#  'SINCBRGR151': 'Sinclair Broadcast Group',
#  'INGLMAxx847': 'Ingles Markets',
#  'MONSBExx031': 'Monster Beverage',
#  'MURPOIxx692': 'Murphy Oil',
#  'VERTPHxx500': 'Vertex Pharmaceuticals',
#  'FIRSREBA610': 'First Republic Bank',
#  'BLOOBRxx562': "Bloomin' Brands",
#  'SPECBRHO622': 'Spectrum Brands Holdings',
#  'QUADGRAP225': 'Quad/graphics',
#  'FLOWFOxx742': 'Flowers Foods',
#  'CUNAMUGR057': 'Cuna Mutual Group',
#  'ALLETExx390': 'Allegheny Technologies',
#  'OLDDOFRLI241': 'Old Dominion Freight Line',
#  'LANDSYxx829': 'Landstar System',
#  'AMERNAIN030': 'American National Insurance',
#  'SNAPONxx677': 'Snap-on',
#  'BROOSELI469': 'Brookdale Senior Living',
#  'AMKOTExx574': 'Amkor Technology',
#  'WYNDDExx364': 'Wyndham Destinations',
#  'PPDxxxxx128': 'Ppd',
#  'DENTSIxx161': 'Dentsply Sirona',
#  'CNOFIGRx784': 'Cno Financial Group',
#  'URBAOUxx745': 'Urban Outfitters',
#  'SABRExxx766': 'Sabre',
#  'MERCGExx563': 'Mercury General',
#  'DIAMENxx463': 'Diamondback Energy',
#  'PARSONSx766': 'Parsons',
#  'AARONSxx429': "Aaron's",
#  'FLOWSERV195': 'Flowserve',
#  'CARVANAx158': 'Carvana',
#  'ASGNxxxx894': 'Asgn',
#  'SALLBEHO618': 'Sally Beauty Holdings',
#  'SCANSOUR312': 'Scansource',
#  'VENTASxx164': 'Ventas',
#  'COUNFIxx291': 'Country Financial',
#  'TRINGRxx229': 'Trinet Group',
#  'SPIRAIxx084': 'Spirit Airlines',
#  'COMERICA558': 'Comerica',
#  'LENNINxx885': 'Lennox International',
#  'TIMKENxx124': 'Timken',
#  'PAYCHEXx162': 'Paychex',
#  'AMERCOxx287': 'Amerco',
#  'WORTINxx887': 'Worthington Industries',
#  'LAMBWEHO702': 'Lamb Weston Holdings',
#  'LAUREDxx439': 'Laureate Education',
#  'PENNMULI615': 'Penn Mutual Life Insurance',
#  'IHEARTME499': 'Iheartmedia',
#  'BRINKSxx406': "Brink's",
#  'SENTINGR632': 'Sentry Insurance Group',
#  'ACUIBRxx262': 'Acuity Brands',
#  'HUBGRxxx223': 'Hub Group',
#  'MERIHOxx211': 'Meritage Homes',
#  'MRCGLxxx185': 'Mrc Global',
#  'ALLIENxx220': 'Alliant Energy',
#  'WORKDAYx463': 'Workday',
#  'BMCSTHOx644': 'Bmc Stock Holdings',
#  'ABERFIxx678': 'Abercrombie & Fitch',
#  'DOMIPIxx792': "Domino's Pizza",
#  'LYFTxxxx662': 'Lyft',
#  'MEREDITH696': 'Meredith',
#  'AMERWAWO148': 'American Water Works',
#  'ALBEMARL755': 'Albemarle',
#  'CIENAxxx940': 'Ciena',
#  'BARNNOxx494': 'Barnes & Noble',
#  'WEISMAxx823': 'Weis Markets',
#  'ILLUMINA448': 'Illumina',
#  'SVBFIGRx500': 'Svb Financial Group',
#  'CARTERSx166': "Carter's",
#  'STIFFIxx280': 'Stifel Financial',
#  'MEDNAXxx603': 'Mednax',
#  'EQUIFAXx863': 'Equifax',
#  'KARAUSEx714': 'Kar Auction Services',
#  'ASHLGLHO060': 'Ashland Global Holdings',
#  'MEDIMUOH251': 'Medical Mutual Of Ohio',
#  'SPRARExx513': 'Sprague Resources',
#  'SUPEMICO188': 'Super Micro Computer',
#  'DESIBRxx678': 'Designer Brands',
#  'PITNBOxx800': 'Pitney Bowes',
#  'APPLINTE541': 'Applied Industrial Technologies',
#  'PINNWECA758': 'Pinnacle West Capital',
#  'AMEREQIN237': 'American Equity Investment Life Holding',
#  'SERVICEN642': 'Servicenow',
#  'TWITTERx677': 'Twitter',
#  'CALUSPPR117': 'Calumet Specialty Products Partners',
#  'STEELCAS297': 'Steelcase',
#  'SANDFAxx116': 'Sanderson Farms',
#  'WABCHOxx042': 'Wabco Holdings',
#  'CLEAHAxx490': 'Clean Harbors',
#  'PUGEENxx933': 'Puget Energy',
#  'SCIEGAxx796': 'Scientific Games',
#  'GRANCOxx447': 'Granite Construction',
#  'CARLGRxx433': 'Carlyle Group',
#  'SKYWSOxx775': 'Skyworks Solutions',
#  'ALERISxx108': 'Aleris',
#  'TRIPMAxx151': 'Triple-s Management',
#  'HEXIONxx353': 'Hexion',
#  'HOLOGICx664': 'Hologic',
#  'TRIUGRxx392': 'Triumph Group',
#  'DARLINxx756': 'Darling Ingredients',
#  'MSCINDIx668': 'Msc Industrial Direct',
#  'REDHAxxx678': 'Red Hat',
#  'SYNOPSYS600': 'Synopsys',
#  'POLYONEx769': 'Polyone',
#  'DYCOINxx656': 'Dycom Industries',
#  'CABOTxxx250': 'Cabot',
#  'PROLOGIS158': 'Prologis',
#  'BOYDGAxx366': 'Boyd Gaming',
#  'LSCCOxxx127': 'Lsc Communications',
#  'BROWNFOR151': 'Brown-forman',
#  'STERICYC169': 'Stericycle',
#  'CITGRxxx465': 'Cit Group',
#  'MDCHOxxx175': 'Mdc Holdings',
#  'HYSTMAHA112': 'Hyster-yale Materials Handling',
#  'CRANExxx907': 'Crane',
#  'CINEHOxx319': 'Cinemark Holdings',
#  'AUTODESK010': 'Autodesk',
#  'TRIMBLEx732': 'Trimble',
#  'GARRMOxx215': 'Garrett Motion',
#  'ZIONBAxx339': 'Zions Bancorp.',
#  'REGABExx547': 'Regal Beloit',
#  'SERVCOIN595': 'Service Corp. International',
#  'VARIMESY285': 'Varian Medical Systems',
#  'PRICESMA859': 'Pricesmart',
#  'BRININxx303': 'Brinker International',
#  'DIGIRETR362': 'Digital Realty Trust',
#  'POOLCOxx967': 'Pool Corp',
#  'CRESEQPA226': 'Crestwood Equity Partners',
#  'INFORxxx758': 'Infor',
#  'PLEXUSxx460': 'Plexus',
#  'TELETExx854': 'Teledyne Technologies',
#  'GIIIAPGR168': 'G-iii Apparel Group',
#  'SCOTMIxx682': 'Scotts Miracle-gro',
#  'APOLGLMA399': 'Apollo Global Management',
#  'ETRAFIxx732': 'E*trade Financial',
#  'TOROxxxx594': 'Toro',
#  'SOUTGAHO178': 'Southwest Gas Holdings',
#  'GMSxxxxx336': 'Gms',
#  'COOPHOxx955': 'Cooper-standard Holdings',
#  'ACADHExx680': 'Acadia Healthcare',
#  'TETRTExx214': 'Tetra Tech',
#  'PRIMSExx346': 'Primoris Services',
#  'TEMPSEIN877': 'Tempur Sealy International',
#  'HRBLxxxx676': 'H&r Block',
#  'QORVOxxx466': 'Qorvo',
#  'TRIPOGRx977': 'Tri Pointe Group',
#  'CRACBAOL139': 'Cracker Barrel Old Country Store',
#  'ELANANHE188': 'Elanco Animal Health',
#  'PRAHESCx225': 'Pra Health Sciences',
#  'FIRSSOxx309': 'First Solar',
#  'AMCNExxx942': 'Amc Networks',
#  'XILINXxx698': 'Xilinx',
#  'GREEPLxx453': 'Green Plains',
#  'COLUSPxx895': 'Columbia Sportswear',
#  'NEXSMEGR380': 'Nexstar Media Group',
#  'SOUTENxx055': 'Southwestern Energy',
#  'GREENBRI536': 'Greenbrier',
#  'PRESIDIO785': 'Presidio',
#  'CITRSYxx037': 'Citrix Systems',
#  'METTINxx610': 'Mettler-toledo International',
#  'TRININxx521': 'Trinity Industries',
#  'MUTUAMLI799': 'Mutual Of America Life Insurance',
#  'LINCELHO028': 'Lincoln Electric Holdings',
#  'TAILBRxx590': 'Tailored Brands',
#  'AOSMxxxx532': 'A.o. Smith',
#  'ARCBESTx264': 'Arcbest',
#  'GODADDYx784': 'Godaddy',
#  'SKYWESTx531': 'Skywest',
#  'BOSTPRxx805': 'Boston Properties',
#  'ENABMIPA599': 'Enable Midstream Partners',
#  'MIDDLEBY524': 'Middleby',
#  'NOWxxxxx326': 'Now',
#  'UNISYSxx023': 'Unisys',
#  'VISTEONx779': 'Visteon',
#  'GRAHHOxx910': 'Graham Holdings',
#  'RESOFOPR934': 'Resolute Forest Products',
#  'CALERESx611': 'Caleres',
#  'AGNCINxx613': 'Agnc Investment',
#  'HILLHOxx276': 'Hill-rom Holdings',
#  'MOOGxxxx542': 'Moog',
#  'LEGGMAxx232': 'Legg Mason',
#  'ATMOENxx721': 'Atmos Energy',
#  'WOODWARD838': 'Woodward',
#  'PALOALNE032': 'Palo Alto Networks',
#  'HBFUxxxx297': 'H.b. Fuller',
#  'AKAMTExx188': 'Akamai Technologies',
#  'AVAYHOxx113': 'Avaya Holdings',
#  'MAXIMUSx517': 'Maximus',
#  'PERKINEL429': 'Perkinelmer',
#  'HAWAELIN227': 'Hawaiian Electric Industries',
#  'KANSCISO376': 'Kansas City Southern',
#  'APTARGRO169': 'Aptargroup',
#  'PUBLSTxx831': 'Public Storage',
#  'SELEINGR209': 'Selective Insurance Group',
#  'ITTxxxxx298': 'Itt',
#  'DONALDSO115': 'Donaldson',
#  'PARKHORE835': 'Park Hotels & Resorts',
#  'KIRBYxxx166': 'Kirby',
#  'HAWAHOxx855': 'Hawaiian Holdings',
#  'POPULARx320': 'Popular',
#  'RANGRExx655': 'Range Resources',
#  'PCCOxxxx161': 'Pc Connection',
#  'AMICMUIN278': 'Amica Mutual Insurance',
#  'ENERSYSx797': 'Enersys',
#  'HELMPAxx750': 'Helmerich & Payne',
#  'NLVFIxxx525': 'Nlv Financial',
#  'VALMINxx262': 'Valmont Industries',
#  'PAExxxxx158': 'Pae',
#  'TEXAROxx175': 'Texas Roadhouse',
#  'COOPTIRU209': 'Cooper Tire & Rubber',
#  'EUROWOxx307': 'Euronet Worldwide',
#  'ZILLGRxx859': 'Zillow Group',
#  'ATLAAIWO706': 'Atlas Air Worldwide Holdings',
#  'ENERHOxx115': 'Energizer Holdings',
#  'MAGEMIPA355': 'Magellan Midstream Partners',
#  'HAINCEGR427': 'Hain Celestial Group',
#  'UNIVCOxx156': 'Universal Corp',
#  'EQUIRExx680': 'Equity Residential',
#  'ALLITRHO601': 'Allison Transmission Holdings',
#  'COLOCAxx747': 'Colony Capital',
#  'TTMTExxx530': 'Ttm Technologies',
#  'CLEACHOU953': 'Clear Channel Outdoor Holdings',
#  'GUESSxxx371': 'Guess',
#  'RENTACEN567': 'Rent-a-center',
#  'TAKEINSO378': 'Take-two Interactive Software',
#  'VISHINxx472': 'Vishay Intertechnology',
#  'TRANSUNI713': 'Transunion',
#  'COOPERxx148': 'Cooper',
#  'FLEETExx606': 'Fleetcor Technologies',
#  'RHxxxxxx102': 'Rh',
#  'RENEENGR623': 'Renewable Energy Group',
#  'BLUEHOxx497': 'Bluelinx Holdings',
#  'CALIRExx174': 'California Resources',
#  'TOPBUILD522': 'Topbuild',
#  'CHARRILA876': 'Charles River Laboratories International',
#  'COMFSYUS508': 'Comfort Systems Usa',
#  'VERIANxx865': 'Verisk Analytics',
#  'RESMEDxx032': 'Resmed',
#  'TELEFLEX468': 'Teleflex',
#  'NEWJEREx452': 'New Jersey Resources',
#  'NEWREINx463': 'New Residential Investment',
#  'INTEBRGR419': 'Interactive Brokers Group',
#  'ZAYOGRHO872': 'Zayo Group Holdings',
#  'HERMMIxx028': 'Herman Miller',
#  'GROCOUHO721': 'Grocery Outlet Holding',
#  'JCREGRxx272': 'J.crew Group',
#  'CENTCOxx980': 'Century Communities',
#  'ELDORExx851': 'Eldorado Resorts',
#  'CATALENT003': 'Catalent',
#  'ITRONxxx833': 'Itron',
#  'MIHOxxxx842': 'M/i Homes',
#  'CBOEGLMA440': 'Cboe Global Markets',
#  'IDEXxxxx905': 'Idex',
#  'BELDENxx172': 'Belden',
#  'CURTISSW170': 'Curtiss-wright',
#  'CHEEFAxx156': 'Cheesecake Factory',
#  'GENEENxx302': 'Genesis Energy',
#  'GEOGRxxx505': 'Geo Group',
#  'PATTENxx842': 'Patterson-uti Energy',
#  'WERNENxx225': 'Werner Enterprises',
#  'INGERAxx491': 'Ingersoll Rand',
#  'VERSOxxx917': 'Verso',
#  'MUELINxx787': 'Mueller Industries',
#  'NUSKENxx245': 'Nu Skin Enterprises',
#  'REVLONxx588': 'Revlon',
#  'ARISNExx596': 'Arista Networks',
#  'IDEXLAxx309': 'Idexx Laboratories',
#  'ALIGTExx238': 'Align Technology',
#  'WATERSxx215': 'Waters',
#  'SYNOFIxx653': 'Synovus Financial',
#  'BRIGHOxx529': 'Brightview Holdings',
#  'REVGRxxx235': 'Rev Group',
#  'BROWBRxx301': 'Brown & Brown',
#  'VALVOLIN910': 'Valvoline',
#  'KNIGCOxx027': 'Knights Of Columbus',
#  'CENTGAPE834': 'Central Garden & Pet',
#  'CARPTExx114': 'Carpenter Technology',
#  'SLMCOxxx744': 'Slm Corp',
#  'KENNAMET756': 'Kennametal',
#  'LCIINxxx651': 'Lci Industries',
#  'TRUEBLUE789': 'Trueblue',
#  'CIMAENxx515': 'Cimarex Energy',
#  'SPLUNKxx121': 'Splunk',
#  'SITELASU646': 'Siteone Landscape Supply',
#  'HEXCELxx504': 'Hexcel',
#  'FTICOxxx628': 'Fti Consulting',
#  'PARTCIHO545': 'Party City Holdco',
#  'OHIONAMU497': 'Ohio National Mutual',
#  'PATRINxx924': 'Patrick Industries',
#  'CADEDESY497': 'Cadence Design Systems',
#  'CDKGLxxx746': 'Cdk Global',
#  'AVALCOxx989': 'Avalonbay Communities',
#  'WABANAxx760': 'Wabash National',
#  'SERVPRTR814': 'Service Properties Trust',
#  'MAXIINPR467': 'Maxim Integrated Products',
#  'PEOPUNFI339': "People's United Financial",
#  'BIORLAxx904': 'Bio-rad Laboratories',
#  'OPTICAHE467': 'Option Care Health',
#  'LOUISIAN811': 'Louisiana-pacific',
#  'TEGNAxxx410': 'Tegna',
#  'TERADYNE309': 'Teradyne',
#  'ARCHRExx889': 'Arch Resources',
#  'EPAMSYxx263': 'Epam Systems',
#  'WPXENxxx204': 'Wpx Energy',
#  'CONTENxx281': 'Contura Energy',
#  'ENSIGRxx168': 'Ensign Group',
#  'FIRSHONA344': 'First Horizon National',
#  'WOLVWOWI202': 'Wolverine World Wide',
#  'VAILRExx617': 'Vail Resorts',
#  'BENCELxx221': 'Benchmark Electronics',
#  'HNIxxxxx345': 'Hni',
#  'F5NExxxx497': 'F5 Networks',
#  'AFFIMAGR120': 'Affiliated Managers Group',
#  'OGEENxxx747': 'Oge Energy',
#  'BOKFIxxx433': 'Bok Financial',
#  'MANTINxx373': 'Mantech International',
#  'SUMMMAxx490': 'Summit Materials',
#  'AMNHESEx062': 'Amn Healthcare Services',
#  'GROUPONx475': 'Groupon',
#  'NEWMGRxx519': 'Newmark Group',
#  'FOSSGRxx494': 'Fossil Group',
#  'MODIMAxx476': 'Modine Manufacturing',
#  'GRIFCOxx832': 'Griffon Corporation',
#  'CYPRSExx773': 'Cypress Semiconductor',
#  'GENEHOxx709': 'Generac Holdings',
#  'MATSONxx740': 'Matson',
#  'GENESCOx554': 'Genesco',
#  'NORDSONx511': 'Nordson',
#  'NEWMARKE484': 'Newmarket',
#  'ECHOGLLO158': 'Echo Global Logistics',
#  'REXNORDx381': 'Rexnord',
#  'INCYTExx571': 'Incyte',
#  'FORTINET575': 'Fortinet',
#  'FOUNBUMA280': 'Foundation Building Materials',
#  'AARxxxxx838': 'Aar',
#  'CENTBRxx260': 'Centric Brands',
#  'EDGEPECA938': 'Edgewell Personal Care',
#  'FEDEMUIN546': 'Federated Mutual Insurance',
#  'SCHNSTIN106': 'Schnitzer Steel Industries',
#  'PORTGEEL215': 'Portland General Electric',
#  'GRAYTExx826': 'Gray Television',
#  'BGCPAxxx123': 'Bgc Partners',
#  'ECHOSTAR707': 'Echostar',
#  'BEAZHOUS900': 'Beazer Homes Usa',
#  'LHCGRxxx257': 'Lhc Group',
#  'SERVGLHO768': 'Servicemaster Global Holdings',
#  'BRUKERxx118': 'Bruker',
#  'OASIPExx502': 'Oasis Petroleum',
#  'CROSPAxx574': 'Crossamerica Partners',
#  'MYRGRxxx686': 'Myr Group',
#  'VIASATxx214': 'Viasat',
#  'GNCHOxxx836': 'Gnc Holdings',
#  'CABOOIGA265': 'Cabot Oil & Gas',
#  'BRIGHOFA372': 'Bright Horizons Family Solutions',
#  'VISTOUxx498': 'Vista Outdoor',
#  'HEICOxxx214': 'Heico',
#  'WYNDHORE371': 'Wyndham Hotels & Resorts',
#  'TCFFIxxx124': 'Tcf Financial',
#  'PRIMERIC932': 'Primerica',
#  'PROPHOxx776': 'Propetro Holding',
#  'OCEAINxx039': 'Oceaneering International',
#  'FLOODEHO196': 'Floor & Decor Holdings',
#  'COPARTxx650': 'Copart',
#  'CHICFAxx538': "Chico's Fas",
#  'BARNNOED873': 'Barnes & Noble Education',
#  'MAXATExx428': 'Maxar Technologies',
#  'EVERCORE261': 'Evercore',
#  'DECKOUxx074': 'Deckers Outdoor',
#  'EXPRESSx647': 'Express',
#  'HOVNENxx376': 'Hovnanian Enterprises',
#  'AIRLExxx290': 'Air Lease',
#  'ROLLINSx172': 'Rollins',
#  'SBACOxxx569': 'Sba Communications',
#  'DELUXExx797': 'Deluxe',
#  'MRCOGRxx673': 'Mr. Cooper Group',
#  'HERCHOxx612': 'Herc Holdings',
#  'HEALPRxx540': 'Healthpeak Properties',
#  'SPXFLxxx116': 'Spx Flow',
#  'LIBEOISE645': 'Liberty Oilfield Services'}
