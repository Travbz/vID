# %% [markdown]
# ### This script converts a column of names into unique IDs and populates a new column with those values.
#
# ### You will need to change a few values to run this code on your unique file name and colume name

# %%
import pandas as pd

# %%
# This code reads the file. Change to ('path/your-file-name.filetype')
try:
    df = pd.read_excel('company.xlsx')
    df.to_csv('company.csv', mode = 'w', index=False)
except:
    df = pd.read_csv('company.csv')
df
# Out:
#        Rank            Metals Industry  Number Of Employees Change In \n Rank  \
# 0       1.0                    Walmart            2200000.0                 -
# 1       2.0                 Amazon.com             798000.0               3.0
# 2       3.0                Exxon Mobil              74900.0              -1.0
# 3       4.0                      Apple             137000.0              -1.0
# 4       5.0                 Cvs Health             290000.0               3.0
# ..      ...                        ...                  ...               ...
# 995   996.0           Mr. Cooper Group               9100.0                 -
# 996   997.0              Herc Holdings               5100.0              -4.0
# 997   998.0      Healthpeak Properties                204.0                 -
# 998   999.0                   Spx Flow               5000.0             -37.0
# 999  1000.0  Liberty Oilfield Services               2571.0             -58.0
#
#                         Industry  \
# 0                 Retail Company
# 1             E-commerce Company
# 2                    Corporation
# 3             Technology Company
# 4             Healthcare Company
# ..                           ...
# 995          Home Loan Servicers
# 996             Equipment Rental
# 997       Real Estate Investment
# 998  Pumps And Pumping Equipment
# 999                  Oil And Gas
#
#                                    Company Description  \
# 0    Walmart Inc. Is An American Multinational Reta...
# 1    Amazon.com, Inc. Is An American Multinational ...
# 2    Exxon Mobil Corp. engages in the exploration, ...
# 3    Apple Inc. Is An American Multinational Techno...
# 4    Cvs Health Is An American Healthcare Company T...
# ..                                                 ...
# 995  Mr. Cooper Group Inc. Provides Quality Servici...
# 996  They Are One Of The Largest Equipment Rental C...
# 997  Healthpeak Properties, Inc. Is A Real Estate I...
# 998  It Is A World Leader In Sustainable Solutions ...
# 999  Liberty Is An Innovative Service Company Provi...
#
#      Revenues\n ($millions) Revenue \n Change Profits\n ($millions)  \
# 0                  523964.0             0.019               14881.0
# 1                  280522.0             0.205               11588.0
# 2                  264938.0            -0.087               14340.0
# 3                  260174.0             -0.02               55256.0
# 4                  256776.0              0.32                6634.0
# ..                      ...               ...                   ...
# 995                  2007.0                 -                 274.0
# 996                  1999.0             0.011                  47.5
# 997                  1997.0             0.082                  45.5
# 998                  1996.0            -0.045                 -95.1
# 999                  1990.0            -0.076                  39.0
#
#     Profit \n Change  Assets\n ($millions) Market Value \n As of 3/31/20 ($m)
# 0              1.231              236495.0                           321803.0
# 1               0.15              225248.0                           970680.0
# 2             -0.312              362597.0                           160696.0
# 3             -0.072              338516.0                          1112641.0
# 4                  -              222449.0                            77376.0
# ..               ...                   ...                                ...
# 995                -               18305.0                              674.0
# 996           -0.313                3817.0                              591.0
# 997           -0.957               14033.0                            12059.0
# 998           -3.161                2437.0                             1212.0
# 999           -0.692                1283.0                              303.0
#
# [1000 rows x 12 columns]

# %%
import pandas as pd

def generate_unique_id(company_name: str) -> str:
    """
    :params company_name 
    :return a unique 12 character ID based on the named from the input
    
    """
    unique_key = ''
    company_name = company_name.upper()
    
    for char in (("THE ", ""), (" THE ", " "), (" AND ", " "), (" OF ", " ")):
        company_name = company_name.replace(*char)
        
    new_name_list = []
    name_list = company_name.split(' ')
    wordCount = len(name_list)
    
    for name in name_list:
        new_name_list.append(''.join(ch for ch in name if ch.isalnum()))
    
    if wordCount == 1:
            unique_key = new_name_list[0][0:8]
    else:
        for i in range(len(new_name_list)):
            if i == 0:
                unique_key += new_name_list[i][:4]
            else:
                unique_key += new_name_list[i][:2]

            if len(unique_key) > 7:
                break

    if len(unique_key) <= 8:
        unique_key += 'x' * (8 - len(unique_key))
    
    hash = 0    
    for ch in company_name:
        hash = ( hash*281  ^ ord(ch)*997) & 0xFFFFFFFF
    hash_number = str(hash)
    
    unique_key += hash_number[1:3]
    
    return unique_key

# %%
print(generate_unique_id("Lignetics Data Solutions of the Rockie"))
# Out:
# LIGNDASO16

# %%
keys_list = []
"""Change the name of (row[" <Your name column's name here>  "])) to match your columns name"""

for index, row in df.iterrows():       # change name here to your columns name
    keys_list.append(generate_unique_id(row["Metals Industry"]))
                                    # RIGHT HERE ^^^
df['unique_ID'] = keys_list

# %%
temp_cols=df.columns.tolist()
new_cols=temp_cols[-1:] + temp_cols[:-1]
df=df[new_cols]
df.head()
# Out:
#     unique_ID  Rank Metals Industry  Number Of Employees Change In \n Rank  \
# 0  WALMARTx20   1.0         Walmart            2200000.0                 -
# 1  AMAZONCO71   2.0      Amazon.com             798000.0               3.0
# 2  EXXOMOxx12   3.0     Exxon Mobil              74900.0              -1.0
# 3  APPLExxx96   4.0           Apple             137000.0              -1.0
# 4  CVSHExxx24   5.0      Cvs Health             290000.0               3.0
#
#              Industry                                Company Description  \
# 0      Retail Company  Walmart Inc. Is An American Multinational Reta...
# 1  E-commerce Company  Amazon.com, Inc. Is An American Multinational ...
# 2         Corporation  Exxon Mobil Corp. engages in the exploration, ...
# 3  Technology Company  Apple Inc. Is An American Multinational Techno...
# 4  Healthcare Company  Cvs Health Is An American Healthcare Company T...
#
#    Revenues\n ($millions) Revenue \n Change Profits\n ($millions)  \
# 0                523964.0             0.019               14881.0
# 1                280522.0             0.205               11588.0
# 2                264938.0            -0.087               14340.0
# 3                260174.0             -0.02               55256.0
# 4                256776.0              0.32                6634.0
#
#   Profit \n Change  Assets\n ($millions) Market Value \n As of 3/31/20 ($m)
# 0            1.231              236495.0                           321803.0
# 1             0.15              225248.0                           970680.0
# 2           -0.312              362597.0                           160696.0
# 3           -0.072              338516.0                          1112641.0
# 4                -              222449.0                            77376.0

# %%
# check for duplicates, none if true
print(len(keys_list) == len(list(set(keys_list))))
# Out:
# False

# %%
"""Change the name of ['Metals Industry'] to match your columns name"""
keys = keys_list

# your col name below vvvvv
values = df['Metals Industry'].to_list()
# change name above ^^^^^

alphaZip= zip(keys,values)
myDict = dict(alphaZip)
myDict
# Out:
# {'WALMARTx20': 'Walmart',
#  'AMAZONCO71': 'Amazon.com',
#  'EXXOMOxx12': 'Exxon Mobil',
#  'APPLExxx96': 'Apple',
#  'CVSHExxx24': 'Cvs Health',
#  'BERKHAxx22': 'Berkshire Hathaway',
#  'UNITGRxx12': 'Unitedhealth Group',
#  'MCKESSON68': 'Mckesson',
#  'ATTxxxxx97': 'At&t',
#  'AMERISOU37': 'Amerisourcebergen',
#  'ALPHABET99': 'Alphabet',
#  'FORDMOxx40': 'Ford Motor',
#  'CIGNAxxx87': 'Cigna',
#  'COSTWHxx16': 'Costco Wholesale',
#  'CHEVRONx14': 'Chevron',
#  'CARDHExx93': 'Cardinal Health',
#  'JPMOCHxx98': 'Jpmorgan Chase',
#  'GENEMOxx46': 'General Motors',
#  'WALGBOAL06': 'Walgreens Boots Alliance',
#  'VERICOxx17': 'Verizon Communications',
#  'MICROSOF52': 'Microsoft',
#  'MARAPExx18': 'Marathon Petroleum',
#  'KROGERxx95': 'Kroger',
#  'FANNMAxx03': 'Fannie Mae',
#  'BANKAMxx92': 'Bank Of America',
#  'HOMEDExx20': 'Home Depot',
#  'PHIL66xx89': 'Phillips 66',
#  'COMCASTx83': 'Comcast',
#  'ANTHEMxx84': 'Anthem',
#  'WELLFAxx15': 'Wells Fargo',
#  'CITIGROU27': 'Citigroup',
#  'VALEENxx76': 'Valero Energy',
#  'GENEELxx18': 'General Electric',
#  'DELLTExx65': 'Dell Technologies',
#  'JOHNJOxx74': 'Johnson & Johnson',
#  'STATFAIN27': 'State Farm Insurance',
#  'TARGETxx81': 'Target',
#  'IBMxxxxx18': 'Ibm',
#  'RAYTTExx70': 'Raytheon Technologies',
#  'BOEINGxx24': 'Boeing',
#  'FREDMAxx44': 'Freddie Mac',
#  'CENTENEx00': 'Centene',
#  'UNITPASE09': 'United Parcel Service',
#  'LOWESxxx79': "Lowe's",
#  'INTELxxx29': 'Intel',
#  'FACEBOOK50': 'Facebook',
#  'FEDEXxxx01': 'Fedex',
#  'METLIFEx27': 'Metlife',
#  'WALTDIxx30': 'Walt Disney',
#  'PROCGAxx48': 'Procter & Gamble',
#  'PEPSICOx96': 'Pepsico',
#  'HUMANAxx15': 'Humana',
#  'PRUDFIxx27': 'Prudential Financial',
#  'ARCHDAMI29': 'Archer Daniels Midland',
#  'ALBERTSO07': 'Albertsons',
#  'SYSCOxxx28': 'Sysco',
#  'LOCKMAxx95': 'Lockheed Martin',
#  'HPxxxxxx63': 'Hp',
#  'ENERTRxx59': 'Energy Transfer',
#  'GOLDSAGR38': 'Goldman Sachs Group',
#  'MORGSTxx75': 'Morgan Stanley',
#  'CATERPIL33': 'Caterpillar',
#  'CISCSYxx03': 'Cisco Systems',
#  'PFIZERxx75': 'Pfizer',
#  'HCAHExxx22': 'Hca Healthcare',
#  'AIGxxxxx07': 'Aig',
#  'AMEREXxx92': 'American Express',
#  'DELTAILI21': 'Delta Air Lines',
#  'MERCKxxx31': 'Merck',
#  'AMERAIGR73': 'American Airlines Group',
#  'CHARCOxx45': 'Charter Communications',
#  'ALLSTATE10': 'Allstate',
#  'NEWYOLIIN05': 'New York Life Insurance',
#  'NATIONWI78': 'Nationwide',
#  'BESTBUxx79': 'Best Buy',
#  'UNITAIHO03': 'United Airlines Holdings',
#  'LIBEMUIN41': 'Liberty Mutual Insurance Group',
#  'DOWxxxxx00': 'Dow',
#  'TYSOFOxx27': 'Tyson Foods',
#  'TJXxxxxx20': 'Tjx',
#  'TIAAxxxx58': 'Tiaa',
#  'ORACLExx91': 'Oracle',
#  'GENEDYxx38': 'General Dynamics',
#  'DEERExxx61': 'Deere',
#  'NIKExxxx15': 'Nike',
#  'PROGRESS09': 'Progressive',
#  'PUBLSUMA95': 'Publix Super Markets',
#  'COCACOLA39': 'Coca-cola',
#  'MASSMULI25': 'Massachusetts Mutual Life Insurance',
#  'TECHDAxx35': 'Tech Data',
#  'WORLFUSE34': 'World Fuel Services',
#  'HONEINxx93': 'Honeywell International',
#  'CONOCOPH11': 'Conocophillips',
#  'USAAxxxx76': 'Usaa',
#  'EXELONxx55': 'Exelon',
#  'NORTGRxx32': 'Northrop Grumman',
#  'CAPIONFI30': 'Capital One Financial',
#  'PLAIGPHO11': 'Plains Gp Holdings',
#  'ABBVIExx34': 'Abbvie',
#  'STONGRxx92': 'Stonex Group',
#  'ENTEPRPA92': 'Enterprise Products Partners',
#  'NORTMUxx75': 'Northwestern Mutual',
#  '3Mxxxxxx80': '3m',
#  'ABBOLAxx53': 'Abbott Laboratories',
#  'CHSxxxxx04': 'Chs',
#  'TRAVELER82': 'Travelers',
#  'PHILMOIN45': 'Philip Morris International',
#  'RAYTHEON61': 'Raytheon',
#  'HEWLPAEN90': 'Hewlett Packard Enterprise',
#  'ARROELxx05': 'Arrow Electronics',
#  'VIACOMCB84': 'Viacomcbs',
#  'DOLLGExx86': 'Dollar General',
#  'USBAxxxx17': 'U.s. Bancorp',
#  'STARBUCK65': 'Starbucks',
#  'BRISSQxx97': 'Bristol-myers Squibb',
#  'USFOHOxx50': 'Us Foods Holding',
#  'MONDINxx04': 'Mondelez International',
#  'PACCARxx03': 'Paccar',
#  'THERFISC72': 'Thermo Fisher Scientific',
#  'MACYSxxx00': "Macy's",
#  'JABILxxx82': 'Jabil',
#  'KRAFHExx93': 'Kraft Heinz',
#  'DUKEENxx29': 'Duke Energy',
#  'TESLAxxx92': 'Tesla',
#  'PBFENxxx96': 'Pbf Energy',
#  'QUALCOMM31': 'Qualcomm',
#  'NGLENPAx20': 'Ngl Energy Partners',
#  'CBREGRxx40': 'Cbre Group',
#  'BAKEHUxx64': 'Baker Hughes',
#  'SYNNEXxx21': 'Synnex',
#  'DOLLTRxx20': 'Dollar Tree',
#  'CUMMINSx98': 'Cummins',
#  'UNITNAFO50': 'United Natural Foods',
#  'MICRTExx72': 'Microchip Technology',
#  'AMGENxxx76': 'Amgen',
#  'PENSAUGR05': 'Penske Automotive Group',
#  'VISAxxxx07': 'Visa',
#  'BROADCOM72': 'Broadcom',
#  'NUCORxxx34': 'Nucor',
#  'GILESCxx25': 'Gilead Sciences',
#  'SOUTAIxx21': 'Southwest Airlines',
#  'HALLIBUR70': 'Halliburton',
#  'CENTURYL79': 'Centurylink',
#  'INTEPAxx58': 'International Paper',
#  'ELILIxxx54': 'Eli Lilly',
#  'AFLACxxx19': 'Aflac',
#  'LENNARxx02': 'Lennar',
#  'OCCIPExx05': 'Occidental Petroleum',
#  'UNIOPAxx73': 'Union Pacific',
#  'RITEAIxx51': 'Rite Aid',
#  'PNCFISEGR10': 'Pnc Financial Services Group',
#  'DUPONTxx85': 'Dupont',
#  'SOUTHERN99': 'Southern',
#  'AUTONATI97': 'Autonation',
#  'DXCTExxx15': 'Dxc Technology',
#  'MCDONALD53': "Mcdonald's",
#  'MARRINxx10': 'Marriott International',
#  'MANPOWER49': 'Manpowergroup',
#  'BANKNEYO33': 'Bank Of New York Mellon',
#  'HARTFISE96': 'Hartford Financial Services Group',
#  'DANAHERx26': 'Danaher',
#  'WHIRLPOO06': 'Whirlpool',
#  'AECOMxxx90': 'Aecom',
#  'NETFLIXx07': 'Netflix',
#  'KOHLSxxx21': "Kohl's",
#  'LEARxxxx84': 'Lear',
#  'ALTRGRxx86': 'Altria Group',
#  'PERFFOGR57': '\nperformance Food Group',
#  'AVNETxxx77': 'Avnet',
#  'SYNCFIxx04': 'Synchrony Financial',
#  'GENUPAxx40': 'Genuine Parts',
#  'NEXTENxx32': 'Nextera Energy',
#  'CARMAXxx16': 'Carmax',
#  'TENEHExx74': 'Tenet Healthcare',
#  'KIMBERLY88': 'Kimberly-clark',
#  'EMERELxx31': 'Emerson Electric',
#  'WESTROCK77': 'Westrock',
#  'CDWxxxxx19': 'Cdw',
#  'JONELALA29': 'Jones Lang Lasalle',
#  'SHERWINW27': 'Sherwin-williams',
#  'FLUORxxx82': 'Fluor',
#  'PAYPHOxx16': 'Paypal Holdings',
#  'DRHOxxxx28': 'D.r. Horton',
#  'HOLLYFRO16': 'Hollyfrontier',
#  'TENNECOx47': 'Tenneco',
#  'EOGRExxx06': 'Eog Resources',
#  'BECTDIxx72': 'Becton Dickinson',
#  'LINCNAxx24': 'Lincoln National',
#  'PGExxxxx28': 'Pg&e',
#  'SALESFOR28': 'Salesforce.com',
#  'MASTERCA53': 'Mastercard',
#  'GENEMIxx00': 'General Mills',
#  'MOLIHExx46': 'Molina Healthcare',
#  'COGNTESO08': 'Cognizant Technology Solutions',
#  'MARSMCxx40': 'Marsh & Mclennan',
#  'XPOLOxxx60': 'Xpo Logistics',
#  'DOMIENxx13': 'Dominion Energy',
#  'WESTDIxx14': 'Western Digital',
#  'GAPxxxxx99': 'Gap',
#  'ARAMARKx81': 'Aramark',
#  'PRINFIxx68': 'Principal Financial',
#  'ROSSSTxx96': '\nross Stores',
#  'COLGATEP94': 'Colgate-palmolive',
#  'AMERELPO52': 'American Electric Power',
#  'NORDSTRO92': 'Nordstrom',
#  'JACOENGR77': 'Jacobs Engineering Group',
#  'WASTMAxx16': 'Waste Management',
#  'CHROWOxx98': 'C.h. Robinson Worldwide',
#  'PPGINxxx14': 'Ppg Industries',
#  'BOOKHOxx27': 'Booking Holdings',
#  'OMNIGRxx07': 'Omnicom Group',
#  'LOEWSxxx83': 'Loews',
#  'ECOLABxx07': 'Ecolab',
#  'STRYKERx30': 'Stryker',
#  'ESTELAxx03': 'Estee Lauder',
#  'GOODTIRU67': 'Goodyear Tire & Rubber',
#  'TRUIFIxx50': 'Truist Financial',
#  'APPLMAxx35': 'Applied Materials',
#  'BLACKROC79': 'Blackrock',
#  'STANBLDE91': 'Stanley Black & Decker',
#  'FREEPORT62': 'Freeport-mcmoran',
#  'TEXAINxx24': 'Texas Instruments',
#  'BIOGENxx99': 'Biogen',
#  'PARKERHA76': 'Parker-hannifin',
#  'REINGRAM27': 'Reinsurance Group Of America',
#  'HOWMAExx40': 'Howmet Aerospace',
#  'AUTODAPR05': 'Automatic Data Processing',
#  'UBERTExx39': 'Uber Technologies',
#  'ILLITOWO64': 'Illinois Tool Works',
#  'DAVITAxx96': 'Davita',
#  'DISCFISE79': 'Discover Financial Services',
#  'LANDOLxx63': "Land O'lakes",
#  'VFxxxxxx43': 'Vf',
#  'CORTEVAx45': 'Corteva',
#  'LASVESAx44': 'Las Vegas Sands',
#  'TEXTRONx86': 'Textron',
#  'KELLOGGx16': 'Kellogg',
#  'GUARLIIN34': 'Guardian Life Ins. Co. Of America',
#  'QURARExx87': 'Qurate Retail',
#  'COREHOxx13': 'Core-mark Holding',
#  'COMMHESY27': 'Community Health Systems',
#  'KINDMOxx92': 'Kinder Morgan',
#  'BJSWHCLx72': "Bj's Wholesale Club",
#  'STATSTxx51': 'State Street',
#  'AMERFIxx57': 'Ameriprise Financial',
#  'GLOBPAxx04': 'Global Payments',
#  'UNITSTST59': 'United States Steel',
#  'LBRxxxxx64': 'L Brands',
#  'MGMREINx99': 'Mgm Resorts International',
#  'L3HATExx15': 'L3harris Technologies',
#  'DISHNExx83': 'Dish Network',
#  'LITHMOxx48': 'Lithia Motors',
#  'DTEENxxx00': 'Dte Energy',
#  'AMERFAIN05': 'American Family Insurance Group',
#  'FARMINEX24': 'Farmers Insurance Exchange',
#  'CONSEDxx04': 'Consolidated Edison',
#  'LKQxxxxx36': 'Lkq',
#  'SEMPENxx43': 'Sempra Energy',
#  'EDISINxx14': 'Edison International',
#  'CENTENxx00': 'Centerpoint Energy',
#  'QUANSExx74': 'Quanta Services',
#  'MURPUSxx21': 'Murphy Usa',
#  'EXPEGRxx18': 'Expedia Group',
#  'GROU1AUx64': 'Group 1 Automotive',
#  'BEDBABEx99': 'Bed Bath & Beyond',
#  'UNUMGRxx17': 'Unum Group',
#  'CSXxxxxx40': 'Csx',
#  'AUTOZONE36': 'Autozone',
#  'PACILIxx87': 'Pacific Life',
#  'VISTENxx94': 'Vistra Energy',
#  'CHARSCxx39': 'Charles Schwab',
#  'CROWHOxx01': 'Crown Holdings',
#  'ALLYFIxx54': 'Ally Financial',
#  'LABOCOAM15': 'Laboratory Corp. Of America',
#  'LIVENAEN70': 'Live Nation Entertainment',
#  'XCELENxx16': 'Xcel Energy',
#  'CORNINGx49': 'Corning',
#  'WWGRxxxx81': 'W.w. Grainger',
#  'BALLxxxx39': 'Ball',
#  'FOXxxxxx09': 'Fox',
#  'UNIVHESE29': 'Universal Health Services',
#  'BAXTINxx32': 'Baxter International',
#  'NORFSOxx90': 'Norfolk Southern',
#  'NAVIINxx44': 'Navistar International',
#  'ADOBExxx32': 'Adobe',
#  'JCPExxxx40': 'J.c. Penney',
#  'DISCOVER24': 'Discovery',
#  'KEURDRPE56': 'Keurig Dr Pepper',
#  'LEIDHOxx15': 'Leidos Holdings',
#  'IQVIHOxx25': 'Iqvia Holdings',
#  'RELISTAL78': 'Reliance Steel & Aluminum',
#  'NVIDIAxx65': 'Nvidia',
#  'ENTERGYx14': 'Entergy',
#  'FIRSTENE86': 'Firstenergy',
#  'EBAYxxxx22': 'Ebay',
#  'BOSTSCxx59': 'Boston Scientific',
#  'OFFIDExx28': 'Office Depot',
#  'MOLSCOBE45': 'Molson Coors Beverage',
#  'STEEDYxx84': 'Steel Dynamics',
#  'MUTUOMIN58': 'Mutual Of Omaha Insurance',
#  'SONIAUxx30': 'Sonic Automotive',
#  'ALCOAxxx25': 'Alcoa',
#  'FIDENAIN42': 'Fidelity National Information Services',
#  'HENRSCxx42': 'Henry Schein',
#  'REPUSExx32': 'Republic Services',
#  'LIBEMExx78': 'Liberty Media',
#  'PETEKISO65': "Peter Kiewit Sons'",
#  'INTEGRxx12': 'Interpublic Group',
#  'PULTEGRO71': 'Pultegroup',
#  'AESxxxxx90': 'Aes',
#  'FISERVxx22': 'Fiserv',
#  'BORGWARN34': 'Borgwarner',
#  'ONEOKxxx27': 'Oneok',
#  'OREIAUxx94': "O'reilly Automotive",
#  'ASSURANT85': 'Assurant',
#  'NEWEBRxx10': 'Newell Brands',
#  'PUBLSEEN03': 'Public Service Enterprise Group',
#  'NEWSCOxx91': 'News Corp.',
#  'CALPINEx30': 'Calpine',
#  'AUTOINxx74': 'Auto-owners Insurance',
#  'MOHAINxx50': 'Mohawk Industries',
#  'PVHxxxxx70': 'Pvh',
#  'CAMPSOxx08': 'Campbell Soup',
#  'NRGENxxx55': 'Nrg Energy',
#  'FIFTTHBA49': 'Fifth Third Bancorp',
#  'HERTGLHO60': 'Hertz Global Holdings',
#  'ALTIUSxx70': 'Altice Usa',
#  'NEWMONTx82': 'Newmont',
#  'CHENENxx69': 'Cheniere Energy',
#  'ADVAAUPA51': 'Advance Auto Parts',
#  'LAMRExxx06': 'Lam Research',
#  'OWENMIxx12': 'Owens & Minor',
#  'EQUIHOxx98': 'Equitable Holdings',
#  'CONABRxx08': 'Conagra Brands',
#  'MARKELxx80': 'Markel',
#  'JONEFIED10': 'Jones Financial (edward Jones)',
#  'HORMFOxx26': 'Hormel Foods',
#  'HILTWOHO76': 'Hilton Worldwide Holdings',
#  'UNIVSOxx55': 'Univar Solutions',
#  'UNITRExx50': 'United Rentals',
#  'PIONNARE31': 'Pioneer Natural Resources',
#  'DELEUSHO69': 'Delek Us Holdings',
#  'EASTCHxx97': 'Eastman Chemical',
#  'EMCOGRxx23': 'Emcor Group',
#  'AVISBUGR09': 'Avis Budget Group',
#  'JBHUTRSE04': 'J.b. Hunt Transport Services',
#  'XEROHOxx10': 'Xerox Holdings',
#  'WAYFAIRx80': 'Wayfair',
#  'KKRxxxxx48': 'Kkr',
#  'AGCOxxxx24': 'Agco',
#  'ALLEGHAN23': 'Alleghany',
#  'ICAHENxx80': 'Icahn Enterprises',
#  'VOYAFIxx06': 'Voya Financial',
#  'RYDESYxx39': 'Ryder System',
#  'AIRPRCHx29': 'Air Products & Chemicals',
#  'MOSAICxx16': 'Mosaic',
#  'HUNTININ58': 'Huntington Ingalls Industries',
#  'BERRGLGR92': 'Berry Global Group',
#  'ANIXINxx72': 'Anixter International',
#  'ALASAIGR28': 'Alaska Air Group',
#  'YUMCHHOx57': 'Yum China Holdings',
#  'DICKSPGO87': "Dick's Sporting Goods",
#  'CAESENxx60': 'Caesars Entertainment',
#  'GENWFIxx05': 'Genworth Financial',
#  'TARGRExx38': 'Targa Resources',
#  'COTYxxxx18': 'Coty',
#  'DANAxxxx19': 'Dana',
#  'THRIFIFO34': 'Thrivent Financial For Lutherans',
#  'AUTOLIVx32': 'Autoliv',
#  'SPARTANN70': 'Spartannash',
#  'EVERENxx71': 'Eversource Energy',
#  'DARDRExx38': 'Darden Restaurants',
#  'CHESENxx34': 'Chesapeake Energy',
#  'NATIOIVA46': 'National Oilwell Varco',
#  'FIDENAFI39': 'Fidelity National Financial',
#  'ERIEINGR14': 'Erie Insurance Group',
#  'OSHKOSHx46': 'Oshkosh',
#  'CASEGEST81': "Casey's General Stores",
#  'WESCINxx47': 'Wesco International',
#  'TRACSUxx07': 'Tractor Supply',
#  'COMMHOxx83': 'Commscope Holding',
#  'HUNTSMAN18': 'Huntsman',
#  'AMERFIGR58': 'American Financial Group',
#  'MASCOxxx73': 'Masco',
#  'SANMINAx97': 'Sanmina',
#  'AMPHENOL08': 'Amphenol',
#  'WILLIAMS91': 'Williams-sonoma',
#  'WESTAIBR25': 'Westinghouse Air Brake',
#  'EXPEINWA28': 'Expeditors Intl. Of Washington',
#  'ANDERSON24': 'Andersons',
#  'WESTCHxx48': 'Westlake Chemical',
#  'CONSBRxx59': 'Constellation Brands',
#  'FRONCOxx36': 'Frontier Communications',
#  'JETBAIxx91': 'Jetblue Airways',
#  'CITIFIGR73': 'Citizens Financial Group',
#  'RAYMJAFI09': 'Raymond James Financial',
#  'FOOTLOxx66': 'Foot Locker',
#  'HERSHEYx26': 'Hershey',
#  'ZIMMBIHO16': 'Zimmer Biomet Holdings',
#  'CINCFIxx21': 'Cincinnati Financial',
#  'WESTSOFI19': 'Western & Southern Financial Group',
#  'WRBExxxx03': 'W.r. Berkley',
#  'MOTOSOxx52': 'Motorola Solutions',
#  'THORINxx84': 'Thor Industries',
#  'REGEPHxx09': 'Regeneron Pharmaceuticals',
#  'SPIRAEHO41': 'Spirit Aerosystems Holdings',
#  'JMSMxxxx03': 'J.m. Smucker',
#  'PPLxxxxx15': 'Ppl',
#  'INSIENxx17': 'Insight Enterprises',
#  'QUESDIxx10': 'Quest Diagnostics',
#  'KEYCORPx32': 'Keycorp',
#  'VERITIVx95': 'Veritiv',
#  'DCPMIxxx12': 'Dcp Midstream',
#  'AMERTOxx46': 'American Tower',
#  'GRAYELxx07': 'Graybar Electric',
#  'WECENGRx36': 'Wec Energy Group',
#  'NVRxxxxx20': 'Nvr',
#  'ULTABExx10': 'Ulta Beauty',
#  'DEVOENxx26': 'Devon Energy',
#  'BLACGRxx43': 'Blackstone Group',
#  'DEANFOxx75': 'Dean Foods',
#  'FORTIVEx67': 'Fortive',
#  'UGIxxxxx66': 'Ugi',
#  'BURLSTxx10': 'Burlington Stores',
#  'BUILFIxx60': 'Builders Firstsource',
#  'TOLLBRxx20': 'Toll Brothers',
#  'OLDREINx69': 'Old Republic International',
#  'ASBUAUGR66': 'Asbury Automotive Group',
#  'ARTHJGAx82': 'Arthur J. Gallagher',
#  'MASTECxx06': 'Mastec',
#  'OWENCOxx38': 'Owens Corning',
#  'MAGEHExx17': 'Magellan Health',
#  'DOVERxxx00': 'Dover',
#  'BEACROSU17': 'Beacon Roofing Supply',
#  'AVERDExx10': 'Avery Dennison',
#  'HANESBRA69': 'Hanesbrands',
#  'PACKCOAM45': 'Packaging Corp. Of America',
#  'MTBAxxxx57': 'M&t Bank',
#  'NCRxxxxx42': 'Ncr',
#  'NORTTRxx75': 'Northern Trust',
#  'CINTASxx46': 'Cintas',
#  'POLARISx68': 'Polaris',
#  'CMSENxxx83': 'Cms Energy',
#  'SEABOARD55': 'Seaboard',
#  'INTUITxx51': 'Intuit',
#  'REGIFIxx77': 'Regions Financial',
#  'FMGLxxxx46': 'Fm Global',
#  'ADVAMIDE06': 'Advanced Micro Devices',
#  'OVINTIVx12': 'Ovintiv',
#  'BOOZALHA20': 'Booz Allen Hamilton Holding',
#  'SPGLxxxx71': 'S&p Global',
#  'ROCKAUxx15': 'Rockwell Automation',
#  'OIGLxxxx41': 'O-i Glass',
#  'WYNNRExx57': 'Wynn Resorts',
#  'SECUFIGR74': 'Securian Financial Group',
#  'ALLIDASY18': 'Alliance Data Systems',
#  'WEYERHAE57': 'Weyerhaeuser',
#  'BRIGFIxx10': 'Brighthouse Financial',
#  'INTEEXxx61': 'Intercontinental Exchange',
#  'AMERAXMA88': 'American Axle & Manufacturing',
#  'HESSxxxx33': 'Hess',
#  'ABMINxxx37': 'Abm Industries',
#  'ACTIBLxx44': 'Activision Blizzard',
#  'GAMESTOP75': 'Gamestop',
#  'APACHExx62': 'Apache',
#  'SCIEAPIN48': 'Science Applications International',
#  'AKSTHOxx47': 'Ak Steel Holding',
#  'DILLARDS46': "Dillard's",
#  'RALPLAxx06': 'Ralph Lauren',
#  'CELANESE50': 'Celanese',
#  'RRDOSOxx80': 'R.r. Donnelley & Sons',
#  'ZOETISxx65': 'Zoetis',
#  'ASCEREGR35': 'Ascena Retail Group',
#  'CLOROXxx60': 'Clorox',
#  'INGREDIO35': 'Ingredion',
#  'FIRSAMFI70': 'First American Financial',
#  'GRAPPAHO17': 'Graphic Packaging Holding',
#  'NETAPPxx50': 'Netapp',
#  'HDSUHOxx19': 'Hd Supply Holdings',
#  'TRAVAMxx85': 'Travelcenters Of America',
#  'OLINxxxx40': 'Olin',
#  'ROBEHAIN30': 'Robert Half International',
#  'ENLIMIxx33': 'Enlink Midstream',
#  'AVANTORx51': 'Avantor',
#  'TAPESTRY62': 'Tapestry',
#  'TDAMHOxx06': 'Td Ameritrade Holding',
#  'ANALDExx49': 'Analog Devices',
#  'AMERENxx40': 'Ameren',
#  'REALHOxx72': 'Realogy Holdings',
#  'COMMMExx05': 'Commercial Metals',
#  'RUSHENxx37': 'Rush Enterprises',
#  'FRANRExx44': 'Franklin Resources',
#  'FORTBRHO69': 'Fortune Brands Home & Security',
#  'LEVISTxx02': 'Levi Strauss',
#  'CROWCAIN93': 'Crown Castle International',
#  'SIMOPRGR19': 'Simon Property Group',
#  'CERNERxx74': 'Cerner',
#  'POSTHOxx16': 'Post Holdings',
#  'HUNTBAxx60': 'Huntington Bancshares',
#  'KBRxxxxx99': 'Kbr',
#  'SPROFAMA08': 'Sprouts Farmers Market',
#  'LPLFIHOx88': 'Lpl Financial Holdings',
#  'TROPRxxx34': 'T. Rowe Price',
#  'YUMBRxxx11': 'Yum Brands',
#  'CHIPMEGR15': 'Chipotle Mexican Grill',
#  'PATTERSO31': 'Patterson',
#  'RPMINxxx35': 'Rpm International',
#  'EQUINIXx35': 'Equinix',
#  'NAVIENTx60': 'Navient',
#  'CHEMOURS79': 'Chemours',
#  'ONSExxxx58': 'On Semiconductor',
#  'TRANGRxx10': 'Transdigm Group',
#  'HOSTHORE29': 'Host Hotels & Resorts',
#  'SELEMEHO22': 'Select Medical Holdings',
#  'PARPAHOx82': 'Par Pacific Holdings',
#  'SONOPRxx55': 'Sonoco Products',
#  'ROPETExx55': 'Roper Technologies',
#  'HARLEYDA62': 'Harley-davidson',
#  'JEFFFIGR82': 'Jefferies Financial Group',
#  'KELLSExx05': 'Kelly Services',
#  'MCCORMIC12': 'Mccormick',
#  'MDUREGRx05': 'Mdu Resources Group',
#  'FASTENAL97': 'Fastenal',
#  'BIGLOxxx97': 'Big Lots',
#  'PENNNAGA53': 'Penn National Gaming',
#  'WESTUNxx51': 'Western Union',
#  'UNDEARxx04': 'Under Armour',
#  'XYLEMxxx08': 'Xylem',
#  'SKECUSxx14': 'Skechers U.s.a.',
#  'DOMTARxx16': 'Domtar',
#  'NISOURCE14': 'Nisource',
#  'MARAOIxx33': 'Marathon Oil',
#  'NATIGEHO20': 'National General Holdings',
#  'TELEDASY64': 'Telephone & Data Systems',
#  'AGILTExx49': 'Agilent Technologies',
#  'AMETEKxx28': 'Ametek',
#  'EVERGYxx11': 'Evergy',
#  'INTEFLFR97': 'International Flavors & Fragrances',
#  'ADTxxxxx29': 'Adt',
#  'WELLTOWE81': 'Welltower',
#  'WINDHOxx66': 'Windstream Holdings',
#  'MICHAELS21': 'Michaels',
#  'KEMPERxx50': 'Kemper',
#  'HYATHOxx60': 'Hyatt Hotels',
#  'ALEXPHxx57': 'Alexion Pharmaceuticals',
#  'RESITExx14': 'Resideo Technologies',
#  'CACIINxx08': 'Caci International',
#  'ELECARxx54': 'Electronic Arts',
#  'VULCMAxx51': 'Vulcan Materials',
#  'TREEFOxx17': 'Treehouse Foods',
#  'HANOINGR63': 'Hanover Insurance Group',
#  'CAMPWOHO15': 'Camping World Holdings',
#  'CORNBUBR03': 'Cornerstone Building Brands',
#  'YRCWOxxx03': 'Yrc Worldwide',
#  'CMEGRxxx34': 'Cme Group',
#  'CHEWYxxx50': 'Chewy',
#  'KNIGTRHO60': 'Knight-swift Transportation Holdings',
#  'MOODYSxx15': "Moody's",
#  'COCACOxx40': 'Coca-cola Consolidated',
#  'CARLISLE97': 'Carlisle',
#  'SEALAIxx07': 'Sealed Air',
#  'AMARPRME12': 'A-mark Precious Metals',
#  'WATSCOxx01': 'Watsco',
#  'TAYLMOHO45': 'Taylor Morrison Home',
#  'IACINTER16': 'Iac/interactivecorp',
#  'LEGGPLxx97': 'Leggett & Platt',
#  'ONEMHOxx18': 'Onemain Holdings',
#  'SCHNNAxx24': 'Schneider National',
#  'MARTMAMA49': 'Martin Marietta Materials',
#  'NORTONLI91': 'Nortonlifelock',
#  'HASBROxx40': 'Hasbro',
#  'SQUARExx79': 'Square',
#  'TEREXxxx07': 'Terex',
#  'SYNEHExx09': 'Syneos Health',
#  'FMCxxxxx19': 'Fmc',
#  'BOISCAxx16': 'Boise Cascade',
#  'SSCTEHOx78': 'Ss&c Technologies Holdings',
#  'CONTRExx46': 'Continental Resources',
#  'PEABENxx76': 'Peabody Energy',
#  'ENCOHExx71': 'Encompass Health',
#  'GREIFxxx42': 'Greif',
#  'CONCRExx83': 'Concho Resources',
#  'HUBBELLx24': 'Hubbell',
#  'CFINHOxx25': 'Cf Industries Holdings',
#  'KLAxxxxx18': 'Kla',
#  'GENEHExx23': 'Genesis Healthcare',
#  'BRUNSWIC34': 'Brunswick',
#  'KBHOxxxx74': 'Kb Home',
#  'GLOBLIxx28': 'Globe Life',
#  'MATTELxx28': 'Mattel',
#  'RYERHOxx01': 'Ryerson Holding',
#  'SILGHOxx07': 'Silgan Holdings',
#  'ZEBRTExx22': 'Zebra Technologies',
#  'INTUSUxx98': 'Intuitive Surgical',
#  'WARNMUGR32': 'Warner Music Group',
#  'CONDUENT63': 'Conduent',
#  'TUTOPExx53': 'Tutor Perini',
#  'JUNINExx23': 'Juniper Networks',
#  'NOBLENxx34': 'Noble Energy',
#  'VERTHOxx07': 'Vertiv Holdings',
#  'TIFFANYx10': 'Tiffany',
#  'EQTxxxxx01': 'Eqt',
#  'UFPINxxx25': 'Ufp Industries',
#  'DIEBNIxx85': 'Diebold Nixdorf',
#  'ANTERExx44': 'Antero Resources',
#  'MERITORx06': 'Meritor',
#  'BROAFISO38': 'Broadridge Financial Solutions',
#  'CHURDWxx52': 'Church & Dwight',
#  'MARRVAWO79': 'Marriott Vacations Worldwide',
#  'EDWALIxx28': 'Edwards Lifesciences',
#  'COLFAXxx18': 'Colfax',
#  'INSPERIT46': 'Insperity',
#  'AMEREAOU82': 'American Eagle Outfitters',
#  'KEYSTExx93': 'Keysight Technologies',
#  'JELDHOxx87': 'Jeld-wen Holding',
#  'IRONMOxx82': 'Iron Mountain',
#  'NASDAQxx49': 'Nasdaq',
#  'GARTNERx68': 'Gartner',
#  'SINCBRGR60': 'Sinclair Broadcast Group',
#  'INGLMAxx68': 'Ingles Markets',
#  'MONSBExx93': 'Monster Beverage',
#  'MURPOIxx58': 'Murphy Oil',
#  'VERTPHxx18': 'Vertex Pharmaceuticals',
#  'FIRSREBA34': 'First Republic Bank',
#  'BLOOBRxx68': "Bloomin' Brands",
#  'SPECBRHO83': 'Spectrum Brands Holdings',
#  'QUADGRAP58': 'Quad/graphics',
#  'FLOWFOxx66': 'Flowers Foods',
#  'CUNAMUGR92': 'Cuna Mutual Group',
#  'ALLETExx16': 'Allegheny Technologies',
#  'OLDDOFRLI35': 'Old Dominion Freight Line',
#  'LANDSYxx35': 'Landstar System',
#  'AMERNAIN30': 'American National Insurance',
#  'SNAPONxx44': 'Snap-on',
#  'BROOSELI02': 'Brookdale Senior Living',
#  'AMKOTExx09': 'Amkor Technology',
#  'WYNDDExx43': 'Wyndham Destinations',
#  'PPDxxxxx79': 'Ppd',
#  'DENTSIxx26': 'Dentsply Sirona',
#  'CNOFIGRx01': 'Cno Financial Group',
#  'URBAOUxx56': 'Urban Outfitters',
#  'SABRExxx04': 'Sabre',
#  'MERCGExx71': 'Mercury General',
#  'DIAMENxx50': 'Diamondback Energy',
#  'PARSONSx27': 'Parsons',
#  'AARONSxx75': "Aaron's",
#  'FLOWSERV75': 'Flowserve',
#  'CARVANAx77': 'Carvana',
#  'ASGNxxxx28': 'Asgn',
#  'SALLBEHO77': 'Sally Beauty Holdings',
#  'SCANSOUR84': 'Scansource',
#  'VENTASxx25': 'Ventas',
#  'COUNFIxx43': 'Country Financial',
#  'TRINGRxx44': 'Trinet Group',
#  'SPIRAIxx74': 'Spirit Airlines',
#  'COMERICA80': 'Comerica',
#  'LENNINxx32': 'Lennox International',
#  'TIMKENxx41': 'Timken',
#  'PAYCHEXx87': 'Paychex',
#  'AMERCOxx98': 'Amerco',
#  'WORTINxx39': 'Worthington Industries',
#  'LAMBWEHO24': 'Lamb Weston Holdings',
#  'LAUREDxx96': 'Laureate Education',
#  'PENNMULI73': 'Penn Mutual Life Insurance',
#  'IHEARTME55': 'Iheartmedia',
#  'BRINKSxx37': "Brink's",
#  'SENTINGR99': 'Sentry Insurance Group',
#  'ACUIBRxx23': 'Acuity Brands',
#  'HUBGRxxx00': 'Hub Group',
#  'MERIHOxx46': 'Meritage Homes',
#  'MRCGLxxx61': 'Mrc Global',
#  'ALLIENxx02': 'Alliant Energy',
#  'WORKDAYx44': 'Workday',
#  'BMCSTHOx33': 'Bmc Stock Holdings',
#  'ABERFIxx30': 'Abercrombie & Fitch',
#  'DOMIPIxx64': "Domino's Pizza",
#  'LYFTxxxx29': 'Lyft',
#  'MEREDITH48': 'Meredith',
#  'AMERWAWO94': 'American Water Works',
#  'ALBEMARL91': 'Albemarle',
#  'CIENAxxx77': 'Ciena',
#  'BARNNOxx28': 'Barnes & Noble',
#  'WEISMAxx10': 'Weis Markets',
#  'ILLUMINA13': 'Illumina',
#  'SVBFIGRx06': 'Svb Financial Group',
#  'CARTERSx01': "Carter's",
#  'STIFFIxx38': 'Stifel Financial',
#  'MEDNAXxx21': 'Mednax',
#  'EQUIFAXx31': 'Equifax',
#  'KARAUSEx80': 'Kar Auction Services',
#  'ASHLGLHO59': 'Ashland Global Holdings',
#  'MEDIMUOH94': 'Medical Mutual Of Ohio',
#  'SPRARExx44': 'Sprague Resources',
#  'SUPEMICO28': 'Super Micro Computer',
#  'DESIBRxx02': 'Designer Brands',
#  'PITNBOxx37': 'Pitney Bowes',
#  'APPLINTE68': 'Applied Industrial Technologies',
#  'PINNWECA68': 'Pinnacle West Capital',
#  'AMEREQIN14': 'American Equity Investment Life Holding',
#  'SERVICEN26': 'Servicenow',
#  'TWITTERx72': 'Twitter',
#  'CALUSPPR88': 'Calumet Specialty Products Partners',
#  'STEELCAS50': 'Steelcase',
#  'SANDFAxx64': 'Sanderson Farms',
#  'WABCHOxx08': 'Wabco Holdings',
#  'CLEAHAxx39': 'Clean Harbors',
#  'PUGEENxx96': 'Puget Energy',
#  'SCIEGAxx45': 'Scientific Games',
#  'GRANCOxx08': 'Granite Construction',
#  'CARLGRxx88': 'Carlyle Group',
#  'SKYWSOxx55': 'Skyworks Solutions',
#  'ALERISxx16': 'Aleris',
#  'TRIPMAxx13': 'Triple-s Management',
#  'HEXIONxx87': 'Hexion',
#  'HOLOGICx06': 'Hologic',
#  'TRIUGRxx76': 'Triumph Group',
#  'DARLINxx44': 'Darling Ingredients',
#  'MSCINDIx49': 'Msc Industrial Direct',
#  'REDHAxxx97': 'Red Hat',
#  'SYNOPSYS52': 'Synopsys',
#  'POLYONEx04': 'Polyone',
#  'DYCOINxx77': 'Dycom Industries',
#  'CABOTxxx48': 'Cabot',
#  'PROLOGIS35': 'Prologis',
#  'BOYDGAxx28': 'Boyd Gaming',
#  'LSCCOxxx85': 'Lsc Communications',
#  'BROWNFOR27': 'Brown-forman',
#  'STERICYC96': 'Stericycle',
#  'CITGRxxx77': 'Cit Group',
#  'MDCHOxxx47': 'Mdc Holdings',
#  'HYSTMAHA40': 'Hyster-yale Materials Handling',
#  'CRANExxx21': 'Crane',
#  'CINEHOxx17': 'Cinemark Holdings',
#  'AUTODESK70': 'Autodesk',
#  'TRIMBLEx09': 'Trimble',
#  'GARRMOxx53': 'Garrett Motion',
#  'ZIONBAxx40': 'Zions Bancorp.',
#  'REGABExx09': 'Regal Beloit',
#  'SERVCOIN48': 'Service Corp. International',
#  'VARIMESY19': 'Varian Medical Systems',
#  'PRICESMA44': 'Pricesmart',
#  'BRININxx53': 'Brinker International',
#  'DIGIRETR04': 'Digital Realty Trust',
#  'POOLCOxx01': 'Pool Corp',
#  'CRESEQPA36': 'Crestwood Equity Partners',
#  'INFORxxx17': 'Infor',
#  'PLEXUSxx21': 'Plexus',
#  'TELETExx04': 'Teledyne Technologies',
#  'GIIIAPGR03': 'G-iii Apparel Group',
#  'SCOTMIxx06': 'Scotts Miracle-gro',
#  'APOLGLMA80': 'Apollo Global Management',
#  'ETRAFIxx41': 'E*trade Financial',
#  'TOROxxxx67': 'Toro',
#  'SOUTGAHO04': 'Southwest Gas Holdings',
#  'GMSxxxxx96': 'Gms',
#  'COOPHOxx72': 'Cooper-standard Holdings',
#  'ACADHExx07': 'Acadia Healthcare',
#  'TETRTExx43': 'Tetra Tech',
#  'PRIMSExx13': 'Primoris Services',
#  'TEMPSEIN92': 'Tempur Sealy International',
#  'HRBLxxxx43': 'H&r Block',
#  'QORVOxxx61': 'Qorvo',
#  'TRIPOGRx38': 'Tri Pointe Group',
#  'CRACBAOL64': 'Cracker Barrel Old Country Store',
#  'ELANANHE67': 'Elanco Animal Health',
#  'PRAHESCx36': 'Pra Health Sciences',
#  'FIRSSOxx15': 'First Solar',
#  'AMCNExxx28': 'Amc Networks',
#  'XILINXxx82': 'Xilinx',
#  'GREEPLxx27': 'Green Plains',
#  'COLUSPxx04': 'Columbia Sportswear',
#  'NEXSMEGR27': 'Nexstar Media Group',
#  'SOUTENxx20': 'Southwestern Energy',
#  'GREENBRI61': 'Greenbrier',
#  'PRESIDIO48': 'Presidio',
#  'CITRSYxx93': 'Citrix Systems',
#  'METTINxx12': 'Mettler-toledo International',
#  'TRININxx08': 'Trinity Industries',
#  'MUTUAMLI53': 'Mutual Of America Life Insurance',
#  'LINCELHO66': 'Lincoln Electric Holdings',
#  'TAILBRxx76': 'Tailored Brands',
#  'AOSMxxxx69': 'A.o. Smith',
#  'ARCBESTx39': 'Arcbest',
#  'GODADDYx75': 'Godaddy',
#  'SKYWESTx19': 'Skywest',
#  'BOSTPRxx51': 'Boston Properties',
#  'ENABMIPA44': 'Enable Midstream Partners',
#  'MIDDLEBY63': 'Middleby',
#  'NOWxxxxx69': 'Now',
#  'UNISYSxx89': 'Unisys',
#  'VISTEONx38': 'Visteon',
#  'GRAHHOxx03': 'Graham Holdings',
#  'RESOFOPR25': 'Resolute Forest Products',
#  'CALERESx07': 'Caleres',
#  'AGNCINxx57': 'Agnc Investment',
#  'HILLHOxx97': 'Hill-rom Holdings',
#  'MOOGxxxx51': 'Moog',
#  'LEGGMAxx10': 'Legg Mason',
#  'ATMOENxx98': 'Atmos Energy',
#  'WOODWARD70': 'Woodward',
#  'PALOALNE56': 'Palo Alto Networks',
#  'HBFUxxxx12': 'H.b. Fuller',
#  'AKAMTExx83': 'Akamai Technologies',
#  'AVAYHOxx46': 'Avaya Holdings',
#  'MAXIMUSx23': 'Maximus',
#  'PERKINEL53': 'Perkinelmer',
#  'HAWAELIN76': 'Hawaiian Electric Industries',
#  'KANSCISO85': 'Kansas City Southern',
#  'APTARGRO47': 'Aptargroup',
#  'PUBLSTxx88': 'Public Storage',
#  'SELEINGR56': 'Selective Insurance Group',
#  'ITTxxxxx83': 'Itt',
#  'DONALDSO60': 'Donaldson',
#  'PARKHORE28': 'Park Hotels & Resorts',
#  'KIRBYxxx05': 'Kirby',
#  'HAWAHOxx61': 'Hawaiian Holdings',
#  'POPULARx10': 'Popular',
#  'RANGRExx37': 'Range Resources',
#  'PCCOxxxx05': 'Pc Connection',
#  'AMICMUIN78': 'Amica Mutual Insurance',
#  'ENERSYSx79': 'Enersys',
#  'HELMPAxx86': 'Helmerich & Payne',
#  'NLVFIxxx25': 'Nlv Financial',
#  'VALMINxx67': 'Valmont Industries',
#  'PAExxxxx32': 'Pae',
#  'TEXAROxx56': 'Texas Roadhouse',
#  'COOPTIRU73': 'Cooper Tire & Rubber',
#  'EUROWOxx20': 'Euronet Worldwide',
#  'ZILLGRxx70': 'Zillow Group',
#  'ATLAAIWO93': 'Atlas Air Worldwide Holdings',
#  'ENERHOxx16': 'Energizer Holdings',
#  'MAGEMIPA79': 'Magellan Midstream Partners',
#  'HAINCEGR23': 'Hain Celestial Group',
#  'UNIVCOxx56': 'Universal Corp',
#  'EQUIRExx59': 'Equity Residential',
#  'ALLITRHO75': 'Allison Transmission Holdings',
#  'COLOCAxx86': 'Colony Capital',
#  'TTMTExxx92': 'Ttm Technologies',
#  'CLEACHOU18': 'Clear Channel Outdoor Holdings',
#  'GUESSxxx07': 'Guess',
#  'RENTACEN37': 'Rent-a-center',
#  'TAKEINSO26': 'Take-two Interactive Software',
#  'VISHINxx38': 'Vishay Intertechnology',
#  'TRANSUNI69': 'Transunion',
#  'COOPERxx62': 'Cooper',
#  'FLEETExx46': 'Fleetcor Technologies',
#  'RHxxxxxx06': 'Rh',
#  'RENEENGR65': 'Renewable Energy Group',
#  'BLUEHOxx64': 'Bluelinx Holdings',
#  'CALIRExx01': 'California Resources',
#  'TOPBUILD86': 'Topbuild',
#  'CHARRILA20': 'Charles River Laboratories International',
#  'COMFSYUS24': 'Comfort Systems Usa',
#  'VERIANxx65': 'Verisk Analytics',
#  'RESMEDxx99': 'Resmed',
#  'TELEFLEX96': 'Teleflex',
#  'NEWJEREx98': 'New Jersey Resources',
#  'NEWREINx22': 'New Residential Investment',
#  'INTEBRGR52': 'Interactive Brokers Group',
#  'ZAYOGRHO19': 'Zayo Group Holdings',
#  'HERMMIxx77': 'Herman Miller',
#  'GROCOUHO54': 'Grocery Outlet Holding',
#  'JCREGRxx14': 'J.crew Group',
#  'CENTCOxx19': 'Century Communities',
#  'ELDORExx07': 'Eldorado Resorts',
#  'CATALENT28': 'Catalent',
#  'ITRONxxx18': 'Itron',
#  'MIHOxxxx29': 'M/i Homes',
#  'CBOEGLMA65': 'Cboe Global Markets',
#  'IDEXxxxx40': 'Idex',
#  'BELDENxx75': 'Belden',
#  'CURTISSW80': 'Curtiss-wright',
#  'CHEEFAxx18': 'Cheesecake Factory',
#  'GENEENxx03': 'Genesis Energy',
#  'GEOGRxxx56': 'Geo Group',
#  'PATTENxx12': 'Patterson-uti Energy',
#  'WERNENxx51': 'Werner Enterprises',
#  'INGERAxx68': 'Ingersoll Rand',
#  'VERSOxxx86': 'Verso',
#  'MUELINxx05': 'Mueller Industries',
#  'NUSKENxx74': 'Nu Skin Enterprises',
#  'REVLONxx82': 'Revlon',
#  'ARISNExx67': 'Arista Networks',
#  'IDEXLAxx73': 'Idexx Laboratories',
#  'ALIGTExx26': 'Align Technology',
#  'WATERSxx12': 'Waters',
#  'SYNOFIxx98': 'Synovus Financial',
#  'BRIGHOxx50': 'Brightview Holdings',
#  'REVGRxxx42': 'Rev Group',
#  'BROWBRxx26': 'Brown & Brown',
#  'VALVOLIN85': 'Valvoline',
#  'KNIGCOxx85': 'Knights Of Columbus',
#  'CENTGAPE88': 'Central Garden & Pet',
#  'CARPTExx61': 'Carpenter Technology',
#  'SLMCOxxx10': 'Slm Corp',
#  'KENNAMET21': 'Kennametal',
#  'LCIINxxx47': 'Lci Industries',
#  'TRUEBLUE41': 'Trueblue',
#  'CIMAENxx38': 'Cimarex Energy',
#  'SPLUNKxx64': 'Splunk',
#  'SITELASU16': 'Siteone Landscape Supply',
#  'HEXCELxx35': 'Hexcel',
#  'FTICOxxx37': 'Fti Consulting',
#  'PARTCIHO79': 'Party City Holdco',
#  'OHIONAMU24': 'Ohio National Mutual',
#  'PATRINxx90': 'Patrick Industries',
#  'CADEDESY02': 'Cadence Design Systems',
#  'CDKGLxxx27': 'Cdk Global',
#  'AVALCOxx44': 'Avalonbay Communities',
#  'WABANAxx40': 'Wabash National',
#  'SERVPRTR79': 'Service Properties Trust',
#  'MAXIINPR33': 'Maxim Integrated Products',
#  'PEOPUNFI67': "People's United Financial",
#  'BIORLAxx30': 'Bio-rad Laboratories',
#  'OPTICAHE35': 'Option Care Health',
#  'LOUISIAN94': 'Louisiana-pacific',
#  'TEGNAxxx62': 'Tegna',
#  'TERADYNE08': 'Teradyne',
#  'ARCHRExx97': 'Arch Resources',
#  'EPAMSYxx19': 'Epam Systems',
#  'WPXENxxx14': 'Wpx Energy',
#  'CONTENxx33': 'Contura Energy',
#  'ENSIGRxx35': 'Ensign Group',
#  'FIRSHONA12': 'First Horizon National',
#  'WOLVWOWI87': 'Wolverine World Wide',
#  'VAILRExx03': 'Vail Resorts',
#  'BENCELxx12': 'Benchmark Electronics',
#  'HNIxxxxx45': 'Hni',
#  'F5NExxxx21': 'F5 Networks',
#  'AFFIMAGR90': 'Affiliated Managers Group',
#  'OGEENxxx26': 'Oge Energy',
#  'BOKFIxxx68': 'Bok Financial',
#  'MANTINxx42': 'Mantech International',
#  'SUMMMAxx26': 'Summit Materials',
#  'AMNHESEx38': 'Amn Healthcare Services',
#  'GROUPONx81': 'Groupon',
#  'NEWMGRxx93': 'Newmark Group',
#  'FOSSGRxx92': 'Fossil Group',
#  'MODIMAxx47': 'Modine Manufacturing',
#  'GRIFCOxx37': 'Griffon Corporation',
#  'CYPRSExx04': 'Cypress Semiconductor',
#  'GENEHOxx05': 'Generac Holdings',
#  'MATSONxx03': 'Matson',
#  'GENESCOx97': 'Genesco',
#  'NORDSONx99': 'Nordson',
#  'NEWMARKE57': 'Newmarket',
#  'ECHOGLLO00': 'Echo Global Logistics',
#  'REXNORDx50': 'Rexnord',
#  'INCYTExx31': 'Incyte',
#  'FORTINET75': 'Fortinet',
#  'FOUNBUMA76': 'Foundation Building Materials',
#  'AARxxxxx52': 'Aar',
#  'CENTBRxx22': 'Centric Brands',
#  'EDGEPECA86': 'Edgewell Personal Care',
#  'FEDEMUIN99': 'Federated Mutual Insurance',
#  'SCHNSTIN36': 'Schnitzer Steel Industries',
#  'PORTGEEL83': 'Portland General Electric',
#  'GRAYTExx03': 'Gray Television',
#  'BGCPAxxx69': 'Bgc Partners',
#  'ECHOSTAR10': 'Echostar',
#  'BEAZHOUS69': 'Beazer Homes Usa',
#  'LHCGRxxx38': 'Lhc Group',
#  'SERVGLHO90': 'Servicemaster Global Holdings',
#  'BRUKERxx90': 'Bruker',
#  'OASIPExx58': 'Oasis Petroleum',
#  'CROSPAxx30': 'Crossamerica Partners',
#  'MYRGRxxx81': 'Myr Group',
#  'VIASATxx77': 'Viasat',
#  'GNCHOxxx03': 'Gnc Holdings',
#  'CABOOIGA23': 'Cabot Oil & Gas',
#  'BRIGHOFA51': 'Bright Horizons Family Solutions',
#  'VISTOUxx36': 'Vista Outdoor',
#  'HEICOxxx68': 'Heico',
#  'WYNDHORE14': 'Wyndham Hotels & Resorts',
#  'TCFFIxxx84': 'Tcf Financial',
#  'PRIMERIC25': 'Primerica',
#  'PROPHOxx26': 'Propetro Holding',
#  'OCEAINxx12': 'Oceaneering International',
#  'FLOODEHO58': 'Floor & Decor Holdings',
#  'COPARTxx20': 'Copart',
#  'CHICFAxx25': "Chico's Fas",
#  'BARNNOED29': 'Barnes & Noble Education',
#  'MAXATExx64': 'Maxar Technologies',
#  'EVERCORE13': 'Evercore',
#  'DECKOUxx35': 'Deckers Outdoor',
#  'EXPRESSx58': 'Express',
#  'HOVNENxx99': 'Hovnanian Enterprises',
#  'AIRLExxx56': 'Air Lease',
#  'ROLLINSx37': 'Rollins',
#  'SBACOxxx51': 'Sba Communications',
#  'DELUXExx56': 'Deluxe',
#  'MRCOGRxx72': 'Mr. Cooper Group',
#  'HERCHOxx97': 'Herc Holdings',
#  'HEALPRxx44': 'Healthpeak Properties',
#  'SPXFLxxx47': 'Spx Flow',
#  'LIBEOISE95': 'Liberty Oilfield Services'}
