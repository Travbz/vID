# %%
import pandas as pd
'''
This script converts a column of names into unique IDs
Rename the company/customer-names column of this file(code below) to match the column name in your file.

'''  
try:
    df = pd.read_excel('company.xlsx')
    df.to_csv('company.csv', mode = 'w', index=False)
except:
    df = pd.read_csv('company.csv')

# %%
import pandas as pd

def generate_unique_id(company_name: str) -> str:
    """
    :params company_name 
    :return a unique 12 character ID based on the named from the input
    
    """
    unique_key = ''
    company_name = company_name.upper()
    
    # remove designated 'stop' words from name
    for char in (("THE ", ""), (" THE ", " "), (" AND ", " "), (" OF ", " ")):
        company_name= company_name.replace(*char)
    
    name_list = company_name.split(' ')
    wordCount = len(name_list)
    new_name_list = []

    for name in name_list:
        new_name_list.append(''.join(ch.upper() for ch in name if ch.isalnum()))
    
    if wordCount == 1:
            unique_key = new_name_list[0][0:8]
    else:
        for i in range(len(new_name_list)):
            if i == 0:
                unique_key += new_name_list[i][:4]
            else:
                unique_key += new_name_list[i][:2]

            if len(unique_key) > 7:
                break

    if len(unique_key) <= 8:
        unique_key += 'x' * (8 - len(unique_key))
    
    hash_number = str(hash(company_name.upper()))[1:4]
        
    unique_key += hash_number
    
    return unique_key

# %%
keys_list = []

"""Change the name of (row[" <Your name column's name here>  "])) to match your columns name"""
for index, row in df.iterrows():
    keys_list.append(generate_unique_id(row["Metals Industry"]))
    
df['unique_ID'] = keys_list

# %%
temp_cols=df.columns.tolist()
new_cols=temp_cols[-1:] + temp_cols[:-1]
df=df[new_cols]
df.head(20)
# Out:
#       unique_ID Market Value \n As of 3/31/20 ($m)  Rank  \
# 0   WALMARTx510                           321803.0   1.0
# 1   AMAZONCO737                           970680.0   2.0
# 2   EXXOMOxx749                           160696.0   3.0
# 3   APPLExxx195                          1112641.0   4.0
# 4   CVSHExxx188                            77376.0   5.0
# 5   BERKHAxx710                           442897.0   6.0
# 6   UNITGRxx399                           236555.0   7.0
# 7   MCKESSON953                            21845.0   8.0
# 8   ATTxxxxx020                           209388.0   9.0
# 9   AMERISOU711                            18221.0  10.0
# 10  ALPHABET847                           798905.0  11.0
# 11  FORDMOxx394                            19151.0  12.0
# 12  CIGNAxxx612                            65897.0  13.0
# 13  COSTWHxx316                           125908.0  14.0
# 14  CHEVRONx870                           136176.0  15.0
# 15  CARDHExx382                            13988.0  16.0
# 16  JPMOCHxx221                           276750.0  17.0
# 17  GENEMOxx533                            29695.0  18.0
# 18  WALGBOAL740                            40528.0  19.0
# 19  VERICOxx322                           222220.0  20.0
#
#              Metals Industry  Number Of Employees Change In \n Rank  \
# 0                    Walmart            2200000.0                 -
# 1                 Amazon.com             798000.0               3.0
# 2                Exxon Mobil              74900.0              -1.0
# 3                      Apple             137000.0              -1.0
# 4                 Cvs Health             290000.0               3.0
# 5         Berkshire Hathaway             391500.0              -2.0
# 6         Unitedhealth Group             325000.0              -1.0
# 7                   Mckesson              70000.0              -1.0
# 8                       At&t             247800.0                 -
# 9          Amerisourcebergen              21500.0                 -
# 10                  Alphabet             118899.0               4.0
# 11                Ford Motor             190000.0                 -
# 12                     Cigna              73700.0              52.0
# 13          Costco Wholesale             201500.0                 -
# 14                   Chevron              48200.0              -4.0
# 15           Cardinal Health              49500.0                 -
# 16            Jpmorgan Chase             256981.0               1.0
# 17            General Motors             164000.0              -5.0
# 18  Walgreens Boots Alliance             287000.0              -2.0
# 19    Verizon Communications             135000.0              -1.0
#
#                                Industry  \
# 0                        Retail Company
# 1                    E-commerce Company
# 2                           Corporation
# 3                    Technology Company
# 4                    Healthcare Company
# 5    Multinational Conglomerate Company
# 6                  Managed Care Company
# 7                   Health Care Company
# 8            Telecommunications Company
# 9                     Wholesale Company
# 10  Information Technology And Services
# 11                    Automaker Company
# 12                    Insurance Company
# 13                       Retail Company
# 14                 Oil Industry Company
# 15                  Health Care Company
# 16           Investment Banking Company
# 17                 Vehicle Manufacturer
# 18                       Retail Company
# 19           Telecommunications Company
#
#                                   Company Description  Revenues\n ($millions)  \
# 0   Walmart Inc. Is An American Multinational Reta...                523964.0
# 1   Amazon.com, Inc. Is An American Multinational ...                280522.0
# 2   Exxon Mobil Corp. engages in the exploration, ...                264938.0
# 3   Apple Inc. Is An American Multinational Techno...                260174.0
# 4   Cvs Health Is An American Healthcare Company T...                256776.0
# 5   Berkshire Hathaway Is An American Multinationa...                254616.0
# 6   Unitedhealth Group Incorporated Is An American...                242155.0
# 7   Mckesson Corporation Is An American Company Di...                214319.0
# 8   At&t Inc. Is An American Multinational Conglom...                181193.0
# 9   Amerisourcebergen Corporation Is An American D...                179589.0
# 10  Alphabet Inc. Is An American Multinational Con...                161857.0
# 11  Ford Motor Company, Commonly Known As Ford, Is...                155900.0
# 12  Cigna Is An American Worldwide Health Services...                153566.0
# 13  Costco Wholesale Corporation Is An American Mu...                152703.0
# 14  Chevron Corporation Is An American Multination...                146516.0
# 15  Cardinal Health, Inc. Is An American Multinati...                145534.0
# 16  Jpmorgan Chase & Co. Is An American Multinatio...                142422.0
# 17  General Motors Company Is An American Multinat...                137237.0
# 18  Walgreens Boots Alliance, Inc. Is An American ...                136866.0
# 19  Verizon Communications Inc. Is An American Mul...                131868.0
#
#    Revenue \n Change Profits\n ($millions) Profit \n Change  \
# 0              0.019               14881.0            1.231
# 1              0.205               11588.0             0.15
# 2             -0.087               14340.0           -0.312
# 3              -0.02               55256.0           -0.072
# 4               0.32                6634.0                -
# 5              0.027               81417.0           19.248
# 6               0.07               13839.0            0.155
# 7              0.029                  34.0           -0.493
# 8              0.061               13903.0           -0.282
# 9              0.069                 855.4           -0.484
# 10             0.183               34343.0            0.117
# 11            -0.028                  47.0           -0.987
# 12             2.157                5104.0            0.936
# 13             0.079                3659.0            0.168
# 14            -0.119                2924.0           -0.803
# 15             0.064                1363.0            4.324
# 16             0.084               36431.0            0.122
# 17            -0.067                6732.0            -0.16
# 18             0.041                3982.0           -0.207
# 19             0.008               19265.0            0.241
#
#     Assets\n ($millions)
# 0               236495.0
# 1               225248.0
# 2               362597.0
# 3               338516.0
# 4               222449.0
# 5               817729.0
# 6               173889.0
# 7                59672.0
# 8               551669.0
# 9                39172.0
# 10              275909.0
# 11              258537.0
# 12              155774.0
# 13               45400.0
# 14              237428.0
# 15               40963.0
# 16             2687379.0
# 17              228037.0
# 18               67598.0
# 19              291727.0

# %%
# check for duplicates, none if true
print(len(keys_list) == len(list(set(keys_list))))
# Out:
# True

# %%
"""Change the name of ['Metals Industry'] to match your columns name"""
keys = keys_list
values = df['Metals Industry'].to_list()
alphaZip= zip(keys,values)
myDict = dict(alphaZip)
myDict
# Out:
# {'WALMARTx510': 'Walmart',
#  'AMAZONCO737': 'Amazon.com',
#  'EXXOMOxx749': 'Exxon Mobil',
#  'APPLExxx195': 'Apple',
#  'CVSHExxx188': 'Cvs Health',
#  'BERKHAxx710': 'Berkshire Hathaway',
#  'UNITGRxx399': 'Unitedhealth Group',
#  'MCKESSON953': 'Mckesson',
#  'ATTxxxxx020': 'At&t',
#  'AMERISOU711': 'Amerisourcebergen',
#  'ALPHABET847': 'Alphabet',
#  'FORDMOxx394': 'Ford Motor',
#  'CIGNAxxx612': 'Cigna',
#  'COSTWHxx316': 'Costco Wholesale',
#  'CHEVRONx870': 'Chevron',
#  'CARDHExx382': 'Cardinal Health',
#  'JPMOCHxx221': 'Jpmorgan Chase',
#  'GENEMOxx533': 'General Motors',
#  'WALGBOAL740': 'Walgreens Boots Alliance',
#  'VERICOxx322': 'Verizon Communications',
#  'MICROSOF521': 'Microsoft',
#  'MARAPExx113': 'Marathon Petroleum',
#  'KROGERxx262': 'Kroger',
#  'FANNMAxx471': 'Fannie Mae',
#  'BANKOFAM758': 'Bank Of America',
#  'HOMEDExx562': 'Home Depot',
#  'PHIL66xx903': 'Phillips 66',
#  'COMCASTx313': 'Comcast',
#  'ANTHEMxx694': 'Anthem',
#  'WELLFAxx302': 'Wells Fargo',
#  'CITIGROU735': 'Citigroup',
#  'VALEENxx325': 'Valero Energy',
#  'GENEELxx349': 'General Electric',
#  'DELLTExx218': 'Dell Technologies',
#  'JOHNJOxx396': 'Johnson & Johnson',
#  'STATFAIN282': 'State Farm Insurance',
#  'TARGETxx204': 'Target',
#  'IBMxxxxx160': 'Ibm',
#  'RAYTTExx335': 'Raytheon Technologies',
#  'BOEINGxx773': 'Boeing',
#  'FREDMAxx679': 'Freddie Mac',
#  'CENTENEx340': 'Centene',
#  'UNITPASE558': 'United Parcel Service',
#  'LOWESxxx241': "Lowe's",
#  'INTELxxx560': 'Intel',
#  'FACEBOOK918': 'Facebook',
#  'FEDEXxxx614': 'Fedex',
#  'METLIFEx039': 'Metlife',
#  'WALTDIxx650': 'Walt Disney',
#  'PROCGAxx983': 'Procter & Gamble',
#  'PEPSICOx588': 'Pepsico',
#  'HUMANAxx775': 'Humana',
#  'PRUDFIxx586': 'Prudential Financial',
#  'ARCHDAMI652': 'Archer Daniels Midland',
#  'ALBERTSO594': 'Albertsons',
#  'SYSCOxxx882': 'Sysco',
#  'LOCKMAxx674': 'Lockheed Martin',
#  'HPxxxxxx284': 'Hp',
#  'ENERTRxx209': 'Energy Transfer',
#  'GOLDSAGR475': 'Goldman Sachs Group',
#  'MORGSTxx576': 'Morgan Stanley',
#  'CATERPIL247': 'Caterpillar',
#  'CISCSYxx119': 'Cisco Systems',
#  'PFIZERxx605': 'Pfizer',
#  'HCAHExxx478': 'Hca Healthcare',
#  'AIGxxxxx683': 'Aig',
#  'AMEREXxx375': 'American Express',
#  'DELTAILI211': 'Delta Air Lines',
#  'MERCKxxx260': 'Merck',
#  'AMERAIGR543': 'American Airlines Group',
#  'CHARCOxx650': 'Charter Communications',
#  'ALLSTATE351': 'Allstate',
#  'NEWYOLIIN802': 'New York Life Insurance',
#  'NATIONWI656': 'Nationwide',
#  'BESTBUxx422': 'Best Buy',
#  'UNITAIHO228': 'United Airlines Holdings',
#  'LIBEMUIN527': 'Liberty Mutual Insurance Group',
#  'DOWxxxxx007': 'Dow',
#  'TYSOFOxx577': 'Tyson Foods',
#  'TJXxxxxx212': 'Tjx',
#  'TIAAxxxx742': 'Tiaa',
#  'ORACLExx518': 'Oracle',
#  'GENEDYxx510': 'General Dynamics',
#  'DEERExxx333': 'Deere',
#  'NIKExxxx582': 'Nike',
#  'PROGRESS266': 'Progressive',
#  'PUBLSUMA908': 'Publix Super Markets',
#  'COCACOLA862': 'Coca-cola',
#  'MASSMULI747': 'Massachusetts Mutual Life Insurance',
#  'TECHDAxx539': 'Tech Data',
#  'WORLFUSE643': 'World Fuel Services',
#  'HONEINxx591': 'Honeywell International',
#  'CONOCOPH991': 'Conocophillips',
#  'USAAxxxx133': 'Usaa',
#  'EXELONxx486': 'Exelon',
#  'NORTGRxx874': 'Northrop Grumman',
#  'CAPIONFI557': 'Capital One Financial',
#  'PLAIGPHO974': 'Plains Gp Holdings',
#  'ABBVIExx362': 'Abbvie',
#  'STONGRxx795': 'Stonex Group',
#  'ENTEPRPA113': 'Enterprise Products Partners',
#  'NORTMUxx767': 'Northwestern Mutual',
#  '3Mxxxxxx435': '3m',
#  'ABBOLAxx289': 'Abbott Laboratories',
#  'CHSxxxxx030': 'Chs',
#  'TRAVELER287': 'Travelers',
#  'PHILMOIN103': 'Philip Morris International',
#  'RAYTHEON710': 'Raytheon',
#  'HEWLPAEN335': 'Hewlett Packard Enterprise',
#  'ARROELxx236': 'Arrow Electronics',
#  'VIACOMCB264': 'Viacomcbs',
#  'DOLLGExx184': 'Dollar General',
#  'USBAxxxx875': 'U.s. Bancorp',
#  'STARBUCK638': 'Starbucks',
#  'BRISSQxx876': 'Bristol-myers Squibb',
#  'USFOHOxx210': 'Us Foods Holding',
#  'MONDINxx806': 'Mondelez International',
#  'PACCARxx487': 'Paccar',
#  'THERFISC452': 'Thermo Fisher Scientific',
#  'MACYSxxx303': "Macy's",
#  'JABILxxx073': 'Jabil',
#  'KRAFHExx518': 'Kraft Heinz',
#  'DUKEENxx887': 'Duke Energy',
#  'TESLAxxx694': 'Tesla',
#  'PBFENxxx290': 'Pbf Energy',
#  'QUALCOMM409': 'Qualcomm',
#  'NGLENPAx309': 'Ngl Energy Partners',
#  'CBREGRxx526': 'Cbre Group',
#  'BAKEHUxx230': 'Baker Hughes',
#  'SYNNEXxx397': 'Synnex',
#  'DOLLTRxx175': 'Dollar Tree',
#  'CUMMINSx296': 'Cummins',
#  'UNITNAFO256': 'United Natural Foods',
#  'MICRTExx291': 'Micron Technology',
#  'AMGENxxx015': 'Amgen',
#  'PENSAUGR259': 'Penske Automotive Group',
#  'VISAxxxx210': 'Visa',
#  'BROADCOM507': 'Broadcom',
#  'NUCORxxx986': 'Nucor',
#  'GILESCxx934': 'Gilead Sciences',
#  'SOUTAIxx291': 'Southwest Airlines',
#  'HALLIBUR923': 'Halliburton',
#  'CENTURYL196': 'Centurylink',
#  'INTEPAxx166': 'International Paper',
#  'ELILIxxx793': 'Eli Lilly',
#  'AFLACxxx475': 'Aflac',
#  'LENNARxx290': 'Lennar',
#  'OCCIPExx270': 'Occidental Petroleum',
#  'UNIOPAxx481': 'Union Pacific',
#  'RITEAIxx832': 'Rite Aid',
#  'PNCFISEGR944': 'Pnc Financial Services Group',
#  'DUPONTxx762': 'Dupont',
#  'SOUTHERN802': 'Southern',
#  'AUTONATI030': 'Autonation',
#  'DXCTExxx180': 'Dxc Technology',
#  'MCDONALD120': "Mcdonald's",
#  'MARRINxx682': 'Marriott International',
#  'MANPOWER948': 'Manpowergroup',
#  'BANKOFNE581': 'Bank Of New York Mellon',
#  'HARTFISE446': 'Hartford Financial Services Group',
#  'DANAHERx509': 'Danaher',
#  'WHIRLPOO583': 'Whirlpool',
#  'AECOMxxx190': 'Aecom',
#  'NETFLIXx656': 'Netflix',
#  'KOHLSxxx418': "Kohl's",
#  'LEARxxxx803': 'Lear',
#  'ALTRGRxx410': 'Altria Group',
#  'PERFFOGR718': '\nperformance Food Group',
#  'AVNETxxx594': 'Avnet',
#  'SYNCFIxx189': 'Synchrony Financial',
#  'GENUPAxx705': 'Genuine Parts',
#  'NEXTENxx839': 'Nextera Energy',
#  'CARMAXxx678': 'Carmax',
#  'TENEHExx763': 'Tenet Healthcare',
#  'KIMBERLY848': 'Kimberly-clark',
#  'EMERELxx728': 'Emerson Electric',
#  'WESTROCK513': 'Westrock',
#  'CDWxxxxx169': 'Cdw',
#  'JONELALA233': 'Jones Lang Lasalle',
#  'SHERWINW571': 'Sherwin-williams',
#  'FLUORxxx352': 'Fluor',
#  'PAYPHOxx347': 'Paypal Holdings',
#  'DRHOxxxx387': 'D.r. Horton',
#  'HOLLYFRO702': 'Hollyfrontier',
#  'TENNECOx184': 'Tenneco',
#  'EOGRExxx133': 'Eog Resources',
#  'BECTDIxx252': 'Becton Dickinson',
#  'LINCNAxx635': 'Lincoln National',
#  'PGExxxxx335': 'Pg&e',
#  'SALESFOR413': 'Salesforce.com',
#  'MASTERCA887': 'Mastercard',
#  'GENEMIxx668': 'General Mills',
#  'MOLIHExx738': 'Molina Healthcare',
#  'COGNTESO622': 'Cognizant Technology Solutions',
#  'MARSMCxx289': 'Marsh & Mclennan',
#  'XPOLOxxx756': 'Xpo Logistics',
#  'DOMIENxx391': 'Dominion Energy',
#  'WESTDIxx080': 'Western Digital',
#  'GAPxxxxx960': 'Gap',
#  'ARAMARKx791': 'Aramark',
#  'PRINFIxx472': 'Principal Financial',
#  'ROSSSTxx629': '\nross Stores',
#  'COLGATEP713': 'Colgate-palmolive',
#  'AMERELPO450': 'American Electric Power',
#  'NORDSTRO748': 'Nordstrom',
#  'JACOENGR641': 'Jacobs Engineering Group',
#  'WASTMAxx347': 'Waste Management',
#  'CHROWOxx812': 'C.h. Robinson Worldwide',
#  'PPGINxxx462': 'Ppg Industries',
#  'BOOKHOxx424': 'Booking Holdings',
#  'OMNIGRxx400': 'Omnicom Group',
#  'LOEWSxxx903': 'Loews',
#  'ECOLABxx500': 'Ecolab',
#  'STRYKERx687': 'Stryker',
#  'ESTELAxx274': 'Estee Lauder',
#  'GOODTIRU273': 'Goodyear Tire & Rubber',
#  'TRUIFIxx801': 'Truist Financial',
#  'APPLMAxx761': 'Applied Materials',
#  'BLACKROC748': 'Blackrock',
#  'STANBLDE841': 'Stanley Black & Decker',
#  'FREEPORT548': 'Freeport-mcmoran',
#  'TEXAINxx514': 'Texas Instruments',
#  'BIOGENxx544': 'Biogen',
#  'PARKERHA315': 'Parker-hannifin',
#  'REINGROF623': 'Reinsurance Group Of America',
#  'HOWMAExx933': 'Howmet Aerospace',
#  'AUTODAPR105': 'Automatic Data Processing',
#  'UBERTExx272': 'Uber Technologies',
#  'ILLITOWO231': 'Illinois Tool Works',
#  'DAVITAxx424': 'Davita',
#  'DISCFISE418': 'Discover Financial Services',
#  'LANDOLxx121': "Land O'lakes",
#  'VFxxxxxx468': 'Vf',
#  'CORTEVAx880': 'Corteva',
#  'LASVESAx773': 'Las Vegas Sands',
#  'TEXTRONx233': 'Textron',
#  'KELLOGGx518': 'Kellogg',
#  'GUARLIIN903': 'Guardian Life Ins. Co. Of America',
#  'QURARExx223': 'Qurate Retail',
#  'COREHOxx495': 'Core-mark Holding',
#  'COMMHESY153': 'Community Health Systems',
#  'KINDMOxx143': 'Kinder Morgan',
#  'BJSWHCLx190': "Bj's Wholesale Club",
#  'STATSTxx695': 'State Street',
#  'AMERFIxx793': 'Ameriprise Financial',
#  'GLOBPAxx806': 'Global Partners',
#  'UNITSTST575': 'United States Steel',
#  'LBRxxxxx749': 'L Brands',
#  'MGMREINx740': 'Mgm Resorts International',
#  'L3HATExx167': 'L3harris Technologies',
#  'DISHNExx008': 'Dish Network',
#  'LITHMOxx533': 'Lithia Motors',
#  'DTEENxxx234': 'Dte Energy',
#  'AMERFAIN323': 'American Family Insurance Group',
#  'FARMINEX845': 'Farmers Insurance Exchange',
#  'CONSEDxx869': 'Consolidated Edison',
#  'LKQxxxxx087': 'Lkq',
#  'SEMPENxx496': 'Sempra Energy',
#  'EDISINxx571': 'Edison International',
#  'CENTENxx269': 'Centerpoint Energy',
#  'QUANSExx632': 'Quanta Services',
#  'MURPUSxx131': 'Murphy Usa',
#  'EXPEGRxx695': 'Expedia Group',
#  'GROU1AUx338': 'Group 1 Automotive',
#  'BEDBABEx609': 'Bed Bath & Beyond',
#  'UNUMGRxx294': 'Unum Group',
#  'CSXxxxxx648': 'Csx',
#  'AUTOZONE050': 'Autozone',
#  'PACILIxx307': 'Pacific Life',
#  'VISTENxx267': 'Vistra Energy',
#  'CHARSCxx764': 'Charles Schwab',
#  'CROWHOxx621': 'Crown Holdings',
#  'ALLYFIxx633': 'Ally Financial',
#  'LABOCOOF235': 'Laboratory Corp. Of America',
#  'LIVENAEN269': 'Live Nation Entertainment',
#  'XCELENxx879': 'Xcel Energy',
#  'CORNINGx712': 'Corning',
#  'WWGRxxxx828': 'W.w. Grainger',
#  'BALLxxxx270': 'Ball',
#  'FOXxxxxx247': 'Fox',
#  'UNIVHESE899': 'Universal Health Services',
#  'BAXTINxx412': 'Baxter International',
#  'NORFSOxx312': 'Norfolk Southern',
#  'NAVIINxx549': 'Navistar International',
#  'ADOBExxx938': 'Adobe',
#  'JCPExxxx710': 'J.c. Penney',
#  'DISCOVER824': 'Discovery',
#  'KEURDRPE138': 'Keurig Dr Pepper',
#  'LEIDHOxx961': 'Leidos Holdings',
#  'IQVIHOxx242': 'Iqvia Holdings',
#  'RELISTAL918': 'Reliance Steel & Aluminum',
#  'NVIDIAxx575': 'Nvidia',
#  'ENTERGYx160': 'Entergy',
#  'FIRSTENE678': 'Firstenergy',
#  'EBAYxxxx851': 'Ebay',
#  'BOSTSCxx208': 'Boston Scientific',
#  'OFFIDExx703': 'Office Depot',
#  'MOLSCOBE119': 'Molson Coors Beverage',
#  'STEEDYxx605': 'Steel Dynamics',
#  'MUTUOFOM493': 'Mutual Of Omaha Insurance',
#  'SONIAUxx146': 'Sonic Automotive',
#  'ALCOAxxx484': 'Alcoa',
#  'FIDENAIN911': 'Fidelity National Information Services',
#  'HENRSCxx381': 'Henry Schein',
#  'REPUSExx708': 'Republic Services',
#  'LIBEMExx602': 'Liberty Media',
#  'PETEKISO322': "Peter Kiewit Sons'",
#  'INTEGRxx776': 'Interpublic Group',
#  'PULTEGRO480': 'Pultegroup',
#  'AESxxxxx965': 'Aes',
#  'FISERVxx073': 'Fiserv',
#  'BORGWARN745': 'Borgwarner',
#  'ONEOKxxx234': 'Oneok',
#  'OREIAUxx382': "O'reilly Automotive",
#  'ASSURANT661': 'Assurant',
#  'NEWEBRxx677': 'Newell Brands',
#  'PUBLSEEN276': 'Public Service Enterprise Group',
#  'NEWSCOxx950': 'News Corp.',
#  'CALPINEx555': 'Calpine',
#  'AUTOINxx353': 'Auto-owners Insurance',
#  'MOHAINxx887': 'Mohawk Industries',
#  'PVHxxxxx170': 'Pvh',
#  'CAMPSOxx008': 'Campbell Soup',
#  'NRGENxxx230': 'Nrg Energy',
#  'FIFTTHBA292': 'Fifth Third Bancorp',
#  'HERTGLHO776': 'Hertz Global Holdings',
#  'ALTIUSxx170': 'Altice Usa',
#  'NEWMONTx494': 'Newmont',
#  'CHENENxx186': 'Cheniere Energy',
#  'ADVAAUPA276': 'Advance Auto Parts',
#  'LAMRExxx253': 'Lam Research',
#  'OWENMIxx604': 'Owens & Minor',
#  'EQUIHOxx500': 'Equitable Holdings',
#  'CONABRxx459': 'Conagra Brands',
#  'MARKELxx081': 'Markel',
#  'JONEFIED202': 'Jones Financial (edward Jones)',
#  'HORMFOxx680': 'Hormel Foods',
#  'HILTWOHO884': 'Hilton Worldwide Holdings',
#  'UNIVSOxx773': 'Univar Solutions',
#  'UNITRExx404': 'United Rentals',
#  'PIONNARE942': 'Pioneer Natural Resources',
#  'DELEUSHO166': 'Delek Us Holdings',
#  'EASTCHxx624': 'Eastman Chemical',
#  'EMCOGRxx764': 'Emcor Group',
#  'AVISBUGR178': 'Avis Budget Group',
#  'JBHUTRSE572': 'J.b. Hunt Transport Services',
#  'XEROHOxx753': 'Xerox Holdings',
#  'WAYFAIRx443': 'Wayfair',
#  'KKRxxxxx868': 'Kkr',
#  'AGCOxxxx670': 'Agco',
#  'ALLEGHAN718': 'Alleghany',
#  'ICAHENxx678': 'Icahn Enterprises',
#  'VOYAFIxx816': 'Voya Financial',
#  'RYDESYxx494': 'Ryder System',
#  'AIRPRCHx562': 'Air Products & Chemicals',
#  'MOSAICxx201': 'Mosaic',
#  'HUNTININ174': 'Huntington Ingalls Industries',
#  'BERRGLGR714': 'Berry Global Group',
#  'ANIXINxx295': 'Anixter International',
#  'ALASAIGR589': 'Alaska Air Group',
#  'YUMCHHOx490': 'Yum China Holdings',
#  'DICKSPGO057': "Dick's Sporting Goods",
#  'CAESENxx454': 'Caesars Entertainment',
#  'GENWFIxx697': 'Genworth Financial',
#  'TARGRExx910': 'Targa Resources',
#  'COTYxxxx599': 'Coty',
#  'DANAxxxx578': 'Dana',
#  'THRIFIFO125': 'Thrivent Financial For Lutherans',
#  'AUTOLIVx361': 'Autoliv',
#  'SPARTANN411': 'Spartannash',
#  'EVERENxx121': 'Eversource Energy',
#  'DARDRExx514': 'Darden Restaurants',
#  'CHESENxx986': 'Chesapeake Energy',
#  'NATIOIVA333': 'National Oilwell Varco',
#  'FIDENAFI764': 'Fidelity National Financial',
#  'ERIEINGR861': 'Erie Insurance Group',
#  'OSHKOSHx673': 'Oshkosh',
#  'CASEGEST064': "Casey's General Stores",
#  'WESCINxx383': 'Wesco International',
#  'TRACSUxx907': 'Tractor Supply',
#  'COMMHOxx720': 'Commscope Holding',
#  'HUNTSMAN311': 'Huntsman',
#  'AMERFIGR699': 'American Financial Group',
#  'MASCOxxx274': 'Masco',
#  'SANMINAx635': 'Sanmina',
#  'AMPHENOL933': 'Amphenol',
#  'WILLIAMS799': 'Williams',
#  'WESTAIBR609': 'Westinghouse Air Brake',
#  'EXPEINOF539': 'Expeditors Intl. Of Washington',
#  'ANDERSON771': 'Andersons',
#  'WESTCHxx380': 'Westlake Chemical',
#  'CONSBRxx472': 'Constellation Brands',
#  'FRONCOxx626': 'Frontier Communications',
#  'JETBAIxx117': 'Jetblue Airways',
#  'CITIFIGR670': 'Citizens Financial Group',
#  'RAYMJAFI181': 'Raymond James Financial',
#  'FOOTLOxx518': 'Foot Locker',
#  'HERSHEYx347': 'Hershey',
#  'ZIMMBIHO542': 'Zimmer Biomet Holdings',
#  'CINCFIxx053': 'Cincinnati Financial',
#  'WESTSOFI129': 'Western & Southern Financial Group',
#  'WRBExxxx598': 'W.r. Berkley',
#  'MOTOSOxx281': 'Motorola Solutions',
#  'THORINxx167': 'Thor Industries',
#  'REGEPHxx756': 'Regeneron Pharmaceuticals',
#  'SPIRAEHO383': 'Spirit Aerosystems Holdings',
#  'JMSMxxxx216': 'J.m. Smucker',
#  'PPLxxxxx696': 'Ppl',
#  'INSIENxx218': 'Insight Enterprises',
#  'QUESDIxx507': 'Quest Diagnostics',
#  'KEYCORPx617': 'Keycorp',
#  'VERITIVx748': 'Veritiv',
#  'DCPMIxxx132': 'Dcp Midstream',
#  'AMERTOxx478': 'American Tower',
#  'GRAYELxx124': 'Graybar Electric',
#  'WECENGRx107': 'Wec Energy Group',
#  'NVRxxxxx438': 'Nvr',
#  'ULTABExx444': 'Ulta Beauty',
#  'DEVOENxx385': 'Devon Energy',
#  'BLACGRxx583': 'Blackstone Group',
#  'DEANFOxx682': 'Dean Foods',
#  'FORTIVEx866': 'Fortive',
#  'UGIxxxxx470': 'Ugi',
#  'BURLSTxx275': 'Burlington Stores',
#  'BUILFIxx648': 'Builders Firstsource',
#  'TOLLBRxx676': 'Toll Brothers',
#  'OLDREINx444': 'Old Republic International',
#  'ASBUAUGR211': 'Asbury Automotive Group',
#  'ARTHJGAx747': 'Arthur J. Gallagher',
#  'MASTECxx963': 'Mastec',
#  'OWENCOxx375': 'Owens Corning',
#  'MAGEHExx434': 'Magellan Health',
#  'DOVERxxx822': 'Dover',
#  'BEACROSU069': 'Beacon Roofing Supply',
#  'AVERDExx646': 'Avery Dennison',
#  'HANESBRA569': 'Hanesbrands',
#  'PACKCOOF711': 'Packaging Corp. Of America',
#  'MTBAxxxx993': 'M&t Bank',
#  'NCRxxxxx861': 'Ncr',
#  'NORTTRxx806': 'Northern Trust',
#  'CINTASxx658': 'Cintas',
#  'POLARISx224': 'Polaris',
#  'CMSENxxx771': 'Cms Energy',
#  'SEABOARD341': 'Seaboard',
#  'INTUITxx659': 'Intuit',
#  'REGIFIxx109': 'Regions Financial',
#  'FMGLxxxx888': 'Fm Global',
#  'ADVAMIDE386': 'Advanced Micro Devices',
#  'OVINTIVx246': 'Ovintiv',
#  'BOOZALHA372': 'Booz Allen Hamilton Holding',
#  'SPGLxxxx545': 'S&p Global',
#  'ROCKAUxx265': 'Rockwell Automation',
#  'OIGLxxxx259': 'O-i Glass',
#  'WYNNRExx591': 'Wynn Resorts',
#  'SECUFIGR263': 'Securian Financial Group',
#  'ALLIDASY205': 'Alliance Data Systems',
#  'WEYERHAE116': 'Weyerhaeuser',
#  'BRIGFIxx121': 'Brighthouse Financial',
#  'INTEEXxx248': 'Intercontinental Exchange',
#  'AMERAXMA526': 'American Axle & Manufacturing',
#  'HESSxxxx539': 'Hess',
#  'ABMINxxx453': 'Abm Industries',
#  'ACTIBLxx583': 'Activision Blizzard',
#  'GAMESTOP394': 'Gamestop',
#  'APACHExx774': 'Apache',
#  'SCIEAPIN421': 'Science Applications International',
#  'AKSTHOxx012': 'Ak Steel Holding',
#  'DILLARDS860': "Dillard's",
#  'RALPLAxx236': 'Ralph Lauren',
#  'CELANESE856': 'Celanese',
#  'RRDOSOxx912': 'R.r. Donnelley & Sons',
#  'ZOETISxx110': 'Zoetis',
#  'ASCEREGR823': 'Ascena Retail Group',
#  'CLOROXxx762': 'Clorox',
#  'INGREDIO312': 'Ingredion',
#  'FIRSAMFI526': 'First American Financial',
#  'GRAPPAHO792': 'Graphic Packaging Holding',
#  'NETAPPxx905': 'Netapp',
#  'HDSUHOxx353': 'Hd Supply Holdings',
#  'TRAVOFAM125': 'Travelcenters Of America',
#  'OLINxxxx444': 'Olin',
#  'ROBEHAIN583': 'Robert Half International',
#  'ENLIMIxx685': 'Enlink Midstream',
#  'AVANTORx428': 'Avantor',
#  'TAPESTRY321': 'Tapestry',
#  'TDAMHOxx454': 'Td Ameritrade Holding',
#  'ANALDExx620': 'Analog Devices',
#  'AMERENxx079': 'Ameren',
#  'WILLIAMS378': 'Williams-sonoma',
#  'REALHOxx499': 'Realogy Holdings',
#  'COMMMExx268': 'Commercial Metals',
#  'RUSHENxx418': 'Rush Enterprises',
#  'FRANRExx201': 'Franklin Resources',
#  'FORTBRHO255': 'Fortune Brands Home & Security',
#  'LEVISTxx274': 'Levi Strauss',
#  'CROWCAIN234': 'Crown Castle International',
#  'SIMOPRGR444': 'Simon Property Group',
#  'CERNERxx511': 'Cerner',
#  'POSTHOxx198': 'Post Holdings',
#  'HUNTBAxx824': 'Huntington Bancshares',
#  'KBRxxxxx512': 'Kbr',
#  'SPROFAMA857': 'Sprouts Farmers Market',
#  'LPLFIHOx671': 'Lpl Financial Holdings',
#  'TROPRxxx237': 'T. Rowe Price',
#  'YUMBRxxx533': 'Yum Brands',
#  'CHIPMEGR177': 'Chipotle Mexican Grill',
#  'PATTERSO890': 'Patterson',
#  'RPMINxxx231': 'Rpm International',
#  'EQUINIXx203': 'Equinix',
#  'NAVIENTx180': 'Navient',
#  'CHEMOURS457': 'Chemours',
#  'ONSExxxx170': 'On Semiconductor',
#  'TRANGRxx269': 'Transdigm Group',
#  'HOSTHORE390': 'Host Hotels & Resorts',
#  'SELEMEHO300': 'Select Medical Holdings',
#  'PARPAHOx118': 'Par Pacific Holdings',
#  'SONOPRxx805': 'Sonoco Products',
#  'ROPETExx464': 'Roper Technologies',
#  'HARLEYDA846': 'Harley-davidson',
#  'JEFFFIGR147': 'Jefferies Financial Group',
#  'KELLSExx899': 'Kelly Services',
#  'MICRTExx570': 'Microchip Technology',
#  'MCCORMIC220': 'Mccormick',
#  'MDUREGRx673': 'Mdu Resources Group',
#  'FASTENAL796': 'Fastenal',
#  'BIGLOxxx379': 'Big Lots',
#  'PENNNAGA782': 'Penn National Gaming',
#  'WESTUNxx506': 'Western Union',
#  'UNDEARxx540': 'Under Armour',
#  'XYLEMxxx120': 'Xylem',
#  'SKECUSxx614': 'Skechers U.s.a.',
#  'DOMTARxx021': 'Domtar',
#  'NISOURCE483': 'Nisource',
#  'MARAOIxx421': 'Marathon Oil',
#  'NATIGEHO585': 'National General Holdings',
#  'TELEDASY376': 'Telephone & Data Systems',
#  'AGILTExx073': 'Agilent Technologies',
#  'AMETEKxx470': 'Ametek',
#  'EVERGYxx529': 'Evergy',
#  'INTEFLFR808': 'International Flavors & Fragrances',
#  'ADTxxxxx517': 'Adt',
#  'WELLTOWE197': 'Welltower',
#  'WINDHOxx735': 'Windstream Holdings',
#  'MICHAELS384': 'Michaels',
#  'KEMPERxx499': 'Kemper',
#  'HYATHOxx481': 'Hyatt Hotels',
#  'ALEXPHxx584': 'Alexion Pharmaceuticals',
#  'RESITExx252': 'Resideo Technologies',
#  'CACIINxx921': 'Caci International',
#  'ELECARxx579': 'Electronic Arts',
#  'VULCMAxx611': 'Vulcan Materials',
#  'TREEFOxx897': 'Treehouse Foods',
#  'GLOBPAxx504': 'Global Payments',
#  'HANOINGR253': 'Hanover Insurance Group',
#  'CAMPWOHO743': 'Camping World Holdings',
#  'CORNBUBR891': 'Cornerstone Building Brands',
#  'YRCWOxxx720': 'Yrc Worldwide',
#  'CMEGRxxx883': 'Cme Group',
#  'CHEWYxxx120': 'Chewy',
#  'KNIGTRHO574': 'Knight-swift Transportation Holdings',
#  'MOODYSxx203': "Moody's",
#  'COCACOxx435': 'Coca-cola Consolidated',
#  'CARLISLE853': 'Carlisle',
#  'SEALAIxx066': 'Sealed Air',
#  'AMARPRME561': 'A-mark Precious Metals',
#  'WATSCOxx110': 'Watsco',
#  'TAYLMOHO143': 'Taylor Morrison Home',
#  'IACINTER742': 'Iac/interactivecorp',
#  'LEGGPLxx606': 'Leggett & Platt',
#  'ONEMHOxx201': 'Onemain Holdings',
#  'SCHNNAxx609': 'Schneider National',
#  'MARTMAMA808': 'Martin Marietta Materials',
#  'NORTONLI678': 'Nortonlifelock',
#  'HASBROxx146': 'Hasbro',
#  'SQUARExx397': 'Square',
#  'TEREXxxx161': 'Terex',
#  'SYNEHExx632': 'Syneos Health',
#  'FMCxxxxx846': 'Fmc',
#  'BOISCAxx822': 'Boise Cascade',
#  'SSCTEHOx756': 'Ss&c Technologies Holdings',
#  'CONTRExx813': 'Continental Resources',
#  'PEABENxx387': 'Peabody Energy',
#  'ENCOHExx641': 'Encompass Health',
#  'GREIFxxx584': 'Greif',
#  'CONCRExx455': 'Concho Resources',
#  'HUBBELLx441': 'Hubbell',
#  'CFINHOxx664': 'Cf Industries Holdings',
#  'KLAxxxxx705': 'Kla',
#  'GENEHExx346': 'Genesis Healthcare',
#  'BRUNSWIC648': 'Brunswick',
#  'KBHOxxxx739': 'Kb Home',
#  'GLOBLIxx432': 'Globe Life',
#  'MATTELxx179': 'Mattel',
#  'RYERHOxx516': 'Ryerson Holding',
#  'SILGHOxx421': 'Silgan Holdings',
#  'ZEBRTExx181': 'Zebra Technologies',
#  'INTUSUxx239': 'Intuitive Surgical',
#  'WARNMUGR380': 'Warner Music Group',
#  'CONDUENT579': 'Conduent',
#  'TUTOPExx316': 'Tutor Perini',
#  'JUNINExx770': 'Juniper Networks',
#  'NOBLENxx023': 'Noble Energy',
#  'VERTHOxx030': 'Vertiv Holdings',
#  'TIFFANYx579': 'Tiffany',
#  'EQTxxxxx872': 'Eqt',
#  'UFPINxxx561': 'Ufp Industries',
#  'DIEBNIxx880': 'Diebold Nixdorf',
#  'ANTERExx806': 'Antero Resources',
#  'MERITORx648': 'Meritor',
#  'BROAFISO788': 'Broadridge Financial Solutions',
#  'CHURDWxx149': 'Church & Dwight',
#  'MARRVAWO454': 'Marriott Vacations Worldwide',
#  'EDWALIxx168': 'Edwards Lifesciences',
#  'COLFAXxx398': 'Colfax',
#  'INSPERIT698': 'Insperity',
#  'AMEREAOU703': 'American Eagle Outfitters',
#  'KEYSTExx893': 'Keysight Technologies',
#  'JELDHOxx624': 'Jeld-wen Holding',
#  'IRONMOxx463': 'Iron Mountain',
#  'NASDAQxx319': 'Nasdaq',
#  'GARTNERx216': 'Gartner',
#  'SINCBRGR307': 'Sinclair Broadcast Group',
#  'INGLMAxx772': 'Ingles Markets',
#  'MONSBExx417': 'Monster Beverage',
#  'MURPOIxx316': 'Murphy Oil',
#  'VERTPHxx485': 'Vertex Pharmaceuticals',
#  'FIRSREBA344': 'First Republic Bank',
#  'BLOOBRxx105': "Bloomin' Brands",
#  'SPECBRHO903': 'Spectrum Brands Holdings',
#  'QUADGRAP484': 'Quad/graphics',
#  'FLOWFOxx802': 'Flowers Foods',
#  'CUNAMUGR710': 'Cuna Mutual Group',
#  'ALLETExx976': 'Allegheny Technologies',
#  'OLDDOFRLI045': 'Old Dominion Freight Line',
#  'LANDSYxx835': 'Landstar System',
#  'AMERNAIN107': 'American National Insurance',
#  'SNAPONxx552': 'Snap-on',
#  'BROOSELI522': 'Brookdale Senior Living',
#  'AMKOTExx465': 'Amkor Technology',
#  'WYNDDExx881': 'Wyndham Destinations',
#  'PPDxxxxx240': 'Ppd',
#  'DENTSIxx441': 'Dentsply Sirona',
#  'CNOFIGRx523': 'Cno Financial Group',
#  'URBAOUxx010': 'Urban Outfitters',
#  'SABRExxx650': 'Sabre',
#  'MERCGExx879': 'Mercury General',
#  'DIAMENxx641': 'Diamondback Energy',
#  'PARSONSx535': 'Parsons',
#  'AARONSxx301': "Aaron's",
#  'FLOWSERV614': 'Flowserve',
#  'CARVANAx060': 'Carvana',
#  'ASGNxxxx258': 'Asgn',
#  'SALLBEHO195': 'Sally Beauty Holdings',
#  'SCANSOUR395': 'Scansource',
#  'VENTASxx757': 'Ventas',
#  'COUNFIxx100': 'Country Financial',
#  'TRINGRxx738': 'Trinet Group',
#  'SPIRAIxx115': 'Spirit Airlines',
#  'COMERICA378': 'Comerica',
#  'LENNINxx461': 'Lennox International',
#  'TIMKENxx137': 'Timken',
#  'PAYCHEXx580': 'Paychex',
#  'AMERCOxx873': 'Amerco',
#  'WORTINxx701': 'Worthington Industries',
#  'LAMBWEHO367': 'Lamb Weston Holdings',
#  'LAUREDxx032': 'Laureate Education',
#  'PENNMULI048': 'Penn Mutual Life Insurance',
#  'IHEARTME509': 'Iheartmedia',
#  'BRINKSxx145': "Brink's",
#  'SENTINGR194': 'Sentry Insurance Group',
#  'ACUIBRxx900': 'Acuity Brands',
#  'HUBGRxxx429': 'Hub Group',
#  'MERIHOxx277': 'Meritage Homes',
#  'MRCGLxxx632': 'Mrc Global',
#  'ALLIENxx211': 'Alliant Energy',
#  'WORKDAYx907': 'Workday',
#  'BMCSTHOx168': 'Bmc Stock Holdings',
#  'ABERFIxx490': 'Abercrombie & Fitch',
#  'DOMIPIxx716': "Domino's Pizza",
#  'LYFTxxxx667': 'Lyft',
#  'MEREDITH552': 'Meredith',
#  'AMERWAWO400': 'American Water Works',
#  'ALBEMARL801': 'Albemarle',
#  'CIENAxxx367': 'Ciena',
#  'BARNNOxx431': 'Barnes & Noble',
#  'WEISMAxx870': 'Weis Markets',
#  'ILLUMINA303': 'Illumina',
#  'SVBFIGRx515': 'Svb Financial Group',
#  'CARTERSx373': "Carter's",
#  'STIFFIxx860': 'Stifel Financial',
#  'MEDNAXxx659': 'Mednax',
#  'EQUIFAXx588': 'Equifax',
#  'KARAUSEx168': 'Kar Auction Services',
#  'ASHLGLHO378': 'Ashland Global Holdings',
#  'MEDIMUOF778': 'Medical Mutual Of Ohio',
#  'SPRARExx235': 'Sprague Resources',
#  'SUPEMICO668': 'Super Micro Computer',
#  'DESIBRxx457': 'Designer Brands',
#  'PITNBOxx369': 'Pitney Bowes',
#  'APPLINTE365': 'Applied Industrial Technologies',
#  'PINNWECA383': 'Pinnacle West Capital',
#  'AMEREQIN365': 'American Equity Investment Life Holding',
#  'SERVICEN635': 'Servicenow',
#  'TWITTERx540': 'Twitter',
#  'CALUSPPR869': 'Calumet Specialty Products Partners',
#  'STEELCAS546': 'Steelcase',
#  'SANDFAxx020': 'Sanderson Farms',
#  'WABCHOxx832': 'Wabco Holdings',
#  'CLEAHAxx984': 'Clean Harbors',
#  'PUGEENxx475': 'Puget Energy',
#  'SCIEGAxx863': 'Scientific Games',
#  'GRANCOxx622': 'Granite Construction',
#  'CARLGRxx457': 'Carlyle Group',
#  'SKYWSOxx572': 'Skyworks Solutions',
#  'ALERISxx779': 'Aleris',
#  'TRIPMAxx152': 'Triple-s Management',
#  'HEXIONxx471': 'Hexion',
#  'HOLOGICx222': 'Hologic',
#  'TRIUGRxx812': 'Triumph Group',
#  'DARLINxx249': 'Darling Ingredients',
#  'MSCINDIx264': 'Msc Industrial Direct',
#  'REDHAxxx900': 'Red Hat',
#  'SYNOPSYS079': 'Synopsys',
#  'POLYONEx204': 'Polyone',
#  'DYCOINxx689': 'Dycom Industries',
#  'CABOTxxx830': 'Cabot',
#  'PROLOGIS276': 'Prologis',
#  'BOYDGAxx659': 'Boyd Gaming',
#  'LSCCOxxx768': 'Lsc Communications',
#  'BROWNFOR809': 'Brown-forman',
#  'STERICYC206': 'Stericycle',
#  'CITGRxxx767': 'Cit Group',
#  'MDCHOxxx512': 'Mdc Holdings',
#  'HYSTMAHA059': 'Hyster-yale Materials Handling',
#  'CRANExxx849': 'Crane',
#  'CINEHOxx056': 'Cinemark Holdings',
#  'AUTODESK737': 'Autodesk',
#  'TRIMBLEx140': 'Trimble',
#  'GARRMOxx888': 'Garrett Motion',
#  'ZIONBAxx716': 'Zions Bancorp.',
#  'REGABExx653': 'Regal Beloit',
#  'SERVCOIN323': 'Service Corp. International',
#  'VARIMESY972': 'Varian Medical Systems',
#  'PRICESMA899': 'Pricesmart',
#  'BRININxx396': 'Brinker International',
#  'DIGIRETR391': 'Digital Realty Trust',
#  'POOLCOxx120': 'Pool Corp',
#  'CRESEQPA003': 'Crestwood Equity Partners',
#  'INFORxxx359': 'Infor',
#  'PLEXUSxx386': 'Plexus',
#  'TELETExx783': 'Teledyne Technologies',
#  'GIIIAPGR561': 'G-iii Apparel Group',
#  'SCOTMIxx652': 'Scotts Miracle-gro',
#  'APOLGLMA878': 'Apollo Global Management',
#  'ETRAFIxx213': 'E*trade Financial',
#  'TOROxxxx577': 'Toro',
#  'SOUTGAHO237': 'Southwest Gas Holdings',
#  'GMSxxxxx911': 'Gms',
#  'COOPHOxx603': 'Cooper-standard Holdings',
#  'ACADHExx639': 'Acadia Healthcare',
#  'TETRTExx733': 'Tetra Tech',
#  'PRIMSExx731': 'Primoris Services',
#  'TEMPSEIN364': 'Tempur Sealy International',
#  'HRBLxxxx533': 'H&r Block',
#  'QORVOxxx909': 'Qorvo',
#  'TRIPOGRx153': 'Tri Pointe Group',
#  'CRACBAOL470': 'Cracker Barrel Old Country Store',
#  'ELANANHE908': 'Elanco Animal Health',
#  'PRAHESCx590': 'Pra Health Sciences',
#  'FIRSSOxx251': 'First Solar',
#  'AMCNExxx642': 'Amc Networks',
#  'XILINXxx624': 'Xilinx',
#  'GREEPLxx266': 'Green Plains',
#  'COLUSPxx730': 'Columbia Sportswear',
#  'NEXSMEGR231': 'Nexstar Media Group',
#  'SOUTENxx187': 'Southwestern Energy',
#  'GREENBRI437': 'Greenbrier',
#  'PRESIDIO437': 'Presidio',
#  'CITRSYxx930': 'Citrix Systems',
#  'METTINxx157': 'Mettler-toledo International',
#  'TRININxx785': 'Trinity Industries',
#  'MUTUOFAM398': 'Mutual Of America Life Insurance',
#  'LINCELHO317': 'Lincoln Electric Holdings',
#  'TAILBRxx634': 'Tailored Brands',
#  'AOSMxxxx105': 'A.o. Smith',
#  'ARCBESTx089': 'Arcbest',
#  'GODADDYx964': 'Godaddy',
#  'SKYWESTx489': 'Skywest',
#  'BOSTPRxx954': 'Boston Properties',
#  'ENABMIPA722': 'Enable Midstream Partners',
#  'MIDDLEBY888': 'Middleby',
#  'NOWxxxxx736': 'Now',
#  'UNISYSxx777': 'Unisys',
#  'VISTEONx134': 'Visteon',
#  'GRAHHOxx222': 'Graham Holdings',
#  'RESOFOPR440': 'Resolute Forest Products',
#  'CALERESx606': 'Caleres',
#  'AGNCINxx208': 'Agnc Investment',
#  'HILLHOxx413': 'Hill-rom Holdings',
#  'MOOGxxxx108': 'Moog',
#  'LEGGMAxx849': 'Legg Mason',
#  'ATMOENxx851': 'Atmos Energy',
#  'WOODWARD234': 'Woodward',
#  'PALOALNE554': 'Palo Alto Networks',
#  'HBFUxxxx547': 'H.b. Fuller',
#  'AKAMTExx757': 'Akamai Technologies',
#  'AVAYHOxx716': 'Avaya Holdings',
#  'MAXIMUSx991': 'Maximus',
#  'PERKINEL303': 'Perkinelmer',
#  'HAWAELIN675': 'Hawaiian Electric Industries',
#  'KANSCISO787': 'Kansas City Southern',
#  'APTARGRO554': 'Aptargroup',
#  'PUBLSTxx431': 'Public Storage',
#  'SELEINGR907': 'Selective Insurance Group',
#  'ITTxxxxx676': 'Itt',
#  'DONALDSO369': 'Donaldson',
#  'PARKHORE552': 'Park Hotels & Resorts',
#  'KIRBYxxx332': 'Kirby',
#  'HAWAHOxx200': 'Hawaiian Holdings',
#  'POPULARx606': 'Popular',
#  'RANGRExx773': 'Range Resources',
#  'PCCOxxxx833': 'Pc Connection',
#  'AMICMUIN826': 'Amica Mutual Insurance',
#  'ENERSYSx290': 'Enersys',
#  'HELMPAxx525': 'Helmerich & Payne',
#  'NLVFIxxx132': 'Nlv Financial',
#  'VALMINxx345': 'Valmont Industries',
#  'PAExxxxx763': 'Pae',
#  'TEXAROxx234': 'Texas Roadhouse',
#  'COOPTIRU223': 'Cooper Tire & Rubber',
#  'EUROWOxx173': 'Euronet Worldwide',
#  'ZILLGRxx524': 'Zillow Group',
#  'ATLAAIWO409': 'Atlas Air Worldwide Holdings',
#  'ENERHOxx742': 'Energizer Holdings',
#  'MAGEMIPA369': 'Magellan Midstream Partners',
#  'HAINCEGR900': 'Hain Celestial Group',
#  'UNIVCOxx398': 'Univision Communications',
#  'EQUIRExx753': 'Equity Residential',
#  'ALLITRHO465': 'Allison Transmission Holdings',
#  'COLOCAxx447': 'Colony Capital',
#  'TTMTExxx494': 'Ttm Technologies',
#  'CLEACHOU520': 'Clear Channel Outdoor Holdings',
#  'GUESSxxx799': 'Guess',
#  'RENTACEN160': 'Rent-a-center',
#  'TAKEINSO990': 'Take-two Interactive Software',
#  'VISHINxx165': 'Vishay Intertechnology',
#  'TRANSUNI581': 'Transunion',
#  'COOPERxx475': 'Cooper',
#  'FLEETExx922': 'Fleetcor Technologies',
#  'RHxxxxxx701': 'Rh',
#  'RENEENGR818': 'Renewable Energy Group',
#  'BLUEHOxx871': 'Bluelinx Holdings',
#  'CALIRExx305': 'California Resources',
#  'TOPBUILD229': 'Topbuild',
#  'CHARRILA342': 'Charles River Laboratories International',
#  'COMFSYUS399': 'Comfort Systems Usa',
#  'VERIANxx482': 'Verisk Analytics',
#  'RESMEDxx742': 'Resmed',
#  'TELEFLEX985': 'Teleflex',
#  'NEWJEREx104': 'New Jersey Resources',
#  'NEWREINx125': 'New Residential Investment',
#  'INTEBRGR636': 'Interactive Brokers Group',
#  'ZAYOGRHO489': 'Zayo Group Holdings',
#  'HERMMIxx885': 'Herman Miller',
#  'GROCOUHO644': 'Grocery Outlet Holding',
#  'JCREGRxx864': 'J.crew Group',
#  'CENTCOxx236': 'Century Communities',
#  'ELDORExx875': 'Eldorado Resorts',
#  'CATALENT276': 'Catalent',
#  'ITRONxxx830': 'Itron',
#  'MIHOxxxx449': 'M/i Homes',
#  'CBOEGLMA528': 'Cboe Global Markets',
#  'IDEXxxxx846': 'Idex',
#  'BELDENxx201': 'Belden',
#  'CURTISSW666': 'Curtiss-wright',
#  'CHEEFAxx314': 'Cheesecake Factory',
#  'GENEENxx270': 'Genesis Energy',
#  'GEOGRxxx981': 'Geo Group',
#  'PATTENxx190': 'Patterson-uti Energy',
#  'WERNENxx196': 'Werner Enterprises',
#  'INGERAxx933': 'Ingersoll Rand',
#  'VERSOxxx718': 'Verso',
#  'MUELINxx672': 'Mueller Industries',
#  'NUSKENxx243': 'Nu Skin Enterprises',
#  'REVLONxx957': 'Revlon',
#  'ARISNExx719': 'Arista Networks',
#  'IDEXLAxx362': 'Idexx Laboratories',
#  'ALIGTExx290': 'Align Technology',
#  'WATERSxx101': 'Waters',
#  'SYNOFIxx779': 'Synovus Financial',
#  'BRIGHOxx545': 'Brightview Holdings',
#  'REVGRxxx375': 'Rev Group',
#  'BROWBRxx583': 'Brown & Brown',
#  'VALVOLIN355': 'Valvoline',
#  'KNIGOFCO600': 'Knights Of Columbus',
#  'CENTGAPE032': 'Central Garden & Pet',
#  'CARPTExx850': 'Carpenter Technology',
#  'SLMCOxxx913': 'Slm Corp',
#  'KENNAMET419': 'Kennametal',
#  'LCIINxxx524': 'Lci Industries',
#  'TRUEBLUE278': 'Trueblue',
#  'CIMAENxx414': 'Cimarex Energy',
#  'SPLUNKxx432': 'Splunk',
#  'SITELASU591': 'Siteone Landscape Supply',
#  'HEXCELxx824': 'Hexcel',
#  'FTICOxxx581': 'Fti Consulting',
#  'PARTCIHO520': 'Party City Holdco',
#  'OHIONAMU163': 'Ohio National Mutual',
#  'PATRINxx396': 'Patrick Industries',
#  'CADEDESY680': 'Cadence Design Systems',
#  'CDKGLxxx168': 'Cdk Global',
#  'AVALCOxx134': 'Avalonbay Communities',
#  'WABANAxx896': 'Wabash National',
#  'SERVPRTR822': 'Service Properties Trust',
#  'MAXIINPR769': 'Maxim Integrated Products',
#  'PEOPUNFI515': "People's United Financial",
#  'BIORLAxx878': 'Bio-rad Laboratories',
#  'OPTICAHE241': 'Option Care Health',
#  'LOUISIAN230': 'Louisiana-pacific',
#  'TEGNAxxx411': 'Tegna',
#  'TERADYNE997': 'Teradyne',
#  'ARCHRExx595': 'Arch Resources',
#  'EPAMSYxx510': 'Epam Systems',
#  'WPXENxxx860': 'Wpx Energy',
#  'CONTENxx345': 'Contura Energy',
#  'ENSIGRxx153': 'Ensign Group',
#  'FIRSHONA431': 'First Horizon National',
#  'WOLVWOWI635': 'Wolverine World Wide',
#  'VAILRExx934': 'Vail Resorts',
#  'BENCELxx227': 'Benchmark Electronics',
#  'HNIxxxxx718': 'Hni',
#  'F5NExxxx915': 'F5 Networks',
#  'AFFIMAGR513': 'Affiliated Managers Group',
#  'OGEENxxx441': 'Oge Energy',
#  'UNIVCOxx625': 'Universal Corp',
#  'BOKFIxxx734': 'Bok Financial',
#  'MANTINxx743': 'Mantech International',
#  'SUMMMAxx834': 'Summit Materials',
#  'AMNHESEx047': 'Amn Healthcare Services',
#  'GROUPONx580': 'Groupon',
#  'NEWMGRxx599': 'Newmark Group',
#  'FOSSGRxx081': 'Fossil Group',
#  'MODIMAxx574': 'Modine Manufacturing',
#  'GRIFCOxx626': 'Griffon Corporation',
#  'CYPRSExx388': 'Cypress Semiconductor',
#  'GENEHOxx791': 'Generac Holdings',
#  'MATSONxx531': 'Matson',
#  'GENESCOx614': 'Genesco',
#  'NORDSONx008': 'Nordson',
#  'NEWMARKE217': 'Newmarket',
#  'ECHOGLLO734': 'Echo Global Logistics',
#  'REXNORDx118': 'Rexnord',
#  'INCYTExx746': 'Incyte',
#  'FORTINET651': 'Fortinet',
#  'FOUNBUMA783': 'Foundation Building Materials',
#  'AARxxxxx823': 'Aar',
#  'CENTBRxx188': 'Centric Brands',
#  'EDGEPECA844': 'Edgewell Personal Care',
#  'FEDEMUIN983': 'Federated Mutual Insurance',
#  'SCHNSTIN808': 'Schnitzer Steel Industries',
#  'PORTGEEL533': 'Portland General Electric',
#  'GRAYTExx012': 'Gray Television',
#  'BGCPAxxx721': 'Bgc Partners',
#  'ECHOSTAR223': 'Echostar',
#  'BEAZHOUS213': 'Beazer Homes Usa',
#  'LHCGRxxx174': 'Lhc Group',
#  'SERVGLHO247': 'Servicemaster Global Holdings',
#  'BRUKERxx689': 'Bruker',
#  'OASIPExx439': 'Oasis Petroleum',
#  'CROSPAxx829': 'Crossamerica Partners',
#  'MYRGRxxx739': 'Myr Group',
#  'VIASATxx717': 'Viasat',
#  'GNCHOxxx129': 'Gnc Holdings',
#  'CABOOIGA814': 'Cabot Oil & Gas',
#  'BRIGHOFA449': 'Bright Horizons Family Solutions',
#  'VISTOUxx086': 'Vista Outdoor',
#  'HEICOxxx762': 'Heico',
#  'WYNDHORE367': 'Wyndham Hotels & Resorts',
#  'TCFFIxxx343': 'Tcf Financial',
#  'PRIMERIC254': 'Primerica',
#  'PROPHOxx448': 'Propetro Holding',
#  'OCEAINxx487': 'Oceaneering International',
#  'FLOODEHO925': 'Floor & Decor Holdings',
#  'COPARTxx772': 'Copart',
#  'CHICFAxx502': "Chico's Fas",
#  'BARNNOED744': 'Barnes & Noble Education',
#  'MAXATExx800': 'Maxar Technologies',
#  'EVERCORE875': 'Evercore',
#  'DECKOUxx235': 'Deckers Outdoor',
#  'EXPRESSx859': 'Express',
#  'HOVNENxx567': 'Hovnanian Enterprises',
#  'AIRLExxx661': 'Air Lease',
#  'ROLLINSx781': 'Rollins',
#  'SBACOxxx434': 'Sba Communications',
#  'DELUXExx475': 'Deluxe',
#  'MRCOGRxx442': 'Mr. Cooper Group',
#  'HERCHOxx151': 'Herc Holdings',
#  'HEALPRxx387': 'Healthpeak Properties',
#  'SPXFLxxx610': 'Spx Flow',
#  'LIBEOISE438': 'Liberty Oilfield Services'}
