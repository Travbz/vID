# %%
import pandas as pd
'''
This script converts a column of names into unique IDs
'''  
try:
    df = pd.read_excel('company.xlsx')
    df.to_csv('company.csv', mode = 'w', index=False)
except:
    df = pd.read_csv('company.csv')
df
# Out:
#        Rank            Metals Industry  Number Of Employees Change In \n Rank  \
# 0       1.0                    Walmart            2200000.0                 -
# 1       2.0                 Amazon.com             798000.0               3.0
# 2       3.0                Exxon Mobil              74900.0              -1.0
# 3       4.0                      Apple             137000.0              -1.0
# 4       5.0                 Cvs Health             290000.0               3.0
# ..      ...                        ...                  ...               ...
# 995   996.0           Mr. Cooper Group               9100.0                 -
# 996   997.0              Herc Holdings               5100.0              -4.0
# 997   998.0      Healthpeak Properties                204.0                 -
# 998   999.0                   Spx Flow               5000.0             -37.0
# 999  1000.0  Liberty Oilfield Services               2571.0             -58.0
#
#                         Industry  \
# 0                 Retail Company
# 1             E-commerce Company
# 2                    Corporation
# 3             Technology Company
# 4             Healthcare Company
# ..                           ...
# 995          Home Loan Servicers
# 996             Equipment Rental
# 997       Real Estate Investment
# 998  Pumps And Pumping Equipment
# 999                  Oil And Gas
#
#                                    Company Description  \
# 0    Walmart Inc. Is An American Multinational Reta...
# 1    Amazon.com, Inc. Is An American Multinational ...
# 2    Exxon Mobil Corp. engages in the exploration, ...
# 3    Apple Inc. Is An American Multinational Techno...
# 4    Cvs Health Is An American Healthcare Company T...
# ..                                                 ...
# 995  Mr. Cooper Group Inc. Provides Quality Servici...
# 996  They Are One Of The Largest Equipment Rental C...
# 997  Healthpeak Properties, Inc. Is A Real Estate I...
# 998  It Is A World Leader In Sustainable Solutions ...
# 999  Liberty Is An Innovative Service Company Provi...
#
#      Revenues\n ($millions) Revenue \n Change Profits\n ($millions)  \
# 0                  523964.0             0.019               14881.0
# 1                  280522.0             0.205               11588.0
# 2                  264938.0            -0.087               14340.0
# 3                  260174.0             -0.02               55256.0
# 4                  256776.0              0.32                6634.0
# ..                      ...               ...                   ...
# 995                  2007.0                 -                 274.0
# 996                  1999.0             0.011                  47.5
# 997                  1997.0             0.082                  45.5
# 998                  1996.0            -0.045                 -95.1
# 999                  1990.0            -0.076                  39.0
#
#     Profit \n Change  Assets\n ($millions) Market Value \n As of 3/31/20 ($m)
# 0              1.231              236495.0                           321803.0
# 1               0.15              225248.0                           970680.0
# 2             -0.312              362597.0                           160696.0
# 3             -0.072              338516.0                          1112641.0
# 4                  -              222449.0                            77376.0
# ..               ...                   ...                                ...
# 995                -               18305.0                              674.0
# 996           -0.313                3817.0                              591.0
# 997           -0.957               14033.0                            12059.0
# 998           -3.161                2437.0                             1212.0
# 999           -0.692                1283.0                              303.0
#
# [1000 rows x 12 columns]

# %%
import pandas as pd

def generate_unique_id(company_name: str) -> str:
    """
    :params company_name 
    :return a unique 12 character ID based on the named from the input
    
    """
    unique_key = ''
    company_name = company_name.upper()
    
    for char in (("THE ", ""), (" THE ", " "), (" AND ", " "), (" OF ", " ")):
        company_name = company_name.replace(*char)
        
    new_name_list = []
    name_list = company_name.split(' ')
    wordCount = len(name_list)
    
    for name in name_list:
        new_name_list.append(''.join(ch for ch in name if ch.isalnum()))
    
    if wordCount == 1:
            unique_key = new_name_list[0][0:8]
    else:
        for i in range(len(new_name_list)):
            if i == 0:
                unique_key += new_name_list[i][:4]
            else:
                unique_key += new_name_list[i][:2]

            if len(unique_key) > 7:
                break

    if len(unique_key) <= 8:
        unique_key += 'x' * (8 - len(unique_key))
    
    hash_number = str(hash(company_name.upper()))[1:4]
        
    unique_key += hash_number
    
    return unique_key

# %%
keys_list = []

"""Change the name of (row[" <Your name column's name here>  "])) to match your columns name"""
for index, row in df.iterrows():
    keys_list.append(generate_unique_id(row["Metals Industry"]))
    
df['unique_ID'] = keys_list

# %%
temp_cols=df.columns.tolist()
new_cols=temp_cols[-1:] + temp_cols[:-1]
df=df[new_cols]
df.head(20)
# Out:
#       unique_ID  Rank           Metals Industry  Number Of Employees  \
# 0   WALMARTx449   1.0                   Walmart            2200000.0
# 1   AMAZONCO369   2.0                Amazon.com             798000.0
# 2   EXXOMOxx415   3.0               Exxon Mobil              74900.0
# 3   APPLExxx702   4.0                     Apple             137000.0
# 4   CVSHExxx816   5.0                Cvs Health             290000.0
# 5   BERKHAxx738   6.0        Berkshire Hathaway             391500.0
# 6   UNITGRxx842   7.0        Unitedhealth Group             325000.0
# 7   MCKESSON498   8.0                  Mckesson              70000.0
# 8   ATTxxxxx637   9.0                      At&t             247800.0
# 9   AMERISOU538  10.0         Amerisourcebergen              21500.0
# 10  ALPHABET260  11.0                  Alphabet             118899.0
# 11  FORDMOxx982  12.0                Ford Motor             190000.0
# 12  CIGNAxxx422  13.0                     Cigna              73700.0
# 13  COSTWHxx512  14.0          Costco Wholesale             201500.0
# 14  CHEVRONx818  15.0                   Chevron              48200.0
# 15  CARDHExx284  16.0           Cardinal Health              49500.0
# 16  JPMOCHxx273  17.0            Jpmorgan Chase             256981.0
# 17  GENEMOxx740  18.0            General Motors             164000.0
# 18  WALGBOAL311  19.0  Walgreens Boots Alliance             287000.0
# 19  VERICOxx161  20.0    Verizon Communications             135000.0
#
#    Change In \n Rank                             Industry  \
# 0                  -                       Retail Company
# 1                3.0                   E-commerce Company
# 2               -1.0                          Corporation
# 3               -1.0                   Technology Company
# 4                3.0                   Healthcare Company
# 5               -2.0   Multinational Conglomerate Company
# 6               -1.0                 Managed Care Company
# 7               -1.0                  Health Care Company
# 8                  -           Telecommunications Company
# 9                  -                    Wholesale Company
# 10               4.0  Information Technology And Services
# 11                 -                    Automaker Company
# 12              52.0                    Insurance Company
# 13                 -                       Retail Company
# 14              -4.0                 Oil Industry Company
# 15                 -                  Health Care Company
# 16               1.0           Investment Banking Company
# 17              -5.0                 Vehicle Manufacturer
# 18              -2.0                       Retail Company
# 19              -1.0           Telecommunications Company
#
#                                   Company Description  Revenues\n ($millions)  \
# 0   Walmart Inc. Is An American Multinational Reta...                523964.0
# 1   Amazon.com, Inc. Is An American Multinational ...                280522.0
# 2   Exxon Mobil Corp. engages in the exploration, ...                264938.0
# 3   Apple Inc. Is An American Multinational Techno...                260174.0
# 4   Cvs Health Is An American Healthcare Company T...                256776.0
# 5   Berkshire Hathaway Is An American Multinationa...                254616.0
# 6   Unitedhealth Group Incorporated Is An American...                242155.0
# 7   Mckesson Corporation Is An American Company Di...                214319.0
# 8   At&t Inc. Is An American Multinational Conglom...                181193.0
# 9   Amerisourcebergen Corporation Is An American D...                179589.0
# 10  Alphabet Inc. Is An American Multinational Con...                161857.0
# 11  Ford Motor Company, Commonly Known As Ford, Is...                155900.0
# 12  Cigna Is An American Worldwide Health Services...                153566.0
# 13  Costco Wholesale Corporation Is An American Mu...                152703.0
# 14  Chevron Corporation Is An American Multination...                146516.0
# 15  Cardinal Health, Inc. Is An American Multinati...                145534.0
# 16  Jpmorgan Chase & Co. Is An American Multinatio...                142422.0
# 17  General Motors Company Is An American Multinat...                137237.0
# 18  Walgreens Boots Alliance, Inc. Is An American ...                136866.0
# 19  Verizon Communications Inc. Is An American Mul...                131868.0
#
#    Revenue \n Change Profits\n ($millions) Profit \n Change  \
# 0              0.019               14881.0            1.231
# 1              0.205               11588.0             0.15
# 2             -0.087               14340.0           -0.312
# 3              -0.02               55256.0           -0.072
# 4               0.32                6634.0                -
# 5              0.027               81417.0           19.248
# 6               0.07               13839.0            0.155
# 7              0.029                  34.0           -0.493
# 8              0.061               13903.0           -0.282
# 9              0.069                 855.4           -0.484
# 10             0.183               34343.0            0.117
# 11            -0.028                  47.0           -0.987
# 12             2.157                5104.0            0.936
# 13             0.079                3659.0            0.168
# 14            -0.119                2924.0           -0.803
# 15             0.064                1363.0            4.324
# 16             0.084               36431.0            0.122
# 17            -0.067                6732.0            -0.16
# 18             0.041                3982.0           -0.207
# 19             0.008               19265.0            0.241
#
#     Assets\n ($millions) Market Value \n As of 3/31/20 ($m)
# 0               236495.0                           321803.0
# 1               225248.0                           970680.0
# 2               362597.0                           160696.0
# 3               338516.0                          1112641.0
# 4               222449.0                            77376.0
# 5               817729.0                           442897.0
# 6               173889.0                           236555.0
# 7                59672.0                            21845.0
# 8               551669.0                           209388.0
# 9                39172.0                            18221.0
# 10              275909.0                           798905.0
# 11              258537.0                            19151.0
# 12              155774.0                            65897.0
# 13               45400.0                           125908.0
# 14              237428.0                           136176.0
# 15               40963.0                            13988.0
# 16             2687379.0                           276750.0
# 17              228037.0                            29695.0
# 18               67598.0                            40528.0
# 19              291727.0                           222220.0

# %%
# check for duplicates, none if true
print(len(keys_list) == len(list(set(keys_list))))
# Out:
# True

# %%
"""Change the name of ['Metals Industry'] to match your columns name"""
keys = keys_list
values = df['Metals Industry'].to_list()
alphaZip= zip(keys,values)
myDict = dict(alphaZip)
myDict
# Out:
# {'WALMARTx449': 'Walmart',
#  'AMAZONCO369': 'Amazon.com',
#  'EXXOMOxx415': 'Exxon Mobil',
#  'APPLExxx702': 'Apple',
#  'CVSHExxx816': 'Cvs Health',
#  'BERKHAxx738': 'Berkshire Hathaway',
#  'UNITGRxx842': 'Unitedhealth Group',
#  'MCKESSON498': 'Mckesson',
#  'ATTxxxxx637': 'At&t',
#  'AMERISOU538': 'Amerisourcebergen',
#  'ALPHABET260': 'Alphabet',
#  'FORDMOxx982': 'Ford Motor',
#  'CIGNAxxx422': 'Cigna',
#  'COSTWHxx512': 'Costco Wholesale',
#  'CHEVRONx818': 'Chevron',
#  'CARDHExx284': 'Cardinal Health',
#  'JPMOCHxx273': 'Jpmorgan Chase',
#  'GENEMOxx740': 'General Motors',
#  'WALGBOAL311': 'Walgreens Boots Alliance',
#  'VERICOxx161': 'Verizon Communications',
#  'MICROSOF241': 'Microsoft',
#  'MARAPExx482': 'Marathon Petroleum',
#  'KROGERxx313': 'Kroger',
#  'FANNMAxx259': 'Fannie Mae',
#  'BANKAMxx957': 'Bank Of America',
#  'HOMEDExx174': 'Home Depot',
#  'PHIL66xx347': 'Phillips 66',
#  'COMCASTx589': 'Comcast',
#  'ANTHEMxx610': 'Anthem',
#  'WELLFAxx357': 'Wells Fargo',
#  'CITIGROU876': 'Citigroup',
#  'VALEENxx480': 'Valero Energy',
#  'GENEELxx205': 'General Electric',
#  'DELLTExx672': 'Dell Technologies',
#  'JOHNJOxx139': 'Johnson & Johnson',
#  'STATFAIN867': 'State Farm Insurance',
#  'TARGETxx800': 'Target',
#  'IBMxxxxx580': 'Ibm',
#  'RAYTTExx412': 'Raytheon Technologies',
#  'BOEINGxx555': 'Boeing',
#  'FREDMAxx337': 'Freddie Mac',
#  'CENTENEx899': 'Centene',
#  'UNITPASE101': 'United Parcel Service',
#  'LOWESxxx158': "Lowe's",
#  'INTELxxx145': 'Intel',
#  'FACEBOOK773': 'Facebook',
#  'FEDEXxxx207': 'Fedex',
#  'METLIFEx615': 'Metlife',
#  'WALTDIxx813': 'Walt Disney',
#  'PROCGAxx610': 'Procter & Gamble',
#  'PEPSICOx670': 'Pepsico',
#  'HUMANAxx838': 'Humana',
#  'PRUDFIxx373': 'Prudential Financial',
#  'ARCHDAMI109': 'Archer Daniels Midland',
#  'ALBERTSO736': 'Albertsons',
#  'SYSCOxxx281': 'Sysco',
#  'LOCKMAxx458': 'Lockheed Martin',
#  'HPxxxxxx502': 'Hp',
#  'ENERTRxx250': 'Energy Transfer',
#  'GOLDSAGR231': 'Goldman Sachs Group',
#  'MORGSTxx533': 'Morgan Stanley',
#  'CATERPIL677': 'Caterpillar',
#  'CISCSYxx253': 'Cisco Systems',
#  'PFIZERxx659': 'Pfizer',
#  'HCAHExxx407': 'Hca Healthcare',
#  'AIGxxxxx966': 'Aig',
#  'AMEREXxx973': 'American Express',
#  'DELTAILI806': 'Delta Air Lines',
#  'MERCKxxx562': 'Merck',
#  'AMERAIGR369': 'American Airlines Group',
#  'CHARCOxx802': 'Charter Communications',
#  'ALLSTATE970': 'Allstate',
#  'NEWYOLIIN500': 'New York Life Insurance',
#  'NATIONWI348': 'Nationwide',
#  'BESTBUxx050': 'Best Buy',
#  'UNITAIHO021': 'United Airlines Holdings',
#  'LIBEMUIN268': 'Liberty Mutual Insurance Group',
#  'DOWxxxxx619': 'Dow',
#  'TYSOFOxx285': 'Tyson Foods',
#  'TJXxxxxx403': 'Tjx',
#  'TIAAxxxx201': 'Tiaa',
#  'ORACLExx791': 'Oracle',
#  'GENEDYxx659': 'General Dynamics',
#  'DEERExxx783': 'Deere',
#  'NIKExxxx515': 'Nike',
#  'PROGRESS180': 'Progressive',
#  'PUBLSUMA782': 'Publix Super Markets',
#  'COCACOLA655': 'Coca-cola',
#  'MASSMULI455': 'Massachusetts Mutual Life Insurance',
#  'TECHDAxx420': 'Tech Data',
#  'WORLFUSE786': 'World Fuel Services',
#  'HONEINxx226': 'Honeywell International',
#  'CONOCOPH562': 'Conocophillips',
#  'USAAxxxx988': 'Usaa',
#  'EXELONxx718': 'Exelon',
#  'NORTGRxx285': 'Northrop Grumman',
#  'CAPIONFI041': 'Capital One Financial',
#  'PLAIGPHO619': 'Plains Gp Holdings',
#  'ABBVIExx836': 'Abbvie',
#  'STONGRxx867': 'Stonex Group',
#  'ENTEPRPA585': 'Enterprise Products Partners',
#  'NORTMUxx098': 'Northwestern Mutual',
#  '3Mxxxxxx581': '3m',
#  'ABBOLAxx161': 'Abbott Laboratories',
#  'CHSxxxxx747': 'Chs',
#  'TRAVELER259': 'Travelers',
#  'PHILMOIN785': 'Philip Morris International',
#  'RAYTHEON790': 'Raytheon',
#  'HEWLPAEN883': 'Hewlett Packard Enterprise',
#  'ARROELxx816': 'Arrow Electronics',
#  'VIACOMCB357': 'Viacomcbs',
#  'DOLLGExx334': 'Dollar General',
#  'USBAxxxx186': 'U.s. Bancorp',
#  'STARBUCK772': 'Starbucks',
#  'BRISSQxx110': 'Bristol-myers Squibb',
#  'USFOHOxx920': 'Us Foods Holding',
#  'MONDINxx995': 'Mondelez International',
#  'PACCARxx908': 'Paccar',
#  'THERFISC289': 'Thermo Fisher Scientific',
#  'MACYSxxx316': "Macy's",
#  'JABILxxx178': 'Jabil',
#  'KRAFHExx000': 'Kraft Heinz',
#  'DUKEENxx507': 'Duke Energy',
#  'TESLAxxx274': 'Tesla',
#  'PBFENxxx310': 'Pbf Energy',
#  'QUALCOMM654': 'Qualcomm',
#  'NGLENPAx108': 'Ngl Energy Partners',
#  'CBREGRxx907': 'Cbre Group',
#  'BAKEHUxx405': 'Baker Hughes',
#  'SYNNEXxx712': 'Synnex',
#  'DOLLTRxx990': 'Dollar Tree',
#  'CUMMINSx644': 'Cummins',
#  'UNITNAFO708': 'United Natural Foods',
#  'MICRTExx266': 'Micron Technology',
#  'AMGENxxx046': 'Amgen',
#  'PENSAUGR490': 'Penske Automotive Group',
#  'VISAxxxx818': 'Visa',
#  'BROADCOM279': 'Broadcom',
#  'NUCORxxx605': 'Nucor',
#  'GILESCxx640': 'Gilead Sciences',
#  'SOUTAIxx206': 'Southwest Airlines',
#  'HALLIBUR835': 'Halliburton',
#  'CENTURYL759': 'Centurylink',
#  'INTEPAxx746': 'International Paper',
#  'ELILIxxx245': 'Eli Lilly',
#  'AFLACxxx792': 'Aflac',
#  'LENNARxx659': 'Lennar',
#  'OCCIPExx900': 'Occidental Petroleum',
#  'UNIOPAxx199': 'Union Pacific',
#  'RITEAIxx491': 'Rite Aid',
#  'PNCFISEGR259': 'Pnc Financial Services Group',
#  'DUPONTxx300': 'Dupont',
#  'SOUTHERN271': 'Southern',
#  'AUTONATI316': 'Autonation',
#  'DXCTExxx578': 'Dxc Technology',
#  'MCDONALD954': "Mcdonald's",
#  'MARRINxx788': 'Marriott International',
#  'MANPOWER595': 'Manpowergroup',
#  'BANKNEYO453': 'Bank Of New York Mellon',
#  'HARTFISE756': 'Hartford Financial Services Group',
#  'DANAHERx229': 'Danaher',
#  'WHIRLPOO840': 'Whirlpool',
#  'AECOMxxx310': 'Aecom',
#  'NETFLIXx360': 'Netflix',
#  'KOHLSxxx232': "Kohl's",
#  'LEARxxxx397': 'Lear',
#  'ALTRGRxx228': 'Altria Group',
#  'PERFFOGR242': '\nperformance Food Group',
#  'AVNETxxx632': 'Avnet',
#  'SYNCFIxx963': 'Synchrony Financial',
#  'GENUPAxx490': 'Genuine Parts',
#  'NEXTENxx806': 'Nextera Energy',
#  'CARMAXxx505': 'Carmax',
#  'TENEHExx337': 'Tenet Healthcare',
#  'KIMBERLY621': 'Kimberly-clark',
#  'EMERELxx820': 'Emerson Electric',
#  'WESTROCK149': 'Westrock',
#  'CDWxxxxx165': 'Cdw',
#  'JONELALA503': 'Jones Lang Lasalle',
#  'SHERWINW556': 'Sherwin-williams',
#  'FLUORxxx433': 'Fluor',
#  'PAYPHOxx897': 'Paypal Holdings',
#  'DRHOxxxx161': 'D.r. Horton',
#  'HOLLYFRO204': 'Hollyfrontier',
#  'TENNECOx132': 'Tenneco',
#  'EOGRExxx247': 'Eog Resources',
#  'BECTDIxx488': 'Becton Dickinson',
#  'LINCNAxx302': 'Lincoln National',
#  'PGExxxxx568': 'Pg&e',
#  'SALESFOR402': 'Salesforce.com',
#  'MASTERCA040': 'Mastercard',
#  'GENEMIxx454': 'General Mills',
#  'MOLIHExx216': 'Molina Healthcare',
#  'COGNTESO209': 'Cognizant Technology Solutions',
#  'MARSMCxx368': 'Marsh & Mclennan',
#  'XPOLOxxx392': 'Xpo Logistics',
#  'DOMIENxx659': 'Dominion Energy',
#  'WESTDIxx534': 'Western Digital',
#  'GAPxxxxx377': 'Gap',
#  'ARAMARKx143': 'Aramark',
#  'PRINFIxx373': 'Principal Financial',
#  'ROSSSTxx633': '\nross Stores',
#  'COLGATEP509': 'Colgate-palmolive',
#  'AMERELPO791': 'American Electric Power',
#  'NORDSTRO762': 'Nordstrom',
#  'JACOENGR641': 'Jacobs Engineering Group',
#  'WASTMAxx441': 'Waste Management',
#  'CHROWOxx150': 'C.h. Robinson Worldwide',
#  'PPGINxxx015': 'Ppg Industries',
#  'BOOKHOxx360': 'Booking Holdings',
#  'OMNIGRxx515': 'Omnicom Group',
#  'LOEWSxxx725': 'Loews',
#  'ECOLABxx596': 'Ecolab',
#  'STRYKERx455': 'Stryker',
#  'ESTELAxx130': 'Estee Lauder',
#  'GOODTIRU526': 'Goodyear Tire & Rubber',
#  'TRUIFIxx680': 'Truist Financial',
#  'APPLMAxx696': 'Applied Materials',
#  'BLACKROC769': 'Blackrock',
#  'STANBLDE348': 'Stanley Black & Decker',
#  'FREEPORT841': 'Freeport-mcmoran',
#  'TEXAINxx625': 'Texas Instruments',
#  'BIOGENxx257': 'Biogen',
#  'PARKERHA283': 'Parker-hannifin',
#  'REINGRAM307': 'Reinsurance Group Of America',
#  'HOWMAExx422': 'Howmet Aerospace',
#  'AUTODAPR159': 'Automatic Data Processing',
#  'UBERTExx910': 'Uber Technologies',
#  'ILLITOWO427': 'Illinois Tool Works',
#  'DAVITAxx930': 'Davita',
#  'DISCFISE605': 'Discover Financial Services',
#  'LANDOLxx544': "Land O'lakes",
#  'VFxxxxxx371': 'Vf',
#  'CORTEVAx241': 'Corteva',
#  'LASVESAx176': 'Las Vegas Sands',
#  'TEXTRONx002': 'Textron',
#  'KELLOGGx431': 'Kellogg',
#  'GUARLIIN170': 'Guardian Life Ins. Co. Of America',
#  'QURARExx608': 'Qurate Retail',
#  'COREHOxx946': 'Core-mark Holding',
#  'COMMHESY279': 'Community Health Systems',
#  'KINDMOxx668': 'Kinder Morgan',
#  'BJSWHCLx579': "Bj's Wholesale Club",
#  'STATSTxx655': 'State Street',
#  'AMERFIxx628': 'Ameriprise Financial',
#  'GLOBPAxx950': 'Global Partners',
#  'UNITSTST253': 'United States Steel',
#  'LBRxxxxx719': 'L Brands',
#  'MGMREINx125': 'Mgm Resorts International',
#  'L3HATExx840': 'L3harris Technologies',
#  'DISHNExx401': 'Dish Network',
#  'LITHMOxx550': 'Lithia Motors',
#  'DTEENxxx361': 'Dte Energy',
#  'AMERFAIN605': 'American Family Insurance Group',
#  'FARMINEX696': 'Farmers Insurance Exchange',
#  'CONSEDxx346': 'Consolidated Edison',
#  'LKQxxxxx528': 'Lkq',
#  'SEMPENxx345': 'Sempra Energy',
#  'EDISINxx065': 'Edison International',
#  'CENTENxx225': 'Centerpoint Energy',
#  'QUANSExx344': 'Quanta Services',
#  'MURPUSxx152': 'Murphy Usa',
#  'EXPEGRxx499': 'Expedia Group',
#  'GROU1AUx697': 'Group 1 Automotive',
#  'BEDBABEx518': 'Bed Bath & Beyond',
#  'UNUMGRxx480': 'Unum Group',
#  'CSXxxxxx064': 'Csx',
#  'AUTOZONE860': 'Autozone',
#  'PACILIxx921': 'Pacific Life',
#  'VISTENxx413': 'Vistra Energy',
#  'CHARSCxx002': 'Charles Schwab',
#  'CROWHOxx808': 'Crown Holdings',
#  'ALLYFIxx288': 'Ally Financial',
#  'LABOCOAM625': 'Laboratory Corp. Of America',
#  'LIVENAEN204': 'Live Nation Entertainment',
#  'XCELENxx543': 'Xcel Energy',
#  'CORNINGx709': 'Corning',
#  'WWGRxxxx937': 'W.w. Grainger',
#  'BALLxxxx303': 'Ball',
#  'FOXxxxxx187': 'Fox',
#  'UNIVHESE114': 'Universal Health Services',
#  'BAXTINxx679': 'Baxter International',
#  'NORFSOxx871': 'Norfolk Southern',
#  'NAVIINxx571': 'Navistar International',
#  'ADOBExxx009': 'Adobe',
#  'JCPExxxx464': 'J.c. Penney',
#  'DISCOVER638': 'Discovery',
#  'KEURDRPE104': 'Keurig Dr Pepper',
#  'LEIDHOxx686': 'Leidos Holdings',
#  'IQVIHOxx176': 'Iqvia Holdings',
#  'RELISTAL312': 'Reliance Steel & Aluminum',
#  'NVIDIAxx172': 'Nvidia',
#  'ENTERGYx250': 'Entergy',
#  'FIRSTENE943': 'Firstenergy',
#  'EBAYxxxx506': 'Ebay',
#  'BOSTSCxx962': 'Boston Scientific',
#  'OFFIDExx794': 'Office Depot',
#  'MOLSCOBE212': 'Molson Coors Beverage',
#  'STEEDYxx139': 'Steel Dynamics',
#  'MUTUOMIN520': 'Mutual Of Omaha Insurance',
#  'SONIAUxx276': 'Sonic Automotive',
#  'ALCOAxxx934': 'Alcoa',
#  'FIDENAIN647': 'Fidelity National Information Services',
#  'HENRSCxx540': 'Henry Schein',
#  'REPUSExx731': 'Republic Services',
#  'LIBEMExx465': 'Liberty Media',
#  'PETEKISO363': "Peter Kiewit Sons'",
#  'INTEGRxx971': 'Interpublic Group',
#  'PULTEGRO766': 'Pultegroup',
#  'AESxxxxx259': 'Aes',
#  'FISERVxx712': 'Fiserv',
#  'BORGWARN188': 'Borgwarner',
#  'ONEOKxxx494': 'Oneok',
#  'OREIAUxx658': "O'reilly Automotive",
#  'ASSURANT920': 'Assurant',
#  'NEWEBRxx213': 'Newell Brands',
#  'PUBLSEEN507': 'Public Service Enterprise Group',
#  'NEWSCOxx376': 'News Corp.',
#  'CALPINEx527': 'Calpine',
#  'AUTOINxx479': 'Auto-owners Insurance',
#  'MOHAINxx031': 'Mohawk Industries',
#  'PVHxxxxx683': 'Pvh',
#  'CAMPSOxx370': 'Campbell Soup',
#  'NRGENxxx364': 'Nrg Energy',
#  'FIFTTHBA137': 'Fifth Third Bancorp',
#  'HERTGLHO373': 'Hertz Global Holdings',
#  'ALTIUSxx189': 'Altice Usa',
#  'NEWMONTx894': 'Newmont',
#  'CHENENxx058': 'Cheniere Energy',
#  'ADVAAUPA600': 'Advance Auto Parts',
#  'LAMRExxx429': 'Lam Research',
#  'OWENMIxx744': 'Owens & Minor',
#  'EQUIHOxx736': 'Equitable Holdings',
#  'CONABRxx738': 'Conagra Brands',
#  'MARKELxx497': 'Markel',
#  'JONEFIED745': 'Jones Financial (edward Jones)',
#  'HORMFOxx761': 'Hormel Foods',
#  'HILTWOHO799': 'Hilton Worldwide Holdings',
#  'UNIVSOxx912': 'Univar Solutions',
#  'UNITRExx686': 'United Rentals',
#  'PIONNARE925': 'Pioneer Natural Resources',
#  'DELEUSHO656': 'Delek Us Holdings',
#  'EASTCHxx192': 'Eastman Chemical',
#  'EMCOGRxx047': 'Emcor Group',
#  'AVISBUGR706': 'Avis Budget Group',
#  'JBHUTRSE717': 'J.b. Hunt Transport Services',
#  'XEROHOxx704': 'Xerox Holdings',
#  'WAYFAIRx903': 'Wayfair',
#  'KKRxxxxx157': 'Kkr',
#  'AGCOxxxx856': 'Agco',
#  'ALLEGHAN533': 'Alleghany',
#  'ICAHENxx129': 'Icahn Enterprises',
#  'VOYAFIxx019': 'Voya Financial',
#  'RYDESYxx530': 'Ryder System',
#  'AIRPRCHx655': 'Air Products & Chemicals',
#  'MOSAICxx667': 'Mosaic',
#  'HUNTININ760': 'Huntington Ingalls Industries',
#  'BERRGLGR755': 'Berry Global Group',
#  'ANIXINxx152': 'Anixter International',
#  'ALASAIGR505': 'Alaska Air Group',
#  'YUMCHHOx381': 'Yum China Holdings',
#  'DICKSPGO840': "Dick's Sporting Goods",
#  'CAESENxx830': 'Caesars Entertainment',
#  'GENWFIxx282': 'Genworth Financial',
#  'TARGRExx324': 'Targa Resources',
#  'COTYxxxx405': 'Coty',
#  'DANAxxxx776': 'Dana',
#  'THRIFIFO703': 'Thrivent Financial For Lutherans',
#  'AUTOLIVx484': 'Autoliv',
#  'SPARTANN824': 'Spartannash',
#  'EVERENxx688': 'Eversource Energy',
#  'DARDRExx955': 'Darden Restaurants',
#  'CHESENxx439': 'Chesapeake Energy',
#  'NATIOIVA858': 'National Oilwell Varco',
#  'FIDENAFI472': 'Fidelity National Financial',
#  'ERIEINGR342': 'Erie Insurance Group',
#  'OSHKOSHx755': 'Oshkosh',
#  'CASEGEST329': "Casey's General Stores",
#  'WESCINxx567': 'Wesco International',
#  'TRACSUxx729': 'Tractor Supply',
#  'COMMHOxx339': 'Commscope Holding',
#  'HUNTSMAN311': 'Huntsman',
#  'AMERFIGR692': 'American Financial Group',
#  'MASCOxxx705': 'Masco',
#  'SANMINAx856': 'Sanmina',
#  'AMPHENOL013': 'Amphenol',
#  'WILLIAMS560': 'Williams',
#  'WESTAIBR882': 'Westinghouse Air Brake',
#  'EXPEINWA796': 'Expeditors Intl. Of Washington',
#  'ANDERSON509': 'Andersons',
#  'WESTCHxx047': 'Westlake Chemical',
#  'CONSBRxx333': 'Constellation Brands',
#  'FRONCOxx855': 'Frontier Communications',
#  'JETBAIxx451': 'Jetblue Airways',
#  'CITIFIGR251': 'Citizens Financial Group',
#  'RAYMJAFI575': 'Raymond James Financial',
#  'FOOTLOxx503': 'Foot Locker',
#  'HERSHEYx453': 'Hershey',
#  'ZIMMBIHO493': 'Zimmer Biomet Holdings',
#  'CINCFIxx364': 'Cincinnati Financial',
#  'WESTSOFI143': 'Western & Southern Financial Group',
#  'WRBExxxx848': 'W.r. Berkley',
#  'MOTOSOxx909': 'Motorola Solutions',
#  'THORINxx349': 'Thor Industries',
#  'REGEPHxx639': 'Regeneron Pharmaceuticals',
#  'SPIRAEHO253': 'Spirit Aerosystems Holdings',
#  'JMSMxxxx874': 'J.m. Smucker',
#  'PPLxxxxx309': 'Ppl',
#  'INSIENxx487': 'Insight Enterprises',
#  'QUESDIxx803': 'Quest Diagnostics',
#  'KEYCORPx869': 'Keycorp',
#  'VERITIVx038': 'Veritiv',
#  'DCPMIxxx863': 'Dcp Midstream',
#  'AMERTOxx156': 'American Tower',
#  'GRAYELxx126': 'Graybar Electric',
#  'WECENGRx247': 'Wec Energy Group',
#  'NVRxxxxx245': 'Nvr',
#  'ULTABExx767': 'Ulta Beauty',
#  'DEVOENxx741': 'Devon Energy',
#  'BLACGRxx993': 'Blackstone Group',
#  'DEANFOxx324': 'Dean Foods',
#  'FORTIVEx236': 'Fortive',
#  'UGIxxxxx115': 'Ugi',
#  'BURLSTxx479': 'Burlington Stores',
#  'BUILFIxx621': 'Builders Firstsource',
#  'TOLLBRxx489': 'Toll Brothers',
#  'OLDREINx422': 'Old Republic International',
#  'ASBUAUGR116': 'Asbury Automotive Group',
#  'ARTHJGAx916': 'Arthur J. Gallagher',
#  'MASTECxx550': 'Mastec',
#  'OWENCOxx258': 'Owens Corning',
#  'MAGEHExx182': 'Magellan Health',
#  'DOVERxxx751': 'Dover',
#  'BEACROSU003': 'Beacon Roofing Supply',
#  'AVERDExx995': 'Avery Dennison',
#  'HANESBRA855': 'Hanesbrands',
#  'PACKCOAM286': 'Packaging Corp. Of America',
#  'MTBAxxxx579': 'M&t Bank',
#  'NCRxxxxx706': 'Ncr',
#  'NORTTRxx343': 'Northern Trust',
#  'CINTASxx631': 'Cintas',
#  'POLARISx719': 'Polaris',
#  'CMSENxxx208': 'Cms Energy',
#  'SEABOARD930': 'Seaboard',
#  'INTUITxx375': 'Intuit',
#  'REGIFIxx273': 'Regions Financial',
#  'FMGLxxxx461': 'Fm Global',
#  'ADVAMIDE304': 'Advanced Micro Devices',
#  'OVINTIVx241': 'Ovintiv',
#  'BOOZALHA191': 'Booz Allen Hamilton Holding',
#  'SPGLxxxx687': 'S&p Global',
#  'ROCKAUxx687': 'Rockwell Automation',
#  'OIGLxxxx948': 'O-i Glass',
#  'WYNNRExx523': 'Wynn Resorts',
#  'SECUFIGR257': 'Securian Financial Group',
#  'ALLIDASY533': 'Alliance Data Systems',
#  'WEYERHAE897': 'Weyerhaeuser',
#  'BRIGFIxx227': 'Brighthouse Financial',
#  'INTEEXxx398': 'Intercontinental Exchange',
#  'AMERAXMA161': 'American Axle & Manufacturing',
#  'HESSxxxx272': 'Hess',
#  'ABMINxxx692': 'Abm Industries',
#  'ACTIBLxx325': 'Activision Blizzard',
#  'GAMESTOP628': 'Gamestop',
#  'APACHExx304': 'Apache',
#  'SCIEAPIN895': 'Science Applications International',
#  'AKSTHOxx852': 'Ak Steel Holding',
#  'DILLARDS789': "Dillard's",
#  'RALPLAxx280': 'Ralph Lauren',
#  'CELANESE156': 'Celanese',
#  'RRDOSOxx237': 'R.r. Donnelley & Sons',
#  'ZOETISxx907': 'Zoetis',
#  'ASCEREGR265': 'Ascena Retail Group',
#  'CLOROXxx402': 'Clorox',
#  'INGREDIO454': 'Ingredion',
#  'FIRSAMFI871': 'First American Financial',
#  'GRAPPAHO411': 'Graphic Packaging Holding',
#  'NETAPPxx744': 'Netapp',
#  'HDSUHOxx260': 'Hd Supply Holdings',
#  'TRAVAMxx647': 'Travelcenters Of America',
#  'OLINxxxx415': 'Olin',
#  'ROBEHAIN688': 'Robert Half International',
#  'ENLIMIxx372': 'Enlink Midstream',
#  'AVANTORx760': 'Avantor',
#  'TAPESTRY610': 'Tapestry',
#  'TDAMHOxx559': 'Td Ameritrade Holding',
#  'ANALDExx128': 'Analog Devices',
#  'AMERENxx649': 'Ameren',
#  'WILLIAMS046': 'Williams-sonoma',
#  'REALHOxx266': 'Realogy Holdings',
#  'COMMMExx549': 'Commercial Metals',
#  'RUSHENxx801': 'Rush Enterprises',
#  'FRANRExx485': 'Franklin Resources',
#  'FORTBRHO485': 'Fortune Brands Home & Security',
#  'LEVISTxx134': 'Levi Strauss',
#  'CROWCAIN896': 'Crown Castle International',
#  'SIMOPRGR251': 'Simon Property Group',
#  'CERNERxx956': 'Cerner',
#  'POSTHOxx489': 'Post Holdings',
#  'HUNTBAxx796': 'Huntington Bancshares',
#  'KBRxxxxx702': 'Kbr',
#  'SPROFAMA771': 'Sprouts Farmers Market',
#  'LPLFIHOx482': 'Lpl Financial Holdings',
#  'TROPRxxx875': 'T. Rowe Price',
#  'YUMBRxxx156': 'Yum Brands',
#  'CHIPMEGR718': 'Chipotle Mexican Grill',
#  'PATTERSO052': 'Patterson',
#  'RPMINxxx246': 'Rpm International',
#  'EQUINIXx610': 'Equinix',
#  'NAVIENTx131': 'Navient',
#  'CHEMOURS359': 'Chemours',
#  'ONSExxxx244': 'On Semiconductor',
#  'TRANGRxx611': 'Transdigm Group',
#  'HOSTHORE554': 'Host Hotels & Resorts',
#  'SELEMEHO802': 'Select Medical Holdings',
#  'PARPAHOx228': 'Par Pacific Holdings',
#  'SONOPRxx125': 'Sonoco Products',
#  'ROPETExx850': 'Roper Technologies',
#  'HARLEYDA263': 'Harley-davidson',
#  'JEFFFIGR170': 'Jefferies Financial Group',
#  'KELLSExx242': 'Kelly Services',
#  'MICRTExx758': 'Microchip Technology',
#  'MCCORMIC747': 'Mccormick',
#  'MDUREGRx798': 'Mdu Resources Group',
#  'FASTENAL767': 'Fastenal',
#  'BIGLOxxx512': 'Big Lots',
#  'PENNNAGA074': 'Penn National Gaming',
#  'WESTUNxx810': 'Western Union',
#  'UNDEARxx352': 'Under Armour',
#  'XYLEMxxx411': 'Xylem',
#  'SKECUSxx773': 'Skechers U.s.a.',
#  'DOMTARxx851': 'Domtar',
#  'NISOURCE937': 'Nisource',
#  'MARAOIxx472': 'Marathon Oil',
#  'NATIGEHO231': 'National General Holdings',
#  'TELEDASY366': 'Telephone & Data Systems',
#  'AGILTExx866': 'Agilent Technologies',
#  'AMETEKxx826': 'Ametek',
#  'EVERGYxx359': 'Evergy',
#  'INTEFLFR761': 'International Flavors & Fragrances',
#  'ADTxxxxx954': 'Adt',
#  'WELLTOWE091': 'Welltower',
#  'WINDHOxx423': 'Windstream Holdings',
#  'MICHAELS531': 'Michaels',
#  'KEMPERxx458': 'Kemper',
#  'HYATHOxx157': 'Hyatt Hotels',
#  'ALEXPHxx393': 'Alexion Pharmaceuticals',
#  'RESITExx269': 'Resideo Technologies',
#  'CACIINxx915': 'Caci International',
#  'ELECARxx547': 'Electronic Arts',
#  'VULCMAxx100': 'Vulcan Materials',
#  'TREEFOxx966': 'Treehouse Foods',
#  'GLOBPAxx796': 'Global Payments',
#  'HANOINGR916': 'Hanover Insurance Group',
#  'CAMPWOHO853': 'Camping World Holdings',
#  'CORNBUBR250': 'Cornerstone Building Brands',
#  'YRCWOxxx824': 'Yrc Worldwide',
#  'CMEGRxxx607': 'Cme Group',
#  'CHEWYxxx765': 'Chewy',
#  'KNIGTRHO708': 'Knight-swift Transportation Holdings',
#  'MOODYSxx016': "Moody's",
#  'COCACOxx540': 'Coca-cola Consolidated',
#  'CARLISLE437': 'Carlisle',
#  'SEALAIxx916': 'Sealed Air',
#  'AMARPRME608': 'A-mark Precious Metals',
#  'WATSCOxx913': 'Watsco',
#  'TAYLMOHO701': 'Taylor Morrison Home',
#  'IACINTER400': 'Iac/interactivecorp',
#  'LEGGPLxx717': 'Leggett & Platt',
#  'ONEMHOxx963': 'Onemain Holdings',
#  'SCHNNAxx702': 'Schneider National',
#  'MARTMAMA488': 'Martin Marietta Materials',
#  'NORTONLI579': 'Nortonlifelock',
#  'HASBROxx064': 'Hasbro',
#  'SQUARExx999': 'Square',
#  'TEREXxxx722': 'Terex',
#  'SYNEHExx421': 'Syneos Health',
#  'FMCxxxxx262': 'Fmc',
#  'BOISCAxx881': 'Boise Cascade',
#  'SSCTEHOx319': 'Ss&c Technologies Holdings',
#  'CONTRExx785': 'Continental Resources',
#  'PEABENxx632': 'Peabody Energy',
#  'ENCOHExx632': 'Encompass Health',
#  'GREIFxxx976': 'Greif',
#  'CONCRExx222': 'Concho Resources',
#  'HUBBELLx905': 'Hubbell',
#  'CFINHOxx518': 'Cf Industries Holdings',
#  'KLAxxxxx236': 'Kla',
#  'GENEHExx978': 'Genesis Healthcare',
#  'BRUNSWIC277': 'Brunswick',
#  'KBHOxxxx764': 'Kb Home',
#  'GLOBLIxx244': 'Globe Life',
#  'MATTELxx623': 'Mattel',
#  'RYERHOxx438': 'Ryerson Holding',
#  'SILGHOxx439': 'Silgan Holdings',
#  'ZEBRTExx039': 'Zebra Technologies',
#  'INTUSUxx267': 'Intuitive Surgical',
#  'WARNMUGR863': 'Warner Music Group',
#  'CONDUENT588': 'Conduent',
#  'TUTOPExx330': 'Tutor Perini',
#  'JUNINExx645': 'Juniper Networks',
#  'NOBLENxx602': 'Noble Energy',
#  'VERTHOxx516': 'Vertiv Holdings',
#  'TIFFANYx062': 'Tiffany',
#  'EQTxxxxx202': 'Eqt',
#  'UFPINxxx773': 'Ufp Industries',
#  'DIEBNIxx141': 'Diebold Nixdorf',
#  'ANTERExx377': 'Antero Resources',
#  'MERITORx582': 'Meritor',
#  'BROAFISO236': 'Broadridge Financial Solutions',
#  'CHURDWxx591': 'Church & Dwight',
#  'MARRVAWO380': 'Marriott Vacations Worldwide',
#  'EDWALIxx893': 'Edwards Lifesciences',
#  'COLFAXxx542': 'Colfax',
#  'INSPERIT340': 'Insperity',
#  'AMEREAOU681': 'American Eagle Outfitters',
#  'KEYSTExx190': 'Keysight Technologies',
#  'JELDHOxx968': 'Jeld-wen Holding',
#  'IRONMOxx050': 'Iron Mountain',
#  'NASDAQxx433': 'Nasdaq',
#  'GARTNERx855': 'Gartner',
#  'SINCBRGR109': 'Sinclair Broadcast Group',
#  'INGLMAxx149': 'Ingles Markets',
#  'MONSBExx540': 'Monster Beverage',
#  'MURPOIxx213': 'Murphy Oil',
#  'VERTPHxx402': 'Vertex Pharmaceuticals',
#  'FIRSREBA512': 'First Republic Bank',
#  'BLOOBRxx875': "Bloomin' Brands",
#  'SPECBRHO642': 'Spectrum Brands Holdings',
#  'QUADGRAP729': 'Quad/graphics',
#  'FLOWFOxx179': 'Flowers Foods',
#  'CUNAMUGR299': 'Cuna Mutual Group',
#  'ALLETExx117': 'Allegheny Technologies',
#  'OLDDOFRLI492': 'Old Dominion Freight Line',
#  'LANDSYxx268': 'Landstar System',
#  'AMERNAIN378': 'American National Insurance',
#  'SNAPONxx149': 'Snap-on',
#  'BROOSELI452': 'Brookdale Senior Living',
#  'AMKOTExx411': 'Amkor Technology',
#  'WYNDDExx359': 'Wyndham Destinations',
#  'PPDxxxxx528': 'Ppd',
#  'DENTSIxx730': 'Dentsply Sirona',
#  'CNOFIGRx811': 'Cno Financial Group',
#  'URBAOUxx065': 'Urban Outfitters',
#  'SABRExxx279': 'Sabre',
#  'MERCGExx312': 'Mercury General',
#  'DIAMENxx768': 'Diamondback Energy',
#  'PARSONSx275': 'Parsons',
#  'AARONSxx623': "Aaron's",
#  'FLOWSERV897': 'Flowserve',
#  'CARVANAx544': 'Carvana',
#  'ASGNxxxx151': 'Asgn',
#  'SALLBEHO075': 'Sally Beauty Holdings',
#  'SCANSOUR196': 'Scansource',
#  'VENTASxx747': 'Ventas',
#  'COUNFIxx207': 'Country Financial',
#  'TRINGRxx208': 'Trinet Group',
#  'SPIRAIxx973': 'Spirit Airlines',
#  'COMERICA452': 'Comerica',
#  'LENNINxx895': 'Lennox International',
#  'TIMKENxx092': 'Timken',
#  'PAYCHEXx299': 'Paychex',
#  'AMERCOxx494': 'Amerco',
#  'WORTINxx528': 'Worthington Industries',
#  'LAMBWEHO678': 'Lamb Weston Holdings',
#  'LAUREDxx015': 'Laureate Education',
#  'PENNMULI532': 'Penn Mutual Life Insurance',
#  'IHEARTME478': 'Iheartmedia',
#  'BRINKSxx315': "Brink's",
#  'SENTINGR845': 'Sentry Insurance Group',
#  'ACUIBRxx824': 'Acuity Brands',
#  'HUBGRxxx354': 'Hub Group',
#  'MERIHOxx712': 'Meritage Homes',
#  'MRCGLxxx743': 'Mrc Global',
#  'ALLIENxx455': 'Alliant Energy',
#  'WORKDAYx328': 'Workday',
#  'BMCSTHOx768': 'Bmc Stock Holdings',
#  'ABERFIxx251': 'Abercrombie & Fitch',
#  'DOMIPIxx746': "Domino's Pizza",
#  'LYFTxxxx299': 'Lyft',
#  'MEREDITH013': 'Meredith',
#  'AMERWAWO232': 'American Water Works',
#  'ALBEMARL078': 'Albemarle',
#  'CIENAxxx320': 'Ciena',
#  'BARNNOxx238': 'Barnes & Noble',
#  'WEISMAxx107': 'Weis Markets',
#  'ILLUMINA566': 'Illumina',
#  'SVBFIGRx294': 'Svb Financial Group',
#  'CARTERSx836': "Carter's",
#  'STIFFIxx894': 'Stifel Financial',
#  'MEDNAXxx701': 'Mednax',
#  'EQUIFAXx515': 'Equifax',
#  'KARAUSEx177': 'Kar Auction Services',
#  'ASHLGLHO403': 'Ashland Global Holdings',
#  'MEDIMUOH169': 'Medical Mutual Of Ohio',
#  'SPRARExx292': 'Sprague Resources',
#  'SUPEMICO468': 'Super Micro Computer',
#  'DESIBRxx734': 'Designer Brands',
#  'PITNBOxx715': 'Pitney Bowes',
#  'APPLINTE564': 'Applied Industrial Technologies',
#  'PINNWECA397': 'Pinnacle West Capital',
#  'AMEREQIN139': 'American Equity Investment Life Holding',
#  'SERVICEN339': 'Servicenow',
#  'TWITTERx048': 'Twitter',
#  'CALUSPPR528': 'Calumet Specialty Products Partners',
#  'STEELCAS073': 'Steelcase',
#  'SANDFAxx723': 'Sanderson Farms',
#  'WABCHOxx219': 'Wabco Holdings',
#  'CLEAHAxx213': 'Clean Harbors',
#  'PUGEENxx598': 'Puget Energy',
#  'SCIEGAxx664': 'Scientific Games',
#  'GRANCOxx769': 'Granite Construction',
#  'CARLGRxx644': 'Carlyle Group',
#  'SKYWSOxx709': 'Skyworks Solutions',
#  'ALERISxx123': 'Aleris',
#  'TRIPMAxx731': 'Triple-s Management',
#  'HEXIONxx183': 'Hexion',
#  'HOLOGICx768': 'Hologic',
#  'TRIUGRxx515': 'Triumph Group',
#  'DARLINxx982': 'Darling Ingredients',
#  'MSCINDIx293': 'Msc Industrial Direct',
#  'REDHAxxx955': 'Red Hat',
#  'SYNOPSYS208': 'Synopsys',
#  'POLYONEx988': 'Polyone',
#  'DYCOINxx371': 'Dycom Industries',
#  'CABOTxxx865': 'Cabot',
#  'PROLOGIS521': 'Prologis',
#  'BOYDGAxx810': 'Boyd Gaming',
#  'LSCCOxxx080': 'Lsc Communications',
#  'BROWNFOR138': 'Brown-forman',
#  'STERICYC811': 'Stericycle',
#  'CITGRxxx339': 'Cit Group',
#  'MDCHOxxx532': 'Mdc Holdings',
#  'HYSTMAHA166': 'Hyster-yale Materials Handling',
#  'CRANExxx662': 'Crane',
#  'CINEHOxx996': 'Cinemark Holdings',
#  'AUTODESK713': 'Autodesk',
#  'TRIMBLEx777': 'Trimble',
#  'GARRMOxx630': 'Garrett Motion',
#  'ZIONBAxx883': 'Zions Bancorp.',
#  'REGABExx189': 'Regal Beloit',
#  'SERVCOIN734': 'Service Corp. International',
#  'VARIMESY971': 'Varian Medical Systems',
#  'PRICESMA803': 'Pricesmart',
#  'BRININxx301': 'Brinker International',
#  'DIGIRETR814': 'Digital Realty Trust',
#  'POOLCOxx355': 'Pool Corp',
#  'CRESEQPA908': 'Crestwood Equity Partners',
#  'INFORxxx627': 'Infor',
#  'PLEXUSxx390': 'Plexus',
#  'TELETExx841': 'Teledyne Technologies',
#  'GIIIAPGR763': 'G-iii Apparel Group',
#  'SCOTMIxx853': 'Scotts Miracle-gro',
#  'APOLGLMA140': 'Apollo Global Management',
#  'ETRAFIxx443': 'E*trade Financial',
#  'TOROxxxx782': 'Toro',
#  'SOUTGAHO197': 'Southwest Gas Holdings',
#  'GMSxxxxx245': 'Gms',
#  'COOPHOxx409': 'Cooper-standard Holdings',
#  'ACADHExx843': 'Acadia Healthcare',
#  'TETRTExx963': 'Tetra Tech',
#  'PRIMSExx752': 'Primoris Services',
#  'TEMPSEIN467': 'Tempur Sealy International',
#  'HRBLxxxx377': 'H&r Block',
#  'QORVOxxx980': 'Qorvo',
#  'TRIPOGRx300': 'Tri Pointe Group',
#  'CRACBAOL916': 'Cracker Barrel Old Country Store',
#  'ELANANHE967': 'Elanco Animal Health',
#  'PRAHESCx704': 'Pra Health Sciences',
#  'FIRSSOxx203': 'First Solar',
#  'AMCNExxx853': 'Amc Networks',
#  'XILINXxx631': 'Xilinx',
#  'GREEPLxx028': 'Green Plains',
#  'COLUSPxx665': 'Columbia Sportswear',
#  'NEXSMEGR934': 'Nexstar Media Group',
#  'SOUTENxx694': 'Southwestern Energy',
#  'GREENBRI572': 'Greenbrier',
#  'PRESIDIO354': 'Presidio',
#  'CITRSYxx757': 'Citrix Systems',
#  'METTINxx910': 'Mettler-toledo International',
#  'TRININxx726': 'Trinity Industries',
#  'MUTUAMLI901': 'Mutual Of America Life Insurance',
#  'LINCELHO283': 'Lincoln Electric Holdings',
#  'TAILBRxx344': 'Tailored Brands',
#  'AOSMxxxx147': 'A.o. Smith',
#  'ARCBESTx272': 'Arcbest',
#  'GODADDYx363': 'Godaddy',
#  'SKYWESTx797': 'Skywest',
#  'BOSTPRxx906': 'Boston Properties',
#  'ENABMIPA375': 'Enable Midstream Partners',
#  'MIDDLEBY451': 'Middleby',
#  'NOWxxxxx497': 'Now',
#  'UNISYSxx113': 'Unisys',
#  'VISTEONx503': 'Visteon',
#  'GRAHHOxx889': 'Graham Holdings',
#  'RESOFOPR213': 'Resolute Forest Products',
#  'CALERESx219': 'Caleres',
#  'AGNCINxx187': 'Agnc Investment',
#  'HILLHOxx979': 'Hill-rom Holdings',
#  'MOOGxxxx141': 'Moog',
#  'LEGGMAxx931': 'Legg Mason',
#  'ATMOENxx349': 'Atmos Energy',
#  'WOODWARD191': 'Woodward',
#  'PALOALNE594': 'Palo Alto Networks',
#  'HBFUxxxx368': 'H.b. Fuller',
#  'AKAMTExx741': 'Akamai Technologies',
#  'AVAYHOxx584': 'Avaya Holdings',
#  'MAXIMUSx673': 'Maximus',
#  'PERKINEL829': 'Perkinelmer',
#  'HAWAELIN703': 'Hawaiian Electric Industries',
#  'KANSCISO662': 'Kansas City Southern',
#  'APTARGRO700': 'Aptargroup',
#  'PUBLSTxx828': 'Public Storage',
#  'SELEINGR450': 'Selective Insurance Group',
#  'ITTxxxxx884': 'Itt',
#  'DONALDSO525': 'Donaldson',
#  'PARKHORE634': 'Park Hotels & Resorts',
#  'KIRBYxxx428': 'Kirby',
#  'HAWAHOxx623': 'Hawaiian Holdings',
#  'POPULARx460': 'Popular',
#  'RANGRExx852': 'Range Resources',
#  'PCCOxxxx425': 'Pc Connection',
#  'AMICMUIN739': 'Amica Mutual Insurance',
#  'ENERSYSx497': 'Enersys',
#  'HELMPAxx789': 'Helmerich & Payne',
#  'NLVFIxxx700': 'Nlv Financial',
#  'VALMINxx399': 'Valmont Industries',
#  'PAExxxxx072': 'Pae',
#  'TEXAROxx600': 'Texas Roadhouse',
#  'COOPTIRU474': 'Cooper Tire & Rubber',
#  'EUROWOxx854': 'Euronet Worldwide',
#  'ZILLGRxx175': 'Zillow Group',
#  'ATLAAIWO772': 'Atlas Air Worldwide Holdings',
#  'ENERHOxx231': 'Energizer Holdings',
#  'MAGEMIPA917': 'Magellan Midstream Partners',
#  'HAINCEGR484': 'Hain Celestial Group',
#  'UNIVCOxx449': 'Univision Communications',
#  'EQUIRExx263': 'Equity Residential',
#  'ALLITRHO251': 'Allison Transmission Holdings',
#  'COLOCAxx366': 'Colony Capital',
#  'TTMTExxx573': 'Ttm Technologies',
#  'CLEACHOU262': 'Clear Channel Outdoor Holdings',
#  'GUESSxxx638': 'Guess',
#  'RENTACEN296': 'Rent-a-center',
#  'TAKEINSO370': 'Take-two Interactive Software',
#  'VISHINxx037': 'Vishay Intertechnology',
#  'TRANSUNI746': 'Transunion',
#  'COOPERxx237': 'Cooper',
#  'FLEETExx668': 'Fleetcor Technologies',
#  'RHxxxxxx609': 'Rh',
#  'RENEENGR220': 'Renewable Energy Group',
#  'BLUEHOxx481': 'Bluelinx Holdings',
#  'CALIRExx558': 'California Resources',
#  'TOPBUILD194': 'Topbuild',
#  'CHARRILA174': 'Charles River Laboratories International',
#  'COMFSYUS077': 'Comfort Systems Usa',
#  'VERIANxx225': 'Verisk Analytics',
#  'RESMEDxx714': 'Resmed',
#  'TELEFLEX574': 'Teleflex',
#  'NEWJEREx314': 'New Jersey Resources',
#  'NEWREINx383': 'New Residential Investment',
#  'INTEBRGR847': 'Interactive Brokers Group',
#  'ZAYOGRHO906': 'Zayo Group Holdings',
#  'HERMMIxx498': 'Herman Miller',
#  'GROCOUHO474': 'Grocery Outlet Holding',
#  'JCREGRxx511': 'J.crew Group',
#  'CENTCOxx337': 'Century Communities',
#  'ELDORExx661': 'Eldorado Resorts',
#  'CATALENT590': 'Catalent',
#  'ITRONxxx594': 'Itron',
#  'MIHOxxxx111': 'M/i Homes',
#  'CBOEGLMA300': 'Cboe Global Markets',
#  'IDEXxxxx179': 'Idex',
#  'BELDENxx229': 'Belden',
#  'CURTISSW905': 'Curtiss-wright',
#  'CHEEFAxx209': 'Cheesecake Factory',
#  'GENEENxx616': 'Genesis Energy',
#  'GEOGRxxx720': 'Geo Group',
#  'PATTENxx847': 'Patterson-uti Energy',
#  'WERNENxx261': 'Werner Enterprises',
#  'INGERAxx505': 'Ingersoll Rand',
#  'VERSOxxx343': 'Verso',
#  'MUELINxx986': 'Mueller Industries',
#  'NUSKENxx293': 'Nu Skin Enterprises',
#  'REVLONxx957': 'Revlon',
#  'ARISNExx220': 'Arista Networks',
#  'IDEXLAxx650': 'Idexx Laboratories',
#  'ALIGTExx852': 'Align Technology',
#  'WATERSxx283': 'Waters',
#  'SYNOFIxx891': 'Synovus Financial',
#  'BRIGHOxx857': 'Brightview Holdings',
#  'REVGRxxx465': 'Rev Group',
#  'BROWBRxx275': 'Brown & Brown',
#  'VALVOLIN290': 'Valvoline',
#  'KNIGCOxx062': 'Knights Of Columbus',
#  'CENTGAPE405': 'Central Garden & Pet',
#  'CARPTExx480': 'Carpenter Technology',
#  'SLMCOxxx706': 'Slm Corp',
#  'KENNAMET158': 'Kennametal',
#  'LCIINxxx365': 'Lci Industries',
#  'TRUEBLUE269': 'Trueblue',
#  'CIMAENxx303': 'Cimarex Energy',
#  'SPLUNKxx243': 'Splunk',
#  'SITELASU203': 'Siteone Landscape Supply',
#  'HEXCELxx514': 'Hexcel',
#  'FTICOxxx799': 'Fti Consulting',
#  'PARTCIHO166': 'Party City Holdco',
#  'OHIONAMU608': 'Ohio National Mutual',
#  'PATRINxx666': 'Patrick Industries',
#  'CADEDESY323': 'Cadence Design Systems',
#  'CDKGLxxx729': 'Cdk Global',
#  'AVALCOxx241': 'Avalonbay Communities',
#  'WABANAxx610': 'Wabash National',
#  'SERVPRTR412': 'Service Properties Trust',
#  'MAXIINPR390': 'Maxim Integrated Products',
#  'PEOPUNFI423': "People's United Financial",
#  'BIORLAxx225': 'Bio-rad Laboratories',
#  'OPTICAHE352': 'Option Care Health',
#  'LOUISIAN596': 'Louisiana-pacific',
#  'TEGNAxxx848': 'Tegna',
#  'TERADYNE361': 'Teradyne',
#  'ARCHRExx183': 'Arch Resources',
#  'EPAMSYxx619': 'Epam Systems',
#  'WPXENxxx474': 'Wpx Energy',
#  'CONTENxx868': 'Contura Energy',
#  'ENSIGRxx506': 'Ensign Group',
#  'FIRSHONA377': 'First Horizon National',
#  'WOLVWOWI485': 'Wolverine World Wide',
#  'VAILRExx470': 'Vail Resorts',
#  'BENCELxx402': 'Benchmark Electronics',
#  'HNIxxxxx370': 'Hni',
#  'F5NExxxx759': 'F5 Networks',
#  'AFFIMAGR102': 'Affiliated Managers Group',
#  'OGEENxxx216': 'Oge Energy',
#  'UNIVCOxx277': 'Universal Corp',
#  'BOKFIxxx294': 'Bok Financial',
#  'MANTINxx673': 'Mantech International',
#  'SUMMMAxx324': 'Summit Materials',
#  'AMNHESEx903': 'Amn Healthcare Services',
#  'GROUPONx469': 'Groupon',
#  'NEWMGRxx227': 'Newmark Group',
#  'FOSSGRxx870': 'Fossil Group',
#  'MODIMAxx628': 'Modine Manufacturing',
#  'GRIFCOxx788': 'Griffon Corporation',
#  'CYPRSExx403': 'Cypress Semiconductor',
#  'GENEHOxx692': 'Generac Holdings',
#  'MATSONxx379': 'Matson',
#  'GENESCOx414': 'Genesco',
#  'NORDSONx736': 'Nordson',
#  'NEWMARKE332': 'Newmarket',
#  'ECHOGLLO208': 'Echo Global Logistics',
#  'REXNORDx884': 'Rexnord',
#  'INCYTExx045': 'Incyte',
#  'FORTINET887': 'Fortinet',
#  'FOUNBUMA702': 'Foundation Building Materials',
#  'AARxxxxx269': 'Aar',
#  'CENTBRxx181': 'Centric Brands',
#  'EDGEPECA216': 'Edgewell Personal Care',
#  'FEDEMUIN547': 'Federated Mutual Insurance',
#  'SCHNSTIN723': 'Schnitzer Steel Industries',
#  'PORTGEEL938': 'Portland General Electric',
#  'GRAYTExx759': 'Gray Television',
#  'BGCPAxxx862': 'Bgc Partners',
#  'ECHOSTAR364': 'Echostar',
#  'BEAZHOUS648': 'Beazer Homes Usa',
#  'LHCGRxxx222': 'Lhc Group',
#  'SERVGLHO164': 'Servicemaster Global Holdings',
#  'BRUKERxx112': 'Bruker',
#  'OASIPExx224': 'Oasis Petroleum',
#  'CROSPAxx016': 'Crossamerica Partners',
#  'MYRGRxxx455': 'Myr Group',
#  'VIASATxx259': 'Viasat',
#  'GNCHOxxx686': 'Gnc Holdings',
#  'CABOOIGA450': 'Cabot Oil & Gas',
#  'BRIGHOFA780': 'Bright Horizons Family Solutions',
#  'VISTOUxx131': 'Vista Outdoor',
#  'HEICOxxx345': 'Heico',
#  'WYNDHORE343': 'Wyndham Hotels & Resorts',
#  'TCFFIxxx081': 'Tcf Financial',
#  'PRIMERIC488': 'Primerica',
#  'PROPHOxx603': 'Propetro Holding',
#  'OCEAINxx122': 'Oceaneering International',
#  'FLOODEHO162': 'Floor & Decor Holdings',
#  'COPARTxx268': 'Copart',
#  'CHICFAxx519': "Chico's Fas",
#  'BARNNOED569': 'Barnes & Noble Education',
#  'MAXATExx368': 'Maxar Technologies',
#  'EVERCORE766': 'Evercore',
#  'DECKOUxx132': 'Deckers Outdoor',
#  'EXPRESSx195': 'Express',
#  'HOVNENxx174': 'Hovnanian Enterprises',
#  'AIRLExxx584': 'Air Lease',
#  'ROLLINSx174': 'Rollins',
#  'SBACOxxx506': 'Sba Communications',
#  'DELUXExx259': 'Deluxe',
#  'MRCOGRxx293': 'Mr. Cooper Group',
#  'HERCHOxx756': 'Herc Holdings',
#  'HEALPRxx567': 'Healthpeak Properties',
#  'SPXFLxxx539': 'Spx Flow',
#  'LIBEOISE866': 'Liberty Oilfield Services'}
