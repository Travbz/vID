# %% [markdown]
# ### This script converts a column of names into unique IDs and populates a new column with those values.
#
# ### You will need to change a few values to run this code on your unique file name and colume name

# %%
import pandas as pd

# %%
# This code reads the file. Change to ('path/your-file-name.filetype')
try:
    df = pd.read_excel('company.xlsx')
    df.to_csv('company.csv', mode = 'w', index=False)
except:
    df = pd.read_csv('company.csv')
df
# Out:
#        Rank            Metals Industry  Number Of Employees Change In \n Rank  \
# 0       1.0                    Walmart            2200000.0                 -
# 1       2.0                 Amazon.com             798000.0               3.0
# 2       3.0                Exxon Mobil              74900.0              -1.0
# 3       4.0                      Apple             137000.0              -1.0
# 4       5.0                 Cvs Health             290000.0               3.0
# ..      ...                        ...                  ...               ...
# 995   996.0           Mr. Cooper Group               9100.0                 -
# 996   997.0              Herc Holdings               5100.0              -4.0
# 997   998.0      Healthpeak Properties                204.0                 -
# 998   999.0                   Spx Flow               5000.0             -37.0
# 999  1000.0  Liberty Oilfield Services               2571.0             -58.0
#
#                         Industry  \
# 0                 Retail Company
# 1             E-commerce Company
# 2                    Corporation
# 3             Technology Company
# 4             Healthcare Company
# ..                           ...
# 995          Home Loan Servicers
# 996             Equipment Rental
# 997       Real Estate Investment
# 998  Pumps And Pumping Equipment
# 999                  Oil And Gas
#
#                                    Company Description  \
# 0    Walmart Inc. Is An American Multinational Reta...
# 1    Amazon.com, Inc. Is An American Multinational ...
# 2    Exxon Mobil Corp. engages in the exploration, ...
# 3    Apple Inc. Is An American Multinational Techno...
# 4    Cvs Health Is An American Healthcare Company T...
# ..                                                 ...
# 995  Mr. Cooper Group Inc. Provides Quality Servici...
# 996  They Are One Of The Largest Equipment Rental C...
# 997  Healthpeak Properties, Inc. Is A Real Estate I...
# 998  It Is A World Leader In Sustainable Solutions ...
# 999  Liberty Is An Innovative Service Company Provi...
#
#      Revenues\n ($millions) Revenue \n Change Profits\n ($millions)  \
# 0                  523964.0             0.019               14881.0
# 1                  280522.0             0.205               11588.0
# 2                  264938.0            -0.087               14340.0
# 3                  260174.0             -0.02               55256.0
# 4                  256776.0              0.32                6634.0
# ..                      ...               ...                   ...
# 995                  2007.0                 -                 274.0
# 996                  1999.0             0.011                  47.5
# 997                  1997.0             0.082                  45.5
# 998                  1996.0            -0.045                 -95.1
# 999                  1990.0            -0.076                  39.0
#
#     Profit \n Change  Assets\n ($millions) Market Value \n As of 3/31/20 ($m)
# 0              1.231              236495.0                           321803.0
# 1               0.15              225248.0                           970680.0
# 2             -0.312              362597.0                           160696.0
# 3             -0.072              338516.0                          1112641.0
# 4                  -              222449.0                            77376.0
# ..               ...                   ...                                ...
# 995                -               18305.0                              674.0
# 996           -0.313                3817.0                              591.0
# 997           -0.957               14033.0                            12059.0
# 998           -3.161                2437.0                             1212.0
# 999           -0.692                1283.0                              303.0
#
# [1000 rows x 12 columns]

# %%
import pandas as pd

def generate_unique_id(company_name: str) -> str:
    """
    :params company_name 
    :return a unique 12 character ID based on the named from the input
    
    """
    unique_key = ''
    company_name = company_name.upper()
    
    for char in (("THE ", ""), (" THE ", " "), (" AND ", " "), (" OF ", " ")):
        company_name = company_name.replace(*char)
        
    new_name_list = []
    name_list = company_name.split(' ')
    wordCount = len(name_list)
    
    for name in name_list:
        new_name_list.append(''.join(ch for ch in name if ch.isalnum()))
    
    if wordCount == 1:
            unique_key = new_name_list[0][0:8]
    else:
        for i in range(len(new_name_list)):
            if i == 0:
                unique_key += new_name_list[i][:4]
            else:
                unique_key += new_name_list[i][:2]

            if len(unique_key) > 7:
                break

    if len(unique_key) <= 8:
        unique_key += 'x' * (8 - len(unique_key))
    
    hash = 0    
    for ch in unique_key:
        hash = ( hash*281  ^ ord(ch)*997) & 0xFFFFFFFF
    hash_number = str(hash)
    
    unique_key += hash_number[1:3]
    
    return unique_key

# %%
keys_list = []
"""Change the name of (row[" <Your name column's name here>  "])) to match your columns name"""

for index, row in df.iterrows():       # change name here to your columns name
    keys_list.append(generate_unique_id(row["Metals Industry"]))
                                    # RIGHT HERE ^^^
df['unique_ID'] = keys_list

# %%
temp_cols=df.columns.tolist()
new_cols=temp_cols[-1:] + temp_cols[:-1]
df=df[new_cols]
df.head()
# Out:
#      unique_ID  Rank Metals Industry  Number Of Employees Change In \n Rank  \
# 0  WALMARTx920   1.0         Walmart            2200000.0                 -
# 1  AMAZONCO171   2.0      Amazon.com             798000.0               3.0
# 2  EXXOMOxx312   3.0     Exxon Mobil              74900.0              -1.0
# 3  APPLExxx196   4.0           Apple             137000.0              -1.0
# 4  CVSHExxx124   5.0      Cvs Health             290000.0               3.0
#
#              Industry                                Company Description  \
# 0      Retail Company  Walmart Inc. Is An American Multinational Reta...
# 1  E-commerce Company  Amazon.com, Inc. Is An American Multinational ...
# 2         Corporation  Exxon Mobil Corp. engages in the exploration, ...
# 3  Technology Company  Apple Inc. Is An American Multinational Techno...
# 4  Healthcare Company  Cvs Health Is An American Healthcare Company T...
#
#    Revenues\n ($millions) Revenue \n Change Profits\n ($millions)  \
# 0                523964.0             0.019               14881.0
# 1                280522.0             0.205               11588.0
# 2                264938.0            -0.087               14340.0
# 3                260174.0             -0.02               55256.0
# 4                256776.0              0.32                6634.0
#
#   Profit \n Change  Assets\n ($millions) Market Value \n As of 3/31/20 ($m)
# 0            1.231              236495.0                           321803.0
# 1             0.15              225248.0                           970680.0
# 2           -0.312              362597.0                           160696.0
# 3           -0.072              338516.0                          1112641.0
# 4                -              222449.0                            77376.0

# %%
# check for duplicates, none if true
print(len(keys_list) == len(list(set(keys_list))))
# Out:
# False

# %%
"""Change the name of ['Metals Industry'] to match your columns name"""
keys = keys_list

# your col name below vvvvv
values = df['Metals Industry'].to_list()
# change name above ^^^^^

alphaZip= zip(keys,values)
myDict = dict(alphaZip)
myDict
# Out:
# {'WALMARTx920': 'Walmart',
#  'AMAZONCO171': 'Amazon.com',
#  'EXXOMOxx312': 'Exxon Mobil',
#  'APPLExxx196': 'Apple',
#  'CVSHExxx124': 'Cvs Health',
#  'BERKHAxx222': 'Berkshire Hathaway',
#  'UNITGRxx112': 'Unitedhealth Group',
#  'MCKESSON268': 'Mckesson',
#  'ATTxxxxx997': 'At&t',
#  'AMERISOU237': 'Amerisourcebergen',
#  'ALPHABET799': 'Alphabet',
#  'FORDMOxx240': 'Ford Motor',
#  'CIGNAxxx587': 'Cigna',
#  'COSTWHxx216': 'Costco Wholesale',
#  'CHEVRONx214': 'Chevron',
#  'CARDHExx293': 'Cardinal Health',
#  'JPMOCHxx298': 'Jpmorgan Chase',
#  'GENEMOxx446': 'General Motors',
#  'WALGBOAL206': 'Walgreens Boots Alliance',
#  'VERICOxx117': 'Verizon Communications',
#  'MICROSOF152': 'Microsoft',
#  'MARAPExx418': 'Marathon Petroleum',
#  'KROGERxx195': 'Kroger',
#  'FANNMAxx603': 'Fannie Mae',
#  'BANKAMxx292': 'Bank Of America',
#  'HOMEDExx120': 'Home Depot',
#  'PHIL66xx389': 'Phillips 66',
#  'COMCASTx283': 'Comcast',
#  'ANTHEMxx384': 'Anthem',
#  'WELLFAxx315': 'Wells Fargo',
#  'CITIGROU327': 'Citigroup',
#  'VALEENxx176': 'Valero Energy',
#  'GENEELxx418': 'General Electric',
#  'DELLTExx165': 'Dell Technologies',
#  'JOHNJOxx274': 'Johnson & Johnson',
#  'STATFAIN327': 'State Farm Insurance',
#  'TARGETxx281': 'Target',
#  'IBMxxxxx318': 'Ibm',
#  'RAYTTExx270': 'Raytheon Technologies',
#  'BOEINGxx824': 'Boeing',
#  'FREDMAxx144': 'Freddie Mac',
#  'CENTENEx100': 'Centene',
#  'UNITPASE309': 'United Parcel Service',
#  'LOWESxxx279': "Lowe's",
#  'INTELxxx129': 'Intel',
#  'FACEBOOK350': 'Facebook',
#  'FEDEXxxx401': 'Fedex',
#  'METLIFEx327': 'Metlife',
#  'WALTDIxx130': 'Walt Disney',
#  'PROCGAxx148': 'Procter & Gamble',
#  'PEPSICOx196': 'Pepsico',
#  'HUMANAxx215': 'Humana',
#  'PRUDFIxx427': 'Prudential Financial',
#  'ARCHDAMI329': 'Archer Daniels Midland',
#  'ALBERTSO407': 'Albertsons',
#  'SYSCOxxx428': 'Sysco',
#  'LOCKMAxx195': 'Lockheed Martin',
#  'HPxxxxxx263': 'Hp',
#  'ENERTRxx359': 'Energy Transfer',
#  'GOLDSAGR138': 'Goldman Sachs Group',
#  'MORGSTxx275': 'Morgan Stanley',
#  'CATERPIL233': 'Caterpillar',
#  'CISCSYxx303': 'Cisco Systems',
#  'PFIZERxx175': 'Pfizer',
#  'HCAHExxx422': 'Hca Healthcare',
#  'AIGxxxxx307': 'Aig',
#  'AMEREXxx392': 'American Express',
#  'DELTAILI421': 'Delta Air Lines',
#  'MERCKxxx231': 'Merck',
#  'AMERAIGR173': 'American Airlines Group',
#  'CHARCOxx345': 'Charter Communications',
#  'ALLSTATE310': 'Allstate',
#  'NEWYOLIIN105': 'New York Life Insurance',
#  'NATIONWI378': 'Nationwide',
#  'BESTBUxx179': 'Best Buy',
#  'UNITAIHO303': 'United Airlines Holdings',
#  'LIBEMUIN241': 'Liberty Mutual Insurance Group',
#  'DOWxxxxx100': 'Dow',
#  'TYSOFOxx327': 'Tyson Foods',
#  'TJXxxxxx320': 'Tjx',
#  'TIAAxxxx258': 'Tiaa',
#  'ORACLExx191': 'Oracle',
#  'GENEDYxx238': 'General Dynamics',
#  'DEERExxx261': 'Deere',
#  'NIKExxxx315': 'Nike',
#  'PROGRESS109': 'Progressive',
#  'PUBLSUMA395': 'Publix Super Markets',
#  'COCACOLA239': 'Coca-cola',
#  'MASSMULI325': 'Massachusetts Mutual Life Insurance',
#  'TECHDAxx535': 'Tech Data',
#  'WORLFUSE134': 'World Fuel Services',
#  'HONEINxx393': 'Honeywell International',
#  'CONOCOPH311': 'Conocophillips',
#  'USAAxxxx276': 'Usaa',
#  'EXELONxx155': 'Exelon',
#  'NORTGRxx232': 'Northrop Grumman',
#  'CAPIONFI130': 'Capital One Financial',
#  'PLAIGPHO311': 'Plains Gp Holdings',
#  'ABBVIExx434': 'Abbvie',
#  'STONGRxx392': 'Stonex Group',
#  'ENTEPRPA492': 'Enterprise Products Partners',
#  'NORTMUxx875': 'Northwestern Mutual',
#  '3Mxxxxxx180': '3m',
#  'ABBOLAxx253': 'Abbott Laboratories',
#  'CHSxxxxx304': 'Chs',
#  'TRAVELER382': 'Travelers',
#  'PHILMOIN845': 'Philip Morris International',
#  'RAYTHEON261': 'Raytheon',
#  'HEWLPAEN190': 'Hewlett Packard Enterprise',
#  'ARROELxx205': 'Arrow Electronics',
#  'VIACOMCB184': 'Viacomcbs',
#  'DOLLGExx286': 'Dollar General',
#  'USBAxxxx417': 'U.s. Bancorp',
#  'STARBUCK665': 'Starbucks',
#  'BRISSQxx297': 'Bristol-myers Squibb',
#  'USFOHOxx350': 'Us Foods Holding',
#  'MONDINxx104': 'Mondelez International',
#  'PACCARxx103': 'Paccar',
#  'THERFISC772': 'Thermo Fisher Scientific',
#  'MACYSxxx100': "Macy's",
#  'JABILxxx282': 'Jabil',
#  'KRAFHExx793': 'Kraft Heinz',
#  'DUKEENxx329': 'Duke Energy',
#  'TESLAxxx392': 'Tesla',
#  'PBFENxxx396': 'Pbf Energy',
#  'QUALCOMM531': 'Qualcomm',
#  'NGLENPAx320': 'Ngl Energy Partners',
#  'CBREGRxx140': 'Cbre Group',
#  'BAKEHUxx164': 'Baker Hughes',
#  'SYNNEXxx121': 'Synnex',
#  'DOLLTRxx320': 'Dollar Tree',
#  'CUMMINSx398': 'Cummins',
#  'UNITNAFO250': 'United Natural Foods',
#  'MICRTExx372': 'Microchip Technology',
#  'AMGENxxx176': 'Amgen',
#  'PENSAUGR905': 'Penske Automotive Group',
#  'VISAxxxx107': 'Visa',
#  'BROADCOM272': 'Broadcom',
#  'NUCORxxx334': 'Nucor',
#  'GILESCxx425': 'Gilead Sciences',
#  'SOUTAIxx421': 'Southwest Airlines',
#  'HALLIBUR570': 'Halliburton',
#  'CENTURYL479': 'Centurylink',
#  'INTEPAxx158': 'International Paper',
#  'ELILIxxx254': 'Eli Lilly',
#  'AFLACxxx319': 'Aflac',
#  'LENNARxx202': 'Lennar',
#  'OCCIPExx205': 'Occidental Petroleum',
#  'UNIOPAxx173': 'Union Pacific',
#  'RITEAIxx251': 'Rite Aid',
#  'PNCFISEGR110': 'Pnc Financial Services Group',
#  'DUPONTxx285': 'Dupont',
#  'SOUTHERN299': 'Southern',
#  'AUTONATI297': 'Autonation',
#  'DXCTExxx115': 'Dxc Technology',
#  'MCDONALD353': "Mcdonald's",
#  'MARRINxx110': 'Marriott International',
#  'MANPOWER249': 'Manpowergroup',
#  'BANKNEYO333': 'Bank Of New York Mellon',
#  'HARTFISE396': 'Hartford Financial Services Group',
#  'DANAHERx326': 'Danaher',
#  'WHIRLPOO306': 'Whirlpool',
#  'AECOMxxx290': 'Aecom',
#  'NETFLIXx407': 'Netflix',
#  'KOHLSxxx621': "Kohl's",
#  'LEARxxxx284': 'Lear',
#  'ALTRGRxx386': 'Altria Group',
#  'PERFFOGR857': '\nperformance Food Group',
#  'AVNETxxx977': 'Avnet',
#  'SYNCFIxx404': 'Synchrony Financial',
#  'GENUPAxx240': 'Genuine Parts',
#  'NEXTENxx132': 'Nextera Energy',
#  'CARMAXxx216': 'Carmax',
#  'TENEHExx374': 'Tenet Healthcare',
#  'KIMBERLY188': 'Kimberly-clark',
#  'EMERELxx231': 'Emerson Electric',
#  'WESTROCK277': 'Westrock',
#  'CDWxxxxx919': 'Cdw',
#  'JONELALA229': 'Jones Lang Lasalle',
#  'SHERWINW327': 'Sherwin-williams',
#  'FLUORxxx182': 'Fluor',
#  'PAYPHOxx116': 'Paypal Holdings',
#  'DRHOxxxx228': 'D.r. Horton',
#  'HOLLYFRO216': 'Hollyfrontier',
#  'TENNECOx247': 'Tenneco',
#  'EOGRExxx206': 'Eog Resources',
#  'BECTDIxx372': 'Becton Dickinson',
#  'LINCNAxx124': 'Lincoln National',
#  'PGExxxxx228': 'Pg&e',
#  'SALESFOR128': 'Salesforce.com',
#  'MASTERCA253': 'Mastercard',
#  'GENEMIxx100': 'General Mills',
#  'MOLIHExx246': 'Molina Healthcare',
#  'COGNTESO208': 'Cognizant Technology Solutions',
#  'MARSMCxx340': 'Marsh & Mclennan',
#  'XPOLOxxx460': 'Xpo Logistics',
#  'DOMIENxx313': 'Dominion Energy',
#  'WESTDIxx514': 'Western Digital',
#  'GAPxxxxx299': 'Gap',
#  'ARAMARKx381': 'Aramark',
#  'PRINFIxx268': 'Principal Financial',
#  'ROSSSTxx596': '\nross Stores',
#  'COLGATEP394': 'Colgate-palmolive',
#  'AMERELPO352': 'American Electric Power',
#  'NORDSTRO292': 'Nordstrom',
#  'JACOENGR177': 'Jacobs Engineering Group',
#  'WASTMAxx416': 'Waste Management',
#  'CHROWOxx298': 'C.h. Robinson Worldwide',
#  'PPGINxxx114': 'Ppg Industries',
#  'BOOKHOxx327': 'Booking Holdings',
#  'OMNIGRxx907': 'Omnicom Group',
#  'LOEWSxxx183': 'Loews',
#  'ECOLABxx707': 'Ecolab',
#  'STRYKERx230': 'Stryker',
#  'ESTELAxx903': 'Estee Lauder',
#  'GOODTIRU367': 'Goodyear Tire & Rubber',
#  'TRUIFIxx350': 'Truist Financial',
#  'APPLMAxx235': 'Applied Materials',
#  'BLACKROC279': 'Blackrock',
#  'STANBLDE391': 'Stanley Black & Decker',
#  'FREEPORT262': 'Freeport-mcmoran',
#  'TEXAINxx424': 'Texas Instruments',
#  'BIOGENxx299': 'Biogen',
#  'PARKERHA176': 'Parker-hannifin',
#  'REINGRAM427': 'Reinsurance Group Of America',
#  'HOWMAExx340': 'Howmet Aerospace',
#  'AUTODAPR305': 'Automatic Data Processing',
#  'UBERTExx339': 'Uber Technologies',
#  'ILLITOWO364': 'Illinois Tool Works',
#  'DAVITAxx296': 'Davita',
#  'DISCFISE279': 'Discover Financial Services',
#  'LANDOLxx363': "Land O'lakes",
#  'VFxxxxxx143': 'Vf',
#  'CORTEVAx345': 'Corteva',
#  'LASVESAx344': 'Las Vegas Sands',
#  'TEXTRONx386': 'Textron',
#  'KELLOGGx116': 'Kellogg',
#  'GUARLIIN234': 'Guardian Life Ins. Co. Of America',
#  'QURARExx287': 'Qurate Retail',
#  'COREHOxx413': 'Core-mark Holding',
#  'COMMHESY227': 'Community Health Systems',
#  'KINDMOxx592': 'Kinder Morgan',
#  'BJSWHCLx372': "Bj's Wholesale Club",
#  'STATSTxx251': 'State Street',
#  'AMERFIxx157': 'Ameriprise Financial',
#  'GLOBPAxx404': 'Global Payments',
#  'UNITSTST659': 'United States Steel',
#  'LBRxxxxx764': 'L Brands',
#  'MGMREINx399': 'Mgm Resorts International',
#  'L3HATExx415': 'L3harris Technologies',
#  'DISHNExx683': 'Dish Network',
#  'LITHMOxx248': 'Lithia Motors',
#  'DTEENxxx100': 'Dte Energy',
#  'AMERFAIN305': 'American Family Insurance Group',
#  'FARMINEX124': 'Farmers Insurance Exchange',
#  'CONSEDxx204': 'Consolidated Edison',
#  'LKQxxxxx336': 'Lkq',
#  'SEMPENxx843': 'Sempra Energy',
#  'EDISINxx114': 'Edison International',
#  'CENTENxx100': 'Centerpoint Energy',
#  'QUANSExx374': 'Quanta Services',
#  'MURPUSxx421': 'Murphy Usa',
#  'EXPEGRxx418': 'Expedia Group',
#  'GROU1AUx364': 'Group 1 Automotive',
#  'BEDBABEx199': 'Bed Bath & Beyond',
#  'UNUMGRxx117': 'Unum Group',
#  'CSXxxxxx140': 'Csx',
#  'AUTOZONE236': 'Autozone',
#  'PACILIxx287': 'Pacific Life',
#  'VISTENxx294': 'Vistra Energy',
#  'CHARSCxx339': 'Charles Schwab',
#  'CROWHOxx101': 'Crown Holdings',
#  'ALLYFIxx354': 'Ally Financial',
#  'LABOCOAM515': 'Laboratory Corp. Of America',
#  'LIVENAEN370': 'Live Nation Entertainment',
#  'XCELENxx416': 'Xcel Energy',
#  'CORNINGx949': 'Corning',
#  'WWGRxxxx181': 'W.w. Grainger',
#  'BALLxxxx139': 'Ball',
#  'FOXxxxxx109': 'Fox',
#  'UNIVHESE329': 'Universal Health Services',
#  'BAXTINxx632': 'Baxter International',
#  'NORFSOxx290': 'Norfolk Southern',
#  'NAVIINxx144': 'Navistar International',
#  'ADOBExxx132': 'Adobe',
#  'JCPExxxx140': 'J.c. Penney',
#  'DISCOVER424': 'Discovery',
#  'KEURDRPE156': 'Keurig Dr Pepper',
#  'LEIDHOxx215': 'Leidos Holdings',
#  'IQVIHOxx425': 'Iqvia Holdings',
#  'RELISTAL278': 'Reliance Steel & Aluminum',
#  'NVIDIAxx165': 'Nvidia',
#  'ENTERGYx314': 'Entergy',
#  'FIRSTENE386': 'Firstenergy',
#  'EBAYxxxx322': 'Ebay',
#  'BOSTSCxx159': 'Boston Scientific',
#  'OFFIDExx828': 'Office Depot',
#  'MOLSCOBE245': 'Molson Coors Beverage',
#  'STEEDYxx284': 'Steel Dynamics',
#  'MUTUOMIN258': 'Mutual Of Omaha Insurance',
#  'SONIAUxx230': 'Sonic Automotive',
#  'ALCOAxxx125': 'Alcoa',
#  'FIDENAIN642': 'Fidelity National Information Services',
#  'HENRSCxx142': 'Henry Schein',
#  'REPUSExx132': 'Republic Services',
#  'LIBEMExx378': 'Liberty Media',
#  'PETEKISO365': "Peter Kiewit Sons'",
#  'INTEGRxx312': 'Interpublic Group',
#  'PULTEGRO571': 'Pultegroup',
#  'AESxxxxx390': 'Aes',
#  'FISERVxx222': 'Fiserv',
#  'BORGWARN334': 'Borgwarner',
#  'ONEOKxxx327': 'Oneok',
#  'OREIAUxx194': "O'reilly Automotive",
#  'ASSURANT285': 'Assurant',
#  'NEWEBRxx210': 'Newell Brands',
#  'PUBLSEEN103': 'Public Service Enterprise Group',
#  'NEWSCOxx191': 'News Corp.',
#  'CALPINEx330': 'Calpine',
#  'AUTOINxx174': 'Auto-owners Insurance',
#  'MOHAINxx150': 'Mohawk Industries',
#  'PVHxxxxx670': 'Pvh',
#  'CAMPSOxx208': 'Campbell Soup',
#  'NRGENxxx755': 'Nrg Energy',
#  'FIFTTHBA349': 'Fifth Third Bancorp',
#  'HERTGLHO260': 'Hertz Global Holdings',
#  'ALTIUSxx270': 'Altice Usa',
#  'NEWMONTx282': 'Newmont',
#  'CHENENxx269': 'Cheniere Energy',
#  'ADVAAUPA351': 'Advance Auto Parts',
#  'LAMRExxx106': 'Lam Research',
#  'OWENMIxx112': 'Owens & Minor',
#  'EQUIHOxx198': 'Equitable Holdings',
#  'CONABRxx308': 'Conagra Brands',
#  'MARKELxx280': 'Markel',
#  'JONEFIED310': 'Jones Financial (edward Jones)',
#  'HORMFOxx126': 'Hormel Foods',
#  'HILTWOHO276': 'Hilton Worldwide Holdings',
#  'UNIVSOxx355': 'Univar Solutions',
#  'UNITRExx350': 'United Rentals',
#  'PIONNARE131': 'Pioneer Natural Resources',
#  'DELEUSHO169': 'Delek Us Holdings',
#  'EASTCHxx297': 'Eastman Chemical',
#  'EMCOGRxx423': 'Emcor Group',
#  'AVISBUGR209': 'Avis Budget Group',
#  'JBHUTRSE304': 'J.b. Hunt Transport Services',
#  'XEROHOxx110': 'Xerox Holdings',
#  'WAYFAIRx180': 'Wayfair',
#  'KKRxxxxx148': 'Kkr',
#  'AGCOxxxx524': 'Agco',
#  'ALLEGHAN123': 'Alleghany',
#  'ICAHENxx380': 'Icahn Enterprises',
#  'VOYAFIxx606': 'Voya Financial',
#  'RYDESYxx139': 'Ryder System',
#  'AIRPRCHx429': 'Air Products & Chemicals',
#  'MOSAICxx116': 'Mosaic',
#  'HUNTININ158': 'Huntington Ingalls Industries',
#  'BERRGLGR292': 'Berry Global Group',
#  'ANIXINxx172': 'Anixter International',
#  'ALASAIGR428': 'Alaska Air Group',
#  'YUMCHHOx357': 'Yum China Holdings',
#  'DICKSPGO687': "Dick's Sporting Goods",
#  'CAESENxx360': 'Caesars Entertainment',
#  'GENWFIxx405': 'Genworth Financial',
#  'TARGRExx338': 'Targa Resources',
#  'COTYxxxx118': 'Coty',
#  'DANAxxxx619': 'Dana',
#  'THRIFIFO634': 'Thrivent Financial For Lutherans',
#  'AUTOLIVx632': 'Autoliv',
#  'SPARTANN870': 'Spartannash',
#  'EVERENxx271': 'Eversource Energy',
#  'DARDRExx538': 'Darden Restaurants',
#  'CHESENxx234': 'Chesapeake Energy',
#  'NATIOIVA346': 'National Oilwell Varco',
#  'FIDENAFI639': 'Fidelity National Financial',
#  'ERIEINGR514': 'Erie Insurance Group',
#  'OSHKOSHx846': 'Oshkosh',
#  'CASEGEST981': "Casey's General Stores",
#  'WESCINxx147': 'Wesco International',
#  'TRACSUxx407': 'Tractor Supply',
#  'COMMHOxx383': 'Commscope Holding',
#  'HUNTSMAN218': 'Huntsman',
#  'AMERFIGR158': 'American Financial Group',
#  'MASCOxxx573': 'Masco',
#  'SANMINAx397': 'Sanmina',
#  'AMPHENOL208': 'Amphenol',
#  'WILLIAMS291': 'Williams-sonoma',
#  'WESTAIBR325': 'Westinghouse Air Brake',
#  'EXPEINWA128': 'Expeditors Intl. Of Washington',
#  'ANDERSON124': 'Andersons',
#  'WESTCHxx148': 'Westlake Chemical',
#  'CONSBRxx259': 'Constellation Brands',
#  'FRONCOxx336': 'Frontier Communications',
#  'JETBAIxx291': 'Jetblue Airways',
#  'CITIFIGR373': 'Citizens Financial Group',
#  'RAYMJAFI309': 'Raymond James Financial',
#  'FOOTLOxx766': 'Foot Locker',
#  'HERSHEYx126': 'Hershey',
#  'ZIMMBIHO316': 'Zimmer Biomet Holdings',
#  'CINCFIxx221': 'Cincinnati Financial',
#  'WESTSOFI219': 'Western & Southern Financial Group',
#  'WRBExxxx403': 'W.r. Berkley',
#  'MOTOSOxx252': 'Motorola Solutions',
#  'THORINxx284': 'Thor Industries',
#  'REGEPHxx409': 'Regeneron Pharmaceuticals',
#  'SPIRAEHO141': 'Spirit Aerosystems Holdings',
#  'JMSMxxxx203': 'J.m. Smucker',
#  'PPLxxxxx715': 'Ppl',
#  'INSIENxx317': 'Insight Enterprises',
#  'QUESDIxx110': 'Quest Diagnostics',
#  'KEYCORPx132': 'Keycorp',
#  'VERITIVx295': 'Veritiv',
#  'DCPMIxxx312': 'Dcp Midstream',
#  'AMERTOxx846': 'American Tower',
#  'GRAYELxx107': 'Graybar Electric',
#  'WECENGRx836': 'Wec Energy Group',
#  'NVRxxxxx520': 'Nvr',
#  'ULTABExx510': 'Ulta Beauty',
#  'DEVOENxx326': 'Devon Energy',
#  'BLACGRxx243': 'Blackstone Group',
#  'DEANFOxx375': 'Dean Foods',
#  'FORTIVEx367': 'Fortive',
#  'UGIxxxxx166': 'Ugi',
#  'BURLSTxx410': 'Burlington Stores',
#  'BUILFIxx160': 'Builders Firstsource',
#  'TOLLBRxx420': 'Toll Brothers',
#  'OLDREINx269': 'Old Republic International',
#  'ASBUAUGR366': 'Asbury Automotive Group',
#  'ARTHJGAx382': 'Arthur J. Gallagher',
#  'MASTECxx406': 'Mastec',
#  'OWENCOxx138': 'Owens Corning',
#  'MAGEHExx217': 'Magellan Health',
#  'DOVERxxx100': 'Dover',
#  'BEACROSU917': 'Beacon Roofing Supply',
#  'AVERDExx410': 'Avery Dennison',
#  'HANESBRA169': 'Hanesbrands',
#  'PACKCOAM145': 'Packaging Corp. Of America',
#  'MTBAxxxx157': 'M&t Bank',
#  'NCRxxxxx142': 'Ncr',
#  'NORTTRxx275': 'Northern Trust',
#  'CINTASxx246': 'Cintas',
#  'POLARISx168': 'Polaris',
#  'CMSENxxx183': 'Cms Energy',
#  'SEABOARD255': 'Seaboard',
#  'INTUITxx251': 'Intuit',
#  'REGIFIxx677': 'Regions Financial',
#  'FMGLxxxx346': 'Fm Global',
#  'ADVAMIDE306': 'Advanced Micro Devices',
#  'OVINTIVx412': 'Ovintiv',
#  'BOOZALHA220': 'Booz Allen Hamilton Holding',
#  'SPGLxxxx371': 'S&p Global',
#  'ROCKAUxx215': 'Rockwell Automation',
#  'OIGLxxxx241': 'O-i Glass',
#  'WYNNRExx657': 'Wynn Resorts',
#  'SECUFIGR374': 'Securian Financial Group',
#  'ALLIDASY418': 'Alliance Data Systems',
#  'WEYERHAE357': 'Weyerhaeuser',
#  'BRIGFIxx910': 'Brighthouse Financial',
#  'INTEEXxx361': 'Intercontinental Exchange',
#  'AMERAXMA288': 'American Axle & Manufacturing',
#  'HESSxxxx233': 'Hess',
#  'ABMINxxx337': 'Abm Industries',
#  'ACTIBLxx244': 'Activision Blizzard',
#  'GAMESTOP375': 'Gamestop',
#  'APACHExx162': 'Apache',
#  'SCIEAPIN348': 'Science Applications International',
#  'AKSTHOxx247': 'Ak Steel Holding',
#  'DILLARDS146': "Dillard's",
#  'RALPLAxx406': 'Ralph Lauren',
#  'CELANESE250': 'Celanese',
#  'RRDOSOxx380': 'R.r. Donnelley & Sons',
#  'ZOETISxx165': 'Zoetis',
#  'ASCEREGR135': 'Ascena Retail Group',
#  'CLOROXxx260': 'Clorox',
#  'INGREDIO135': 'Ingredion',
#  'FIRSAMFI170': 'First American Financial',
#  'GRAPPAHO117': 'Graphic Packaging Holding',
#  'NETAPPxx750': 'Netapp',
#  'HDSUHOxx219': 'Hd Supply Holdings',
#  'TRAVAMxx385': 'Travelcenters Of America',
#  'OLINxxxx540': 'Olin',
#  'ROBEHAIN130': 'Robert Half International',
#  'ENLIMIxx233': 'Enlink Midstream',
#  'AVANTORx251': 'Avantor',
#  'TAPESTRY362': 'Tapestry',
#  'TDAMHOxx706': 'Td Ameritrade Holding',
#  'ANALDExx349': 'Analog Devices',
#  'AMERENxx340': 'Ameren',
#  'REALHOxx372': 'Realogy Holdings',
#  'COMMMExx105': 'Commercial Metals',
#  'RUSHENxx137': 'Rush Enterprises',
#  'FRANRExx244': 'Franklin Resources',
#  'FORTBRHO169': 'Fortune Brands Home & Security',
#  'LEVISTxx402': 'Levi Strauss',
#  'CROWCAIN293': 'Crown Castle International',
#  'SIMOPRGR219': 'Simon Property Group',
#  'CERNERxx374': 'Cerner',
#  'POSTHOxx216': 'Post Holdings',
#  'HUNTBAxx360': 'Huntington Bancshares',
#  'KBRxxxxx399': 'Kbr',
#  'SPROFAMA108': 'Sprouts Farmers Market',
#  'LPLFIHOx588': 'Lpl Financial Holdings',
#  'TROPRxxx434': 'T. Rowe Price',
#  'YUMBRxxx311': 'Yum Brands',
#  'CHIPMEGR315': 'Chipotle Mexican Grill',
#  'PATTERSO931': 'Patterson',
#  'RPMINxxx235': 'Rpm International',
#  'EQUINIXx135': 'Equinix',
#  'NAVIENTx360': 'Navient',
#  'CHEMOURS379': 'Chemours',
#  'ONSExxxx158': 'On Semiconductor',
#  'TRANGRxx310': 'Transdigm Group',
#  'HOSTHORE129': 'Host Hotels & Resorts',
#  'SELEMEHO422': 'Select Medical Holdings',
#  'PARPAHOx182': 'Par Pacific Holdings',
#  'SONOPRxx355': 'Sonoco Products',
#  'ROPETExx155': 'Roper Technologies',
#  'HARLEYDA162': 'Harley-davidson',
#  'JEFFFIGR182': 'Jefferies Financial Group',
#  'KELLSExx405': 'Kelly Services',
#  'MCCORMIC212': 'Mccormick',
#  'MDUREGRx505': 'Mdu Resources Group',
#  'FASTENAL397': 'Fastenal',
#  'BIGLOxxx397': 'Big Lots',
#  'PENNNAGA253': 'Penn National Gaming',
#  'WESTUNxx251': 'Western Union',
#  'UNDEARxx304': 'Under Armour',
#  'XYLEMxxx208': 'Xylem',
#  'SKECUSxx114': 'Skechers U.s.a.',
#  'DOMTARxx416': 'Domtar',
#  'NISOURCE114': 'Nisource',
#  'MARAOIxx233': 'Marathon Oil',
#  'NATIGEHO220': 'National General Holdings',
#  'TELEDASY364': 'Telephone & Data Systems',
#  'AGILTExx349': 'Agilent Technologies',
#  'AMETEKxx428': 'Ametek',
#  'EVERGYxx311': 'Evergy',
#  'INTEFLFR997': 'International Flavors & Fragrances',
#  'ADTxxxxx129': 'Adt',
#  'WELLTOWE181': 'Welltower',
#  'WINDHOxx266': 'Windstream Holdings',
#  'MICHAELS321': 'Michaels',
#  'KEMPERxx650': 'Kemper',
#  'HYATHOxx360': 'Hyatt Hotels',
#  'ALEXPHxx557': 'Alexion Pharmaceuticals',
#  'RESITExx414': 'Resideo Technologies',
#  'CACIINxx108': 'Caci International',
#  'ELECARxx154': 'Electronic Arts',
#  'VULCMAxx151': 'Vulcan Materials',
#  'TREEFOxx417': 'Treehouse Foods',
#  'HANOINGR163': 'Hanover Insurance Group',
#  'CAMPWOHO215': 'Camping World Holdings',
#  'CORNBUBR703': 'Cornerstone Building Brands',
#  'YRCWOxxx403': 'Yrc Worldwide',
#  'CMEGRxxx334': 'Cme Group',
#  'CHEWYxxx750': 'Chewy',
#  'KNIGTRHO260': 'Knight-swift Transportation Holdings',
#  'MOODYSxx115': "Moody's",
#  'COCACOxx240': 'Coca-cola Consolidated',
#  'CARLISLE397': 'Carlisle',
#  'SEALAIxx107': 'Sealed Air',
#  'AMARPRME312': 'A-mark Precious Metals',
#  'WATSCOxx101': 'Watsco',
#  'TAYLMOHO245': 'Taylor Morrison Home',
#  'IACINTER816': 'Iac/interactivecorp',
#  'LEGGPLxx297': 'Leggett & Platt',
#  'ONEMHOxx318': 'Onemain Holdings',
#  'SCHNNAxx424': 'Schneider National',
#  'MARTMAMA249': 'Martin Marietta Materials',
#  'NORTONLI391': 'Nortonlifelock',
#  'HASBROxx140': 'Hasbro',
#  'SQUARExx979': 'Square',
#  'TEREXxxx107': 'Terex',
#  'SYNEHExx709': 'Syneos Health',
#  'FMCxxxxx319': 'Fmc',
#  'BOISCAxx316': 'Boise Cascade',
#  'SSCTEHOx978': 'Ss&c Technologies Holdings',
#  'CONTRExx246': 'Continental Resources',
#  'PEABENxx776': 'Peabody Energy',
#  'ENCOHExx271': 'Encompass Health',
#  'GREIFxxx242': 'Greif',
#  'CONCRExx183': 'Concho Resources',
#  'HUBBELLx324': 'Hubbell',
#  'CFINHOxx125': 'Cf Industries Holdings',
#  'KLAxxxxx318': 'Kla',
#  'GENEHExx323': 'Genesis Healthcare',
#  'BRUNSWIC334': 'Brunswick',
#  'KBHOxxxx374': 'Kb Home',
#  'GLOBLIxx428': 'Globe Life',
#  'MATTELxx228': 'Mattel',
#  'RYERHOxx401': 'Ryerson Holding',
#  'SILGHOxx407': 'Silgan Holdings',
#  'ZEBRTExx222': 'Zebra Technologies',
#  'INTUSUxx198': 'Intuitive Surgical',
#  'WARNMUGR132': 'Warner Music Group',
#  'CONDUENT163': 'Conduent',
#  'TUTOPExx153': 'Tutor Perini',
#  'JUNINExx423': 'Juniper Networks',
#  'NOBLENxx234': 'Noble Energy',
#  'VERTHOxx107': 'Vertiv Holdings',
#  'TIFFANYx410': 'Tiffany',
#  'EQTxxxxx601': 'Eqt',
#  'UFPINxxx625': 'Ufp Industries',
#  'DIEBNIxx285': 'Diebold Nixdorf',
#  'ANTERExx844': 'Antero Resources',
#  'MERITORx206': 'Meritor',
#  'BROAFISO938': 'Broadridge Financial Solutions',
#  'CHURDWxx352': 'Church & Dwight',
#  'MARRVAWO279': 'Marriott Vacations Worldwide',
#  'EDWALIxx228': 'Edwards Lifesciences',
#  'COLFAXxx918': 'Colfax',
#  'INSPERIT546': 'Insperity',
#  'AMEREAOU182': 'American Eagle Outfitters',
#  'KEYSTExx393': 'Keysight Technologies',
#  'JELDHOxx287': 'Jeld-wen Holding',
#  'IRONMOxx782': 'Iron Mountain',
#  'NASDAQxx149': 'Nasdaq',
#  'GARTNERx368': 'Gartner',
#  'SINCBRGR860': 'Sinclair Broadcast Group',
#  'INGLMAxx268': 'Ingles Markets',
#  'MONSBExx393': 'Monster Beverage',
#  'MURPOIxx158': 'Murphy Oil',
#  'VERTPHxx418': 'Vertex Pharmaceuticals',
#  'FIRSREBA134': 'First Republic Bank',
#  'BLOOBRxx268': "Bloomin' Brands",
#  'SPECBRHO183': 'Spectrum Brands Holdings',
#  'QUADGRAP358': 'Quad/graphics',
#  'FLOWFOxx166': 'Flowers Foods',
#  'CUNAMUGR592': 'Cuna Mutual Group',
#  'ALLETExx316': 'Allegheny Technologies',
#  'OLDDOFRLI335': 'Old Dominion Freight Line',
#  'LANDSYxx235': 'Landstar System',
#  'AMERNAIN130': 'American National Insurance',
#  'SNAPONxx144': 'Snap-on',
#  'BROOSELI402': 'Brookdale Senior Living',
#  'AMKOTExx109': 'Amkor Technology',
#  'WYNDDExx543': 'Wyndham Destinations',
#  'PPDxxxxx179': 'Ppd',
#  'DENTSIxx126': 'Dentsply Sirona',
#  'CNOFIGRx401': 'Cno Financial Group',
#  'URBAOUxx356': 'Urban Outfitters',
#  'SABRExxx304': 'Sabre',
#  'MERCGExx371': 'Mercury General',
#  'DIAMENxx150': 'Diamondback Energy',
#  'PARSONSx227': 'Parsons',
#  'AARONSxx275': "Aaron's",
#  'FLOWSERV275': 'Flowserve',
#  'CARVANAx177': 'Carvana',
#  'ASGNxxxx628': 'Asgn',
#  'SALLBEHO377': 'Sally Beauty Holdings',
#  'SCANSOUR284': 'Scansource',
#  'VENTASxx425': 'Ventas',
#  'COUNFIxx243': 'Country Financial',
#  'TRINGRxx344': 'Trinet Group',
#  'SPIRAIxx174': 'Spirit Airlines',
#  'COMERICA480': 'Comerica',
#  'LENNINxx132': 'Lennox International',
#  'TIMKENxx441': 'Timken',
#  'PAYCHEXx187': 'Paychex',
#  'AMERCOxx198': 'Amerco',
#  'WORTINxx339': 'Worthington Industries',
#  'LAMBWEHO424': 'Lamb Weston Holdings',
#  'LAUREDxx296': 'Laureate Education',
#  'PENNMULI973': 'Penn Mutual Life Insurance',
#  'IHEARTME155': 'Iheartmedia',
#  'BRINKSxx237': "Brink's",
#  'SENTINGR199': 'Sentry Insurance Group',
#  'ACUIBRxx623': 'Acuity Brands',
#  'HUBGRxxx800': 'Hub Group',
#  'MERIHOxx346': 'Meritage Homes',
#  'MRCGLxxx261': 'Mrc Global',
#  'ALLIENxx402': 'Alliant Energy',
#  'WORKDAYx344': 'Workday',
#  'BMCSTHOx233': 'Bmc Stock Holdings',
#  'ABERFIxx130': 'Abercrombie & Fitch',
#  'DOMIPIxx264': "Domino's Pizza",
#  'LYFTxxxx129': 'Lyft',
#  'MEREDITH248': 'Meredith',
#  'AMERWAWO594': 'American Water Works',
#  'ALBEMARL291': 'Albemarle',
#  'CIENAxxx277': 'Ciena',
#  'BARNNOxx228': 'Barnes & Noble',
#  'WEISMAxx210': 'Weis Markets',
#  'ILLUMINA413': 'Illumina',
#  'SVBFIGRx106': 'Svb Financial Group',
#  'CARTERSx201': "Carter's",
#  'STIFFIxx338': 'Stifel Financial',
#  'MEDNAXxx321': 'Mednax',
#  'EQUIFAXx331': 'Equifax',
#  'KARAUSEx380': 'Kar Auction Services',
#  'ASHLGLHO359': 'Ashland Global Holdings',
#  'MEDIMUOH294': 'Medical Mutual Of Ohio',
#  'SPRARExx344': 'Sprague Resources',
#  'SUPEMICO828': 'Super Micro Computer',
#  'DESIBRxx102': 'Designer Brands',
#  'PITNBOxx237': 'Pitney Bowes',
#  'APPLINTE168': 'Applied Industrial Technologies',
#  'PINNWECA168': 'Pinnacle West Capital',
#  'AMEREQIN314': 'American Equity Investment Life Holding',
#  'SERVICEN326': 'Servicenow',
#  'TWITTERx272': 'Twitter',
#  'CALUSPPR188': 'Calumet Specialty Products Partners',
#  'STEELCAS150': 'Steelcase',
#  'SANDFAxx264': 'Sanderson Farms',
#  'WABCHOxx508': 'Wabco Holdings',
#  'CLEAHAxx339': 'Clean Harbors',
#  'PUGEENxx296': 'Puget Energy',
#  'SCIEGAxx345': 'Scientific Games',
#  'GRANCOxx708': 'Granite Construction',
#  'CARLGRxx188': 'Carlyle Group',
#  'SKYWSOxx155': 'Skyworks Solutions',
#  'ALERISxx316': 'Aleris',
#  'TRIPMAxx313': 'Triple-s Management',
#  'HEXIONxx187': 'Hexion',
#  'HOLOGICx406': 'Hologic',
#  'TRIUGRxx276': 'Triumph Group',
#  'DARLINxx344': 'Darling Ingredients',
#  'MSCINDIx249': 'Msc Industrial Direct',
#  'REDHAxxx297': 'Red Hat',
#  'SYNOPSYS252': 'Synopsys',
#  'POLYONEx304': 'Polyone',
#  'DYCOINxx177': 'Dycom Industries',
#  'CABOTxxx248': 'Cabot',
#  'PROLOGIS135': 'Prologis',
#  'BOYDGAxx228': 'Boyd Gaming',
#  'LSCCOxxx985': 'Lsc Communications',
#  'BROWNFOR327': 'Brown-forman',
#  'STERICYC996': 'Stericycle',
#  'CITGRxxx377': 'Cit Group',
#  'MDCHOxxx147': 'Mdc Holdings',
#  'HYSTMAHA140': 'Hyster-yale Materials Handling',
#  'CRANExxx121': 'Crane',
#  'CINEHOxx417': 'Cinemark Holdings',
#  'AUTODESK270': 'Autodesk',
#  'TRIMBLEx209': 'Trimble',
#  'GARRMOxx353': 'Garrett Motion',
#  'ZIONBAxx340': 'Zions Bancorp.',
#  'REGABExx209': 'Regal Beloit',
#  'SERVCOIN148': 'Service Corp. International',
#  'VARIMESY519': 'Varian Medical Systems',
#  'PRICESMA144': 'Pricesmart',
#  'BRININxx153': 'Brinker International',
#  'DIGIRETR104': 'Digital Realty Trust',
#  'POOLCOxx401': 'Pool Corp',
#  'CRESEQPA336': 'Crestwood Equity Partners',
#  'INFORxxx417': 'Infor',
#  'PLEXUSxx321': 'Plexus',
#  'TELETExx104': 'Teledyne Technologies',
#  'GIIIAPGR303': 'G-iii Apparel Group',
#  'SCOTMIxx806': 'Scotts Miracle-gro',
#  'APOLGLMA180': 'Apollo Global Management',
#  'ETRAFIxx341': 'E*trade Financial',
#  'TOROxxxx267': 'Toro',
#  'SOUTGAHO204': 'Southwest Gas Holdings',
#  'GMSxxxxx196': 'Gms',
#  'COOPHOxx372': 'Cooper-standard Holdings',
#  'ACADHExx207': 'Acadia Healthcare',
#  'TETRTExx143': 'Tetra Tech',
#  'PRIMSExx413': 'Primoris Services',
#  'TEMPSEIN592': 'Tempur Sealy International',
#  'HRBLxxxx143': 'H&r Block',
#  'QORVOxxx161': 'Qorvo',
#  'TRIPOGRx238': 'Tri Pointe Group',
#  'CRACBAOL364': 'Cracker Barrel Old Country Store',
#  'ELANANHE167': 'Elanco Animal Health',
#  'PRAHESCx236': 'Pra Health Sciences',
#  'FIRSSOxx315': 'First Solar',
#  'AMCNExxx128': 'Amc Networks',
#  'XILINXxx282': 'Xilinx',
#  'GREEPLxx327': 'Green Plains',
#  'COLUSPxx404': 'Columbia Sportswear',
#  'NEXSMEGR127': 'Nexstar Media Group',
#  'SOUTENxx220': 'Southwestern Energy',
#  'GREENBRI261': 'Greenbrier',
#  'PRESIDIO148': 'Presidio',
#  'CITRSYxx193': 'Citrix Systems',
#  'METTINxx112': 'Mettler-toledo International',
#  'TRININxx408': 'Trinity Industries',
#  'MUTUAMLI253': 'Mutual Of America Life Insurance',
#  'LINCELHO166': 'Lincoln Electric Holdings',
#  'TAILBRxx576': 'Tailored Brands',
#  'AOSMxxxx269': 'A.o. Smith',
#  'ARCBESTx139': 'Arcbest',
#  'GODADDYx775': 'Godaddy',
#  'SKYWESTx119': 'Skywest',
#  'BOSTPRxx151': 'Boston Properties',
#  'ENABMIPA144': 'Enable Midstream Partners',
#  'MIDDLEBY263': 'Middleby',
#  'NOWxxxxx169': 'Now',
#  'UNISYSxx289': 'Unisys',
#  'VISTEONx238': 'Visteon',
#  'GRAHHOxx103': 'Graham Holdings',
#  'RESOFOPR425': 'Resolute Forest Products',
#  'CALERESx307': 'Caleres',
#  'AGNCINxx757': 'Agnc Investment',
#  'HILLHOxx997': 'Hill-rom Holdings',
#  'MOOGxxxx151': 'Moog',
#  'LEGGMAxx210': 'Legg Mason',
#  'ATMOENxx898': 'Atmos Energy',
#  'WOODWARD870': 'Woodward',
#  'PALOALNE256': 'Palo Alto Networks',
#  'HBFUxxxx412': 'H.b. Fuller',
#  'AKAMTExx283': 'Akamai Technologies',
#  'AVAYHOxx146': 'Avaya Holdings',
#  'MAXIMUSx223': 'Maximus',
#  'PERKINEL253': 'Perkinelmer',
#  'HAWAELIN276': 'Hawaiian Electric Industries',
#  'KANSCISO185': 'Kansas City Southern',
#  'APTARGRO647': 'Aptargroup',
#  'PUBLSTxx388': 'Public Storage',
#  'SELEINGR256': 'Selective Insurance Group',
#  'ITTxxxxx283': 'Itt',
#  'DONALDSO260': 'Donaldson',
#  'PARKHORE228': 'Park Hotels & Resorts',
#  'KIRBYxxx305': 'Kirby',
#  'HAWAHOxx161': 'Hawaiian Holdings',
#  'POPULARx110': 'Popular',
#  'RANGRExx337': 'Range Resources',
#  'PCCOxxxx105': 'Pc Connection',
#  'AMICMUIN378': 'Amica Mutual Insurance',
#  'ENERSYSx279': 'Enersys',
#  'HELMPAxx286': 'Helmerich & Payne',
#  'NLVFIxxx325': 'Nlv Financial',
#  'VALMINxx267': 'Valmont Industries',
#  'PAExxxxx232': 'Pae',
#  'TEXAROxx356': 'Texas Roadhouse',
#  'COOPTIRU373': 'Cooper Tire & Rubber',
#  'EUROWOxx920': 'Euronet Worldwide',
#  'ZILLGRxx170': 'Zillow Group',
#  'ATLAAIWO293': 'Atlas Air Worldwide Holdings',
#  'ENERHOxx316': 'Energizer Holdings',
#  'MAGEMIPA279': 'Magellan Midstream Partners',
#  'HAINCEGR123': 'Hain Celestial Group',
#  'UNIVCOxx256': 'Universal Corp',
#  'EQUIRExx459': 'Equity Residential',
#  'ALLITRHO275': 'Allison Transmission Holdings',
#  'COLOCAxx186': 'Colony Capital',
#  'TTMTExxx292': 'Ttm Technologies',
#  'CLEACHOU118': 'Clear Channel Outdoor Holdings',
#  'GUESSxxx507': 'Guess',
#  'RENTACEN337': 'Rent-a-center',
#  'TAKEINSO726': 'Take-two Interactive Software',
#  'VISHINxx138': 'Vishay Intertechnology',
#  'TRANSUNI669': 'Transunion',
#  'COOPERxx362': 'Cooper',
#  'FLEETExx346': 'Fleetcor Technologies',
#  'RHxxxxxx206': 'Rh',
#  'RENEENGR165': 'Renewable Energy Group',
#  'BLUEHOxx164': 'Bluelinx Holdings',
#  'CALIRExx101': 'California Resources',
#  'TOPBUILD186': 'Topbuild',
#  'CHARRILA320': 'Charles River Laboratories International',
#  'COMFSYUS924': 'Comfort Systems Usa',
#  'VERIANxx565': 'Verisk Analytics',
#  'RESMEDxx199': 'Resmed',
#  'TELEFLEX196': 'Teleflex',
#  'NEWJEREx298': 'New Jersey Resources',
#  'NEWREINx922': 'New Residential Investment',
#  'INTEBRGR152': 'Interactive Brokers Group',
#  'ZAYOGRHO219': 'Zayo Group Holdings',
#  'HERMMIxx377': 'Herman Miller',
#  'GROCOUHO154': 'Grocery Outlet Holding',
#  'JCREGRxx214': 'J.crew Group',
#  'CENTCOxx419': 'Century Communities',
#  'ELDORExx307': 'Eldorado Resorts',
#  'CATALENT428': 'Catalent',
#  'ITRONxxx418': 'Itron',
#  'MIHOxxxx329': 'M/i Homes',
#  'CBOEGLMA565': 'Cboe Global Markets',
#  'IDEXxxxx440': 'Idex',
#  'BELDENxx175': 'Belden',
#  'CURTISSW280': 'Curtiss-wright',
#  'CHEEFAxx418': 'Cheesecake Factory',
#  'GENEENxx403': 'Genesis Energy',
#  'GEOGRxxx256': 'Geo Group',
#  'PATTENxx612': 'Patterson-uti Energy',
#  'WERNENxx351': 'Werner Enterprises',
#  'INGERAxx168': 'Ingersoll Rand',
#  'VERSOxxx386': 'Verso',
#  'MUELINxx405': 'Mueller Industries',
#  'NUSKENxx274': 'Nu Skin Enterprises',
#  'REVLONxx282': 'Revlon',
#  'ARISNExx367': 'Arista Networks',
#  'IDEXLAxx573': 'Idexx Laboratories',
#  'ALIGTExx426': 'Align Technology',
#  'WATERSxx412': 'Waters',
#  'SYNOFIxx298': 'Synovus Financial',
#  'BRIGHOxx350': 'Brightview Holdings',
#  'REVGRxxx242': 'Rev Group',
#  'BROWBRxx826': 'Brown & Brown',
#  'VALVOLIN285': 'Valvoline',
#  'KNIGCOxx185': 'Knights Of Columbus',
#  'CENTGAPE188': 'Central Garden & Pet',
#  'CARPTExx361': 'Carpenter Technology',
#  'SLMCOxxx410': 'Slm Corp',
#  'KENNAMET421': 'Kennametal',
#  'LCIINxxx147': 'Lci Industries',
#  'TRUEBLUE141': 'Trueblue',
#  'CIMAENxx138': 'Cimarex Energy',
#  'SPLUNKxx164': 'Splunk',
#  'SITELASU316': 'Siteone Landscape Supply',
#  'HEXCELxx835': 'Hexcel',
#  'FTICOxxx237': 'Fti Consulting',
#  'PARTCIHO579': 'Party City Holdco',
#  'OHIONAMU324': 'Ohio National Mutual',
#  'PATRINxx590': 'Patrick Industries',
#  'CADEDESY202': 'Cadence Design Systems',
#  'CDKGLxxx227': 'Cdk Global',
#  'AVALCOxx344': 'Avalonbay Communities',
#  'WABANAxx240': 'Wabash National',
#  'SERVPRTR179': 'Service Properties Trust',
#  'MAXIINPR733': 'Maxim Integrated Products',
#  'PEOPUNFI167': "People's United Financial",
#  'BIORLAxx330': 'Bio-rad Laboratories',
#  'OPTICAHE335': 'Option Care Health',
#  'LOUISIAN994': 'Louisiana-pacific',
#  'TEGNAxxx262': 'Tegna',
#  'TERADYNE408': 'Teradyne',
#  'ARCHRExx797': 'Arch Resources',
#  'EPAMSYxx119': 'Epam Systems',
#  'WPXENxxx114': 'Wpx Energy',
#  'CONTENxx933': 'Contura Energy',
#  'ENSIGRxx335': 'Ensign Group',
#  'FIRSHONA112': 'First Horizon National',
#  'WOLVWOWI287': 'Wolverine World Wide',
#  'VAILRExx103': 'Vail Resorts',
#  'BENCELxx712': 'Benchmark Electronics',
#  'HNIxxxxx145': 'Hni',
#  'F5NExxxx421': 'F5 Networks',
#  'AFFIMAGR190': 'Affiliated Managers Group',
#  'OGEENxxx226': 'Oge Energy',
#  'BOKFIxxx768': 'Bok Financial',
#  'MANTINxx142': 'Mantech International',
#  'SUMMMAxx126': 'Summit Materials',
#  'AMNHESEx238': 'Amn Healthcare Services',
#  'GROUPONx281': 'Groupon',
#  'NEWMGRxx293': 'Newmark Group',
#  'FOSSGRxx292': 'Fossil Group',
#  'MODIMAxx147': 'Modine Manufacturing',
#  'GRIFCOxx237': 'Griffon Corporation',
#  'CYPRSExx304': 'Cypress Semiconductor',
#  'GENEHOxx305': 'Generac Holdings',
#  'MATSONxx203': 'Matson',
#  'GENESCOx297': 'Genesco',
#  'NORDSONx799': 'Nordson',
#  'NEWMARKE957': 'Newmarket',
#  'ECHOGLLO100': 'Echo Global Logistics',
#  'REXNORDx650': 'Rexnord',
#  'INCYTExx331': 'Incyte',
#  'FORTINET175': 'Fortinet',
#  'FOUNBUMA276': 'Foundation Building Materials',
#  'AARxxxxx752': 'Aar',
#  'CENTBRxx322': 'Centric Brands',
#  'EDGEPECA586': 'Edgewell Personal Care',
#  'FEDEMUIN799': 'Federated Mutual Insurance',
#  'SCHNSTIN336': 'Schnitzer Steel Industries',
#  'PORTGEEL283': 'Portland General Electric',
#  'GRAYTExx403': 'Gray Television',
#  'BGCPAxxx369': 'Bgc Partners',
#  'ECHOSTAR310': 'Echostar',
#  'BEAZHOUS269': 'Beazer Homes Usa',
#  'LHCGRxxx838': 'Lhc Group',
#  'SERVGLHO190': 'Servicemaster Global Holdings',
#  'BRUKERxx190': 'Bruker',
#  'OASIPExx158': 'Oasis Petroleum',
#  'CROSPAxx330': 'Crossamerica Partners',
#  'MYRGRxxx181': 'Myr Group',
#  'VIASATxx177': 'Viasat',
#  'GNCHOxxx103': 'Gnc Holdings',
#  'CABOOIGA423': 'Cabot Oil & Gas',
#  'BRIGHOFA351': 'Bright Horizons Family Solutions',
#  'VISTOUxx336': 'Vista Outdoor',
#  'HEICOxxx268': 'Heico',
#  'WYNDHORE214': 'Wyndham Hotels & Resorts',
#  'TCFFIxxx384': 'Tcf Financial',
#  'PRIMERIC525': 'Primerica',
#  'PROPHOxx226': 'Propetro Holding',
#  'OCEAINxx412': 'Oceaneering International',
#  'FLOODEHO558': 'Floor & Decor Holdings',
#  'COPARTxx320': 'Copart',
#  'CHICFAxx425': "Chico's Fas",
#  'BARNNOED229': 'Barnes & Noble Education',
#  'MAXATExx364': 'Maxar Technologies',
#  'EVERCORE213': 'Evercore',
#  'DECKOUxx135': 'Deckers Outdoor',
#  'EXPRESSx158': 'Express',
#  'HOVNENxx899': 'Hovnanian Enterprises',
#  'AIRLExxx356': 'Air Lease',
#  'ROLLINSx737': 'Rollins',
#  'SBACOxxx551': 'Sba Communications',
#  'DELUXExx156': 'Deluxe',
#  'MRCOGRxx572': 'Mr. Cooper Group',
#  'HERCHOxx297': 'Herc Holdings',
#  'HEALPRxx644': 'Healthpeak Properties',
#  'SPXFLxxx147': 'Spx Flow',
#  'LIBEOISE195': 'Liberty Oilfield Services'}
