# %% [markdown]
# ### This script converts a column of names into unique IDs and populates a new column with those values.
#
# ### You will need to change a few values to run this code on your unique file name and colume name

# %%
import pandas as pd

# %%
# This code reads the file. Change to ('path/your-file-name.filetype')
try:
    df = pd.read_excel('company.xlsx')
    df.to_csv('company.csv', mode = 'w', index=False)
except:
    df = pd.read_csv('company.csv')
df
# Out:
#        Rank            Metals Industry  Number Of Employees Change In \n Rank  \
# 0       1.0                    Walmart            2200000.0                 -
# 1       2.0                 Amazon.com             798000.0               3.0
# 2       3.0                Exxon Mobil              74900.0              -1.0
# 3       4.0                      Apple             137000.0              -1.0
# 4       5.0                 Cvs Health             290000.0               3.0
# ..      ...                        ...                  ...               ...
# 995   996.0           Mr. Cooper Group               9100.0                 -
# 996   997.0              Herc Holdings               5100.0              -4.0
# 997   998.0      Healthpeak Properties                204.0                 -
# 998   999.0                   Spx Flow               5000.0             -37.0
# 999  1000.0  Liberty Oilfield Services               2571.0             -58.0
#
#                         Industry  \
# 0                 Retail Company
# 1             E-commerce Company
# 2                    Corporation
# 3             Technology Company
# 4             Healthcare Company
# ..                           ...
# 995          Home Loan Servicers
# 996             Equipment Rental
# 997       Real Estate Investment
# 998  Pumps And Pumping Equipment
# 999                  Oil And Gas
#
#                                    Company Description  \
# 0    Walmart Inc. Is An American Multinational Reta...
# 1    Amazon.com, Inc. Is An American Multinational ...
# 2    Exxon Mobil Corp. engages in the exploration, ...
# 3    Apple Inc. Is An American Multinational Techno...
# 4    Cvs Health Is An American Healthcare Company T...
# ..                                                 ...
# 995  Mr. Cooper Group Inc. Provides Quality Servici...
# 996  They Are One Of The Largest Equipment Rental C...
# 997  Healthpeak Properties, Inc. Is A Real Estate I...
# 998  It Is A World Leader In Sustainable Solutions ...
# 999  Liberty Is An Innovative Service Company Provi...
#
#      Revenues\n ($millions) Revenue \n Change Profits\n ($millions)  \
# 0                  523964.0             0.019               14881.0
# 1                  280522.0             0.205               11588.0
# 2                  264938.0            -0.087               14340.0
# 3                  260174.0             -0.02               55256.0
# 4                  256776.0              0.32                6634.0
# ..                      ...               ...                   ...
# 995                  2007.0                 -                 274.0
# 996                  1999.0             0.011                  47.5
# 997                  1997.0             0.082                  45.5
# 998                  1996.0            -0.045                 -95.1
# 999                  1990.0            -0.076                  39.0
#
#     Profit \n Change  Assets\n ($millions) Market Value \n As of 3/31/20 ($m)
# 0              1.231              236495.0                           321803.0
# 1               0.15              225248.0                           970680.0
# 2             -0.312              362597.0                           160696.0
# 3             -0.072              338516.0                          1112641.0
# 4                  -              222449.0                            77376.0
# ..               ...                   ...                                ...
# 995                -               18305.0                              674.0
# 996           -0.313                3817.0                              591.0
# 997           -0.957               14033.0                            12059.0
# 998           -3.161                2437.0                             1212.0
# 999           -0.692                1283.0                              303.0
#
# [1000 rows x 12 columns]

# %%
import pandas as pd

def generate_unique_id(company_name: str) -> str:
    """
    :params company_name 
    :return a unique 12 character ID based on the named from the input
    
    """
    unique_key = ''
    company_name = company_name.upper()
    
    for char in (("THE ", ""), (" THE ", " "), (" AND ", " "), (" OF ", " ")):
        company_name = company_name.replace(*char)
        
    new_name_list = []
    name_list = company_name.split(' ')
    wordCount = len(name_list)
    
    for name in name_list:
        new_name_list.append(''.join(ch for ch in name if ch.isalnum()))
    
    if wordCount == 1:
            unique_key = new_name_list[0][0:8]
    else:
        for i in range(len(new_name_list)):
            if i == 0:
                unique_key += new_name_list[i][:4]
            else:
                unique_key += new_name_list[i][:2]

            if len(unique_key) > 7:
                break

    if len(unique_key) <= 8:
        unique_key += 'x' * (8 - len(unique_key))
    
    hash_number = str(hash(company_name.upper()))[1:4]
        
    unique_key += hash_number
    
    return unique_key

# %%
keys_list = []
"""Change the name of (row[" <Your name column's name here>  "])) to match your columns name"""

for index, row in df.iterrows():       # change name here to your columns name
    keys_list.append(generate_unique_id(row["Metals Industry"]))
                                    # RIGHT HERE ^^^^^^^^^
df['unique_ID'] = keys_list

# %%
temp_cols=df.columns.tolist()
new_cols=temp_cols[-1:] + temp_cols[:-1]
df=df[new_cols]
df[500:520]
# Out:
#        unique_ID   Rank            Metals Industry  Number Of Employees  \
# 500  KBRxxxxx009  501.0                        Kbr              28000.0
# 501  SPROFAMA411  502.0     Sprouts Farmers Market              30000.0
# 502  LPLFIHOx378  503.0     Lpl Financial Holdings               4343.0
# 503  TROPRxxx175  504.0              T. Rowe Price               7365.0
# 504  YUMBRxxx674  505.0                 Yum Brands              34000.0
# 505  CHIPMEGR665  506.0     Chipotle Mexican Grill              83000.0
# 506  PATTERSO505  507.0                  Patterson               7800.0
# 507  RPMINxxx047  508.0          Rpm International              14957.0
# 508  EQUINIXx140  509.0                    Equinix               8378.0
# 509  NAVIENTx777  510.0                    Navient               5800.0
# 510  CHEMOURS542  511.0                   Chemours               7000.0
# 511  ONSExxxx428  512.0           On Semiconductor              34800.0
# 512  TRANGRxx325  513.0            Transdigm Group              18300.0
# 513  HOSTHORE594  514.0      Host Hotels & Resorts                175.0
# 514  SELEMEHO818  515.0    Select Medical Holdings              42800.0
# 515  PARPAHOx073  516.0       Par Pacific Holdings               1408.0
# 516  SONOPRxx617  517.0            Sonoco Products              23000.0
# 517  ROPETExx377  518.0         Roper Technologies              16460.0
# 518  HARLEYDA893  519.0            Harley-davidson               5600.0
# 519  JEFFFIGR288  520.0  Jefferies Financial Group               4800.0
#
#     Change In \n Rank                             Industry  \
# 500              47.0                          Engineering
# 501              25.0                          Supermarket
# 502              28.0                        Broker-dealer
# 503              15.0                Investment Management
# 504             -11.0                    Fast Food Company
# 505              45.0                   Restaurant Company
# 506               3.0                     Dental Equipment
# 507              14.0                            Chemicals
# 508              30.0                             Internet
# 509             -13.0                   Financial Services
# 510             -57.0                    Chemicals Company
# 511             -27.0  Semiconductor Manufacturing Company
# 512             137.0                 Aerospace Components
# 513             -12.0                          Real Estate
# 514              23.0                              Medical
# 515             181.0         Petroleum Refineries Company
# 516               1.0               Packaging And Labeling
# 517              12.0                         Conglomerate
# 518             -27.0             Motorcycle Manufacturers
# 519            -148.0           Investment Banking Company
#
#                                    Company Description  \
# 500  Kbr, Inc. Is An American Engineering, Procurem...
# 501  Sprouts Farmers Market, Inc., Is A Supermarket...
# 502  Lpl Financial Holdings Is Considered The Large...
# 503  T. Rowe Price Group, Inc. Is A Global Investme...
# 504  Yum! Brands, Inc. Is An American Fast Food Cor...
# 505  Chipotle Mexican Grill, Inc. Is An American Ch...
# 506  Patterson Companies Inc Is A Medical Supplies ...
# 507  Rpm International Inc. Owns Subsidiaries That ...
# 508  Equinix Is An Internet Company That Provides D...
# 509  Navient Corporation's Focus Is In Education Lo...
# 510  The Chemours Company Is Using The Power Of Che...
# 511  On Semiconductor Is A Leading Supplier And Dri...
# 512  Transdigm Group Inc. Is A Leading Global Produ...
# 513  The Trust Provides Equity Holdings, Asset Mana...
# 514  Select Medical Holdings Corporation Is An Oper...
# 515  Par Pacific Holdings Is A Houston-based Oil An...
# 516  Sonoco Products Company Is A United States-bas...
# 517  Roper Technologies, Inc. Is An American Divers...
# 518  Harley-davidson Is Pulling Out Of India, The W...
# 519  The Firm Provides Clients With Capital Markets...
#
#      Revenues\n ($millions) Revenue \n Change Profits\n ($millions)  \
# 500                  5639.0             0.148                 202.0
# 501                  5635.0             0.082                 149.6
# 502                  5625.0             0.084                 559.9
# 503                  5618.0             0.046                2131.3
# 504                  5597.0            -0.016                1294.0
# 505                  5586.0             0.148                 350.2
# 506                  5575.0              0.02                  83.6
# 507                  5565.0             0.046                 266.6
# 508                  5562.0             0.097                 507.5
# 509                  5529.0            -0.014                 597.0
# 510                  5526.0            -0.168                 -52.0
# 511                  5518.0            -0.061                 211.7
# 512                  5517.0             0.443                 889.8
# 513                  5469.0             -0.01                 920.0
# 514                  5454.0             0.073                 148.4
# 515                  5402.0             0.584                  40.8
# 516                  5374.0            -0.003                 291.8
# 517                  5367.0             0.034                1767.9
# 518                  5362.0            -0.062                 423.6
# 519                  5359.0            -0.343                 964.7
#
#     Profit \n Change  Assets\n ($millions) Market Value \n As of 3/31/20 ($m)
# 500           -0.281                5364.0                             2943.0
# 501           -0.056                2723.0                             2185.0
# 502            0.274                5880.0                             4305.0
# 503             0.16                9330.0                            22788.0
# 504           -0.161                5231.0                            20615.0
# 505            0.983                5105.0                            18171.0
# 506           -0.584                3269.0                             1465.0
# 507           -0.211                5441.0                             7721.0
# 508            0.389               23966.0                            53366.0
# 509            0.511               94903.0                             1466.0
# 510           -1.052                7258.0                             1456.0
# 511           -0.663                8426.0                             5114.0
# 512            -0.07               16255.0                            17190.0
# 513           -0.154               12305.0                             7793.0
# 514            0.077                7340.0                             2015.0
# 515            0.035                2701.0                              381.0
# 516           -0.069                5126.0                             4651.0
# 517            0.872               18109.0                            33086.0
# 518           -0.203               10528.0                             2893.0
# 519            -0.06               49460.0                             3788.0

# %%
# check for duplicates, none if true
print(len(keys_list) == len(list(set(keys_list))))
# Out:
# True

# %%
"""Change the name of ['Metals Industry'] to match your columns name"""
keys = keys_list

# your col name below vvvvv
values = df['Metals Industry'].to_list()
# change name above ^^^^^

alphaZip= zip(keys,values)
myDict = dict(alphaZip)
myDict
# Out:
# {'WALMARTx653': 'Walmart',
#  'AMAZONCO083': 'Amazon.com',
#  'EXXOMOxx697': 'Exxon Mobil',
#  'APPLExxx862': 'Apple',
#  'CVSHExxx904': 'Cvs Health',
#  'BERKHAxx366': 'Berkshire Hathaway',
#  'UNITGRxx065': 'Unitedhealth Group',
#  'MCKESSON550': 'Mckesson',
#  'ATTxxxxx756': 'At&t',
#  'AMERISOU645': 'Amerisourcebergen',
#  'ALPHABET554': 'Alphabet',
#  'FORDMOxx165': 'Ford Motor',
#  'CIGNAxxx697': 'Cigna',
#  'COSTWHxx782': 'Costco Wholesale',
#  'CHEVRONx259': 'Chevron',
#  'CARDHExx739': 'Cardinal Health',
#  'JPMOCHxx950': 'Jpmorgan Chase',
#  'GENEMOxx250': 'General Motors',
#  'WALGBOAL632': 'Walgreens Boots Alliance',
#  'VERICOxx738': 'Verizon Communications',
#  'MICROSOF777': 'Microsoft',
#  'MARAPExx101': 'Marathon Petroleum',
#  'KROGERxx562': 'Kroger',
#  'FANNMAxx645': 'Fannie Mae',
#  'BANKAMxx096': 'Bank Of America',
#  'HOMEDExx453': 'Home Depot',
#  'PHIL66xx633': 'Phillips 66',
#  'COMCASTx175': 'Comcast',
#  'ANTHEMxx019': 'Anthem',
#  'WELLFAxx723': 'Wells Fargo',
#  'CITIGROU398': 'Citigroup',
#  'VALEENxx721': 'Valero Energy',
#  'GENEELxx430': 'General Electric',
#  'DELLTExx500': 'Dell Technologies',
#  'JOHNJOxx299': 'Johnson & Johnson',
#  'STATFAIN581': 'State Farm Insurance',
#  'TARGETxx592': 'Target',
#  'IBMxxxxx843': 'Ibm',
#  'RAYTTExx399': 'Raytheon Technologies',
#  'BOEINGxx945': 'Boeing',
#  'FREDMAxx402': 'Freddie Mac',
#  'CENTENEx252': 'Centene',
#  'UNITPASE705': 'United Parcel Service',
#  'LOWESxxx235': "Lowe's",
#  'INTELxxx059': 'Intel',
#  'FACEBOOK880': 'Facebook',
#  'FEDEXxxx682': 'Fedex',
#  'METLIFEx190': 'Metlife',
#  'WALTDIxx102': 'Walt Disney',
#  'PROCGAxx262': 'Procter & Gamble',
#  'PEPSICOx628': 'Pepsico',
#  'HUMANAxx610': 'Humana',
#  'PRUDFIxx339': 'Prudential Financial',
#  'ARCHDAMI693': 'Archer Daniels Midland',
#  'ALBERTSO884': 'Albertsons',
#  'SYSCOxxx886': 'Sysco',
#  'LOCKMAxx433': 'Lockheed Martin',
#  'HPxxxxxx211': 'Hp',
#  'ENERTRxx253': 'Energy Transfer',
#  'GOLDSAGR837': 'Goldman Sachs Group',
#  'MORGSTxx647': 'Morgan Stanley',
#  'CATERPIL027': 'Caterpillar',
#  'CISCSYxx263': 'Cisco Systems',
#  'PFIZERxx972': 'Pfizer',
#  'HCAHExxx151': 'Hca Healthcare',
#  'AIGxxxxx266': 'Aig',
#  'AMEREXxx900': 'American Express',
#  'DELTAILI765': 'Delta Air Lines',
#  'MERCKxxx675': 'Merck',
#  'AMERAIGR705': 'American Airlines Group',
#  'CHARCOxx217': 'Charter Communications',
#  'ALLSTATE808': 'Allstate',
#  'NEWYOLIIN943': 'New York Life Insurance',
#  'NATIONWI792': 'Nationwide',
#  'BESTBUxx345': 'Best Buy',
#  'UNITAIHO468': 'United Airlines Holdings',
#  'LIBEMUIN627': 'Liberty Mutual Insurance Group',
#  'DOWxxxxx830': 'Dow',
#  'TYSOFOxx669': 'Tyson Foods',
#  'TJXxxxxx258': 'Tjx',
#  'TIAAxxxx231': 'Tiaa',
#  'ORACLExx610': 'Oracle',
#  'GENEDYxx406': 'General Dynamics',
#  'DEERExxx521': 'Deere',
#  'NIKExxxx892': 'Nike',
#  'PROGRESS147': 'Progressive',
#  'PUBLSUMA016': 'Publix Super Markets',
#  'COCACOLA436': 'Coca-cola',
#  'MASSMULI132': 'Massachusetts Mutual Life Insurance',
#  'TECHDAxx163': 'Tech Data',
#  'WORLFUSE638': 'World Fuel Services',
#  'HONEINxx826': 'Honeywell International',
#  'CONOCOPH201': 'Conocophillips',
#  'USAAxxxx712': 'Usaa',
#  'EXELONxx798': 'Exelon',
#  'NORTGRxx837': 'Northrop Grumman',
#  'CAPIONFI037': 'Capital One Financial',
#  'PLAIGPHO297': 'Plains Gp Holdings',
#  'ABBVIExx230': 'Abbvie',
#  'STONGRxx611': 'Stonex Group',
#  'ENTEPRPA381': 'Enterprise Products Partners',
#  'NORTMUxx771': 'Northwestern Mutual',
#  '3Mxxxxxx858': '3m',
#  'ABBOLAxx697': 'Abbott Laboratories',
#  'CHSxxxxx697': 'Chs',
#  'TRAVELER920': 'Travelers',
#  'PHILMOIN343': 'Philip Morris International',
#  'RAYTHEON627': 'Raytheon',
#  'HEWLPAEN755': 'Hewlett Packard Enterprise',
#  'ARROELxx220': 'Arrow Electronics',
#  'VIACOMCB475': 'Viacomcbs',
#  'DOLLGExx892': 'Dollar General',
#  'USBAxxxx489': 'U.s. Bancorp',
#  'STARBUCK670': 'Starbucks',
#  'BRISSQxx584': 'Bristol-myers Squibb',
#  'USFOHOxx194': 'Us Foods Holding',
#  'MONDINxx565': 'Mondelez International',
#  'PACCARxx277': 'Paccar',
#  'THERFISC125': 'Thermo Fisher Scientific',
#  'MACYSxxx182': "Macy's",
#  'JABILxxx068': 'Jabil',
#  'KRAFHExx134': 'Kraft Heinz',
#  'DUKEENxx158': 'Duke Energy',
#  'TESLAxxx980': 'Tesla',
#  'PBFENxxx513': 'Pbf Energy',
#  'QUALCOMM152': 'Qualcomm',
#  'NGLENPAx702': 'Ngl Energy Partners',
#  'CBREGRxx685': 'Cbre Group',
#  'BAKEHUxx415': 'Baker Hughes',
#  'SYNNEXxx183': 'Synnex',
#  'DOLLTRxx682': 'Dollar Tree',
#  'CUMMINSx443': 'Cummins',
#  'UNITNAFO129': 'United Natural Foods',
#  'MICRTExx565': 'Micron Technology',
#  'AMGENxxx162': 'Amgen',
#  'PENSAUGR340': 'Penske Automotive Group',
#  'VISAxxxx511': 'Visa',
#  'BROADCOM173': 'Broadcom',
#  'NUCORxxx498': 'Nucor',
#  'GILESCxx693': 'Gilead Sciences',
#  'SOUTAIxx295': 'Southwest Airlines',
#  'HALLIBUR906': 'Halliburton',
#  'CENTURYL560': 'Centurylink',
#  'INTEPAxx575': 'International Paper',
#  'ELILIxxx343': 'Eli Lilly',
#  'AFLACxxx121': 'Aflac',
#  'LENNARxx620': 'Lennar',
#  'OCCIPExx699': 'Occidental Petroleum',
#  'UNIOPAxx779': 'Union Pacific',
#  'RITEAIxx241': 'Rite Aid',
#  'PNCFISEGR648': 'Pnc Financial Services Group',
#  'DUPONTxx182': 'Dupont',
#  'SOUTHERN503': 'Southern',
#  'AUTONATI235': 'Autonation',
#  'DXCTExxx637': 'Dxc Technology',
#  'MCDONALD242': "Mcdonald's",
#  'MARRINxx590': 'Marriott International',
#  'MANPOWER094': 'Manpowergroup',
#  'BANKNEYO761': 'Bank Of New York Mellon',
#  'HARTFISE315': 'Hartford Financial Services Group',
#  'DANAHERx389': 'Danaher',
#  'WHIRLPOO846': 'Whirlpool',
#  'AECOMxxx682': 'Aecom',
#  'NETFLIXx904': 'Netflix',
#  'KOHLSxxx915': "Kohl's",
#  'LEARxxxx790': 'Lear',
#  'ALTRGRxx423': 'Altria Group',
#  'PERFFOGR817': '\nperformance Food Group',
#  'AVNETxxx364': 'Avnet',
#  'SYNCFIxx398': 'Synchrony Financial',
#  'GENUPAxx727': 'Genuine Parts',
#  'NEXTENxx660': 'Nextera Energy',
#  'CARMAXxx949': 'Carmax',
#  'TENEHExx164': 'Tenet Healthcare',
#  'KIMBERLY310': 'Kimberly-clark',
#  'EMERELxx346': 'Emerson Electric',
#  'WESTROCK858': 'Westrock',
#  'CDWxxxxx235': 'Cdw',
#  'JONELALA410': 'Jones Lang Lasalle',
#  'SHERWINW471': 'Sherwin-williams',
#  'FLUORxxx791': 'Fluor',
#  'PAYPHOxx475': 'Paypal Holdings',
#  'DRHOxxxx211': 'D.r. Horton',
#  'HOLLYFRO546': 'Hollyfrontier',
#  'TENNECOx254': 'Tenneco',
#  'EOGRExxx167': 'Eog Resources',
#  'BECTDIxx232': 'Becton Dickinson',
#  'LINCNAxx178': 'Lincoln National',
#  'PGExxxxx450': 'Pg&e',
#  'SALESFOR094': 'Salesforce.com',
#  'MASTERCA642': 'Mastercard',
#  'GENEMIxx839': 'General Mills',
#  'MOLIHExx546': 'Molina Healthcare',
#  'COGNTESO255': 'Cognizant Technology Solutions',
#  'MARSMCxx362': 'Marsh & Mclennan',
#  'XPOLOxxx993': 'Xpo Logistics',
#  'DOMIENxx683': 'Dominion Energy',
#  'WESTDIxx461': 'Western Digital',
#  'GAPxxxxx451': 'Gap',
#  'ARAMARKx294': 'Aramark',
#  'PRINFIxx168': 'Principal Financial',
#  'ROSSSTxx676': '\nross Stores',
#  'COLGATEP766': 'Colgate-palmolive',
#  'AMERELPO590': 'American Electric Power',
#  'NORDSTRO750': 'Nordstrom',
#  'JACOENGR364': 'Jacobs Engineering Group',
#  'WASTMAxx773': 'Waste Management',
#  'CHROWOxx734': 'C.h. Robinson Worldwide',
#  'PPGINxxx314': 'Ppg Industries',
#  'BOOKHOxx678': 'Booking Holdings',
#  'OMNIGRxx468': 'Omnicom Group',
#  'LOEWSxxx918': 'Loews',
#  'ECOLABxx700': 'Ecolab',
#  'STRYKERx366': 'Stryker',
#  'ESTELAxx432': 'Estee Lauder',
#  'GOODTIRU034': 'Goodyear Tire & Rubber',
#  'TRUIFIxx669': 'Truist Financial',
#  'APPLMAxx525': 'Applied Materials',
#  'BLACKROC219': 'Blackrock',
#  'STANBLDE691': 'Stanley Black & Decker',
#  'FREEPORT761': 'Freeport-mcmoran',
#  'TEXAINxx753': 'Texas Instruments',
#  'BIOGENxx261': 'Biogen',
#  'PARKERHA207': 'Parker-hannifin',
#  'REINGRAM444': 'Reinsurance Group Of America',
#  'HOWMAExx447': 'Howmet Aerospace',
#  'AUTODAPR614': 'Automatic Data Processing',
#  'UBERTExx506': 'Uber Technologies',
#  'ILLITOWO884': 'Illinois Tool Works',
#  'DAVITAxx087': 'Davita',
#  'DISCFISE514': 'Discover Financial Services',
#  'LANDOLxx145': "Land O'lakes",
#  'VFxxxxxx942': 'Vf',
#  'CORTEVAx377': 'Corteva',
#  'LASVESAx735': 'Las Vegas Sands',
#  'TEXTRONx217': 'Textron',
#  'KELLOGGx580': 'Kellogg',
#  'GUARLIIN357': 'Guardian Life Ins. Co. Of America',
#  'QURARExx088': 'Qurate Retail',
#  'COREHOxx976': 'Core-mark Holding',
#  'COMMHESY601': 'Community Health Systems',
#  'KINDMOxx494': 'Kinder Morgan',
#  'BJSWHCLx494': "Bj's Wholesale Club",
#  'STATSTxx674': 'State Street',
#  'AMERFIxx721': 'Ameriprise Financial',
#  'GLOBPAxx836': 'Global Partners',
#  'UNITSTST132': 'United States Steel',
#  'LBRxxxxx267': 'L Brands',
#  'MGMREINx666': 'Mgm Resorts International',
#  'L3HATExx404': 'L3harris Technologies',
#  'DISHNExx197': 'Dish Network',
#  'LITHMOxx739': 'Lithia Motors',
#  'DTEENxxx197': 'Dte Energy',
#  'AMERFAIN326': 'American Family Insurance Group',
#  'FARMINEX368': 'Farmers Insurance Exchange',
#  'CONSEDxx594': 'Consolidated Edison',
#  'LKQxxxxx394': 'Lkq',
#  'SEMPENxx885': 'Sempra Energy',
#  'EDISINxx239': 'Edison International',
#  'CENTENxx838': 'Centerpoint Energy',
#  'QUANSExx411': 'Quanta Services',
#  'MURPUSxx711': 'Murphy Usa',
#  'EXPEGRxx202': 'Expedia Group',
#  'GROU1AUx852': 'Group 1 Automotive',
#  'BEDBABEx515': 'Bed Bath & Beyond',
#  'UNUMGRxx933': 'Unum Group',
#  'CSXxxxxx405': 'Csx',
#  'AUTOZONE270': 'Autozone',
#  'PACILIxx359': 'Pacific Life',
#  'VISTENxx872': 'Vistra Energy',
#  'CHARSCxx244': 'Charles Schwab',
#  'CROWHOxx279': 'Crown Holdings',
#  'ALLYFIxx821': 'Ally Financial',
#  'LABOCOAM556': 'Laboratory Corp. Of America',
#  'LIVENAEN788': 'Live Nation Entertainment',
#  'XCELENxx039': 'Xcel Energy',
#  'CORNINGx516': 'Corning',
#  'WWGRxxxx705': 'W.w. Grainger',
#  'BALLxxxx574': 'Ball',
#  'FOXxxxxx381': 'Fox',
#  'UNIVHESE839': 'Universal Health Services',
#  'BAXTINxx485': 'Baxter International',
#  'NORFSOxx900': 'Norfolk Southern',
#  'NAVIINxx277': 'Navistar International',
#  'ADOBExxx351': 'Adobe',
#  'JCPExxxx831': 'J.c. Penney',
#  'DISCOVER192': 'Discovery',
#  'KEURDRPE169': 'Keurig Dr Pepper',
#  'LEIDHOxx223': 'Leidos Holdings',
#  'IQVIHOxx067': 'Iqvia Holdings',
#  'RELISTAL308': 'Reliance Steel & Aluminum',
#  'NVIDIAxx157': 'Nvidia',
#  'ENTERGYx282': 'Entergy',
#  'FIRSTENE692': 'Firstenergy',
#  'EBAYxxxx139': 'Ebay',
#  'BOSTSCxx325': 'Boston Scientific',
#  'OFFIDExx691': 'Office Depot',
#  'MOLSCOBE736': 'Molson Coors Beverage',
#  'STEEDYxx906': 'Steel Dynamics',
#  'MUTUOMIN520': 'Mutual Of Omaha Insurance',
#  'SONIAUxx715': 'Sonic Automotive',
#  'ALCOAxxx794': 'Alcoa',
#  'FIDENAIN720': 'Fidelity National Information Services',
#  'HENRSCxx112': 'Henry Schein',
#  'REPUSExx804': 'Republic Services',
#  'LIBEMExx921': 'Liberty Media',
#  'PETEKISO207': "Peter Kiewit Sons'",
#  'INTEGRxx711': 'Interpublic Group',
#  'PULTEGRO728': 'Pultegroup',
#  'AESxxxxx619': 'Aes',
#  'FISERVxx841': 'Fiserv',
#  'BORGWARN277': 'Borgwarner',
#  'ONEOKxxx463': 'Oneok',
#  'OREIAUxx092': "O'reilly Automotive",
#  'ASSURANT315': 'Assurant',
#  'NEWEBRxx252': 'Newell Brands',
#  'PUBLSEEN045': 'Public Service Enterprise Group',
#  'NEWSCOxx487': 'News Corp.',
#  'CALPINEx376': 'Calpine',
#  'AUTOINxx373': 'Auto-owners Insurance',
#  'MOHAINxx189': 'Mohawk Industries',
#  'PVHxxxxx465': 'Pvh',
#  'CAMPSOxx728': 'Campbell Soup',
#  'NRGENxxx582': 'Nrg Energy',
#  'FIFTTHBA688': 'Fifth Third Bancorp',
#  'HERTGLHO572': 'Hertz Global Holdings',
#  'ALTIUSxx630': 'Altice Usa',
#  'NEWMONTx759': 'Newmont',
#  'CHENENxx661': 'Cheniere Energy',
#  'ADVAAUPA962': 'Advance Auto Parts',
#  'LAMRExxx368': 'Lam Research',
#  'OWENMIxx075': 'Owens & Minor',
#  'EQUIHOxx531': 'Equitable Holdings',
#  'CONABRxx920': 'Conagra Brands',
#  'MARKELxx385': 'Markel',
#  'JONEFIED454': 'Jones Financial (edward Jones)',
#  'HORMFOxx865': 'Hormel Foods',
#  'HILTWOHO437': 'Hilton Worldwide Holdings',
#  'UNIVSOxx680': 'Univar Solutions',
#  'UNITRExx311': 'United Rentals',
#  'PIONNARE760': 'Pioneer Natural Resources',
#  'DELEUSHO886': 'Delek Us Holdings',
#  'EASTCHxx569': 'Eastman Chemical',
#  'EMCOGRxx244': 'Emcor Group',
#  'AVISBUGR158': 'Avis Budget Group',
#  'JBHUTRSE455': 'J.b. Hunt Transport Services',
#  'XEROHOxx332': 'Xerox Holdings',
#  'WAYFAIRx827': 'Wayfair',
#  'KKRxxxxx407': 'Kkr',
#  'AGCOxxxx562': 'Agco',
#  'ALLEGHAN981': 'Alleghany',
#  'ICAHENxx398': 'Icahn Enterprises',
#  'VOYAFIxx100': 'Voya Financial',
#  'RYDESYxx688': 'Ryder System',
#  'AIRPRCHx641': 'Air Products & Chemicals',
#  'MOSAICxx705': 'Mosaic',
#  'HUNTININ338': 'Huntington Ingalls Industries',
#  'BERRGLGR473': 'Berry Global Group',
#  'ANIXINxx688': 'Anixter International',
#  'ALASAIGR183': 'Alaska Air Group',
#  'YUMCHHOx355': 'Yum China Holdings',
#  'DICKSPGO317': "Dick's Sporting Goods",
#  'CAESENxx805': 'Caesars Entertainment',
#  'GENWFIxx578': 'Genworth Financial',
#  'TARGRExx070': 'Targa Resources',
#  'COTYxxxx174': 'Coty',
#  'DANAxxxx867': 'Dana',
#  'THRIFIFO667': 'Thrivent Financial For Lutherans',
#  'AUTOLIVx121': 'Autoliv',
#  'SPARTANN830': 'Spartannash',
#  'EVERENxx666': 'Eversource Energy',
#  'DARDRExx638': 'Darden Restaurants',
#  'CHESENxx151': 'Chesapeake Energy',
#  'NATIOIVA522': 'National Oilwell Varco',
#  'FIDENAFI403': 'Fidelity National Financial',
#  'ERIEINGR177': 'Erie Insurance Group',
#  'OSHKOSHx955': 'Oshkosh',
#  'CASEGEST939': "Casey's General Stores",
#  'WESCINxx583': 'Wesco International',
#  'TRACSUxx409': 'Tractor Supply',
#  'COMMHOxx762': 'Commscope Holding',
#  'HUNTSMAN564': 'Huntsman',
#  'AMERFIGR298': 'American Financial Group',
#  'MASCOxxx633': 'Masco',
#  'SANMINAx279': 'Sanmina',
#  'AMPHENOL920': 'Amphenol',
#  'WILLIAMS801': 'Williams',
#  'WESTAIBR447': 'Westinghouse Air Brake',
#  'EXPEINWA315': 'Expeditors Intl. Of Washington',
#  'ANDERSON407': 'Andersons',
#  'WESTCHxx440': 'Westlake Chemical',
#  'CONSBRxx113': 'Constellation Brands',
#  'FRONCOxx892': 'Frontier Communications',
#  'JETBAIxx779': 'Jetblue Airways',
#  'CITIFIGR676': 'Citizens Financial Group',
#  'RAYMJAFI117': 'Raymond James Financial',
#  'FOOTLOxx421': 'Foot Locker',
#  'HERSHEYx122': 'Hershey',
#  'ZIMMBIHO382': 'Zimmer Biomet Holdings',
#  'CINCFIxx857': 'Cincinnati Financial',
#  'WESTSOFI131': 'Western & Southern Financial Group',
#  'WRBExxxx166': 'W.r. Berkley',
#  'MOTOSOxx381': 'Motorola Solutions',
#  'THORINxx448': 'Thor Industries',
#  'REGEPHxx712': 'Regeneron Pharmaceuticals',
#  'SPIRAEHO420': 'Spirit Aerosystems Holdings',
#  'JMSMxxxx824': 'J.m. Smucker',
#  'PPLxxxxx735': 'Ppl',
#  'INSIENxx470': 'Insight Enterprises',
#  'QUESDIxx662': 'Quest Diagnostics',
#  'KEYCORPx134': 'Keycorp',
#  'VERITIVx193': 'Veritiv',
#  'DCPMIxxx872': 'Dcp Midstream',
#  'AMERTOxx483': 'American Tower',
#  'GRAYELxx004': 'Graybar Electric',
#  'WECENGRx443': 'Wec Energy Group',
#  'NVRxxxxx158': 'Nvr',
#  'ULTABExx026': 'Ulta Beauty',
#  'DEVOENxx444': 'Devon Energy',
#  'BLACGRxx510': 'Blackstone Group',
#  'DEANFOxx646': 'Dean Foods',
#  'FORTIVEx576': 'Fortive',
#  'UGIxxxxx572': 'Ugi',
#  'BURLSTxx743': 'Burlington Stores',
#  'BUILFIxx834': 'Builders Firstsource',
#  'TOLLBRxx937': 'Toll Brothers',
#  'OLDREINx900': 'Old Republic International',
#  'ASBUAUGR854': 'Asbury Automotive Group',
#  'ARTHJGAx759': 'Arthur J. Gallagher',
#  'MASTECxx687': 'Mastec',
#  'OWENCOxx393': 'Owens Corning',
#  'MAGEHExx449': 'Magellan Health',
#  'DOVERxxx758': 'Dover',
#  'BEACROSU793': 'Beacon Roofing Supply',
#  'AVERDExx154': 'Avery Dennison',
#  'HANESBRA239': 'Hanesbrands',
#  'PACKCOAM629': 'Packaging Corp. Of America',
#  'MTBAxxxx233': 'M&t Bank',
#  'NCRxxxxx629': 'Ncr',
#  'NORTTRxx825': 'Northern Trust',
#  'CINTASxx119': 'Cintas',
#  'POLARISx032': 'Polaris',
#  'CMSENxxx681': 'Cms Energy',
#  'SEABOARD465': 'Seaboard',
#  'INTUITxx218': 'Intuit',
#  'REGIFIxx401': 'Regions Financial',
#  'FMGLxxxx440': 'Fm Global',
#  'ADVAMIDE481': 'Advanced Micro Devices',
#  'OVINTIVx687': 'Ovintiv',
#  'BOOZALHA698': 'Booz Allen Hamilton Holding',
#  'SPGLxxxx636': 'S&p Global',
#  'ROCKAUxx967': 'Rockwell Automation',
#  'OIGLxxxx464': 'O-i Glass',
#  'WYNNRExx285': 'Wynn Resorts',
#  'SECUFIGR260': 'Securian Financial Group',
#  'ALLIDASY604': 'Alliance Data Systems',
#  'WEYERHAE160': 'Weyerhaeuser',
#  'BRIGFIxx382': 'Brighthouse Financial',
#  'INTEEXxx990': 'Intercontinental Exchange',
#  'AMERAXMA740': 'American Axle & Manufacturing',
#  'HESSxxxx141': 'Hess',
#  'ABMINxxx366': 'Abm Industries',
#  'ACTIBLxx917': 'Activision Blizzard',
#  'GAMESTOP658': 'Gamestop',
#  'APACHExx757': 'Apache',
#  'SCIEAPIN998': 'Science Applications International',
#  'AKSTHOxx345': 'Ak Steel Holding',
#  'DILLARDS204': "Dillard's",
#  'RALPLAxx424': 'Ralph Lauren',
#  'CELANESE648': 'Celanese',
#  'RRDOSOxx621': 'R.r. Donnelley & Sons',
#  'ZOETISxx012': 'Zoetis',
#  'ASCEREGR107': 'Ascena Retail Group',
#  'CLOROXxx717': 'Clorox',
#  'INGREDIO783': 'Ingredion',
#  'FIRSAMFI362': 'First American Financial',
#  'GRAPPAHO842': 'Graphic Packaging Holding',
#  'NETAPPxx775': 'Netapp',
#  'HDSUHOxx691': 'Hd Supply Holdings',
#  'TRAVAMxx252': 'Travelcenters Of America',
#  'OLINxxxx278': 'Olin',
#  'ROBEHAIN753': 'Robert Half International',
#  'ENLIMIxx355': 'Enlink Midstream',
#  'AVANTORx325': 'Avantor',
#  'TAPESTRY476': 'Tapestry',
#  'TDAMHOxx536': 'Td Ameritrade Holding',
#  'ANALDExx233': 'Analog Devices',
#  'AMERENxx134': 'Ameren',
#  'WILLIAMS562': 'Williams-sonoma',
#  'REALHOxx074': 'Realogy Holdings',
#  'COMMMExx168': 'Commercial Metals',
#  'RUSHENxx569': 'Rush Enterprises',
#  'FRANRExx227': 'Franklin Resources',
#  'FORTBRHO124': 'Fortune Brands Home & Security',
#  'LEVISTxx681': 'Levi Strauss',
#  'CROWCAIN761': 'Crown Castle International',
#  'SIMOPRGR174': 'Simon Property Group',
#  'CERNERxx983': 'Cerner',
#  'POSTHOxx326': 'Post Holdings',
#  'HUNTBAxx693': 'Huntington Bancshares',
#  'KBRxxxxx009': 'Kbr',
#  'SPROFAMA411': 'Sprouts Farmers Market',
#  'LPLFIHOx378': 'Lpl Financial Holdings',
#  'TROPRxxx175': 'T. Rowe Price',
#  'YUMBRxxx674': 'Yum Brands',
#  'CHIPMEGR665': 'Chipotle Mexican Grill',
#  'PATTERSO505': 'Patterson',
#  'RPMINxxx047': 'Rpm International',
#  'EQUINIXx140': 'Equinix',
#  'NAVIENTx777': 'Navient',
#  'CHEMOURS542': 'Chemours',
#  'ONSExxxx428': 'On Semiconductor',
#  'TRANGRxx325': 'Transdigm Group',
#  'HOSTHORE594': 'Host Hotels & Resorts',
#  'SELEMEHO818': 'Select Medical Holdings',
#  'PARPAHOx073': 'Par Pacific Holdings',
#  'SONOPRxx617': 'Sonoco Products',
#  'ROPETExx377': 'Roper Technologies',
#  'HARLEYDA893': 'Harley-davidson',
#  'JEFFFIGR288': 'Jefferies Financial Group',
#  'KELLSExx073': 'Kelly Services',
#  'MICRTExx752': 'Microchip Technology',
#  'MCCORMIC360': 'Mccormick',
#  'MDUREGRx361': 'Mdu Resources Group',
#  'FASTENAL286': 'Fastenal',
#  'BIGLOxxx872': 'Big Lots',
#  'PENNNAGA904': 'Penn National Gaming',
#  'WESTUNxx158': 'Western Union',
#  'UNDEARxx737': 'Under Armour',
#  'XYLEMxxx162': 'Xylem',
#  'SKECUSxx219': 'Skechers U.s.a.',
#  'DOMTARxx888': 'Domtar',
#  'NISOURCE204': 'Nisource',
#  'MARAOIxx920': 'Marathon Oil',
#  'NATIGEHO795': 'National General Holdings',
#  'TELEDASY557': 'Telephone & Data Systems',
#  'AGILTExx785': 'Agilent Technologies',
#  'AMETEKxx502': 'Ametek',
#  'EVERGYxx938': 'Evergy',
#  'INTEFLFR082': 'International Flavors & Fragrances',
#  'ADTxxxxx680': 'Adt',
#  'WELLTOWE706': 'Welltower',
#  'WINDHOxx783': 'Windstream Holdings',
#  'MICHAELS171': 'Michaels',
#  'KEMPERxx390': 'Kemper',
#  'HYATHOxx736': 'Hyatt Hotels',
#  'ALEXPHxx270': 'Alexion Pharmaceuticals',
#  'RESITExx778': 'Resideo Technologies',
#  'CACIINxx589': 'Caci International',
#  'ELECARxx439': 'Electronic Arts',
#  'VULCMAxx375': 'Vulcan Materials',
#  'TREEFOxx652': 'Treehouse Foods',
#  'GLOBPAxx353': 'Global Payments',
#  'HANOINGR481': 'Hanover Insurance Group',
#  'CAMPWOHO516': 'Camping World Holdings',
#  'CORNBUBR509': 'Cornerstone Building Brands',
#  'YRCWOxxx730': 'Yrc Worldwide',
#  'CMEGRxxx741': 'Cme Group',
#  'CHEWYxxx758': 'Chewy',
#  'KNIGTRHO823': 'Knight-swift Transportation Holdings',
#  'MOODYSxx044': "Moody's",
#  'COCACOxx191': 'Coca-cola Consolidated',
#  'CARLISLE272': 'Carlisle',
#  'SEALAIxx406': 'Sealed Air',
#  'AMARPRME801': 'A-mark Precious Metals',
#  'WATSCOxx532': 'Watsco',
#  'TAYLMOHO199': 'Taylor Morrison Home',
#  'IACINTER366': 'Iac/interactivecorp',
#  'LEGGPLxx672': 'Leggett & Platt',
#  'ONEMHOxx556': 'Onemain Holdings',
#  'SCHNNAxx138': 'Schneider National',
#  'MARTMAMA649': 'Martin Marietta Materials',
#  'NORTONLI496': 'Nortonlifelock',
#  'HASBROxx181': 'Hasbro',
#  'SQUARExx158': 'Square',
#  'TEREXxxx071': 'Terex',
#  'SYNEHExx860': 'Syneos Health',
#  'FMCxxxxx706': 'Fmc',
#  'BOISCAxx231': 'Boise Cascade',
#  'SSCTEHOx975': 'Ss&c Technologies Holdings',
#  'CONTRExx509': 'Continental Resources',
#  'PEABENxx299': 'Peabody Energy',
#  'ENCOHExx552': 'Encompass Health',
#  'GREIFxxx752': 'Greif',
#  'CONCRExx796': 'Concho Resources',
#  'HUBBELLx182': 'Hubbell',
#  'CFINHOxx236': 'Cf Industries Holdings',
#  'KLAxxxxx130': 'Kla',
#  'GENEHExx711': 'Genesis Healthcare',
#  'BRUNSWIC130': 'Brunswick',
#  'KBHOxxxx746': 'Kb Home',
#  'GLOBLIxx284': 'Globe Life',
#  'MATTELxx721': 'Mattel',
#  'RYERHOxx186': 'Ryerson Holding',
#  'SILGHOxx364': 'Silgan Holdings',
#  'ZEBRTExx579': 'Zebra Technologies',
#  'INTUSUxx864': 'Intuitive Surgical',
#  'WARNMUGR460': 'Warner Music Group',
#  'CONDUENT721': 'Conduent',
#  'TUTOPExx499': 'Tutor Perini',
#  'JUNINExx548': 'Juniper Networks',
#  'NOBLENxx327': 'Noble Energy',
#  'VERTHOxx655': 'Vertiv Holdings',
#  'TIFFANYx467': 'Tiffany',
#  'EQTxxxxx076': 'Eqt',
#  'UFPINxxx250': 'Ufp Industries',
#  'DIEBNIxx871': 'Diebold Nixdorf',
#  'ANTERExx925': 'Antero Resources',
#  'MERITORx700': 'Meritor',
#  'BROAFISO811': 'Broadridge Financial Solutions',
#  'CHURDWxx126': 'Church & Dwight',
#  'MARRVAWO613': 'Marriott Vacations Worldwide',
#  'EDWALIxx600': 'Edwards Lifesciences',
#  'COLFAXxx100': 'Colfax',
#  'INSPERIT315': 'Insperity',
#  'AMEREAOU774': 'American Eagle Outfitters',
#  'KEYSTExx333': 'Keysight Technologies',
#  'JELDHOxx940': 'Jeld-wen Holding',
#  'IRONMOxx585': 'Iron Mountain',
#  'NASDAQxx054': 'Nasdaq',
#  'GARTNERx209': 'Gartner',
#  'SINCBRGR250': 'Sinclair Broadcast Group',
#  'INGLMAxx689': 'Ingles Markets',
#  'MONSBExx477': 'Monster Beverage',
#  'MURPOIxx568': 'Murphy Oil',
#  'VERTPHxx409': 'Vertex Pharmaceuticals',
#  'FIRSREBA907': 'First Republic Bank',
#  'BLOOBRxx495': "Bloomin' Brands",
#  'SPECBRHO183': 'Spectrum Brands Holdings',
#  'QUADGRAP421': 'Quad/graphics',
#  'FLOWFOxx972': 'Flowers Foods',
#  'CUNAMUGR219': 'Cuna Mutual Group',
#  'ALLETExx206': 'Allegheny Technologies',
#  'OLDDOFRLI268': 'Old Dominion Freight Line',
#  'LANDSYxx345': 'Landstar System',
#  'AMERNAIN245': 'American National Insurance',
#  'SNAPONxx485': 'Snap-on',
#  'BROOSELI169': 'Brookdale Senior Living',
#  'AMKOTExx636': 'Amkor Technology',
#  'WYNDDExx711': 'Wyndham Destinations',
#  'PPDxxxxx588': 'Ppd',
#  'DENTSIxx321': 'Dentsply Sirona',
#  'CNOFIGRx429': 'Cno Financial Group',
#  'URBAOUxx185': 'Urban Outfitters',
#  'SABRExxx876': 'Sabre',
#  'MERCGExx086': 'Mercury General',
#  'DIAMENxx221': 'Diamondback Energy',
#  'PARSONSx122': 'Parsons',
#  'AARONSxx740': "Aaron's",
#  'FLOWSERV554': 'Flowserve',
#  'CARVANAx459': 'Carvana',
#  'ASGNxxxx764': 'Asgn',
#  'SALLBEHO343': 'Sally Beauty Holdings',
#  'SCANSOUR584': 'Scansource',
#  'VENTASxx234': 'Ventas',
#  'COUNFIxx705': 'Country Financial',
#  'TRINGRxx662': 'Trinet Group',
#  'SPIRAIxx132': 'Spirit Airlines',
#  'COMERICA792': 'Comerica',
#  'LENNINxx946': 'Lennox International',
#  'TIMKENxx305': 'Timken',
#  'PAYCHEXx863': 'Paychex',
#  'AMERCOxx222': 'Amerco',
#  'WORTINxx588': 'Worthington Industries',
#  'LAMBWEHO806': 'Lamb Weston Holdings',
#  'LAUREDxx273': 'Laureate Education',
#  'PENNMULI297': 'Penn Mutual Life Insurance',
#  'IHEARTME237': 'Iheartmedia',
#  'BRINKSxx667': "Brink's",
#  'SENTINGR255': 'Sentry Insurance Group',
#  'ACUIBRxx378': 'Acuity Brands',
#  'HUBGRxxx136': 'Hub Group',
#  'MERIHOxx154': 'Meritage Homes',
#  'MRCGLxxx697': 'Mrc Global',
#  'ALLIENxx174': 'Alliant Energy',
#  'WORKDAYx862': 'Workday',
#  'BMCSTHOx927': 'Bmc Stock Holdings',
#  'ABERFIxx934': 'Abercrombie & Fitch',
#  'DOMIPIxx746': "Domino's Pizza",
#  'LYFTxxxx563': 'Lyft',
#  'MEREDITH910': 'Meredith',
#  'AMERWAWO245': 'American Water Works',
#  'ALBEMARL131': 'Albemarle',
#  'CIENAxxx623': 'Ciena',
#  'BARNNOxx311': 'Barnes & Noble',
#  'WEISMAxx516': 'Weis Markets',
#  'ILLUMINA551': 'Illumina',
#  'SVBFIGRx687': 'Svb Financial Group',
#  'CARTERSx332': "Carter's",
#  'STIFFIxx654': 'Stifel Financial',
#  'MEDNAXxx428': 'Mednax',
#  'EQUIFAXx106': 'Equifax',
#  'KARAUSEx373': 'Kar Auction Services',
#  'ASHLGLHO808': 'Ashland Global Holdings',
#  'MEDIMUOH106': 'Medical Mutual Of Ohio',
#  'SPRARExx268': 'Sprague Resources',
#  'SUPEMICO841': 'Super Micro Computer',
#  'DESIBRxx529': 'Designer Brands',
#  'PITNBOxx606': 'Pitney Bowes',
#  'APPLINTE772': 'Applied Industrial Technologies',
#  'PINNWECA782': 'Pinnacle West Capital',
#  'AMEREQIN666': 'American Equity Investment Life Holding',
#  'SERVICEN522': 'Servicenow',
#  'TWITTERx646': 'Twitter',
#  'CALUSPPR873': 'Calumet Specialty Products Partners',
#  'STEELCAS182': 'Steelcase',
#  'SANDFAxx544': 'Sanderson Farms',
#  'WABCHOxx068': 'Wabco Holdings',
#  'CLEAHAxx569': 'Clean Harbors',
#  'PUGEENxx985': 'Puget Energy',
#  'SCIEGAxx819': 'Scientific Games',
#  'GRANCOxx053': 'Granite Construction',
#  'CARLGRxx590': 'Carlyle Group',
#  'SKYWSOxx867': 'Skyworks Solutions',
#  'ALERISxx318': 'Aleris',
#  'TRIPMAxx854': 'Triple-s Management',
#  'HEXIONxx459': 'Hexion',
#  'HOLOGICx840': 'Hologic',
#  'TRIUGRxx171': 'Triumph Group',
#  'DARLINxx556': 'Darling Ingredients',
#  'MSCINDIx176': 'Msc Industrial Direct',
#  'REDHAxxx590': 'Red Hat',
#  'SYNOPSYS915': 'Synopsys',
#  'POLYONEx566': 'Polyone',
#  'DYCOINxx684': 'Dycom Industries',
#  'CABOTxxx670': 'Cabot',
#  'PROLOGIS478': 'Prologis',
#  'BOYDGAxx759': 'Boyd Gaming',
#  'LSCCOxxx171': 'Lsc Communications',
#  'BROWNFOR444': 'Brown-forman',
#  'STERICYC172': 'Stericycle',
#  'CITGRxxx087': 'Cit Group',
#  'MDCHOxxx674': 'Mdc Holdings',
#  'HYSTMAHA314': 'Hyster-yale Materials Handling',
#  'CRANExxx829': 'Crane',
#  'CINEHOxx116': 'Cinemark Holdings',
#  'AUTODESK086': 'Autodesk',
#  'TRIMBLEx220': 'Trimble',
#  'GARRMOxx218': 'Garrett Motion',
#  'ZIONBAxx250': 'Zions Bancorp.',
#  'REGABExx103': 'Regal Beloit',
#  'SERVCOIN427': 'Service Corp. International',
#  'VARIMESY534': 'Varian Medical Systems',
#  'PRICESMA598': 'Pricesmart',
#  'BRININxx608': 'Brinker International',
#  'DIGIRETR725': 'Digital Realty Trust',
#  'POOLCOxx290': 'Pool Corp',
#  'CRESEQPA695': 'Crestwood Equity Partners',
#  'INFORxxx421': 'Infor',
#  'PLEXUSxx130': 'Plexus',
#  'TELETExx874': 'Teledyne Technologies',
#  'GIIIAPGR701': 'G-iii Apparel Group',
#  'SCOTMIxx423': 'Scotts Miracle-gro',
#  'APOLGLMA794': 'Apollo Global Management',
#  'ETRAFIxx409': 'E*trade Financial',
#  'TOROxxxx263': 'Toro',
#  'SOUTGAHO647': 'Southwest Gas Holdings',
#  'GMSxxxxx324': 'Gms',
#  'COOPHOxx710': 'Cooper-standard Holdings',
#  'ACADHExx309': 'Acadia Healthcare',
#  'TETRTExx197': 'Tetra Tech',
#  'PRIMSExx355': 'Primoris Services',
#  'TEMPSEIN588': 'Tempur Sealy International',
#  'HRBLxxxx176': 'H&r Block',
#  'QORVOxxx517': 'Qorvo',
#  'TRIPOGRx725': 'Tri Pointe Group',
#  'CRACBAOL719': 'Cracker Barrel Old Country Store',
#  'ELANANHE646': 'Elanco Animal Health',
#  'PRAHESCx052': 'Pra Health Sciences',
#  'FIRSSOxx476': 'First Solar',
#  'AMCNExxx793': 'Amc Networks',
#  'XILINXxx751': 'Xilinx',
#  'GREEPLxx852': 'Green Plains',
#  'COLUSPxx555': 'Columbia Sportswear',
#  'NEXSMEGR349': 'Nexstar Media Group',
#  'SOUTENxx662': 'Southwestern Energy',
#  'GREENBRI683': 'Greenbrier',
#  'PRESIDIO142': 'Presidio',
#  'CITRSYxx890': 'Citrix Systems',
#  'METTINxx858': 'Mettler-toledo International',
#  'TRININxx655': 'Trinity Industries',
#  'MUTUAMLI459': 'Mutual Of America Life Insurance',
#  'LINCELHO797': 'Lincoln Electric Holdings',
#  'TAILBRxx414': 'Tailored Brands',
#  'AOSMxxxx532': 'A.o. Smith',
#  'ARCBESTx905': 'Arcbest',
#  'GODADDYx211': 'Godaddy',
#  'SKYWESTx850': 'Skywest',
#  'BOSTPRxx651': 'Boston Properties',
#  'ENABMIPA580': 'Enable Midstream Partners',
#  'MIDDLEBY563': 'Middleby',
#  'NOWxxxxx556': 'Now',
#  'UNISYSxx433': 'Unisys',
#  'VISTEONx425': 'Visteon',
#  'GRAHHOxx758': 'Graham Holdings',
#  'RESOFOPR249': 'Resolute Forest Products',
#  'CALERESx835': 'Caleres',
#  'AGNCINxx881': 'Agnc Investment',
#  'HILLHOxx636': 'Hill-rom Holdings',
#  'MOOGxxxx667': 'Moog',
#  'LEGGMAxx610': 'Legg Mason',
#  'ATMOENxx560': 'Atmos Energy',
#  'WOODWARD404': 'Woodward',
#  'PALOALNE315': 'Palo Alto Networks',
#  'HBFUxxxx166': 'H.b. Fuller',
#  'AKAMTExx933': 'Akamai Technologies',
#  'AVAYHOxx671': 'Avaya Holdings',
#  'MAXIMUSx059': 'Maximus',
#  'PERKINEL756': 'Perkinelmer',
#  'HAWAELIN508': 'Hawaiian Electric Industries',
#  'KANSCISO072': 'Kansas City Southern',
#  'APTARGRO492': 'Aptargroup',
#  'PUBLSTxx268': 'Public Storage',
#  'SELEINGR482': 'Selective Insurance Group',
#  'ITTxxxxx238': 'Itt',
#  'DONALDSO726': 'Donaldson',
#  'PARKHORE207': 'Park Hotels & Resorts',
#  'KIRBYxxx249': 'Kirby',
#  'HAWAHOxx865': 'Hawaiian Holdings',
#  'POPULARx810': 'Popular',
#  'RANGRExx437': 'Range Resources',
#  'PCCOxxxx270': 'Pc Connection',
#  'AMICMUIN631': 'Amica Mutual Insurance',
#  'ENERSYSx598': 'Enersys',
#  'HELMPAxx666': 'Helmerich & Payne',
#  'NLVFIxxx591': 'Nlv Financial',
#  'VALMINxx563': 'Valmont Industries',
#  'PAExxxxx782': 'Pae',
#  'TEXAROxx661': 'Texas Roadhouse',
#  'COOPTIRU539': 'Cooper Tire & Rubber',
#  'EUROWOxx560': 'Euronet Worldwide',
#  'ZILLGRxx150': 'Zillow Group',
#  'ATLAAIWO697': 'Atlas Air Worldwide Holdings',
#  'ENERHOxx998': 'Energizer Holdings',
#  'MAGEMIPA763': 'Magellan Midstream Partners',
#  'HAINCEGR859': 'Hain Celestial Group',
#  'UNIVCOxx548': 'Univision Communications',
#  'EQUIRExx288': 'Equity Residential',
#  'ALLITRHO383': 'Allison Transmission Holdings',
#  'COLOCAxx593': 'Colony Capital',
#  'TTMTExxx544': 'Ttm Technologies',
#  'CLEACHOU231': 'Clear Channel Outdoor Holdings',
#  'GUESSxxx741': 'Guess',
#  'RENTACEN303': 'Rent-a-center',
#  'TAKEINSO816': 'Take-two Interactive Software',
#  'VISHINxx433': 'Vishay Intertechnology',
#  'TRANSUNI638': 'Transunion',
#  'COOPERxx314': 'Cooper',
#  'FLEETExx944': 'Fleetcor Technologies',
#  'RHxxxxxx280': 'Rh',
#  'RENEENGR738': 'Renewable Energy Group',
#  'BLUEHOxx753': 'Bluelinx Holdings',
#  'CALIRExx216': 'California Resources',
#  'TOPBUILD998': 'Topbuild',
#  'CHARRILA036': 'Charles River Laboratories International',
#  'COMFSYUS150': 'Comfort Systems Usa',
#  'VERIANxx768': 'Verisk Analytics',
#  'RESMEDxx273': 'Resmed',
#  'TELEFLEX318': 'Teleflex',
#  'NEWJEREx265': 'New Jersey Resources',
#  'NEWREINx240': 'New Residential Investment',
#  'INTEBRGR648': 'Interactive Brokers Group',
#  'ZAYOGRHO933': 'Zayo Group Holdings',
#  'HERMMIxx122': 'Herman Miller',
#  'GROCOUHO008': 'Grocery Outlet Holding',
#  'JCREGRxx438': 'J.crew Group',
#  'CENTCOxx559': 'Century Communities',
#  'ELDORExx370': 'Eldorado Resorts',
#  'CATALENT913': 'Catalent',
#  'ITRONxxx499': 'Itron',
#  'MIHOxxxx399': 'M/i Homes',
#  'CBOEGLMA030': 'Cboe Global Markets',
#  'IDEXxxxx645': 'Idex',
#  'BELDENxx744': 'Belden',
#  'CURTISSW680': 'Curtiss-wright',
#  'CHEEFAxx950': 'Cheesecake Factory',
#  'GENEENxx742': 'Genesis Energy',
#  'GEOGRxxx118': 'Geo Group',
#  'PATTENxx915': 'Patterson-uti Energy',
#  'WERNENxx622': 'Werner Enterprises',
#  'INGERAxx306': 'Ingersoll Rand',
#  'VERSOxxx811': 'Verso',
#  'MUELINxx411': 'Mueller Industries',
#  'NUSKENxx195': 'Nu Skin Enterprises',
#  'REVLONxx180': 'Revlon',
#  'ARISNExx418': 'Arista Networks',
#  'IDEXLAxx470': 'Idexx Laboratories',
#  'ALIGTExx692': 'Align Technology',
#  'WATERSxx881': 'Waters',
#  'SYNOFIxx863': 'Synovus Financial',
#  'BRIGHOxx416': 'Brightview Holdings',
#  'REVGRxxx440': 'Rev Group',
#  'BROWBRxx066': 'Brown & Brown',
#  'VALVOLIN034': 'Valvoline',
#  'KNIGCOxx699': 'Knights Of Columbus',
#  'CENTGAPE428': 'Central Garden & Pet',
#  'CARPTExx356': 'Carpenter Technology',
#  'SLMCOxxx384': 'Slm Corp',
#  'KENNAMET079': 'Kennametal',
#  'LCIINxxx639': 'Lci Industries',
#  'TRUEBLUE465': 'Trueblue',
#  'CIMAENxx504': 'Cimarex Energy',
#  'SPLUNKxx683': 'Splunk',
#  'SITELASU933': 'Siteone Landscape Supply',
#  'HEXCELxx505': 'Hexcel',
#  'FTICOxxx694': 'Fti Consulting',
#  'PARTCIHO311': 'Party City Holdco',
#  'OHIONAMU458': 'Ohio National Mutual',
#  'PATRINxx489': 'Patrick Industries',
#  'CADEDESY127': 'Cadence Design Systems',
#  'CDKGLxxx186': 'Cdk Global',
#  'AVALCOxx509': 'Avalonbay Communities',
#  'WABANAxx122': 'Wabash National',
#  'SERVPRTR360': 'Service Properties Trust',
#  'MAXIINPR247': 'Maxim Integrated Products',
#  'PEOPUNFI621': "People's United Financial",
#  'BIORLAxx501': 'Bio-rad Laboratories',
#  'OPTICAHE210': 'Option Care Health',
#  'LOUISIAN553': 'Louisiana-pacific',
#  'TEGNAxxx258': 'Tegna',
#  'TERADYNE258': 'Teradyne',
#  'ARCHRExx281': 'Arch Resources',
#  'EPAMSYxx707': 'Epam Systems',
#  'WPXENxxx458': 'Wpx Energy',
#  'CONTENxx297': 'Contura Energy',
#  'ENSIGRxx615': 'Ensign Group',
#  'FIRSHONA116': 'First Horizon National',
#  'WOLVWOWI143': 'Wolverine World Wide',
#  'VAILRExx556': 'Vail Resorts',
#  'BENCELxx216': 'Benchmark Electronics',
#  'HNIxxxxx409': 'Hni',
#  'F5NExxxx834': 'F5 Networks',
#  'AFFIMAGR149': 'Affiliated Managers Group',
#  'OGEENxxx594': 'Oge Energy',
#  'UNIVCOxx535': 'Universal Corp',
#  'BOKFIxxx426': 'Bok Financial',
#  'MANTINxx350': 'Mantech International',
#  'SUMMMAxx123': 'Summit Materials',
#  'AMNHESEx735': 'Amn Healthcare Services',
#  'GROUPONx956': 'Groupon',
#  'NEWMGRxx791': 'Newmark Group',
#  'FOSSGRxx621': 'Fossil Group',
#  'MODIMAxx385': 'Modine Manufacturing',
#  'GRIFCOxx657': 'Griffon Corporation',
#  'CYPRSExx656': 'Cypress Semiconductor',
#  'GENEHOxx617': 'Generac Holdings',
#  'MATSONxx054': 'Matson',
#  'GENESCOx991': 'Genesco',
#  'NORDSONx676': 'Nordson',
#  'NEWMARKE816': 'Newmarket',
#  'ECHOGLLO520': 'Echo Global Logistics',
#  'REXNORDx550': 'Rexnord',
#  'INCYTExx028': 'Incyte',
#  'FORTINET275': 'Fortinet',
#  'FOUNBUMA309': 'Foundation Building Materials',
#  'AARxxxxx498': 'Aar',
#  'CENTBRxx085': 'Centric Brands',
#  'EDGEPECA214': 'Edgewell Personal Care',
#  'FEDEMUIN357': 'Federated Mutual Insurance',
#  'SCHNSTIN134': 'Schnitzer Steel Industries',
#  'PORTGEEL326': 'Portland General Electric',
#  'GRAYTExx063': 'Gray Television',
#  'BGCPAxxx694': 'Bgc Partners',
#  'ECHOSTAR699': 'Echostar',
#  'BEAZHOUS014': 'Beazer Homes Usa',
#  'LHCGRxxx616': 'Lhc Group',
#  'SERVGLHO739': 'Servicemaster Global Holdings',
#  'BRUKERxx449': 'Bruker',
#  'OASIPExx514': 'Oasis Petroleum',
#  'CROSPAxx144': 'Crossamerica Partners',
#  'MYRGRxxx180': 'Myr Group',
#  'VIASATxx362': 'Viasat',
#  'GNCHOxxx733': 'Gnc Holdings',
#  'CABOOIGA121': 'Cabot Oil & Gas',
#  'BRIGHOFA169': 'Bright Horizons Family Solutions',
#  'VISTOUxx154': 'Vista Outdoor',
#  'HEICOxxx842': 'Heico',
#  'WYNDHORE414': 'Wyndham Hotels & Resorts',
#  'TCFFIxxx831': 'Tcf Financial',
#  'PRIMERIC556': 'Primerica',
#  'PROPHOxx699': 'Propetro Holding',
#  'OCEAINxx645': 'Oceaneering International',
#  'FLOODEHO263': 'Floor & Decor Holdings',
#  'COPARTxx937': 'Copart',
#  'CHICFAxx753': "Chico's Fas",
#  'BARNNOED244': 'Barnes & Noble Education',
#  'MAXATExx513': 'Maxar Technologies',
#  'EVERCORE650': 'Evercore',
#  'DECKOUxx833': 'Deckers Outdoor',
#  'EXPRESSx865': 'Express',
#  'HOVNENxx760': 'Hovnanian Enterprises',
#  'AIRLExxx239': 'Air Lease',
#  'ROLLINSx333': 'Rollins',
#  'SBACOxxx794': 'Sba Communications',
#  'DELUXExx614': 'Deluxe',
#  'MRCOGRxx920': 'Mr. Cooper Group',
#  'HERCHOxx601': 'Herc Holdings',
#  'HEALPRxx901': 'Healthpeak Properties',
#  'SPXFLxxx302': 'Spx Flow',
#  'LIBEOISE242': 'Liberty Oilfield Services'}
