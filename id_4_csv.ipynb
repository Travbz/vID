# %%
import pandas as pd
'''
This script converts a column of names into unique IDs
Rename the company/customer names column of this file(below) to match the column name in your file.
If your file is a csv, comment out the two lines below. Otherwise if its excel, just run the cell as is.

'''  

df = pd.read_excel('company.xlsx')
df.to_csv('company.csv', mode = 'w', index=False)

# %%
df = pd.read_csv('company.csv')

# %%
import pandas as pd

def generate_unique_id(company_name: str) -> str:
    """
    :params company_name 
    :return a unique 12 character ID based on the named from the input
    
    """
    unique_key = ''
    name_list = company_name.split(' ')
    new_name_list = []
    wordCount = len(name_list)

    for name in name_list:
        new_name_list.append(''.join(ch.upper() for ch in name if ch.isalnum()))
    
    if wordCount == 1:
            unique_key = new_name_list[0][0:8]
    else:
        for i in range(len(new_name_list)):
            if i == 0:
                unique_key += new_name_list[i][:4]
            else:
                unique_key += new_name_list[i][:2]

            if len(unique_key) > 7:
                break

    if len(unique_key) <= 8:
        unique_key += 'x' * (8 - len(unique_key))
    
    hash_number = str(hash(company_name.upper()))[1:4]
        
    unique_key += hash_number
    
    return unique_key

# %%
keys_list = []

"""Change the name of [" <Your name column's name here>  "] to match your columns name"""
for index, row in df.iterrows():
    keys_list.append(generate_unique_id(row[" <Your name column's name here>  "]))
    
df['unique_ID'] = keys_list

# %%
temp_cols=df.columns.tolist()
new_cols=temp_cols[-1:] + temp_cols[:-1]
df=df[new_cols]
df.head(20)
# Out:
#     Assets\n ($millions)    unique_ID Market Value \n As of 3/31/20 ($m)  \
# 0               236495.0  WALMARTx153                           321803.0
# 1               225248.0  AMAZONCO839                           970680.0
# 2               362597.0  EXXOMOxx340                           160696.0
# 3               338516.0  APPLExxx766                          1112641.0
# 4               222449.0  CVSHExxx536                            77376.0
# 5               817729.0  BERKHAxx385                           442897.0
# 6               173889.0  UNITGRxx004                           236555.0
# 7                59672.0  MCKESSON143                            21845.0
# 8               551669.0  ATTxxxxx822                           209388.0
# 9                39172.0  AMERISOU987                            18221.0
# 10              275909.0  ALPHABET934                           798905.0
# 11              258537.0  FORDMOxx831                            19151.0
# 12              155774.0  CIGNAxxx287                            65897.0
# 13               45400.0  COSTWHxx345                           125908.0
# 14              237428.0  CHEVRONx685                           136176.0
# 15               40963.0  CARDHExx150                            13988.0
# 16             2687379.0  JPMOCHxx217                           276750.0
# 17              228037.0  GENEMOxx125                            29695.0
# 18               67598.0  WALGBOAL765                            40528.0
# 19              291727.0  VERICOxx657                           222220.0
#
#     Rank           Metals Industry  Number Of Employees Change In \n Rank  \
# 0    1.0                   Walmart            2200000.0                 -
# 1    2.0                Amazon.com             798000.0               3.0
# 2    3.0               Exxon Mobil              74900.0              -1.0
# 3    4.0                     Apple             137000.0              -1.0
# 4    5.0                Cvs Health             290000.0               3.0
# 5    6.0        Berkshire Hathaway             391500.0              -2.0
# 6    7.0        Unitedhealth Group             325000.0              -1.0
# 7    8.0                  Mckesson              70000.0              -1.0
# 8    9.0                      At&t             247800.0                 -
# 9   10.0         Amerisourcebergen              21500.0                 -
# 10  11.0                  Alphabet             118899.0               4.0
# 11  12.0                Ford Motor             190000.0                 -
# 12  13.0                     Cigna              73700.0              52.0
# 13  14.0          Costco Wholesale             201500.0                 -
# 14  15.0                   Chevron              48200.0              -4.0
# 15  16.0           Cardinal Health              49500.0                 -
# 16  17.0            Jpmorgan Chase             256981.0               1.0
# 17  18.0            General Motors             164000.0              -5.0
# 18  19.0  Walgreens Boots Alliance             287000.0              -2.0
# 19  20.0    Verizon Communications             135000.0              -1.0
#
#                                Industry  \
# 0                        Retail Company
# 1                    E-commerce Company
# 2                           Corporation
# 3                    Technology Company
# 4                    Healthcare Company
# 5    Multinational Conglomerate Company
# 6                  Managed Care Company
# 7                   Health Care Company
# 8            Telecommunications Company
# 9                     Wholesale Company
# 10  Information Technology And Services
# 11                    Automaker Company
# 12                    Insurance Company
# 13                       Retail Company
# 14                 Oil Industry Company
# 15                  Health Care Company
# 16           Investment Banking Company
# 17                 Vehicle Manufacturer
# 18                       Retail Company
# 19           Telecommunications Company
#
#                                   Company Description  Revenues\n ($millions)  \
# 0   Walmart Inc. Is An American Multinational Reta...                523964.0
# 1   Amazon.com, Inc. Is An American Multinational ...                280522.0
# 2   Exxon Mobil Corp. engages in the exploration, ...                264938.0
# 3   Apple Inc. Is An American Multinational Techno...                260174.0
# 4   Cvs Health Is An American Healthcare Company T...                256776.0
# 5   Berkshire Hathaway Is An American Multinationa...                254616.0
# 6   Unitedhealth Group Incorporated Is An American...                242155.0
# 7   Mckesson Corporation Is An American Company Di...                214319.0
# 8   At&t Inc. Is An American Multinational Conglom...                181193.0
# 9   Amerisourcebergen Corporation Is An American D...                179589.0
# 10  Alphabet Inc. Is An American Multinational Con...                161857.0
# 11  Ford Motor Company, Commonly Known As Ford, Is...                155900.0
# 12  Cigna Is An American Worldwide Health Services...                153566.0
# 13  Costco Wholesale Corporation Is An American Mu...                152703.0
# 14  Chevron Corporation Is An American Multination...                146516.0
# 15  Cardinal Health, Inc. Is An American Multinati...                145534.0
# 16  Jpmorgan Chase & Co. Is An American Multinatio...                142422.0
# 17  General Motors Company Is An American Multinat...                137237.0
# 18  Walgreens Boots Alliance, Inc. Is An American ...                136866.0
# 19  Verizon Communications Inc. Is An American Mul...                131868.0
#
#    Revenue \n Change Profits\n ($millions) Profit \n Change
# 0              0.019               14881.0            1.231
# 1              0.205               11588.0             0.15
# 2             -0.087               14340.0           -0.312
# 3              -0.02               55256.0           -0.072
# 4               0.32                6634.0                -
# 5              0.027               81417.0           19.248
# 6               0.07               13839.0            0.155
# 7              0.029                  34.0           -0.493
# 8              0.061               13903.0           -0.282
# 9              0.069                 855.4           -0.484
# 10             0.183               34343.0            0.117
# 11            -0.028                  47.0           -0.987
# 12             2.157                5104.0            0.936
# 13             0.079                3659.0            0.168
# 14            -0.119                2924.0           -0.803
# 15             0.064                1363.0            4.324
# 16             0.084               36431.0            0.122
# 17            -0.067                6732.0            -0.16
# 18             0.041                3982.0           -0.207
# 19             0.008               19265.0            0.241

# %%
# check for duplicates
print(len(keys_list) == len(list(set(keys_list))))
# Out:
# True

# %%
"""Change the name of ['Metals Industry'] to match your columns name"""
keys = keys_list
values = df['Metals Industry'].to_list()
alphaZip= zip(keys,values)
myDict = dict(alphaZip)
myDict
# Out:
# {'WALMARTx153': 'Walmart',
#  'AMAZONCO839': 'Amazon.com',
#  'EXXOMOxx340': 'Exxon Mobil',
#  'APPLExxx766': 'Apple',
#  'CVSHExxx536': 'Cvs Health',
#  'BERKHAxx385': 'Berkshire Hathaway',
#  'UNITGRxx004': 'Unitedhealth Group',
#  'MCKESSON143': 'Mckesson',
#  'ATTxxxxx822': 'At&t',
#  'AMERISOU987': 'Amerisourcebergen',
#  'ALPHABET934': 'Alphabet',
#  'FORDMOxx831': 'Ford Motor',
#  'CIGNAxxx287': 'Cigna',
#  'COSTWHxx345': 'Costco Wholesale',
#  'CHEVRONx685': 'Chevron',
#  'CARDHExx150': 'Cardinal Health',
#  'JPMOCHxx217': 'Jpmorgan Chase',
#  'GENEMOxx125': 'General Motors',
#  'WALGBOAL765': 'Walgreens Boots Alliance',
#  'VERICOxx657': 'Verizon Communications',
#  'MICROSOF034': 'Microsoft',
#  'MARAPExx532': 'Marathon Petroleum',
#  'KROGERxx352': 'Kroger',
#  'FANNMAxx341': 'Fannie Mae',
#  'BANKOFAM281': 'Bank Of America',
#  'HOMEDExx449': 'Home Depot',
#  'PHIL66xx778': 'Phillips 66',
#  'COMCASTx724': 'Comcast',
#  'ANTHEMxx666': 'Anthem',
#  'WELLFAxx771': 'Wells Fargo',
#  'CITIGROU132': 'Citigroup',
#  'VALEENxx125': 'Valero Energy',
#  'GENEELxx344': 'General Electric',
#  'DELLTExx751': 'Dell Technologies',
#  'JOHNJOxx438': 'Johnson & Johnson',
#  'STATFAIN229': 'State Farm Insurance',
#  'TARGETxx244': 'Target',
#  'IBMxxxxx466': 'Ibm',
#  'RAYTTExx462': 'Raytheon Technologies',
#  'BOEINGxx728': 'Boeing',
#  'FREDMAxx858': 'Freddie Mac',
#  'CENTENEx741': 'Centene',
#  'UNITPASE321': 'United Parcel Service',
#  'LOWESxxx536': "Lowe's",
#  'INTELxxx434': 'Intel',
#  'FACEBOOK548': 'Facebook',
#  'FEDEXxxx913': 'Fedex',
#  'METLIFEx424': 'Metlife',
#  'WALTDIxx884': 'Walt Disney',
#  'PROCGAxx916': 'Procter & Gamble',
#  'PEPSICOx106': 'Pepsico',
#  'HUMANAxx904': 'Humana',
#  'PRUDFIxx339': 'Prudential Financial',
#  'ARCHDAMI198': 'Archer Daniels Midland',
#  'ALBERTSO468': 'Albertsons',
#  'SYSCOxxx753': 'Sysco',
#  'LOCKMAxx451': 'Lockheed Martin',
#  'HPxxxxxx512': 'Hp',
#  'ENERTRxx339': 'Energy Transfer',
#  'GOLDSAGR586': 'Goldman Sachs Group',
#  'MORGSTxx722': 'Morgan Stanley',
#  'CATERPIL847': 'Caterpillar',
#  'CISCSYxx571': 'Cisco Systems',
#  'PFIZERxx824': 'Pfizer',
#  'HCAHExxx823': 'Hca Healthcare',
#  'AIGxxxxx729': 'Aig',
#  'AMEREXxx487': 'American Express',
#  'DELTAILI834': 'Delta Air Lines',
#  'MERCKxxx229': 'Merck',
#  'AMERAIGR495': 'American Airlines Group',
#  'CHARCOxx826': 'Charter Communications',
#  'ALLSTATE587': 'Allstate',
#  'NEWYOLIIN137': 'New York Life Insurance',
#  'NATIONWI001': 'Nationwide',
#  'BESTBUxx209': 'Best Buy',
#  'UNITAIHO570': 'United Airlines Holdings',
#  'LIBEMUIN054': 'Liberty Mutual Insurance Group',
#  'DOWxxxxx721': 'Dow',
#  'TYSOFOxx404': 'Tyson Foods',
#  'TJXxxxxx525': 'Tjx',
#  'TIAAxxxx150': 'Tiaa',
#  'ORACLExx658': 'Oracle',
#  'GENEDYxx073': 'General Dynamics',
#  'DEERExxx548': 'Deere',
#  'NIKExxxx578': 'Nike',
#  'PROGRESS499': 'Progressive',
#  'PUBLSUMA374': 'Publix Super Markets',
#  'COCACOLA577': 'Coca-cola',
#  'MASSMULI930': 'Massachusetts Mutual Life Insurance',
#  'TECHDAxx663': 'Tech Data',
#  'WORLFUSE245': 'World Fuel Services',
#  'HONEINxx662': 'Honeywell International',
#  'CONOCOPH353': 'Conocophillips',
#  'USAAxxxx745': 'Usaa',
#  'EXELONxx634': 'Exelon',
#  'NORTGRxx263': 'Northrop Grumman',
#  'CAPIONFI420': 'Capital One Financial',
#  'PLAIGPHO175': 'Plains Gp Holdings',
#  'ABBVIExx876': 'Abbvie',
#  'STONGRxx324': 'Stonex Group',
#  'ENTEPRPA776': 'Enterprise Products Partners',
#  'NORTMUxx432': 'Northwestern Mutual',
#  '3Mxxxxxx791': '3m',
#  'ABBOLAxx242': 'Abbott Laboratories',
#  'CHSxxxxx374': 'Chs',
#  'TRAVELER894': 'Travelers',
#  'PHILMOIN761': 'Philip Morris International',
#  'RAYTHEON817': 'Raytheon',
#  'HEWLPAEN368': 'Hewlett Packard Enterprise',
#  'ARROELxx150': 'Arrow Electronics',
#  'VIACOMCB625': 'Viacomcbs',
#  'DOLLGExx569': 'Dollar General',
#  'USBAxxxx326': 'U.s. Bancorp',
#  'STARBUCK171': 'Starbucks',
#  'BRISSQxx577': 'Bristol-myers Squibb',
#  'USFOHOxx834': 'Us Foods Holding',
#  'MONDINxx430': 'Mondelez International',
#  'PACCARxx333': 'Paccar',
#  'THERFISC728': 'Thermo Fisher Scientific',
#  'MACYSxxx937': "Macy's",
#  'JABILxxx910': 'Jabil',
#  'KRAFHExx354': 'Kraft Heinz',
#  'DUKEENxx907': 'Duke Energy',
#  'TESLAxxx683': 'Tesla',
#  'PBFENxxx397': 'Pbf Energy',
#  'QUALCOMM761': 'Qualcomm',
#  'NGLENPAx303': 'Ngl Energy Partners',
#  'CBREGRxx642': 'Cbre Group',
#  'BAKEHUxx506': 'Baker Hughes',
#  'SYNNEXxx820': 'Synnex',
#  'DOLLTRxx122': 'Dollar Tree',
#  'CUMMINSx877': 'Cummins',
#  'UNITNAFO876': 'United Natural Foods',
#  'MICRTExx064': 'Micron Technology',
#  'AMGENxxx260': 'Amgen',
#  'PENSAUGR434': 'Penske Automotive Group',
#  'VISAxxxx217': 'Visa',
#  'BROADCOM413': 'Broadcom',
#  'NUCORxxx375': 'Nucor',
#  'GILESCxx010': 'Gilead Sciences',
#  'SOUTAIxx185': 'Southwest Airlines',
#  'HALLIBUR886': 'Halliburton',
#  'CENTURYL988': 'Centurylink',
#  'INTEPAxx041': 'International Paper',
#  'ELILIxxx860': 'Eli Lilly',
#  'AFLACxxx257': 'Aflac',
#  'LENNARxx015': 'Lennar',
#  'OCCIPExx341': 'Occidental Petroleum',
#  'UNIOPAxx050': 'Union Pacific',
#  'RITEAIxx705': 'Rite Aid',
#  'PNCFISEGR275': 'Pnc Financial Services Group',
#  'DUPONTxx569': 'Dupont',
#  'SOUTHERN646': 'Southern',
#  'AUTONATI968': 'Autonation',
#  'DXCTExxx139': 'Dxc Technology',
#  'MCDONALD284': "Mcdonald's",
#  'MARRINxx550': 'Marriott International',
#  'MANPOWER748': 'Manpowergroup',
#  'BANKOFNE313': 'Bank Of New York Mellon',
#  'HARTFISE827': 'Hartford Financial Services Group',
#  'DANAHERx765': 'Danaher',
#  'WHIRLPOO854': 'Whirlpool',
#  'AECOMxxx969': 'Aecom',
#  'NETFLIXx124': 'Netflix',
#  'KOHLSxxx580': "Kohl's",
#  'LEARxxxx276': 'Lear',
#  'ALTRGRxx927': 'Altria Group',
#  'PERFFOGR703': '\nperformance Food Group',
#  'AVNETxxx724': 'Avnet',
#  'SYNCFIxx117': 'Synchrony Financial',
#  'GENUPAxx591': 'Genuine Parts',
#  'NEXTENxx378': 'Nextera Energy',
#  'CARMAXxx467': 'Carmax',
#  'TENEHExx585': 'Tenet Healthcare',
#  'KIMBERLY429': 'Kimberly-clark',
#  'EMERELxx686': 'Emerson Electric',
#  'WESTROCK205': 'Westrock',
#  'CDWxxxxx831': 'Cdw',
#  'JONELALA468': 'Jones Lang Lasalle',
#  'SHERWINW831': 'Sherwin-williams',
#  'FLUORxxx688': 'Fluor',
#  'PAYPHOxx658': 'Paypal Holdings',
#  'DRHOxxxx880': 'D.r. Horton',
#  'HOLLYFRO475': 'Hollyfrontier',
#  'TENNECOx073': 'Tenneco',
#  'EOGRExxx459': 'Eog Resources',
#  'BECTDIxx611': 'Becton Dickinson',
#  'LINCNAxx259': 'Lincoln National',
#  'PGExxxxx721': 'Pg&e',
#  'SALESFOR878': 'Salesforce.com',
#  'MASTERCA654': 'Mastercard',
#  'GENEMIxx533': 'General Mills',
#  'MOLIHExx548': 'Molina Healthcare',
#  'COGNTESO689': 'Cognizant Technology Solutions',
#  'MARSMCxx835': 'Marsh & Mclennan',
#  'XPOLOxxx748': 'Xpo Logistics',
#  'DOMIENxx117': 'Dominion Energy',
#  'WESTDIxx245': 'Western Digital',
#  'GAPxxxxx682': 'Gap',
#  'ARAMARKx145': 'Aramark',
#  'PRINFIxx371': 'Principal Financial',
#  'ROSSSTxx674': '\nross Stores',
#  'COLGATEP080': 'Colgate-palmolive',
#  'AMERELPO236': 'American Electric Power',
#  'NORDSTRO532': 'Nordstrom',
#  'JACOENGR189': 'Jacobs Engineering Group',
#  'WASTMAxx545': 'Waste Management',
#  'CHROWOxx813': 'C.h. Robinson Worldwide',
#  'PPGINxxx483': 'Ppg Industries',
#  'BOOKHOxx738': 'Booking Holdings',
#  'OMNIGRxx270': 'Omnicom Group',
#  'LOEWSxxx473': 'Loews',
#  'ECOLABxx244': 'Ecolab',
#  'STRYKERx910': 'Stryker',
#  'ESTELAxx848': 'Estee Lauder',
#  'GOODTIRU559': 'Goodyear Tire & Rubber',
#  'TRUIFIxx664': 'Truist Financial',
#  'APPLMAxx534': 'Applied Materials',
#  'BLACKROC293': 'Blackrock',
#  'STANBLDE281': 'Stanley Black & Decker',
#  'FREEPORT656': 'Freeport-mcmoran',
#  'TEXAINxx011': 'Texas Instruments',
#  'BIOGENxx437': 'Biogen',
#  'PARKERHA590': 'Parker-hannifin',
#  'REINGROF725': 'Reinsurance Group Of America',
#  'HOWMAExx150': 'Howmet Aerospace',
#  'AUTODAPR788': 'Automatic Data Processing',
#  'UBERTExx434': 'Uber Technologies',
#  'ILLITOWO595': 'Illinois Tool Works',
#  'DAVITAxx553': 'Davita',
#  'DISCFISE499': 'Discover Financial Services',
#  'LANDOLxx127': "Land O'lakes",
#  'VFxxxxxx556': 'Vf',
#  'CORTEVAx886': 'Corteva',
#  'LASVESAx570': 'Las Vegas Sands',
#  'TEXTRONx024': 'Textron',
#  'KELLOGGx227': 'Kellogg',
#  'GUARLIIN563': 'Guardian Life Ins. Co. Of America',
#  'QURARExx630': 'Qurate Retail',
#  'COREHOxx549': 'Core-mark Holding',
#  'COMMHESY070': 'Community Health Systems',
#  'KINDMOxx135': 'Kinder Morgan',
#  'BJSWHCLx331': "Bj's Wholesale Club",
#  'STATSTxx113': 'State Street',
#  'AMERFIxx723': 'Ameriprise Financial',
#  'GLOBPAxx416': 'Global Partners',
#  'UNITSTST140': 'United States Steel',
#  'LBRxxxxx176': 'L Brands',
#  'MGMREINx090': 'Mgm Resorts International',
#  'L3HATExx916': 'L3harris Technologies',
#  'DISHNExx497': 'Dish Network',
#  'LITHMOxx243': 'Lithia Motors',
#  'DTEENxxx535': 'Dte Energy',
#  'AMERFAIN646': 'American Family Insurance Group',
#  'FARMINEX051': 'Farmers Insurance Exchange',
#  'CONSEDxx259': 'Consolidated Edison',
#  'LKQxxxxx698': 'Lkq',
#  'SEMPENxx930': 'Sempra Energy',
#  'EDISINxx299': 'Edison International',
#  'CENTENxx313': 'Centerpoint Energy',
#  'QUANSExx310': 'Quanta Services',
#  'MURPUSxx506': 'Murphy Usa',
#  'EXPEGRxx482': 'Expedia Group',
#  'GROU1AUx367': 'Group 1 Automotive',
#  'BEDBABEx364': 'Bed Bath & Beyond',
#  'UNUMGRxx397': 'Unum Group',
#  'CSXxxxxx129': 'Csx',
#  'AUTOZONE483': 'Autozone',
#  'PACILIxx493': 'Pacific Life',
#  'VISTENxx367': 'Vistra Energy',
#  'CHARSCxx780': 'Charles Schwab',
#  'CROWHOxx941': 'Crown Holdings',
#  'ALLYFIxx835': 'Ally Financial',
#  'LABOCOOF949': 'Laboratory Corp. Of America',
#  'LIVENAEN874': 'Live Nation Entertainment',
#  'XCELENxx249': 'Xcel Energy',
#  'CORNINGx910': 'Corning',
#  'WWGRxxxx101': 'W.w. Grainger',
#  'BALLxxxx383': 'Ball',
#  'FOXxxxxx502': 'Fox',
#  'UNIVHESE021': 'Universal Health Services',
#  'BAXTINxx873': 'Baxter International',
#  'NORFSOxx637': 'Norfolk Southern',
#  'NAVIINxx739': 'Navistar International',
#  'ADOBExxx684': 'Adobe',
#  'JCPExxxx358': 'J.c. Penney',
#  'DISCOVER721': 'Discovery',
#  'KEURDRPE962': 'Keurig Dr Pepper',
#  'LEIDHOxx262': 'Leidos Holdings',
#  'IQVIHOxx056': 'Iqvia Holdings',
#  'RELISTAL502': 'Reliance Steel & Aluminum',
#  'NVIDIAxx724': 'Nvidia',
#  'ENTERGYx103': 'Entergy',
#  'FIRSTENE158': 'Firstenergy',
#  'EBAYxxxx286': 'Ebay',
#  'BOSTSCxx695': 'Boston Scientific',
#  'OFFIDExx171': 'Office Depot',
#  'MOLSCOBE677': 'Molson Coors Beverage',
#  'STEEDYxx383': 'Steel Dynamics',
#  'MUTUOFOM907': 'Mutual Of Omaha Insurance',
#  'SONIAUxx044': 'Sonic Automotive',
#  'ALCOAxxx221': 'Alcoa',
#  'FIDENAIN541': 'Fidelity National Information Services',
#  'HENRSCxx536': 'Henry Schein',
#  'REPUSExx261': 'Republic Services',
#  'LIBEMExx522': 'Liberty Media',
#  'PETEKISO160': "Peter Kiewit Sons'",
#  'INTEGRxx613': 'Interpublic Group',
#  'PULTEGRO893': 'Pultegroup',
#  'AESxxxxx651': 'Aes',
#  'FISERVxx618': 'Fiserv',
#  'BORGWARN358': 'Borgwarner',
#  'ONEOKxxx688': 'Oneok',
#  'OREIAUxx845': "O'reilly Automotive",
#  'ASSURANT921': 'Assurant',
#  'NEWEBRxx643': 'Newell Brands',
#  'PUBLSEEN914': 'Public Service Enterprise Group',
#  'NEWSCOxx327': 'News Corp.',
#  'CALPINEx203': 'Calpine',
#  'AUTOINxx369': 'Auto-owners Insurance',
#  'MOHAINxx573': 'Mohawk Industries',
#  'PVHxxxxx709': 'Pvh',
#  'CAMPSOxx215': 'Campbell Soup',
#  'NRGENxxx237': 'Nrg Energy',
#  'FIFTTHBA911': 'Fifth Third Bancorp',
#  'HERTGLHO484': 'Hertz Global Holdings',
#  'ALTIUSxx293': 'Altice Usa',
#  'NEWMONTx670': 'Newmont',
#  'CHENENxx877': 'Cheniere Energy',
#  'ADVAAUPA409': 'Advance Auto Parts',
#  'LAMRExxx165': 'Lam Research',
#  'OWENMIxx773': 'Owens & Minor',
#  'EQUIHOxx643': 'Equitable Holdings',
#  'CONABRxx055': 'Conagra Brands',
#  'MARKELxx864': 'Markel',
#  'JONEFIED023': 'Jones Financial (edward Jones)',
#  'HORMFOxx240': 'Hormel Foods',
#  'HILTWOHO786': 'Hilton Worldwide Holdings',
#  'UNIVSOxx171': 'Univar Solutions',
#  'UNITRExx791': 'United Rentals',
#  'PIONNARE761': 'Pioneer Natural Resources',
#  'DELEUSHO360': 'Delek Us Holdings',
#  'EASTCHxx738': 'Eastman Chemical',
#  'EMCOGRxx341': 'Emcor Group',
#  'AVISBUGR920': 'Avis Budget Group',
#  'JBHUTRSE303': 'J.b. Hunt Transport Services',
#  'XEROHOxx523': 'Xerox Holdings',
#  'WAYFAIRx325': 'Wayfair',
#  'KKRxxxxx891': 'Kkr',
#  'AGCOxxxx326': 'Agco',
#  'ALLEGHAN678': 'Alleghany',
#  'ICAHENxx725': 'Icahn Enterprises',
#  'VOYAFIxx470': 'Voya Financial',
#  'RYDESYxx287': 'Ryder System',
#  'AIRPRCHx340': 'Air Products & Chemicals',
#  'MOSAICxx196': 'Mosaic',
#  'HUNTININ615': 'Huntington Ingalls Industries',
#  'BERRGLGR675': 'Berry Global Group',
#  'ANIXINxx929': 'Anixter International',
#  'ALASAIGR532': 'Alaska Air Group',
#  'YUMCHHOx142': 'Yum China Holdings',
#  'DICKSPGO189': "Dick's Sporting Goods",
#  'CAESENxx336': 'Caesars Entertainment',
#  'GENWFIxx218': 'Genworth Financial',
#  'TARGRExx932': 'Targa Resources',
#  'COTYxxxx824': 'Coty',
#  'DANAxxxx700': 'Dana',
#  'THRIFIFO684': 'Thrivent Financial For Lutherans',
#  'AUTOLIVx450': 'Autoliv',
#  'SPARTANN386': 'Spartannash',
#  'EVERENxx590': 'Eversource Energy',
#  'DARDRExx904': 'Darden Restaurants',
#  'CHESENxx861': 'Chesapeake Energy',
#  'NATIOIVA226': 'National Oilwell Varco',
#  'FIDENAFI377': 'Fidelity National Financial',
#  'ERIEINGR663': 'Erie Insurance Group',
#  'OSHKOSHx549': 'Oshkosh',
#  'CASEGEST140': "Casey's General Stores",
#  'WESCINxx221': 'Wesco International',
#  'TRACSUxx397': 'Tractor Supply',
#  'COMMHOxx139': 'Commscope Holding',
#  'HUNTSMAN353': 'Huntsman',
#  'AMERFIGR353': 'American Financial Group',
#  'MASCOxxx633': 'Masco',
#  'SANMINAx131': 'Sanmina',
#  'AMPHENOL231': 'Amphenol',
#  'WILLIAMS029': 'Williams',
#  'WESTAIBR175': 'Westinghouse Air Brake',
#  'EXPEINOF994': 'Expeditors Intl. Of Washington',
#  'ANDERSON247': 'Andersons',
#  'WESTCHxx442': 'Westlake Chemical',
#  'CONSBRxx470': 'Constellation Brands',
#  'FRONCOxx324': 'Frontier Communications',
#  'JETBAIxx669': 'Jetblue Airways',
#  'CITIFIGR824': 'Citizens Financial Group',
#  'RAYMJAFI927': 'Raymond James Financial',
#  'FOOTLOxx185': 'Foot Locker',
#  'HERSHEYx186': 'Hershey',
#  'ZIMMBIHO503': 'Zimmer Biomet Holdings',
#  'CINCFIxx615': 'Cincinnati Financial',
#  'WESTSOFI728': 'Western & Southern Financial Group',
#  'WRBExxxx332': 'W.r. Berkley',
#  'MOTOSOxx469': 'Motorola Solutions',
#  'THORINxx172': 'Thor Industries',
#  'REGEPHxx002': 'Regeneron Pharmaceuticals',
#  'SPIRAEHO082': 'Spirit Aerosystems Holdings',
#  'JMSMxxxx077': 'J.m. Smucker',
#  'PPLxxxxx604': 'Ppl',
#  'INSIENxx983': 'Insight Enterprises',
#  'QUESDIxx787': 'Quest Diagnostics',
#  'KEYCORPx386': 'Keycorp',
#  'VERITIVx530': 'Veritiv',
#  'DCPMIxxx203': 'Dcp Midstream',
#  'AMERTOxx642': 'American Tower',
#  'GRAYELxx776': 'Graybar Electric',
#  'WECENGRx356': 'Wec Energy Group',
#  'NVRxxxxx302': 'Nvr',
#  'ULTABExx220': 'Ulta Beauty',
#  'DEVOENxx176': 'Devon Energy',
#  'BLACGRxx817': 'Blackstone Group',
#  'DEANFOxx263': 'Dean Foods',
#  'FORTIVEx836': 'Fortive',
#  'UGIxxxxx614': 'Ugi',
#  'BURLSTxx278': 'Burlington Stores',
#  'BUILFIxx617': 'Builders Firstsource',
#  'TOLLBRxx108': 'Toll Brothers',
#  'OLDREINx870': 'Old Republic International',
#  'ASBUAUGR899': 'Asbury Automotive Group',
#  'ARTHJGAx448': 'Arthur J. Gallagher',
#  'MASTECxx004': 'Mastec',
#  'OWENCOxx940': 'Owens Corning',
#  'MAGEHExx311': 'Magellan Health',
#  'DOVERxxx808': 'Dover',
#  'BEACROSU367': 'Beacon Roofing Supply',
#  'AVERDExx289': 'Avery Dennison',
#  'HANESBRA206': 'Hanesbrands',
#  'PACKCOOF777': 'Packaging Corp. Of America',
#  'MTBAxxxx790': 'M&t Bank',
#  'NCRxxxxx404': 'Ncr',
#  'NORTTRxx729': 'Northern Trust',
#  'CINTASxx364': 'Cintas',
#  'POLARISx663': 'Polaris',
#  'CMSENxxx219': 'Cms Energy',
#  'SEABOARD262': 'Seaboard',
#  'INTUITxx154': 'Intuit',
#  'REGIFIxx672': 'Regions Financial',
#  'FMGLxxxx230': 'Fm Global',
#  'ADVAMIDE309': 'Advanced Micro Devices',
#  'OVINTIVx980': 'Ovintiv',
#  'BOOZALHA642': 'Booz Allen Hamilton Holding',
#  'SPGLxxxx395': 'S&p Global',
#  'ROCKAUxx720': 'Rockwell Automation',
#  'OIGLxxxx660': 'O-i Glass',
#  'WYNNRExx493': 'Wynn Resorts',
#  'SECUFIGR483': 'Securian Financial Group',
#  'ALLIDASY725': 'Alliance Data Systems',
#  'WEYERHAE377': 'Weyerhaeuser',
#  'BRIGFIxx336': 'Brighthouse Financial',
#  'INTEEXxx916': 'Intercontinental Exchange',
#  'AMERAXMA872': 'American Axle & Manufacturing',
#  'HESSxxxx078': 'Hess',
#  'ABMINxxx882': 'Abm Industries',
#  'ACTIBLxx102': 'Activision Blizzard',
#  'GAMESTOP927': 'Gamestop',
#  'APACHExx075': 'Apache',
#  'SCIEAPIN896': 'Science Applications International',
#  'AKSTHOxx784': 'Ak Steel Holding',
#  'DILLARDS899': "Dillard's",
#  'RALPLAxx730': 'Ralph Lauren',
#  'CELANESE270': 'Celanese',
#  'RRDOSOxx775': 'R.r. Donnelley & Sons',
#  'ZOETISxx287': 'Zoetis',
#  'ASCEREGR605': 'Ascena Retail Group',
#  'CLOROXxx287': 'Clorox',
#  'INGREDIO774': 'Ingredion',
#  'FIRSAMFI439': 'First American Financial',
#  'GRAPPAHO751': 'Graphic Packaging Holding',
#  'NETAPPxx890': 'Netapp',
#  'HDSUHOxx901': 'Hd Supply Holdings',
#  'TRAVOFAM925': 'Travelcenters Of America',
#  'OLINxxxx324': 'Olin',
#  'ROBEHAIN839': 'Robert Half International',
#  'ENLIMIxx333': 'Enlink Midstream',
#  'AVANTORx732': 'Avantor',
#  'TAPESTRY611': 'Tapestry',
#  'TDAMHOxx381': 'Td Ameritrade Holding',
#  'ANALDExx493': 'Analog Devices',
#  'AMERENxx950': 'Ameren',
#  'WILLIAMS637': 'Williams-sonoma',
#  'REALHOxx888': 'Realogy Holdings',
#  'COMMMExx896': 'Commercial Metals',
#  'RUSHENxx456': 'Rush Enterprises',
#  'FRANRExx397': 'Franklin Resources',
#  'FORTBRHO878': 'Fortune Brands Home & Security',
#  'LEVISTxx461': 'Levi Strauss',
#  'CROWCAIN136': 'Crown Castle International',
#  'SIMOPRGR056': 'Simon Property Group',
#  'CERNERxx890': 'Cerner',
#  'POSTHOxx560': 'Post Holdings',
#  'HUNTBAxx877': 'Huntington Bancshares',
#  'KBRxxxxx963': 'Kbr',
#  'SPROFAMA051': 'Sprouts Farmers Market',
#  'LPLFIHOx920': 'Lpl Financial Holdings',
#  'TROPRxxx279': 'T. Rowe Price',
#  'YUMBRxxx910': 'Yum Brands',
#  'CHIPMEGR013': 'Chipotle Mexican Grill',
#  'PATTERSO393': 'Patterson',
#  'RPMINxxx527': 'Rpm International',
#  'EQUINIXx567': 'Equinix',
#  'NAVIENTx356': 'Navient',
#  'CHEMOURS628': 'Chemours',
#  'ONSExxxx608': 'On Semiconductor',
#  'TRANGRxx276': 'Transdigm Group',
#  'HOSTHORE108': 'Host Hotels & Resorts',
#  'SELEMEHO603': 'Select Medical Holdings',
#  'PARPAHOx585': 'Par Pacific Holdings',
#  'SONOPRxx288': 'Sonoco Products',
#  'ROPETExx891': 'Roper Technologies',
#  'HARLEYDA767': 'Harley-davidson',
#  'JEFFFIGR162': 'Jefferies Financial Group',
#  'KELLSExx670': 'Kelly Services',
#  'MICRTExx464': 'Microchip Technology',
#  'MCCORMIC690': 'Mccormick',
#  'MDUREGRx916': 'Mdu Resources Group',
#  'FASTENAL024': 'Fastenal',
#  'BIGLOxxx974': 'Big Lots',
#  'PENNNAGA166': 'Penn National Gaming',
#  'WESTUNxx797': 'Western Union',
#  'UNDEARxx717': 'Under Armour',
#  'XYLEMxxx086': 'Xylem',
#  'SKECUSxx834': 'Skechers U.s.a.',
#  'DOMTARxx261': 'Domtar',
#  'NISOURCE593': 'Nisource',
#  'MARAOIxx763': 'Marathon Oil',
#  'NATIGEHO796': 'National General Holdings',
#  'TELEDASY482': 'Telephone & Data Systems',
#  'AGILTExx910': 'Agilent Technologies',
#  'AMETEKxx231': 'Ametek',
#  'EVERGYxx074': 'Evergy',
#  'INTEFLFR355': 'International Flavors & Fragrances',
#  'ADTxxxxx793': 'Adt',
#  'WELLTOWE089': 'Welltower',
#  'WINDHOxx143': 'Windstream Holdings',
#  'MICHAELS713': 'Michaels',
#  'KEMPERxx581': 'Kemper',
#  'HYATHOxx334': 'Hyatt Hotels',
#  'ALEXPHxx535': 'Alexion Pharmaceuticals',
#  'RESITExx171': 'Resideo Technologies',
#  'CACIINxx971': 'Caci International',
#  'ELECARxx784': 'Electronic Arts',
#  'VULCMAxx731': 'Vulcan Materials',
#  'TREEFOxx230': 'Treehouse Foods',
#  'GLOBPAxx957': 'Global Payments',
#  'HANOINGR328': 'Hanover Insurance Group',
#  'CAMPWOHO765': 'Camping World Holdings',
#  'CORNBUBR299': 'Cornerstone Building Brands',
#  'YRCWOxxx536': 'Yrc Worldwide',
#  'CMEGRxxx530': 'Cme Group',
#  'CHEWYxxx768': 'Chewy',
#  'KNIGTRHO185': 'Knight-swift Transportation Holdings',
#  'MOODYSxx728': "Moody's",
#  'COCACOxx595': 'Coca-cola Consolidated',
#  'CARLISLE723': 'Carlisle',
#  'SEALAIxx253': 'Sealed Air',
#  'AMARPRME135': 'A-mark Precious Metals',
#  'WATSCOxx851': 'Watsco',
#  'TAYLMOHO145': 'Taylor Morrison Home',
#  'IACINTER559': 'Iac/interactivecorp',
#  'LEGGPLxx812': 'Leggett & Platt',
#  'ONEMHOxx853': 'Onemain Holdings',
#  'SCHNNAxx550': 'Schneider National',
#  'MARTMAMA313': 'Martin Marietta Materials',
#  'NORTONLI480': 'Nortonlifelock',
#  'HASBROxx613': 'Hasbro',
#  'SQUARExx803': 'Square',
#  'TEREXxxx668': 'Terex',
#  'SYNEHExx102': 'Syneos Health',
#  'FMCxxxxx199': 'Fmc',
#  'BOISCAxx718': 'Boise Cascade',
#  'SSCTEHOx914': 'Ss&c Technologies Holdings',
#  'CONTRExx338': 'Continental Resources',
#  'PEABENxx726': 'Peabody Energy',
#  'ENCOHExx086': 'Encompass Health',
#  'GREIFxxx400': 'Greif',
#  'CONCRExx817': 'Concho Resources',
#  'HUBBELLx875': 'Hubbell',
#  'CFINHOxx886': 'Cf Industries Holdings',
#  'KLAxxxxx015': 'Kla',
#  'GENEHExx342': 'Genesis Healthcare',
#  'BRUNSWIC970': 'Brunswick',
#  'KBHOxxxx099': 'Kb Home',
#  'GLOBLIxx599': 'Globe Life',
#  'MATTELxx939': 'Mattel',
#  'RYERHOxx704': 'Ryerson Holding',
#  'SILGHOxx815': 'Silgan Holdings',
#  'ZEBRTExx100': 'Zebra Technologies',
#  'INTUSUxx266': 'Intuitive Surgical',
#  'WARNMUGR795': 'Warner Music Group',
#  'CONDUENT895': 'Conduent',
#  'TUTOPExx366': 'Tutor Perini',
#  'JUNINExx133': 'Juniper Networks',
#  'NOBLENxx354': 'Noble Energy',
#  'VERTHOxx014': 'Vertiv Holdings',
#  'TIFFANYx678': 'Tiffany',
#  'EQTxxxxx024': 'Eqt',
#  'UFPINxxx404': 'Ufp Industries',
#  'DIEBNIxx038': 'Diebold Nixdorf',
#  'ANTERExx753': 'Antero Resources',
#  'MERITORx278': 'Meritor',
#  'BROAFISO437': 'Broadridge Financial Solutions',
#  'CHURDWxx842': 'Church & Dwight',
#  'MARRVAWO569': 'Marriott Vacations Worldwide',
#  'EDWALIxx948': 'Edwards Lifesciences',
#  'COLFAXxx764': 'Colfax',
#  'INSPERIT813': 'Insperity',
#  'AMEREAOU876': 'American Eagle Outfitters',
#  'KEYSTExx271': 'Keysight Technologies',
#  'JELDHOxx230': 'Jeld-wen Holding',
#  'IRONMOxx078': 'Iron Mountain',
#  'NASDAQxx299': 'Nasdaq',
#  'GARTNERx785': 'Gartner',
#  'SINCBRGR987': 'Sinclair Broadcast Group',
#  'INGLMAxx865': 'Ingles Markets',
#  'MONSBExx817': 'Monster Beverage',
#  'MURPOIxx680': 'Murphy Oil',
#  'VERTPHxx842': 'Vertex Pharmaceuticals',
#  'FIRSREBA351': 'First Republic Bank',
#  'BLOOBRxx119': "Bloomin' Brands",
#  'SPECBRHO268': 'Spectrum Brands Holdings',
#  'QUADGRAP838': 'Quad/graphics',
#  'FLOWFOxx301': 'Flowers Foods',
#  'CUNAMUGR221': 'Cuna Mutual Group',
#  'ALLETExx047': 'Allegheny Technologies',
#  'OLDDOFRLI283': 'Old Dominion Freight Line',
#  'LANDSYxx688': 'Landstar System',
#  'AMERNAIN709': 'American National Insurance',
#  'SNAPONxx696': 'Snap-on',
#  'BROOSELI389': 'Brookdale Senior Living',
#  'AMKOTExx795': 'Amkor Technology',
#  'WYNDDExx344': 'Wyndham Destinations',
#  'PPDxxxxx783': 'Ppd',
#  'DENTSIxx538': 'Dentsply Sirona',
#  'CNOFIGRx702': 'Cno Financial Group',
#  'URBAOUxx659': 'Urban Outfitters',
#  'SABRExxx744': 'Sabre',
#  'MERCGExx391': 'Mercury General',
#  'DIAMENxx266': 'Diamondback Energy',
#  'PARSONSx344': 'Parsons',
#  'AARONSxx759': "Aaron's",
#  'FLOWSERV539': 'Flowserve',
#  'CARVANAx214': 'Carvana',
#  'ASGNxxxx198': 'Asgn',
#  'SALLBEHO700': 'Sally Beauty Holdings',
#  'SCANSOUR268': 'Scansource',
#  'VENTASxx579': 'Ventas',
#  'COUNFIxx697': 'Country Financial',
#  'TRINGRxx782': 'Trinet Group',
#  'SPIRAIxx858': 'Spirit Airlines',
#  'COMERICA054': 'Comerica',
#  'LENNINxx793': 'Lennox International',
#  'TIMKENxx512': 'Timken',
#  'PAYCHEXx421': 'Paychex',
#  'AMERCOxx915': 'Amerco',
#  'WORTINxx220': 'Worthington Industries',
#  'LAMBWEHO214': 'Lamb Weston Holdings',
#  'LAUREDxx644': 'Laureate Education',
#  'PENNMULI620': 'Penn Mutual Life Insurance',
#  'IHEARTME263': 'Iheartmedia',
#  'BRINKSxx308': "Brink's",
#  'SENTINGR565': 'Sentry Insurance Group',
#  'ACUIBRxx210': 'Acuity Brands',
#  'HUBGRxxx313': 'Hub Group',
#  'MERIHOxx771': 'Meritage Homes',
#  'MRCGLxxx699': 'Mrc Global',
#  'ALLIENxx208': 'Alliant Energy',
#  'WORKDAYx175': 'Workday',
#  'BMCSTHOx350': 'Bmc Stock Holdings',
#  'ABERFIxx133': 'Abercrombie & Fitch',
#  'DOMIPIxx580': "Domino's Pizza",
#  'LYFTxxxx653': 'Lyft',
#  'MEREDITH643': 'Meredith',
#  'AMERWAWO393': 'American Water Works',
#  'ALBEMARL769': 'Albemarle',
#  'CIENAxxx851': 'Ciena',
#  'BARNNOxx857': 'Barnes & Noble',
#  'WEISMAxx545': 'Weis Markets',
#  'ILLUMINA776': 'Illumina',
#  'SVBFIGRx761': 'Svb Financial Group',
#  'CARTERSx687': "Carter's",
#  'STIFFIxx102': 'Stifel Financial',
#  'MEDNAXxx362': 'Mednax',
#  'EQUIFAXx946': 'Equifax',
#  'KARAUSEx243': 'Kar Auction Services',
#  'ASHLGLHO671': 'Ashland Global Holdings',
#  'MEDIMUOF148': 'Medical Mutual Of Ohio',
#  'SPRARExx832': 'Sprague Resources',
#  'SUPEMICO860': 'Super Micro Computer',
#  'DESIBRxx589': 'Designer Brands',
#  'PITNBOxx067': 'Pitney Bowes',
#  'APPLINTE704': 'Applied Industrial Technologies',
#  'PINNWECA500': 'Pinnacle West Capital',
#  'AMEREQIN843': 'American Equity Investment Life Holding',
#  'SERVICEN422': 'Servicenow',
#  'TWITTERx314': 'Twitter',
#  'CALUSPPR826': 'Calumet Specialty Products Partners',
#  'STEELCAS389': 'Steelcase',
#  'SANDFAxx242': 'Sanderson Farms',
#  'WABCHOxx475': 'Wabco Holdings',
#  'CLEAHAxx470': 'Clean Harbors',
#  'PUGEENxx737': 'Puget Energy',
#  'SCIEGAxx740': 'Scientific Games',
#  'GRANCOxx224': 'Granite Construction',
#  'CARLGRxx588': 'Carlyle Group',
#  'SKYWSOxx581': 'Skyworks Solutions',
#  'ALERISxx269': 'Aleris',
#  'TRIPMAxx173': 'Triple-s Management',
#  'HEXIONxx310': 'Hexion',
#  'HOLOGICx292': 'Hologic',
#  'TRIUGRxx844': 'Triumph Group',
#  'DARLINxx935': 'Darling Ingredients',
#  'MSCINDIx755': 'Msc Industrial Direct',
#  'REDHAxxx521': 'Red Hat',
#  'SYNOPSYS267': 'Synopsys',
#  'POLYONEx478': 'Polyone',
#  'DYCOINxx743': 'Dycom Industries',
#  'CABOTxxx536': 'Cabot',
#  'PROLOGIS534': 'Prologis',
#  'BOYDGAxx099': 'Boyd Gaming',
#  'LSCCOxxx839': 'Lsc Communications',
#  'BROWNFOR540': 'Brown-forman',
#  'STERICYC870': 'Stericycle',
#  'CITGRxxx941': 'Cit Group',
#  'MDCHOxxx054': 'Mdc Holdings',
#  'HYSTMAHA481': 'Hyster-yale Materials Handling',
#  'CRANExxx008': 'Crane',
#  'CINEHOxx498': 'Cinemark Holdings',
#  'AUTODESK682': 'Autodesk',
#  'TRIMBLEx325': 'Trimble',
#  'GARRMOxx914': 'Garrett Motion',
#  'ZIONBAxx498': 'Zions Bancorp.',
#  'REGABExx934': 'Regal Beloit',
#  'SERVCOIN911': 'Service Corp. International',
#  'VARIMESY550': 'Varian Medical Systems',
#  'PRICESMA831': 'Pricesmart',
#  'BRININxx158': 'Brinker International',
#  'DIGIRETR298': 'Digital Realty Trust',
#  'POOLCOxx422': 'Pool Corp',
#  'CRESEQPA312': 'Crestwood Equity Partners',
#  'INFORxxx625': 'Infor',
#  'PLEXUSxx416': 'Plexus',
#  'TELETExx075': 'Teledyne Technologies',
#  'GIIIAPGR654': 'G-iii Apparel Group',
#  'SCOTMIxx402': 'Scotts Miracle-gro',
#  'APOLGLMA692': 'Apollo Global Management',
#  'ETRAFIxx277': 'E*trade Financial',
#  'TOROxxxx507': 'Toro',
#  'SOUTGAHO498': 'Southwest Gas Holdings',
#  'GMSxxxxx336': 'Gms',
#  'COOPHOxx865': 'Cooper-standard Holdings',
#  'ACADHExx777': 'Acadia Healthcare',
#  'TETRTExx718': 'Tetra Tech',
#  'PRIMSExx351': 'Primoris Services',
#  'TEMPSEIN433': 'Tempur Sealy International',
#  'HRBLxxxx969': 'H&r Block',
#  'QORVOxxx859': 'Qorvo',
#  'TRIPOGRx586': 'Tri Pointe Group',
#  'CRACBAOL387': 'Cracker Barrel Old Country Store',
#  'ELANANHE320': 'Elanco Animal Health',
#  'PRAHESCx887': 'Pra Health Sciences',
#  'FIRSSOxx165': 'First Solar',
#  'AMCNExxx046': 'Amc Networks',
#  'XILINXxx591': 'Xilinx',
#  'GREEPLxx609': 'Green Plains',
#  'COLUSPxx473': 'Columbia Sportswear',
#  'NEXSMEGR070': 'Nexstar Media Group',
#  'SOUTENxx391': 'Southwestern Energy',
#  'GREENBRI609': 'Greenbrier',
#  'PRESIDIO180': 'Presidio',
#  'CITRSYxx373': 'Citrix Systems',
#  'METTINxx958': 'Mettler-toledo International',
#  'TRININxx580': 'Trinity Industries',
#  'MUTUOFAM149': 'Mutual Of America Life Insurance',
#  'LINCELHO594': 'Lincoln Electric Holdings',
#  'TAILBRxx564': 'Tailored Brands',
#  'AOSMxxxx439': 'A.o. Smith',
#  'ARCBESTx772': 'Arcbest',
#  'GODADDYx186': 'Godaddy',
#  'SKYWESTx724': 'Skywest',
#  'BOSTPRxx243': 'Boston Properties',
#  'ENABMIPA822': 'Enable Midstream Partners',
#  'MIDDLEBY292': 'Middleby',
#  'NOWxxxxx218': 'Now',
#  'UNISYSxx158': 'Unisys',
#  'VISTEONx570': 'Visteon',
#  'GRAHHOxx770': 'Graham Holdings',
#  'RESOFOPR396': 'Resolute Forest Products',
#  'CALERESx106': 'Caleres',
#  'AGNCINxx099': 'Agnc Investment',
#  'HILLHOxx585': 'Hill-rom Holdings',
#  'MOOGxxxx820': 'Moog',
#  'LEGGMAxx681': 'Legg Mason',
#  'ATMOENxx253': 'Atmos Energy',
#  'WOODWARD186': 'Woodward',
#  'PALOALNE823': 'Palo Alto Networks',
#  'HBFUxxxx742': 'H.b. Fuller',
#  'AKAMTExx796': 'Akamai Technologies',
#  'AVAYHOxx305': 'Avaya Holdings',
#  'MAXIMUSx366': 'Maximus',
#  'PERKINEL678': 'Perkinelmer',
#  'HAWAELIN884': 'Hawaiian Electric Industries',
#  'KANSCISO989': 'Kansas City Southern',
#  'APTARGRO571': 'Aptargroup',
#  'PUBLSTxx382': 'Public Storage',
#  'SELEINGR797': 'Selective Insurance Group',
#  'ITTxxxxx910': 'Itt',
#  'DONALDSO686': 'Donaldson',
#  'PARKHORE684': 'Park Hotels & Resorts',
#  'KIRBYxxx693': 'Kirby',
#  'HAWAHOxx360': 'Hawaiian Holdings',
#  'POPULARx432': 'Popular',
#  'RANGRExx233': 'Range Resources',
#  'PCCOxxxx673': 'Pc Connection',
#  'AMICMUIN598': 'Amica Mutual Insurance',
#  'ENERSYSx333': 'Enersys',
#  'HELMPAxx800': 'Helmerich & Payne',
#  'NLVFIxxx209': 'Nlv Financial',
#  'VALMINxx233': 'Valmont Industries',
#  'PAExxxxx438': 'Pae',
#  'TEXAROxx346': 'Texas Roadhouse',
#  'COOPTIRU463': 'Cooper Tire & Rubber',
#  'EUROWOxx489': 'Euronet Worldwide',
#  'ZILLGRxx915': 'Zillow Group',
#  'ATLAAIWO387': 'Atlas Air Worldwide Holdings',
#  'ENERHOxx207': 'Energizer Holdings',
#  'MAGEMIPA514': 'Magellan Midstream Partners',
#  'HAINCEGR650': 'Hain Celestial Group',
#  'UNIVCOxx618': 'Univision Communications',
#  'EQUIRExx632': 'Equity Residential',
#  'ALLITRHO661': 'Allison Transmission Holdings',
#  'COLOCAxx346': 'Colony Capital',
#  'TTMTExxx779': 'Ttm Technologies',
#  'CLEACHOU130': 'Clear Channel Outdoor Holdings',
#  'GUESSxxx142': 'Guess',
#  'RENTACEN691': 'Rent-a-center',
#  'TAKEINSO799': 'Take-two Interactive Software',
#  'VISHINxx675': 'Vishay Intertechnology',
#  'TRANSUNI068': 'Transunion',
#  'COOPERxx160': 'Cooper',
#  'FLEETExx385': 'Fleetcor Technologies',
#  'RHxxxxxx640': 'Rh',
#  'RENEENGR568': 'Renewable Energy Group',
#  'BLUEHOxx578': 'Bluelinx Holdings',
#  'CALIRExx882': 'California Resources',
#  'TOPBUILD790': 'Topbuild',
#  'CHARRILA105': 'Charles River Laboratories International',
#  'COMFSYUS535': 'Comfort Systems Usa',
#  'VERIANxx666': 'Verisk Analytics',
#  'RESMEDxx882': 'Resmed',
#  'TELEFLEX568': 'Teleflex',
#  'NEWJEREx960': 'New Jersey Resources',
#  'NEWREINx342': 'New Residential Investment',
#  'INTEBRGR902': 'Interactive Brokers Group',
#  'ZAYOGRHO528': 'Zayo Group Holdings',
#  'HERMMIxx828': 'Herman Miller',
#  'GROCOUHO042': 'Grocery Outlet Holding',
#  'JCREGRxx225': 'J.crew Group',
#  'CENTCOxx161': 'Century Communities',
#  'ELDORExx605': 'Eldorado Resorts',
#  'CATALENT856': 'Catalent',
#  'ITRONxxx319': 'Itron',
#  'MIHOxxxx289': 'M/i Homes',
#  'CBOEGLMA706': 'Cboe Global Markets',
#  'IDEXxxxx366': 'Idex',
#  'BELDENxx485': 'Belden',
#  'CURTISSW305': 'Curtiss-wright',
#  'CHEEFAxx374': 'Cheesecake Factory',
#  'GENEENxx414': 'Genesis Energy',
#  'GEOGRxxx360': 'Geo Group',
#  'PATTENxx898': 'Patterson-uti Energy',
#  'WERNENxx338': 'Werner Enterprises',
#  'INGERAxx357': 'Ingersoll Rand',
#  'VERSOxxx883': 'Verso',
#  'MUELINxx103': 'Mueller Industries',
#  'NUSKENxx487': 'Nu Skin Enterprises',
#  'REVLONxx831': 'Revlon',
#  'ARISNExx004': 'Arista Networks',
#  'IDEXLAxx421': 'Idexx Laboratories',
#  'ALIGTExx751': 'Align Technology',
#  'WATERSxx749': 'Waters',
#  'SYNOFIxx179': 'Synovus Financial',
#  'BRIGHOxx650': 'Brightview Holdings',
#  'REVGRxxx536': 'Rev Group',
#  'BROWBRxx391': 'Brown & Brown',
#  'VALVOLIN476': 'Valvoline',
#  'KNIGOFCO755': 'Knights Of Columbus',
#  'CENTGAPE469': 'Central Garden & Pet',
#  'CARPTExx548': 'Carpenter Technology',
#  'SLMCOxxx491': 'Slm Corp',
#  'KENNAMET353': 'Kennametal',
#  'LCIINxxx269': 'Lci Industries',
#  'TRUEBLUE125': 'Trueblue',
#  'CIMAENxx451': 'Cimarex Energy',
#  'SPLUNKxx209': 'Splunk',
#  'SITELASU797': 'Siteone Landscape Supply',
#  'HEXCELxx885': 'Hexcel',
#  'FTICOxxx468': 'Fti Consulting',
#  'PARTCIHO648': 'Party City Holdco',
#  'OHIONAMU519': 'Ohio National Mutual',
#  'PATRINxx496': 'Patrick Industries',
#  'CADEDESY383': 'Cadence Design Systems',
#  'CDKGLxxx776': 'Cdk Global',
#  'AVALCOxx549': 'Avalonbay Communities',
#  'WABANAxx822': 'Wabash National',
#  'SERVPRTR531': 'Service Properties Trust',
#  'MAXIINPR465': 'Maxim Integrated Products',
#  'PEOPUNFI746': "People's United Financial",
#  'BIORLAxx231': 'Bio-rad Laboratories',
#  'OPTICAHE529': 'Option Care Health',
#  'LOUISIAN342': 'Louisiana-pacific',
#  'TEGNAxxx225': 'Tegna',
#  'TERADYNE432': 'Teradyne',
#  'ARCHRExx597': 'Arch Resources',
#  'EPAMSYxx352': 'Epam Systems',
#  'WPXENxxx309': 'Wpx Energy',
#  'CONTENxx711': 'Contura Energy',
#  'ENSIGRxx671': 'Ensign Group',
#  'FIRSHONA742': 'First Horizon National',
#  'WOLVWOWI279': 'Wolverine World Wide',
#  'VAILRExx334': 'Vail Resorts',
#  'BENCELxx713': 'Benchmark Electronics',
#  'HNIxxxxx270': 'Hni',
#  'F5NExxxx489': 'F5 Networks',
#  'AFFIMAGR047': 'Affiliated Managers Group',
#  'OGEENxxx135': 'Oge Energy',
#  'UNIVCOxx561': 'Universal Corp',
#  'BOKFIxxx659': 'Bok Financial',
#  'MANTINxx641': 'Mantech International',
#  'SUMMMAxx173': 'Summit Materials',
#  'AMNHESEx388': 'Amn Healthcare Services',
#  'GROUPONx306': 'Groupon',
#  'NEWMGRxx644': 'Newmark Group',
#  'FOSSGRxx519': 'Fossil Group',
#  'MODIMAxx993': 'Modine Manufacturing',
#  'GRIFCOxx093': 'Griffon Corporation',
#  'CYPRSExx186': 'Cypress Semiconductor',
#  'GENEHOxx175': 'Generac Holdings',
#  'MATSONxx753': 'Matson',
#  'GENESCOx187': 'Genesco',
#  'NORDSONx237': 'Nordson',
#  'NEWMARKE186': 'Newmarket',
#  'ECHOGLLO045': 'Echo Global Logistics',
#  'REXNORDx955': 'Rexnord',
#  'INCYTExx124': 'Incyte',
#  'FORTINET243': 'Fortinet',
#  'FOUNBUMA755': 'Foundation Building Materials',
#  'AARxxxxx873': 'Aar',
#  'CENTBRxx554': 'Centric Brands',
#  'EDGEPECA219': 'Edgewell Personal Care',
#  'FEDEMUIN659': 'Federated Mutual Insurance',
#  'SCHNSTIN152': 'Schnitzer Steel Industries',
#  'PORTGEEL742': 'Portland General Electric',
#  'GRAYTExx327': 'Gray Television',
#  'BGCPAxxx037': 'Bgc Partners',
#  'ECHOSTAR634': 'Echostar',
#  'BEAZHOUS655': 'Beazer Homes Usa',
#  'LHCGRxxx286': 'Lhc Group',
#  'SERVGLHO663': 'Servicemaster Global Holdings',
#  'BRUKERxx101': 'Bruker',
#  'OASIPExx980': 'Oasis Petroleum',
#  'CROSPAxx235': 'Crossamerica Partners',
#  'MYRGRxxx853': 'Myr Group',
#  'VIASATxx898': 'Viasat',
#  'GNCHOxxx583': 'Gnc Holdings',
#  'CABOOIGA022': 'Cabot Oil & Gas',
#  'BRIGHOFA497': 'Bright Horizons Family Solutions',
#  'VISTOUxx223': 'Vista Outdoor',
#  'HEICOxxx178': 'Heico',
#  'WYNDHORE670': 'Wyndham Hotels & Resorts',
#  'TCFFIxxx666': 'Tcf Financial',
#  'PRIMERIC316': 'Primerica',
#  'PROPHOxx909': 'Propetro Holding',
#  'OCEAINxx508': 'Oceaneering International',
#  'FLOODEHO794': 'Floor & Decor Holdings',
#  'COPARTxx511': 'Copart',
#  'CHICFAxx115': "Chico's Fas",
#  'BARNNOED488': 'Barnes & Noble Education',
#  'MAXATExx192': 'Maxar Technologies',
#  'EVERCORE320': 'Evercore',
#  'DECKOUxx212': 'Deckers Outdoor',
#  'EXPRESSx647': 'Express',
#  'HOVNENxx587': 'Hovnanian Enterprises',
#  'AIRLExxx537': 'Air Lease',
#  'ROLLINSx202': 'Rollins',
#  'SBACOxxx874': 'Sba Communications',
#  'DELUXExx836': 'Deluxe',
#  'MRCOGRxx359': 'Mr. Cooper Group',
#  'HERCHOxx763': 'Herc Holdings',
#  'HEALPRxx796': 'Healthpeak Properties',
#  'SPXFLxxx569': 'Spx Flow',
#  'LIBEOISE668': 'Liberty Oilfield Services'}
